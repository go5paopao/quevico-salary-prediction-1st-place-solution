# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # SVD
    svd = TruncatedSVD(n_components=2)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 507), (11259, 506))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3573

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "poisson_max_delta_step": 0.05,
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21034.9	valid_1's rmse: 21736.6
# [200]	training's rmse: 19822.7	valid_1's rmse: 21082.1
# [300]	training's rmse: 19187.2	valid_1's rmse: 20846.5
# [400]	training's rmse: 18707.2	valid_1's rmse: 20713.3
# [500]	training's rmse: 18312	valid_1's rmse: 20625.2
# [600]	training's rmse: 17929.9	valid_1's rmse: 20568.1
# [700]	training's rmse: 17602	valid_1's rmse: 20530.4
# [800]	training's rmse: 17273	valid_1's rmse: 20497.9
# [900]	training's rmse: 16960.8	valid_1's rmse: 20474.9
# [1000]	training's rmse: 16691.1	valid_1's rmse: 20456.4
# [1100]	training's rmse: 16414.9	valid_1's rmse: 20436
# [1200]	training's rmse: 16153.5	valid_1's rmse: 20422.9
# [1300]	training's rmse: 15927.6	valid_1's rmse: 20404.1
# [1400]	training's rmse: 15693.1	valid_1's rmse: 20401.7
# [1500]	training's rmse: 15423.5	valid_1's rmse: 20409.6
# Early stopping, best iteration is:
# [1402]	training's rmse: 15685.5	valid_1's rmse: 20401
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21010.2	valid_1's rmse: 21824.9
# [200]	training's rmse: 19832.8	valid_1's rmse: 21041.6
# [300]	training's rmse: 19194.2	valid_1's rmse: 20768.2
# [400]	training's rmse: 18727.2	valid_1's rmse: 20621
# [500]	training's rmse: 18318.6	valid_1's rmse: 20506.3
# [600]	training's rmse: 17968.6	valid_1's rmse: 20426.8
# [700]	training's rmse: 17641.2	valid_1's rmse: 20347.4
# [800]	training's rmse: 17322.1	valid_1's rmse: 20312.5
# [900]	training's rmse: 17040.4	valid_1's rmse: 20269.6
# [1000]	training's rmse: 16753.2	valid_1's rmse: 20252.3
# [1100]	training's rmse: 16478.3	valid_1's rmse: 20230.6
# [1200]	training's rmse: 16206.8	valid_1's rmse: 20182
# [1300]	training's rmse: 15961.8	valid_1's rmse: 20161.7
# [1400]	training's rmse: 15711	valid_1's rmse: 20157.3
# Early stopping, best iteration is:
# [1359]	training's rmse: 15800.3	valid_1's rmse: 20152.8
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21026.1	valid_1's rmse: 21615.9
# [200]	training's rmse: 19798.3	valid_1's rmse: 20978
# [300]	training's rmse: 19163.9	valid_1's rmse: 20803.4
# [400]	training's rmse: 18673.9	valid_1's rmse: 20694.5
# [500]	training's rmse: 18293	valid_1's rmse: 20647.8
# [600]	training's rmse: 17944.8	valid_1's rmse: 20591.3
# [700]	training's rmse: 17634.9	valid_1's rmse: 20576.1
# [800]	training's rmse: 17304.3	valid_1's rmse: 20556.1
# [900]	training's rmse: 16977.4	valid_1's rmse: 20537.6
# [1000]	training's rmse: 16682	valid_1's rmse: 20529.2
# [1100]	training's rmse: 16441.6	valid_1's rmse: 20545.1
# Early stopping, best iteration is:
# [1005]	training's rmse: 16667.5	valid_1's rmse: 20525.5
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20978	valid_1's rmse: 21664.4
# [200]	training's rmse: 19808.1	valid_1's rmse: 20982.7
# [300]	training's rmse: 19190.7	valid_1's rmse: 20737.6
# [400]	training's rmse: 18701	valid_1's rmse: 20597.2
# [500]	training's rmse: 18309.7	valid_1's rmse: 20501.5
# [600]	training's rmse: 17962.1	valid_1's rmse: 20449.9
# [700]	training's rmse: 17654.8	valid_1's rmse: 20383.5
# [800]	training's rmse: 17332	valid_1's rmse: 20346.4
# [900]	training's rmse: 17029.7	valid_1's rmse: 20310.3
# [1000]	training's rmse: 16754.6	valid_1's rmse: 20306
# [1100]	training's rmse: 16460.1	valid_1's rmse: 20267.7
# [1200]	training's rmse: 16193.5	valid_1's rmse: 20257.4
# [1300]	training's rmse: 15948.3	valid_1's rmse: 20250.9
# [1400]	training's rmse: 15710.7	valid_1's rmse: 20246.2
# [1500]	training's rmse: 15469.6	valid_1's rmse: 20241.6
# Early stopping, best iteration is:
# [1444]	training's rmse: 15595.9	valid_1's rmse: 20238.9
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21058.4	valid_1's rmse: 21528.1
# [200]	training's rmse: 19891.1	valid_1's rmse: 20745.4
# [300]	training's rmse: 19253.2	valid_1's rmse: 20490.7
# [400]	training's rmse: 18782.1	valid_1's rmse: 20335.7
# [500]	training's rmse: 18381.5	valid_1's rmse: 20234.1
# [600]	training's rmse: 18019.9	valid_1's rmse: 20146.7
# [700]	training's rmse: 17696.3	valid_1's rmse: 20080.2
# [800]	training's rmse: 17391.9	valid_1's rmse: 20039.9
# [900]	training's rmse: 17083.6	valid_1's rmse: 19999.1
# [1000]	training's rmse: 16816.5	valid_1's rmse: 19968.7
# [1100]	training's rmse: 16561.2	valid_1's rmse: 19943.6
# [1200]	training's rmse: 16306.8	valid_1's rmse: 19919.1
# [1300]	training's rmse: 16075.8	valid_1's rmse: 19913.6
# [1400]	training's rmse: 15831	valid_1's rmse: 19901.7
# [1500]	training's rmse: 15602.5	valid_1's rmse: 19891.2
# [1600]	training's rmse: 15372.1	valid_1's rmse: 19883.3
# [1700]	training's rmse: 15133	valid_1's rmse: 19873.8
# [1800]	training's rmse: 14928	valid_1's rmse: 19863.4
# [1900]	training's rmse: 14698.4	valid_1's rmse: 19872.5
# Early stopping, best iteration is:
# [1800]	training's rmse: 14928	valid_1's rmse: 19863.4

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# 20206.12839792405
# Out:
# 20237.584885499105

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  6.033490e+08
# 1                      te_Country__ohe_DevType_Student  5.975931e+08
# 2               te_Country__ohe_LanguageWorkedWith_PHP  3.718521e+08
# 3                                      te_Country__Age  3.527119e+08
# 4                               te_Country__Dependents  3.137742e+08
# 5                               te_Country__Employment  2.224481e+08
# 6                   te_YearsCodingProf__CurrencySymbol  2.015447e+08
# 7                       te_YearsCodingProf__MilitaryUS  1.970882e+08
# 8                              te_Country__YearsCoding  1.965254e+08
# 9                       te_YearsCodingProf__SalaryType  1.436139e+08
# 10                  te_SalaryType__ohe_DevType_Student  1.304503e+08
# 11   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  1.226147e+08
# 12                          te_Country__CurrencySymbol  1.219106e+08
# 13   te_Country__ohe_EducationTypes_Contributed_to_...  1.081549e+08
# 14                        te_YearsCodingProf__Currency  1.070565e+08
# 15                              te_Country__SalaryType  1.030860e+08
# 16               te_CareerSatisfaction__CurrencySymbol  9.070620e+07
# 17                         te_Country__OperatingSystem  7.745347e+07
# 18                      te_Country__CareerSatisfaction  6.973592e+07
# 19                            te_YearsCoding__Currency  6.011309e+07
# 20                           te_Employment__SalaryType  5.832711e+07
# 21                     te_CompanySize__YearsCodingProf  5.273877e+07
# 22   agg_mean_YearsCodingProf_ohe_CommunicationTool...  5.119546e+07
# 23                             te_Country__CompanySize  5.084456e+07
# 24                   te_Country__ohe_Methodology_Agile  5.053761e+07
# 25                       te_Employment__CurrencySymbol  4.999578e+07
# 26              te_CurrencySymbol__ohe_DevType_Student  4.774235e+07
# 27                 te_YearsCodingProf__OperatingSystem  4.439773e+07
# 28   agg_mean_Country_ohe_EducationTypes_Contribute...  4.425347e+07
# 29                         te_Country__FormalEducation  3.130729e+07
# 30   agg_std_Country_ohe_CommunicationTools_Confluence  3.101625e+07
# 31                                  te_Employment__Age  3.092110e+07
# 32   agg_mean_YearsCodingProf_ohe_EducationTypes_Co...  3.060070e+07
# 33   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.805012e+07
# 34             te_YearsCodingProf__ohe_DevType_Student  2.786009e+07
# 35   te_YearsCodingProf__ohe_CommunicationTools_Con...  2.770605e+07
# 36                    te_Currency__ohe_DevType_Student  2.543039e+07
# 37                      te_YearsCoding__CurrencySymbol  2.528878e+07
# 38                      te_Employment__YearsCodingProf  2.487537e+07
# 39                 te_FormalEducation__YearsCodingProf  2.413312e+07
# 40                     te_YearsCoding__YearsCodingProf  2.300645e+07
# 41                              te_CurrencySymbol__Age  2.243445e+07
# 42                       te_SalaryType__CurrencySymbol  2.130108e+07
# 43                     te_YearsCoding__OperatingSystem  2.128883e+07
# 44                           te_Employment__MilitaryUS  1.993636e+07
# 45      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  1.915062e+07
# 46               te_CompanySize__ohe_Methodology_Agile  1.912517e+07
# 47                     te_CompanySize__OperatingSystem  1.883026e+07
# 48   te_CompanySize__ohe_CommunicationTools_Confluence  1.767637e+07
# 49              te_YearsCodingProf__CareerSatisfaction  1.743721e+07
# 50                  te_CurrencySymbol__OperatingSystem  1.521176e+07
# 51   te_CurrencySymbol__ohe_EducationTypes_Contribu...  1.503482e+07
# 52                      te_Employment__FormalEducation  1.422868e+07
# 53                          te_YearsCoding__MilitaryUS  1.411082e+07
# 54                      te_CompanySize__CurrencySymbol  1.367888e+07
# 55                             te_Employment__Currency  1.360166e+07
# 56                                       te_LastNewJob  1.331755e+07
# 57   agg_mean_Country_ohe_CommunicationTools_Conflu...  1.316341e+07
# 58                  te_CompanySize__CareerSatisfaction  1.288446e+07
# 59                            svd_CommunicationTools_0  1.265924e+07
# 60     agg_mean_Employment_ohe_CommunicationTools_Jira  1.253219e+07
# 61   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  1.246413e+07
# 62            te_CurrencySymbol__ohe_Methodology_Agile  1.229581e+07
# 63                  te_Employment__ohe_DevType_Student  1.221261e+07
# 64                                  te_SalaryType__Age  1.196321e+07
# 65   te_CurrencySymbol__ohe_CommunicationTools_Conf...  1.176877e+07
# 66                      te_Employment__OperatingSystem  1.148860e+07
# 67       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  1.134538e+07
# 68                                 te_CompanySize__Age  1.128329e+07
# 69               te_YearsCoding__ohe_Methodology_Agile  1.106601e+07
# 70                                 te_YearsCoding__Age  1.090008e+07
# 71                       te_CurrencySymbol__MilitaryUS  1.087415e+07
# 72   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  1.076192e+07
# 73      te_Employment__ohe_DevType_Engineering_manager  1.068380e+07
# 74    diff_agg_mean_CurrencySymbol_ohe_DevType_Student  1.032628e+07
# 75                         te_CompanySize__YearsCoding  1.003108e+07
# 76   te_CareerSatisfaction__ohe_CommunicationTools_...  9.866387e+06
# 77         rel_agg_mean_SalaryType_ohe_DevType_Student  9.630380e+06
# 78                             te_YearsCodingProf__Age  9.461173e+06
# 79                 agg_mean_Employment_AssessBenefits2  9.433714e+06
# 80    te_Employment__ohe_CommunicationTools_Confluence  9.145302e+06
# 81   te_CareerSatisfaction__ohe_DevType_Engineering...  8.835446e+06
# 82                 te_YearsCoding__ohe_DevType_Student  8.472348e+06
# 83                          te_Employment__YearsCoding  8.326847e+06
# 84   agg_std_YearsCodingProf_ohe_EducationTypes_Con...  8.017665e+06
# 85                          te_YearsCoding__SalaryType  7.977025e+06
# 86              diff_agg_mean_Currency_AssessBenefits2  7.894352e+06
# 87        agg_mean_YearsCodingProf_ohe_DevType_Student  7.579631e+06
# 88                                te_Country__Currency  7.575881e+06
# 89                          te_Employment__CompanySize  7.556310e+06
# 90                te_Employment__ohe_Methodology_Agile  7.545514e+06
# 91              te_CareerSatisfaction__OperatingSystem  7.351299e+06
# 92   te_ohe_DevType_Engineering_manager__ohe_DevTyp...  7.294427e+06
# 93              agg_mean_Country_ohe_Methodology_Agile  7.179849e+06
# 94   diff_agg_mean_CompanySize_ohe_DevType_Engineer...  7.129583e+06
# 95   te_FormalEducation__ohe_DevType_Engineering_ma...  7.100823e+06
# 96                      te_FormalEducation__SalaryType  7.074914e+06
# 97                       te_Age__ohe_Methodology_Agile  7.050966e+06
# 98           te_YearsCodingProf__ohe_Methodology_Agile  7.049719e+06
# 99                             te_FormalEducation__Age  7.014713e+06
# 100     agg_std_Country_ohe_LanguageDesireNextYear_PHP  6.927817e+06
# 101               rel_agg_mean_Country_AssessBenefits2  6.865306e+06
# 102          te_Employment__ohe_LanguageWorkedWith_PHP  6.632961e+06
# 103  te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  6.609520e+06
# 104                 te_FormalEducation__CurrencySymbol  6.591563e+06
# 105                        te_Age__ohe_DevType_Student  6.560190e+06
# 106                         te_CareerSatisfaction__Age  6.439867e+06
# 107                       te_Currency__OperatingSystem  6.432237e+06
# 108   te_SalaryType__ohe_CommunicationTools_Confluence  6.388356e+06
# 109                 te_YearsCoding__CareerSatisfaction  6.375768e+06
# 110                            te_OperatingSystem__Age  6.371163e+06
# 111          diff_agg_mean_CompanySize_AssessBenefits2  5.907335e+06
# 112                            te_Currency__SalaryType  5.897527e+06
# 113    te_CompanySize__ohe_DevType_Engineering_manager  5.838943e+06
# 114  te_OperatingSystem__ohe_DevType_Engineering_ma...  5.768690e+06
# 115                           svd_LanguageWorkedWith_1  5.757638e+06
# 116  te_CompanySize__ohe_EducationTypes_Contributed...  5.629489e+06
# 117  te_Country__ohe_RaceEthnicity_White_or_of_Euro...  5.431000e+06
# 118         te_CompanySize__ohe_LanguageWorkedWith_PHP  5.277608e+06
# 119  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  5.258247e+06
# 120  te_FormalEducation__ohe_EducationTypes_Contrib...  5.222184e+06
# 121                         te_CompanySize__SalaryType  5.141590e+06
# 122        rel_agg_mean_NumberMonitors_AssessBenefits2  5.135756e+06
# 123  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  4.930270e+06
# 124                te_FormalEducation__OperatingSystem  4.919954e+06
# 125                       svd_DatabaseDesireNextYear_1  4.902886e+06
# 126                                  svd_Methodology_0  4.897966e+06
# 127                         te_CompanySize__Dependents  4.879411e+06
# 128               te_SalaryType__ohe_Methodology_Agile  4.773810e+06
# 129                  te_Employment__CareerSatisfaction  4.760154e+06
# 130      te_Country__ohe_CommunicationTools_Confluence  4.719370e+06
# 131                 te_Currency__ohe_Methodology_Agile  4.642231e+06
# 132                          te_Employment__Dependents  4.610799e+06
# 133  agg_mean_YearsCodingProf_ohe_LanguageDesireNex...  4.499271e+06
# 134                     te_YearsCodingProf__Dependents  4.444333e+06
# 135                    te_FormalEducation__CompanySize  4.345013e+06
# 136                                   te_Currency__Age  4.340780e+06
# 137       diff_agg_mean_NumberMonitors_AssessBenefits2  4.330256e+06
# 138     te_FormalEducation__ohe_LanguageWorkedWith_PHP  4.204090e+06
# 139                               ohe_DevType_Designer  4.144260e+06
# 140          te_FormalEducation__ohe_Methodology_Agile  4.131198e+06
# 141                te_CompanySize__ohe_DevType_Student  4.078985e+06
# 142                           te_CompanySize__Currency  4.074614e+06
# 143                  te_CareerSatisfaction__SalaryType  4.053164e+06
# 144          te_SalaryType__ohe_LanguageWorkedWith_PHP  4.048417e+06
# 145                     te_SalaryType__OperatingSystem  3.974980e+06
# 146                          ohe_LanguageWorkedWith_Go  3.951517e+06
# 147  te_YearsCoding__ohe_CommunicationTools_Confluence  3.935363e+06
# 148  agg_std_Employment_ohe_ErgonomicDevices_Standi...  3.899080e+06
# 149                                JobEmailPriorities5  3.768523e+06
# 150              diff_agg_mean_Country_AssessBenefits2  3.748075e+06
# 151                       te_FormalEducation__Currency  3.701692e+06
# 152                              JobContactPriorities1  3.637279e+06
# 153                                        te_UpdateCV  3.625384e+06
# 154          agg_mean_Employment_ohe_Methodology_Agile  3.618895e+06
# 155                      te_CurrencySymbol__Dependents  3.609918e+06
# 156            rel_agg_mean_SalaryType_AssessBenefits2  3.599440e+06
# 157             te_FormalEducation__CareerSatisfaction  3.571934e+06
# 158        rel_agg_mean_CurrencySymbol_AssessBenefits2  3.563102e+06
# 159                              te_HypotheticalTools2  3.526925e+06
# 160                               svd_VersionControl_1  3.477335e+06
# 161                                         te_Country  3.369311e+06
# 162  te_OperatingSystem__ohe_CommunicationTools_Con...  3.358700e+06
# 163  te_Employment__ohe_EducationTypes_Contributed_...  3.252295e+06
# 164              rel_agg_mean_Currency_AssessBenefits2  3.236534e+06
# 165                           svd_DatabaseWorkedWith_1  3.143985e+06
# 166          diff_agg_mean_Country_ohe_DevType_Student  3.085375e+06
# 167       diff_agg_mean_UndergradMajor_AssessBenefits2  3.084918e+06
# 168                                        AssessJob10  3.051373e+06
# 169  te_CareerSatisfaction__ohe_EducationTypes_Cont...  3.001859e+06
# 170                       ohe_DatabaseWorkedWith_Redis  2.993233e+06
# 171                                   ohe_IDE_NetBeans  2.970456e+06
# 172  agg_mean_Employment_ohe_CommunicationTools_Con...  2.969598e+06
# 173  te_YearsCoding__ohe_EducationTypes_Contributed...  2.881993e+06
# 174                    te_FormalEducation__YearsCoding  2.879743e+06
# 175  agg_std_Employment_ohe_DevType_Engineering_man...  2.852549e+06
# 176                                          svd_IDE_1  2.819054e+06
# 177            te_FormalEducation__ohe_DevType_Student  2.811831e+06
# 178  te_Age__ohe_EducationTypes_Contributed_to_open...  2.803252e+06
# 179                 te_Age__ohe_LanguageWorkedWith_PHP  2.790873e+06
# 180  agg_std_SalaryType_ohe_CommunicationTools_Conf...  2.789486e+06
# 181          te_Age__ohe_CommunicationTools_Confluence  2.782750e+06
# 182                                        te_WakeTime  2.778815e+06
# 183  te_ohe_CommunicationTools_Confluence__ohe_Lang...  2.769035e+06
# 184         te_YearsCoding__ohe_LanguageWorkedWith_PHP  2.731383e+06
# 185  diff_agg_mean_ohe_RaceEthnicity_White_or_of_Eu...  2.723714e+06
# 186                           svd_DatabaseWorkedWith_0  2.685426e+06
# 187      diff_agg_mean_FormalEducation_AssessBenefits2  2.660270e+06
# 188        te_Country__ohe_DevType_Engineering_manager  2.597960e+06
# 189       te_CareerSatisfaction__ohe_Methodology_Agile  2.590944e+06
# 190                    ohe_DevType_Front_end_developer  2.590699e+06
# 191                                    AssessBenefits1  2.572236e+06
# 192           rel_agg_mean_Country_ohe_DevType_Student  2.569236e+06
# 193  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  2.548614e+06
# 194        ohe_DevType_Educator_or_academic_researcher  2.543516e+06
# 195           rel_agg_mean_CompanySize_AssessBenefits2  2.541637e+06
# 196                                      te_Employment  2.517911e+06
# 197        agg_std_FormalEducation_ohe_DevType_Student  2.495103e+06
# 198                     te_OperatingSystem__Dependents  2.493362e+06
# 199                                      svd_DevType_0  2.473587e+06
# 200         te_CareerSatisfaction__ohe_DevType_Student  2.457277e+06
# 201                         ohe_LanguageWorkedWith_CSS  2.450519e+06
# 202  te_FormalEducation__ohe_CommunicationTools_Con...  2.421444e+06
# 203  diff_agg_mean_TimeFullyProductive_AssessBenefits2  2.358111e+06
# 204  agg_std_Country_ohe_EducationTypes_Contributed...  2.318412e+06
# 205                             svd_HackathonReasons_1  2.311788e+06
# 206  rel_agg_mean_Country_ohe_RaceEthnicity_White_o...  2.299354e+06
# 207       agg_mean_Age_ohe_DevType_Engineering_manager  2.256016e+06
# 208                                 te_Age__Dependents  2.232439e+06
# 209                                JobEmailPriorities6  2.225638e+06
# 210                       svd_LanguageDesireNextYear_0  2.224798e+06
# 211                             te_Country__MilitaryUS  2.195317e+06
# 212                              JobContactPriorities3  2.178775e+06
# 213                      sum_answer_DatabaseWorkedWith  2.172524e+06
# 214                   diff_agg_mean_Country_AssessJob5  2.170160e+06
# 215                     ohe_FrameworkWorkedWith_Hadoop  2.159061e+06
# 216    rel_agg_mean_CurrencySymbol_ohe_DevType_Student  2.148049e+06
# 217                agg_std_Country_ohe_DevType_Student  2.120771e+06
# 218                       ohe_PlatformWorkedWith_Azure  2.091865e+06
# 219                              JobContactPriorities4  2.057786e+06
# 220                          svd_FrameworkWorkedWith_1  2.043406e+06
# 221  diff_agg_mean_Country_ohe_DevType_Engineering_...  2.043109e+06
# 222                                        te_Exercise  2.042722e+06
# 223  diff_agg_mean_Dependents_ohe_EducationTypes_Pa...  2.033340e+06
# 224           diff_agg_mean_Employment_AssessBenefits2  2.018005e+06
# 225  diff_agg_mean_Employment_ohe_LanguageDesireNex...  2.017907e+06
# 226  diff_agg_mean_ohe_DevType_Engineering_manager_...  2.009578e+06
# 227                       svd_DatabaseDesireNextYear_0  2.006245e+06
# 228  agg_mean_HopeFiveYears_ohe_EducationTypes_Cont...  1.991945e+06
# 229  agg_std_Employment_ohe_CommunicationTools_Conf...  1.988971e+06
# 230               te_Dependents__ohe_Methodology_Agile  1.986824e+06
# 231                      te_StackOverflowJobsRecommend  1.984194e+06
# 232  rel_agg_mean_ohe_DevType_Engineering_manager_o...  1.971788e+06
# 233                  te_CareerSatisfaction__Dependents  1.970973e+06
# 234                                         AssessJob6  1.969186e+06
# 235              diff_agg_mean_Student_AssessBenefits2  1.962638e+06
# 236  diff_agg_mean_Country_ohe_RaceEthnicity_White_...  1.956273e+06
# 237  te_ohe_CommunicationTools_Confluence__ohe_Meth...  1.937915e+06
# 238               agg_mean_CompanySize_AssessBenefits2  1.937903e+06
# 239                                te_EducationParents  1.929172e+06
# 240                    rel_agg_mean_Country_AssessJob5  1.927034e+06
# 241          diff_agg_mean_YearsCoding_AssessBenefits2  1.917489e+06
# 242             agg_std_SalaryType_ohe_DevType_Student  1.912081e+06
# 243                             sum_answer_Methodology  1.896248e+06
# 244               ohe_DatabaseWorkedWith_Elasticsearch  1.890376e+06
# 245  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.877091e+06
# 246                 te_Dependents__ohe_DevType_Student  1.865542e+06
# 247                    te_CareerSatisfaction__Currency  1.862182e+06
# 248                                     te_CheckInCode  1.860222e+06
# 249                               svd_EducationTypes_0  1.845374e+06
# 250                                         AssessJob1  1.843950e+06
# 251                       ohe_CommunicationTools_Slack  1.843385e+06
# 252     te_Currency__ohe_CommunicationTools_Confluence  1.842080e+06
# 253                         agg_std_Country_AssessJob8  1.840085e+06
# 254  diff_agg_mean_SalaryType_ohe_DevType_Engineeri...  1.833590e+06
# 255                 ohe_DevType_Database_administrator  1.813340e+06
# 256           rel_agg_mean_YearsCoding_AssessBenefits2  1.776876e+06
# 257                                          svd_IDE_0  1.776780e+06
# 258  te_Employment__ohe_RaceEthnicity_White_or_of_E...  1.773189e+06
# 259           diff_agg_mean_SalaryType_AssessBenefits2  1.764090e+06
# 260       rel_agg_mean_FormalEducation_AssessBenefits2  1.761992e+06
# 261  diff_agg_mean_Country_ohe_EducationTypes_Contr...  1.753244e+06
# 262       diff_agg_mean_SalaryType_ohe_DevType_Student  1.750715e+06
# 263                      ohe_LanguageDesireNextYear_F_  1.742631e+06
# 264                                  ohe_IDE_Notepad__  1.741847e+06
# 265       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.741418e+06
# 266                                   AssessBenefits10  1.740383e+06
# 267  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  1.735468e+06
# 268           diff_agg_mean_MilitaryUS_AssessBenefits2  1.731938e+06
# 269            rel_agg_mean_JobSatisfaction_AssessJob5  1.726144e+06
# 270  diff_agg_mean_CurrencySymbol_ohe_LanguageDesir...  1.720645e+06
# 271      diff_agg_mean_YearsCodingProf_AssessBenefits2  1.689688e+06
# 272         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.686542e+06
# 273                           svd_PlatformWorkedWith_1  1.667921e+06
# 274                                   AssessBenefits11  1.663941e+06
# 275     ohe_VersionControl_I_don_t_use_version_control  1.639694e+06
# 276        diff_agg_mean_CareerSatisfaction_AssessJob5  1.638151e+06
# 277  diff_agg_mean_YearsCodingProf_ohe_ErgonomicDev...  1.626217e+06
# 278    agg_mean_Country_ohe_LanguageDesireNextYear_PHP  1.622863e+06
# 279       diff_agg_mean_CurrencySymbol_AssessBenefits2  1.621934e+06
# 280                              svd_SelfTaughtTypes_1  1.620293e+06
# 281                       svd_LanguageDesireNextYear_1  1.619143e+06
# 282                 ohe_PlatformDesireNextYear_Android  1.612848e+06
# 283                                  svd_Methodology_1  1.612094e+06
# 284  te_Age__ohe_RaceEthnicity_White_or_of_European...  1.601021e+06
# 285            rel_agg_mean_MilitaryUS_AssessBenefits2  1.597694e+06
# 286        diff_agg_mean_Country_ohe_Methodology_Agile  1.595665e+06
# 287           diff_agg_mean_JobSatisfaction_AssessJob5  1.588211e+06
# 288      te_ohe_DevType_Student__ohe_Methodology_Agile  1.586752e+06
# 289             ohe_DatabaseWorkedWith_Amazon_Redshift  1.573630e+06
# 290                         te_YearsCoding__Dependents  1.562908e+06
# 291      diff_agg_mean_JobSatisfaction_AssessBenefits2  1.562414e+06
# 292          diff_agg_mean_Student_ohe_DevType_Student  1.560094e+06
# 293     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.559371e+06
# 294  rel_agg_mean_Employment_ohe_CommunicationTools...  1.557089e+06
# 295            diff_agg_mean_CurrencySymbol_AssessJob5  1.547630e+06
# 296       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.543093e+06
# 297  te_ohe_DevType_Engineering_manager__ohe_Educat...  1.540251e+06
# 298                 agg_std_Employment_AssessBenefits2  1.528311e+06
# 299  agg_mean_Employment_ohe_DevType_Engineering_ma...  1.522410e+06

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 68888.55922819,  92484.35842058,  85381.56995033, ...,
#         86929.54968707,  84095.69244943, 119981.96270004])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
# sub_df.to_csv("../predict/018_poisson_20206.csv", index=False)
