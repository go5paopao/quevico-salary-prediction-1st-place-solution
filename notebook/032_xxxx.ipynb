# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 2495

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df.sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                2000,
                valid_sets = [train_dataset],
                verbose_eval=200,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
def null_preds(train_df, test_df, use_cols):
    target_cols = [
        "SalaryType",
        "YearsCodingProf",
        "Age",
    ]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    _lgb_params = lgb_params.copy()
    _lgb_params["objective"] = "multiclass"
    _lgb_params["metric"] = "multi_logloss" 
    for target_col in target_cols:
        print("-"*30)
        print(target_col)
        print("-"*30)

        _use_cols = [c for c in use_cols if c != target_col]
        trnval_idx = all_df[all_df[target_col] >= 0].index
        null_idx = all_df[all_df[target_col] == -1].index
        _train_df = all_df.loc[trnval_idx].reset_index(drop=True)
        _train_X, _valid_X, _train_y, _valid_y = train_test_split(
            _train_df[_use_cols], _train_df[target_col], test_size=0.2, shuffle=True, random_state=2020)
        _lgb_params["num_classes"] = _train_y.nunique()
        print(_train_y.nunique())
        train_dataset = lgb.Dataset(
            _train_X,
            label = _train_y
        )
        valid_dataset = lgb.Dataset(
            _valid_X,
            label = _valid_y
        )
        model = lgb.train(
                    _lgb_params,
                    train_dataset,
                    10000,
                    valid_sets = [train_dataset, valid_dataset],
                    verbose_eval=100,
                    early_stopping_rounds = 300,
                    #feval = eval_f1,
                    #callbacks = [log_callback],
        )
        all_df.loc[null_idx, target_col] = model.predict(all_df.loc[null_idx, _use_cols]).argmax(axis=1)
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    return train_df, test_df

# %%
train_df, test_df = null_preds(train_df, test_df, use_cols)
# Out:
# ------------------------------
# SalaryType
# ------------------------------
# 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00389268	valid_1's multi_logloss: 0.00390239
# [200]	training's multi_logloss: 0.000100625	valid_1's multi_logloss: 0.000101138
# [300]	training's multi_logloss: 5.40613e-05	valid_1's multi_logloss: 5.44222e-05
# [400]	training's multi_logloss: 5.1545e-05	valid_1's multi_logloss: 5.18914e-05
# [500]	training's multi_logloss: 5.11948e-05	valid_1's multi_logloss: 5.15387e-05
# [600]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# [700]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# [800]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# Early stopping, best iteration is:
# [592]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# ------------------------------
# YearsCodingProf
# ------------------------------
# 11
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00892553	valid_1's multi_logloss: 0.00891888
# [200]	training's multi_logloss: 0.00031397	valid_1's multi_logloss: 0.000312365
# [300]	training's multi_logloss: 0.000190536	valid_1's multi_logloss: 0.000189193
# [400]	training's multi_logloss: 0.000178257	valid_1's multi_logloss: 0.000176957
# [500]	training's multi_logloss: 0.000175034	valid_1's multi_logloss: 0.000173739
# [600]	training's multi_logloss: 0.000173437	valid_1's multi_logloss: 0.000172148
# [700]	training's multi_logloss: 0.000172429	valid_1's multi_logloss: 0.000171142
# [800]	training's multi_logloss: 0.000171645	valid_1's multi_logloss: 0.000170361
# [900]	training's multi_logloss: 0.000171197	valid_1's multi_logloss: 0.000169915
# [1000]	training's multi_logloss: 0.000170802	valid_1's multi_logloss: 0.000169523
# [1100]	training's multi_logloss: 0.000170434	valid_1's multi_logloss: 0.000169156
# [1200]	training's multi_logloss: 0.000170212	valid_1's multi_logloss: 0.000168936
# [1300]	training's multi_logloss: 0.00017008	valid_1's multi_logloss: 0.000168805
# [1400]	training's multi_logloss: 0.00016995	valid_1's multi_logloss: 0.000168676
# [1500]	training's multi_logloss: 0.000169811	valid_1's multi_logloss: 0.000168538
# [1600]	training's multi_logloss: 0.000169718	valid_1's multi_logloss: 0.000168445
# [1700]	training's multi_logloss: 0.000169641	valid_1's multi_logloss: 0.000168369
# [1800]	training's multi_logloss: 0.000169552	valid_1's multi_logloss: 0.00016828
# [1900]	training's multi_logloss: 0.000169512	valid_1's multi_logloss: 0.00016824
# [2000]	training's multi_logloss: 0.000169456	valid_1's multi_logloss: 0.000168185
# [2100]	training's multi_logloss: 0.000169433	valid_1's multi_logloss: 0.000168162
# [2200]	training's multi_logloss: 0.000169407	valid_1's multi_logloss: 0.000168136
# [2300]	training's multi_logloss: 0.000169376	valid_1's multi_logloss: 0.000168104
# [2400]	training's multi_logloss: 0.000169369	valid_1's multi_logloss: 0.000168098
# [2500]	training's multi_logloss: 0.000169322	valid_1's multi_logloss: 0.000168051
# [2600]	training's multi_logloss: 0.000169298	valid_1's multi_logloss: 0.000168027
# [2700]	training's multi_logloss: 0.000169254	valid_1's multi_logloss: 0.000167983
# [2800]	training's multi_logloss: 0.000169232	valid_1's multi_logloss: 0.000167961
# [2900]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# [3000]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# [3100]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# Early stopping, best iteration is:
# [2866]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# ------------------------------
# Age
# ------------------------------
# 7
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00592367	valid_1's multi_logloss: 0.00594546
# [200]	training's multi_logloss: 0.00019448	valid_1's multi_logloss: 0.000194694
# [300]	training's multi_logloss: 0.00011481	valid_1's multi_logloss: 0.000114774
# [400]	training's multi_logloss: 0.000105717	valid_1's multi_logloss: 0.000105624
# [500]	training's multi_logloss: 0.000102524	valid_1's multi_logloss: 0.000102409
# [600]	training's multi_logloss: 0.000100017	valid_1's multi_logloss: 9.98819e-05
# [700]	training's multi_logloss: 9.90569e-05	valid_1's multi_logloss: 9.8914e-05
# [800]	training's multi_logloss: 9.80469e-05	valid_1's multi_logloss: 9.7895e-05
# [900]	training's multi_logloss: 9.74899e-05	valid_1's multi_logloss: 9.73327e-05
# [1000]	training's multi_logloss: 9.70215e-05	valid_1's multi_logloss: 9.68597e-05
# [1100]	training's multi_logloss: 9.68088e-05	valid_1's multi_logloss: 9.66451e-05
# [1200]	training's multi_logloss: 9.65381e-05	valid_1's multi_logloss: 9.63718e-05
# [1300]	training's multi_logloss: 9.6397e-05	valid_1's multi_logloss: 9.62293e-05
# [1400]	training's multi_logloss: 9.62223e-05	valid_1's multi_logloss: 9.60531e-05
# [1500]	training's multi_logloss: 9.60943e-05	valid_1's multi_logloss: 9.59239e-05
# [1600]	training's multi_logloss: 9.60314e-05	valid_1's multi_logloss: 9.58604e-05
# [1700]	training's multi_logloss: 9.59695e-05	valid_1's multi_logloss: 9.57982e-05
# [1800]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# [1900]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# [2000]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# Early stopping, best iteration is:
# [1790]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05

# %%
null_pred_cols = [
    "SalaryType",
    "YearsCodingProf",
    "Age",
]
train_df[null_pred_cols].to_csv("../data/train_null_pred.csv", index=False)
test_df[null_pred_cols].to_csv("../data/test_null_pred.csv", index=False)

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

# use_cols = feature_selection(train_df, use_cols, n_features=1000)


for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                10000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 300,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# ------------------------------
# SalaryType
# ------------------------------
# 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00389268	valid_1's multi_logloss: 0.00390239
# [200]	training's multi_logloss: 0.000100625	valid_1's multi_logloss: 0.000101138
# [300]	training's multi_logloss: 5.40613e-05	valid_1's multi_logloss: 5.44222e-05
# [400]	training's multi_logloss: 5.1545e-05	valid_1's multi_logloss: 5.18914e-05
# [500]	training's multi_logloss: 5.11948e-05	valid_1's multi_logloss: 5.15387e-05
# [600]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# [700]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# [800]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# Early stopping, best iteration is:
# [592]	training's multi_logloss: 5.10366e-05	valid_1's multi_logloss: 5.13793e-05
# ------------------------------
# YearsCodingProf
# ------------------------------
# 11
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00892553	valid_1's multi_logloss: 0.00891888
# [200]	training's multi_logloss: 0.00031397	valid_1's multi_logloss: 0.000312365
# [300]	training's multi_logloss: 0.000190536	valid_1's multi_logloss: 0.000189193
# [400]	training's multi_logloss: 0.000178257	valid_1's multi_logloss: 0.000176957
# [500]	training's multi_logloss: 0.000175034	valid_1's multi_logloss: 0.000173739
# [600]	training's multi_logloss: 0.000173437	valid_1's multi_logloss: 0.000172148
# [700]	training's multi_logloss: 0.000172429	valid_1's multi_logloss: 0.000171142
# [800]	training's multi_logloss: 0.000171645	valid_1's multi_logloss: 0.000170361
# [900]	training's multi_logloss: 0.000171197	valid_1's multi_logloss: 0.000169915
# [1000]	training's multi_logloss: 0.000170802	valid_1's multi_logloss: 0.000169523
# [1100]	training's multi_logloss: 0.000170434	valid_1's multi_logloss: 0.000169156
# [1200]	training's multi_logloss: 0.000170212	valid_1's multi_logloss: 0.000168936
# [1300]	training's multi_logloss: 0.00017008	valid_1's multi_logloss: 0.000168805
# [1400]	training's multi_logloss: 0.00016995	valid_1's multi_logloss: 0.000168676
# [1500]	training's multi_logloss: 0.000169811	valid_1's multi_logloss: 0.000168538
# [1600]	training's multi_logloss: 0.000169718	valid_1's multi_logloss: 0.000168445
# [1700]	training's multi_logloss: 0.000169641	valid_1's multi_logloss: 0.000168369
# [1800]	training's multi_logloss: 0.000169552	valid_1's multi_logloss: 0.00016828
# [1900]	training's multi_logloss: 0.000169512	valid_1's multi_logloss: 0.00016824
# [2000]	training's multi_logloss: 0.000169456	valid_1's multi_logloss: 0.000168185
# [2100]	training's multi_logloss: 0.000169433	valid_1's multi_logloss: 0.000168162
# [2200]	training's multi_logloss: 0.000169407	valid_1's multi_logloss: 0.000168136
# [2300]	training's multi_logloss: 0.000169376	valid_1's multi_logloss: 0.000168104
# [2400]	training's multi_logloss: 0.000169369	valid_1's multi_logloss: 0.000168098
# [2500]	training's multi_logloss: 0.000169322	valid_1's multi_logloss: 0.000168051
# [2600]	training's multi_logloss: 0.000169298	valid_1's multi_logloss: 0.000168027
# [2700]	training's multi_logloss: 0.000169254	valid_1's multi_logloss: 0.000167983
# [2800]	training's multi_logloss: 0.000169232	valid_1's multi_logloss: 0.000167961
# [2900]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# [3000]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# [3100]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# Early stopping, best iteration is:
# [2866]	training's multi_logloss: 0.000169213	valid_1's multi_logloss: 0.000167943
# ------------------------------
# Age
# ------------------------------
# 7
# Training until validation scores don't improve for 300 rounds
# [100]	training's multi_logloss: 0.00592367	valid_1's multi_logloss: 0.00594546
# [200]	training's multi_logloss: 0.00019448	valid_1's multi_logloss: 0.000194694
# [300]	training's multi_logloss: 0.00011481	valid_1's multi_logloss: 0.000114774
# [400]	training's multi_logloss: 0.000105717	valid_1's multi_logloss: 0.000105624
# [500]	training's multi_logloss: 0.000102524	valid_1's multi_logloss: 0.000102409
# [600]	training's multi_logloss: 0.000100017	valid_1's multi_logloss: 9.98819e-05
# [700]	training's multi_logloss: 9.90569e-05	valid_1's multi_logloss: 9.8914e-05
# [800]	training's multi_logloss: 9.80469e-05	valid_1's multi_logloss: 9.7895e-05
# [900]	training's multi_logloss: 9.74899e-05	valid_1's multi_logloss: 9.73327e-05
# [1000]	training's multi_logloss: 9.70215e-05	valid_1's multi_logloss: 9.68597e-05
# [1100]	training's multi_logloss: 9.68088e-05	valid_1's multi_logloss: 9.66451e-05
# [1200]	training's multi_logloss: 9.65381e-05	valid_1's multi_logloss: 9.63718e-05
# [1300]	training's multi_logloss: 9.6397e-05	valid_1's multi_logloss: 9.62293e-05
# [1400]	training's multi_logloss: 9.62223e-05	valid_1's multi_logloss: 9.60531e-05
# [1500]	training's multi_logloss: 9.60943e-05	valid_1's multi_logloss: 9.59239e-05
# [1600]	training's multi_logloss: 9.60314e-05	valid_1's multi_logloss: 9.58604e-05
# [1700]	training's multi_logloss: 9.59695e-05	valid_1's multi_logloss: 9.57982e-05
# [1800]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# [1900]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# [2000]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# Early stopping, best iteration is:
# [1790]	training's multi_logloss: 9.59254e-05	valid_1's multi_logloss: 9.57538e-05
# Fold 1
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22677.4	valid_1's rmse: 23006.3
# [200]	training's rmse: 20874.9	valid_1's rmse: 21634.4
# [300]	training's rmse: 20113.1	valid_1's rmse: 21184.5
# [400]	training's rmse: 19626.3	valid_1's rmse: 20950
# [500]	training's rmse: 19255.3	valid_1's rmse: 20807
# [600]	training's rmse: 18949.8	valid_1's rmse: 20696.8
# [700]	training's rmse: 18679.7	valid_1's rmse: 20628.1
# [800]	training's rmse: 18433.5	valid_1's rmse: 20566.4
# [900]	training's rmse: 18213.4	valid_1's rmse: 20508.6
# [1000]	training's rmse: 18003.4	valid_1's rmse: 20463.4
# [1100]	training's rmse: 17814.3	valid_1's rmse: 20431.8
# [1200]	training's rmse: 17620.8	valid_1's rmse: 20399.8
# [1300]	training's rmse: 17414.5	valid_1's rmse: 20374.3
# [1400]	training's rmse: 17245.5	valid_1's rmse: 20351.9
# [1500]	training's rmse: 17068	valid_1's rmse: 20338.2
# [1600]	training's rmse: 16912	valid_1's rmse: 20320.1
# [1700]	training's rmse: 16746.9	valid_1's rmse: 20303.3
# [1800]	training's rmse: 16591.4	valid_1's rmse: 20300.9
# [1900]	training's rmse: 16441.6	valid_1's rmse: 20293.2
# [2000]	training's rmse: 16289.7	valid_1's rmse: 20281
# [2100]	training's rmse: 16150.3	valid_1's rmse: 20275.6
# [2200]	training's rmse: 16008.7	valid_1's rmse: 20261.9
# [2300]	training's rmse: 15868	valid_1's rmse: 20245.3
# [2400]	training's rmse: 15729.6	valid_1's rmse: 20239.8
# [2500]	training's rmse: 15589.1	valid_1's rmse: 20234.3
# [2600]	training's rmse: 15454.3	valid_1's rmse: 20229.8
# [2700]	training's rmse: 15318.5	valid_1's rmse: 20219.3
# [2800]	training's rmse: 15184.5	valid_1's rmse: 20215.9
# [2900]	training's rmse: 15053.6	valid_1's rmse: 20212
# [3000]	training's rmse: 14931.2	valid_1's rmse: 20211
# [3100]	training's rmse: 14806.3	valid_1's rmse: 20219.1
# [3200]	training's rmse: 14672.6	valid_1's rmse: 20219.6
# Early stopping, best iteration is:
# [2947]	training's rmse: 14997.6	valid_1's rmse: 20209.3
# Fold 2
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22635.9	valid_1's rmse: 23235.1
# [200]	training's rmse: 20879	valid_1's rmse: 21731.9
# [300]	training's rmse: 20124.4	valid_1's rmse: 21217.9
# [400]	training's rmse: 19673	valid_1's rmse: 20972.9
# [500]	training's rmse: 19307	valid_1's rmse: 20828.5
# [600]	training's rmse: 18990.1	valid_1's rmse: 20723.8
# [700]	training's rmse: 18716.9	valid_1's rmse: 20647.1
# [800]	training's rmse: 18491.7	valid_1's rmse: 20577.2
# [900]	training's rmse: 18275.2	valid_1's rmse: 20522.7
# [1000]	training's rmse: 18073.4	valid_1's rmse: 20477.2
# [1100]	training's rmse: 17873	valid_1's rmse: 20433.7
# [1200]	training's rmse: 17685	valid_1's rmse: 20389.5
# [1300]	training's rmse: 17510.8	valid_1's rmse: 20363.4
# [1400]	training's rmse: 17334.2	valid_1's rmse: 20338.9
# [1500]	training's rmse: 17181.7	valid_1's rmse: 20316.3
# [1600]	training's rmse: 17002.6	valid_1's rmse: 20289.9
# [1700]	training's rmse: 16846.8	valid_1's rmse: 20262.4
# [1800]	training's rmse: 16694.1	valid_1's rmse: 20238.4
# [1900]	training's rmse: 16540.9	valid_1's rmse: 20216.5
# [2000]	training's rmse: 16391.5	valid_1's rmse: 20197
# [2100]	training's rmse: 16245.1	valid_1's rmse: 20193.2
# [2200]	training's rmse: 16101.2	valid_1's rmse: 20190.6
# [2300]	training's rmse: 15953.5	valid_1's rmse: 20180.4
# [2400]	training's rmse: 15822.3	valid_1's rmse: 20176.7
# [2500]	training's rmse: 15681.9	valid_1's rmse: 20171.8
# [2600]	training's rmse: 15544.2	valid_1's rmse: 20170
# [2700]	training's rmse: 15407.5	valid_1's rmse: 20165.1
# [2800]	training's rmse: 15283	valid_1's rmse: 20158.7
# [2900]	training's rmse: 15146.7	valid_1's rmse: 20153
# [3000]	training's rmse: 15022.1	valid_1's rmse: 20146.1
# [3100]	training's rmse: 14894.9	valid_1's rmse: 20139.9
# [3200]	training's rmse: 14762.3	valid_1's rmse: 20131.3
# [3300]	training's rmse: 14634.7	valid_1's rmse: 20135
# [3400]	training's rmse: 14513	valid_1's rmse: 20136.2
# [3500]	training's rmse: 14382.7	valid_1's rmse: 20125.4
# [3600]	training's rmse: 14256.8	valid_1's rmse: 20122.2
# [3700]	training's rmse: 14139.4	valid_1's rmse: 20116.3
# [3800]	training's rmse: 14027.8	valid_1's rmse: 20108.1
# [3900]	training's rmse: 13910.3	valid_1's rmse: 20100.6
# [4000]	training's rmse: 13789.9	valid_1's rmse: 20098.6
# [4100]	training's rmse: 13673.2	valid_1's rmse: 20089.9
# [4200]	training's rmse: 13570.9	valid_1's rmse: 20087
# [4300]	training's rmse: 13453.9	valid_1's rmse: 20080.3
# [4400]	training's rmse: 13341.4	valid_1's rmse: 20086.5
# [4500]	training's rmse: 13226.5	valid_1's rmse: 20081.4
# Early stopping, best iteration is:
# [4290]	training's rmse: 13466	valid_1's rmse: 20077.7
# Fold 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22690	valid_1's rmse: 23054.9
# [200]	training's rmse: 20860.9	valid_1's rmse: 21568.5
# [300]	training's rmse: 20103.6	valid_1's rmse: 21152.4
# [400]	training's rmse: 19610.1	valid_1's rmse: 20961.6
# [500]	training's rmse: 19244.2	valid_1's rmse: 20845.9
# [600]	training's rmse: 18945.1	valid_1's rmse: 20762
# [700]	training's rmse: 18706.7	valid_1's rmse: 20731.5
# [800]	training's rmse: 18467.3	valid_1's rmse: 20682.8
# [900]	training's rmse: 18238.2	valid_1's rmse: 20646.6
# [1000]	training's rmse: 18044	valid_1's rmse: 20622.3
# [1100]	training's rmse: 17849.8	valid_1's rmse: 20591.7
# [1200]	training's rmse: 17663.5	valid_1's rmse: 20568.1
# [1300]	training's rmse: 17501	valid_1's rmse: 20550.5
# [1400]	training's rmse: 17338.7	valid_1's rmse: 20534.2
# [1500]	training's rmse: 17161.2	valid_1's rmse: 20515.5
# [1600]	training's rmse: 17015.8	valid_1's rmse: 20501.2
# [1700]	training's rmse: 16852.4	valid_1's rmse: 20488.9
# [1800]	training's rmse: 16686.5	valid_1's rmse: 20474.9
# [1900]	training's rmse: 16535.3	valid_1's rmse: 20463
# [2000]	training's rmse: 16388.6	valid_1's rmse: 20461.8
# [2100]	training's rmse: 16236.5	valid_1's rmse: 20458.4
# [2200]	training's rmse: 16101.8	valid_1's rmse: 20457.3
# [2300]	training's rmse: 15966.9	valid_1's rmse: 20463.7
# Early stopping, best iteration is:
# [2063]	training's rmse: 16288.1	valid_1's rmse: 20453.8
# Fold 4
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22681.6	valid_1's rmse: 23051.9
# [200]	training's rmse: 20898.8	valid_1's rmse: 21635.2
# [300]	training's rmse: 20133.6	valid_1's rmse: 21199.5
# [400]	training's rmse: 19663.7	valid_1's rmse: 20977.2
# [500]	training's rmse: 19315.7	valid_1's rmse: 20853.2
# [600]	training's rmse: 19006.5	valid_1's rmse: 20746.7
# [700]	training's rmse: 18740.6	valid_1's rmse: 20640.7
# [800]	training's rmse: 18530.9	valid_1's rmse: 20588.8
# [900]	training's rmse: 18314.1	valid_1's rmse: 20527.7
# [1000]	training's rmse: 18106.4	valid_1's rmse: 20478.3
# [1100]	training's rmse: 17919.8	valid_1's rmse: 20432.2
# [1200]	training's rmse: 17722.9	valid_1's rmse: 20399.3
# [1300]	training's rmse: 17545.7	valid_1's rmse: 20375.8
# [1400]	training's rmse: 17384.2	valid_1's rmse: 20355.7
# [1500]	training's rmse: 17212.5	valid_1's rmse: 20331.1
# [1600]	training's rmse: 17047.7	valid_1's rmse: 20314.1
# [1700]	training's rmse: 16877.5	valid_1's rmse: 20299.7
# [1800]	training's rmse: 16723.6	valid_1's rmse: 20284.4
# [1900]	training's rmse: 16568.4	valid_1's rmse: 20266.8
# [2000]	training's rmse: 16422.9	valid_1's rmse: 20255.6
# [2100]	training's rmse: 16279.7	valid_1's rmse: 20232.5
# [2200]	training's rmse: 16150	valid_1's rmse: 20227.7
# [2300]	training's rmse: 16004.9	valid_1's rmse: 20220.9
# [2400]	training's rmse: 15866.2	valid_1's rmse: 20205.6
# [2500]	training's rmse: 15740.1	valid_1's rmse: 20197.4
# [2600]	training's rmse: 15609.7	valid_1's rmse: 20188.1
# [2700]	training's rmse: 15471.3	valid_1's rmse: 20175.2
# [2800]	training's rmse: 15346	valid_1's rmse: 20173.8
# [2900]	training's rmse: 15215.2	valid_1's rmse: 20161.8
# [3000]	training's rmse: 15082.8	valid_1's rmse: 20171
# [3100]	training's rmse: 14952.3	valid_1's rmse: 20166.1
# [3200]	training's rmse: 14827.8	valid_1's rmse: 20159.7
# [3300]	training's rmse: 14703.6	valid_1's rmse: 20156.2
# [3400]	training's rmse: 14577.8	valid_1's rmse: 20150.1
# [3500]	training's rmse: 14449.7	valid_1's rmse: 20145.1
# [3600]	training's rmse: 14329.4	valid_1's rmse: 20143.8
# [3700]	training's rmse: 14215.6	valid_1's rmse: 20151.8
# [3800]	training's rmse: 14089.8	valid_1's rmse: 20149.5
# Early stopping, best iteration is:
# [3504]	training's rmse: 14444.7	valid_1's rmse: 20143.6
# Fold 5
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22729.3	valid_1's rmse: 23099.1
# [200]	training's rmse: 20955.8	valid_1's rmse: 21496.8
# [300]	training's rmse: 20189.5	valid_1's rmse: 20969.9
# [400]	training's rmse: 19709.2	valid_1's rmse: 20708
# [500]	training's rmse: 19360.8	valid_1's rmse: 20563.6
# [600]	training's rmse: 19069.6	valid_1's rmse: 20473.5
# [700]	training's rmse: 18792.4	valid_1's rmse: 20388.3
# [800]	training's rmse: 18546	valid_1's rmse: 20344.6
# [900]	training's rmse: 18331	valid_1's rmse: 20293
# [1000]	training's rmse: 18142.8	valid_1's rmse: 20254
# [1100]	training's rmse: 17968.3	valid_1's rmse: 20223.7
# [1200]	training's rmse: 17797.3	valid_1's rmse: 20188.8
# [1300]	training's rmse: 17622.6	valid_1's rmse: 20165.1
# [1400]	training's rmse: 17452.7	valid_1's rmse: 20140.5
# [1500]	training's rmse: 17289	valid_1's rmse: 20121
# [1600]	training's rmse: 17122.2	valid_1's rmse: 20102.5
# [1700]	training's rmse: 16963.8	valid_1's rmse: 20079.1
# [1800]	training's rmse: 16804.9	valid_1's rmse: 20072
# [1900]	training's rmse: 16653.6	valid_1's rmse: 20069.4
# [2000]	training's rmse: 16490.5	valid_1's rmse: 20054.5
# [2100]	training's rmse: 16348.3	valid_1's rmse: 20042.6
# [2200]	training's rmse: 16197.1	valid_1's rmse: 20035.6
# [2300]	training's rmse: 16057.6	valid_1's rmse: 20030.5
# [2400]	training's rmse: 15909.8	valid_1's rmse: 20012.2
# [2500]	training's rmse: 15781.7	valid_1's rmse: 20009
# [2600]	training's rmse: 15647.6	valid_1's rmse: 20006.3
# [2700]	training's rmse: 15515	valid_1's rmse: 20009.9
# [2800]	training's rmse: 15389.3	valid_1's rmse: 20002.3
# [2900]	training's rmse: 15268.1	valid_1's rmse: 19997.7
# [3000]	training's rmse: 15146.7	valid_1's rmse: 19992.1
# [3100]	training's rmse: 15010.8	valid_1's rmse: 19994.1
# [3200]	training's rmse: 14880.5	valid_1's rmse: 19994.3
# [3300]	training's rmse: 14759.8	valid_1's rmse: 19994.2
# Early stopping, best iteration is:
# [3052]	training's rmse: 15077.3	valid_1's rmse: 19990

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20175.49002703224

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                               te_Country__SalaryType  4.571061e+08
# 1                               te_Country__Employment  4.173871e+08
# 2                                      te_Country__Age  3.221571e+08
# 3                          te_Country__YearsCodingProf  3.125664e+08
# 4                              te_Country__YearsCoding  2.956867e+08
# 5                      te_Country__ohe_DevType_Student  2.838929e+08
# 6                   te_YearsCodingProf__CurrencySymbol  2.035819e+08
# 7                    te_Country__ohe_Methodology_Agile  1.975331e+08
# 8                          te_Country__FormalEducation  1.863179e+08
# 9                        te_SalaryType__CurrencySymbol  1.688191e+08
# 10   te_Country__ohe_EducationTypes_Contributed_to_...  1.400100e+08
# 11                                    te_Currency__Age  1.200295e+08
# 12                      te_YearsCoding__CurrencySymbol  1.128866e+08
# 13                              te_Country__Dependents  1.020940e+08
# 14         te_Country__ohe_DevType_Engineering_manager  1.013184e+08
# 15                        te_YearsCodingProf__Currency  9.839210e+07
# 16                                  te_SalaryType__Age  9.370765e+07
# 17                                          te_Country  9.057069e+07
# 18       te_Country__ohe_CommunicationTools_Confluence  8.466223e+07
# 19             te_YearsCodingProf__ohe_DevType_Student  8.450563e+07
# 20                      te_Country__CareerSatisfaction  7.434059e+07
# 21                     te_CompanySize__YearsCodingProf  7.403784e+07
# 22                      te_YearsCodingProf__SalaryType  6.077671e+07
# 23                             te_Country__CompanySize  5.339565e+07
# 24              te_CurrencySymbol__ohe_DevType_Student  5.320118e+07
# 25                             te_Currency__SalaryType  4.977463e+07
# 26   te_YearsCodingProf__ohe_CommunicationTools_Con...  4.933035e+07
# 27                       te_Employment__CurrencySymbol  4.733461e+07
# 28                 te_YearsCodingProf__OperatingSystem  4.503290e+07
# 29                              te_Country__MilitaryUS  4.479907e+07
# 30      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  4.462901e+07
# 31                      te_Employment__YearsCodingProf  4.366451e+07
# 32                          te_Country__CurrencySymbol  4.321387e+07
# 33   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  4.063962e+07
# 34                            te_YearsCoding__Currency  3.435627e+07
# 35                 te_FormalEducation__YearsCodingProf  3.131312e+07
# 36            agg_mean_YearsCodingProf_AssessBenefits2  3.120140e+07
# 37              te_Country__ohe_LanguageWorkedWith_PHP  2.935627e+07
# 38                      te_YearsCodingProf__Dependents  2.611066e+07
# 39                                te_Country__Currency  2.538418e+07
# 40                  te_Employment__ohe_DevType_Student  2.485375e+07
# 41   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.432543e+07
# 42                         te_Country__OperatingSystem  2.393954e+07
# 43                             te_Employment__Currency  2.349148e+07
# 44        te_Currency__ohe_DevType_Engineering_manager  2.300179e+07
# 45                     te_YearsCoding__YearsCodingProf  2.184185e+07
# 46                                  te_Age__MilitaryUS  2.128236e+07
# 47                                 te_YearsCoding__Age  2.082480e+07
# 48                              te_CurrencySymbol__Age  2.040659e+07
# 49       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  1.980340e+07
# 50                             te_YearsCodingProf__Age  1.933279e+07
# 51              te_YearsCodingProf__CareerSatisfaction  1.881372e+07
# 52                  te_YearsCoding__CareerSatisfaction  1.788213e+07
# 53                     te_CompanySize__OperatingSystem  1.745455e+07
# 54                                       te_LastNewJob  1.722281e+07
# 55          te_YearsCoding__ohe_LanguageWorkedWith_PHP  1.706006e+07
# 56                  te_CompanySize__CareerSatisfaction  1.693112e+07
# 57   te_CurrencySymbol__ohe_DevType_Engineering_man...  1.648329e+07
# 58                  te_SalaryType__ohe_DevType_Student  1.620500e+07
# 59                          agg_std_Country_AssessJob5  1.604297e+07
# 60                   te_Employment__CareerSatisfaction  1.593564e+07
# 61                      te_YearsCodingProf__MilitaryUS  1.513264e+07
# 62                     te_YearsCoding__OperatingSystem  1.505611e+07
# 63                           te_Employment__SalaryType  1.381672e+07
# 64                  te_FormalEducation__CurrencySymbol  1.370943e+07
# 65               te_CompanySize__ohe_Methodology_Agile  1.319409e+07
# 66                                  te_Employment__Age  1.270168e+07
# 67               te_CareerSatisfaction__CurrencySymbol  1.228621e+07
# 68                                 te_CompanySize__Age  1.207126e+07
# 69           te_YearsCodingProf__ohe_Methodology_Agile  1.205002e+07
# 70                 te_YearsCoding__ohe_DevType_Student  1.194764e+07
# 71                      te_CompanySize__CurrencySymbol  1.140155e+07
# 72                            svd_CommunicationTools_0  1.119913e+07
# 73   te_CompanySize__ohe_CommunicationTools_Confluence  1.117090e+07
# 74                      te_Employment__OperatingSystem  1.096626e+07
# 75                      te_Employment__FormalEducation  1.068834e+07
# 76                          te_CareerSatisfaction__Age  9.950293e+06
# 77   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  9.944985e+06
# 78     te_CompanySize__ohe_DevType_Engineering_manager  9.806620e+06
# 79                  te_CurrencySymbol__OperatingSystem  9.581909e+06
# 80                         te_Age__ohe_DevType_Student  9.389119e+06
# 81    te_Employment__ohe_CommunicationTools_Confluence  9.227180e+06
# 82                 te_CompanySize__ohe_DevType_Student  9.036486e+06
# 83           te_Employment__ohe_LanguageWorkedWith_PHP  8.928882e+06
# 84   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  8.827015e+06
# 85   rank_diff_AssessBenefits_AssessBenefits2_Asses...  8.791640e+06
# 86                      te_FormalEducation__MilitaryUS  8.713860e+06
# 87   te_YearsCoding__ohe_RaceEthnicity_White_or_of_...  8.524955e+06
# 88                          te_Employment__CompanySize  8.446149e+06
# 89                          te_Employment__YearsCoding  8.417530e+06
# 90   te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  8.387311e+06
# 91                    te_Currency__ohe_DevType_Student  8.386320e+06
# 92      te_Employment__ohe_DevType_Engineering_manager  8.014638e+06
# 93   te_CompanySize__ohe_EducationTypes_Contributed...  8.008603e+06
# 94                           te_Employment__Dependents  7.918200e+06
# 95                             te_OperatingSystem__Age  7.840160e+06
# 96   te_YearsCodingProf__ohe_DevType_Engineering_ma...  7.813403e+06
# 97   te_CareerSatisfaction__ohe_DevType_Engineering...  7.642969e+06
# 98             te_FormalEducation__ohe_DevType_Student  7.582311e+06
# 99                  te_MilitaryUS__ohe_DevType_Student  7.418302e+06
# 100                        te_CompanySize__YearsCoding  7.316475e+06
# 101  te_CareerSatisfaction__ohe_CommunicationTools_...  7.248239e+06
# 102                te_FormalEducation__OperatingSystem  7.196451e+06
# 103                     te_OperatingSystem__MilitaryUS  7.092725e+06
# 104             te_CareerSatisfaction__OperatingSystem  7.087717e+06
# 105                      te_CurrencySymbol__MilitaryUS  6.905452e+06
# 106                    te_FormalEducation__CompanySize  6.878740e+06
# 107               te_SalaryType__ohe_Methodology_Agile  6.638708e+06
# 108               rel_agg_mean_Country_AssessBenefits2  6.382791e+06
# 109               te_Employment__ohe_Methodology_Agile  6.291776e+06
# 110              te_YearsCoding__ohe_Methodology_Agile  6.194897e+06
# 111                         te_CompanySize__Dependents  6.182562e+06
# 112  te_FormalEducation__ohe_DevType_Engineering_ma...  6.165114e+06
# 113                         te_CompanySize__SalaryType  6.137784e+06
# 114  agg_mean_Employment_ohe_CommunicationTools_Con...  6.126145e+06
# 115          te_FormalEducation__ohe_Methodology_Agile  6.107493e+06
# 116                       svd_DatabaseDesireNextYear_1  6.078082e+06
# 117           te_CurrencySymbol__ohe_Methodology_Agile  6.064490e+06
# 118              rel_agg_mean_Currency_AssessBenefits2  5.860247e+06
# 119  agg_mean_YearsCodingProf_ohe_LanguageDesireNex...  5.710237e+06
# 120                           te_CompanySize__Currency  5.700209e+06
# 121                     te_SalaryType__OperatingSystem  5.525275e+06
# 122                         te_YearsCoding__SalaryType  5.484524e+06
# 123             te_FormalEducation__CareerSatisfaction  5.482480e+06
# 124                                         MilitaryUS  5.447040e+06
# 125                      te_CurrencySymbol__Dependents  5.424563e+06
# 126                       te_Currency__OperatingSystem  5.377388e+06
# 127                           svd_LanguageWorkedWith_1  5.344418e+06
# 128          diff_agg_mean_Country_ohe_DevType_Student  5.321743e+06
# 129                      te_Age__ohe_Methodology_Agile  5.286235e+06
# 130  te_Employment__ohe_EducationTypes_Contributed_...  5.186316e+06
# 131                                  svd_Methodology_0  4.920126e+06
# 132  te_OperatingSystem__ohe_DevType_Engineering_ma...  4.904436e+06
# 133                            te_FormalEducation__Age  4.814643e+06
# 134                          te_Employment__MilitaryUS  4.799080e+06
# 135   te_SalaryType__ohe_CommunicationTools_Confluence  4.727326e+06
# 136                 te_Age__ohe_LanguageWorkedWith_PHP  4.694685e+06
# 137                               ohe_DevType_Designer  4.643596e+06
# 138                     te_FormalEducation__SalaryType  4.637182e+06
# 139             agg_mean_Country_ohe_Methodology_Agile  4.614979e+06
# 140  te_ohe_CommunicationTools_Confluence__ohe_Lang...  4.550927e+06
# 141                    te_CareerSatisfaction__Currency  4.494889e+06
# 142                                      te_Employment  4.477318e+06
# 143        rel_agg_mean_NumberMonitors_AssessBenefits2  4.417259e+06
# 144        agg_mean_Country_ohe_LanguageWorkedWith_PHP  4.393180e+06
# 145       diff_agg_mean_CurrencySymbol_AssessBenefits2  4.375614e+06
# 146                agg_mean_YearsCodingProf_AssessJob5  4.364736e+06
# 147  te_CareerSatisfaction__ohe_EducationTypes_Cont...  4.357620e+06
# 148  rank_diff_JobContactPriorities_JobContactPrior...  4.351018e+06
# 149            agg_std_YearsCodingProf_AssessBenefits2  4.323238e+06
# 150  te_YearsCoding__ohe_EducationTypes_Contributed...  4.307493e+06
# 151  te_FormalEducation__ohe_EducationTypes_Contrib...  4.298680e+06
# 152                          ohe_LanguageWorkedWith_Go  4.284946e+06
# 153                               svd_VersionControl_1  4.251132e+06
# 154             agg_mean_HopeFiveYears_AssessBenefits2  4.199786e+06
# 155            agg_mean_Employment_ohe_DevType_Student  4.144317e+06
# 156        rel_agg_mean_CurrencySymbol_AssessBenefits2  4.044792e+06
# 157  te_OperatingSystem__ohe_CommunicationTools_Con...  4.009739e+06
# 158  te_CurrencySymbol__ohe_CommunicationTools_Conf...  3.984203e+06
# 159       te_CareerSatisfaction__ohe_Methodology_Agile  3.840758e+06
# 160                                        te_UpdateCV  3.780764e+06
# 161    agg_mean_Employment_ohe_CommunicationTools_Jira  3.710978e+06
# 162             diff_agg_mean_Currency_AssessBenefits2  3.669650e+06
# 163     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  3.552682e+06
# 164                           svd_DatabaseWorkedWith_1  3.510588e+06
# 165  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.471408e+06
# 166                       ohe_DatabaseWorkedWith_Redis  3.468815e+06
# 167  te_Country__ohe_RaceEthnicity_White_or_of_Euro...  3.422798e+06
# 168    agg_mean_Country_ohe_LanguageDesireNextYear_PHP  3.420172e+06
# 169         te_CareerSatisfaction__ohe_DevType_Student  3.417641e+06
# 170  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  3.356014e+06
# 171     te_FormalEducation__ohe_LanguageWorkedWith_PHP  3.325193e+06
# 172     agg_std_Employment_ohe_CommunicationTools_Jira  3.314970e+06
# 173         rank_diff_AssessJob_AssessJob1_AssessJob10  3.282308e+06
# 174  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  3.277265e+06
# 175  rank_diff_AssessBenefits_AssessBenefits2_Asses...  3.268970e+06
# 176                              te_HypotheticalTools2  3.251324e+06
# 177              diff_agg_mean_Country_AssessBenefits2  3.242685e+06
# 178                agg_mean_Employment_AssessBenefits2  3.218847e+06
# 179  te_FormalEducation__ohe_CommunicationTools_Con...  3.208104e+06
# 180                agg_mean_YearsCodingProf_AssessJob8  3.190315e+06
# 181                   rel_agg_mean_Age_AssessBenefits2  3.164430e+06
# 182         rank_diff_AssessJob_AssessJob4_AssessJob10  3.145036e+06
# 183      te_ohe_DevType_Student__ohe_Methodology_Agile  3.113253e+06
# 184  te_YearsCoding__ohe_CommunicationTools_Confluence  3.048221e+06
# 185                                   ohe_IDE_NetBeans  3.042784e+06
# 186                                        te_WakeTime  3.013431e+06
# 187                         te_YearsCoding__MilitaryUS  2.991157e+06
# 188   diff_agg_mean_CurrencySymbol_ohe_DevType_Student  2.976518e+06
# 189            rel_agg_mean_Dependents_AssessBenefits2  2.966044e+06
# 190  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.934563e+06
# 191          diff_agg_mean_Student_ohe_DevType_Student  2.895740e+06
# 192  rank_diff_JobEmailPriorities_JobEmailPrioritie...  2.874944e+06
# 193          diff_agg_mean_CompanySize_AssessBenefits2  2.862179e+06
# 194  te_ohe_DevType_Engineering_manager__ohe_Educat...  2.834933e+06
# 195      diff_agg_mean_JobSatisfaction_AssessBenefits2  2.816717e+06
# 196                       te_FormalEducation__Currency  2.799114e+06
# 197     te_SalaryType__ohe_DevType_Engineering_manager  2.776978e+06
# 198          rank_diff_AssessJob_AssessJob4_AssessJob5  2.701728e+06
# 199                  te_CareerSatisfaction__SalaryType  2.691864e+06
# 200       rel_agg_mean_FormalEducation_AssessBenefits2  2.665533e+06
# 201          te_SalaryType__ohe_LanguageWorkedWith_PHP  2.654166e+06
# 202  te_ohe_DevType_Engineering_manager__ohe_Commun...  2.619829e+06
# 203                         ohe_LanguageWorkedWith_CSS  2.598857e+06
# 204       diff_agg_mean_NumberMonitors_AssessBenefits2  2.579848e+06
# 205  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.571451e+06
# 206  agg_std_YearsCodingProf_ohe_LanguageDesireNext...  2.555179e+06
# 207         te_CompanySize__ohe_LanguageWorkedWith_PHP  2.541391e+06
# 208  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  2.456278e+06
# 209                           svd_DatabaseWorkedWith_0  2.455635e+06
# 210                 ohe_ErgonomicDevices_Standing_desk  2.413373e+06
# 211                         agg_std_Country_AssessJob8  2.409969e+06
# 212        ohe_DevType_Educator_or_academic_researcher  2.408359e+06
# 213      diff_agg_mean_FormalEducation_AssessBenefits2  2.404367e+06
# 214                             svd_HackathonReasons_1  2.386588e+06
# 215                                          svd_IDE_1  2.380560e+06
# 216     te_Currency__ohe_CommunicationTools_Confluence  2.380013e+06
# 217                     ohe_FrameworkWorkedWith_Hadoop  2.372225e+06
# 218  rank_diff_JobContactPriorities_JobContactPrior...  2.289626e+06
# 219  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.276223e+06
# 220                       svd_LanguageDesireNextYear_0  2.257828e+06
# 221  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.238619e+06
# 222       agg_mean_YearsCodingProf_ohe_DevType_Student  2.235988e+06
# 223               agg_mean_Country_ohe_DevType_Student  2.232783e+06
# 224  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.232679e+06
# 225                     te_OperatingSystem__Dependents  2.217650e+06
# 226                 agg_std_YearsCodingProf_AssessJob5  2.217173e+06
# 227                     agg_mean_Employment_AssessJob5  2.217133e+06
# 228     ohe_EducationTypes_Participated_in_a_hackathon  2.211223e+06
# 229  rank_diff_AssessBenefits_AssessBenefits1_Asses...  2.202332e+06
# 230  diff_agg_mean_Country_ohe_LanguageDesireNextYe...  2.198892e+06
# 231                                      svd_DevType_0  2.186565e+06
# 232         rank_diff_AssessJob_AssessJob6_AssessJob10  2.144933e+06
# 233  agg_mean_SalaryType_ohe_CommunicationTools_Con...  2.132952e+06
# 234                 te_Currency__ohe_Methodology_Agile  2.121538e+06
# 235  agg_std_Country_ohe_CommunicationTools_Confluence  2.108194e+06
# 236  diff_agg_mean_Employment_ohe_LanguageDesireNex...  2.100012e+06
# 237          rank_diff_AssessJob_AssessJob5_AssessJob7  2.095582e+06
# 238                    ohe_DevType_Front_end_developer  2.095574e+06
# 239       rel_agg_mean_YearsCoding_ohe_DevType_Student  2.092756e+06
# 240  te_OperatingSystem__ohe_EducationTypes_Contrib...  2.086233e+06
# 241  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.083796e+06
# 242  te_ohe_CommunicationTools_Confluence__ohe_Meth...  2.078665e+06
# 243  agg_std_Employment_ohe_CommunicationTools_Conf...  2.056316e+06
# 244                       ohe_PlatformWorkedWith_Azure  2.055761e+06
# 245                                  te_CurrencySymbol  2.053137e+06
# 246                      sum_answer_DatabaseWorkedWith  2.021106e+06
# 247  diff_agg_mean_TimeFullyProductive_ohe_Communic...  2.020977e+06
# 248                                  ohe_IDE_Notepad__  2.010129e+06
# 249                               svd_EducationTypes_0  1.996365e+06
# 250   rel_agg_mean_TimeFullyProductive_AssessBenefits2  1.995371e+06
# 251                        agg_mean_Country_AssessJob5  1.994931e+06
# 252               ohe_DatabaseWorkedWith_Elasticsearch  1.988374e+06
# 253            rel_agg_mean_SalaryType_AssessBenefits2  1.979709e+06
# 254  rank_diff_AssessBenefits_AssessBenefits8_Asses...  1.951952e+06
# 255                                    YearsCodingProf  1.937979e+06
# 256                       svd_LanguageDesireNextYear_1  1.936454e+06
# 257  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.934201e+06
# 258                                      svd_DevType_1  1.931823e+06
# 259   te_Dependents__ohe_CommunicationTools_Confluence  1.898050e+06
# 260  agg_mean_Country_ohe_CommunicationTools_Conflu...  1.891550e+06
# 261  rank_diff_AssessBenefits_AssessBenefits6_Asses...  1.883962e+06
# 262                                ohe_DevType_Student  1.880177e+06
# 263               te_Dependents__ohe_Methodology_Agile  1.878772e+06
# 264  te_Employment__ohe_RaceEthnicity_White_or_of_E...  1.864162e+06
# 265                agg_std_Country_ohe_DevType_Student  1.856961e+06
# 266                       svd_DatabaseDesireNextYear_0  1.855605e+06
# 267             ohe_DatabaseWorkedWith_Amazon_Redshift  1.839423e+06
# 268           rel_agg_mean_Student_ohe_DevType_Student  1.836871e+06
# 269                                        te_Exercise  1.831095e+06
# 270                 ohe_DevType_Database_administrator  1.828922e+06
# 271     agg_mean_Employment_ohe_LanguageWorkedWith_PHP  1.825000e+06
# 272  rank_diff_AssessBenefits_AssessBenefits3_Asses...  1.823701e+06
# 273  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.821365e+06
# 274  rank_diff_JobContactPriorities_JobContactPrior...  1.820554e+06
# 275          rank_diff_AssessJob_AssessJob7_AssessJob9  1.813395e+06
# 276            te_Currency__ohe_LanguageWorkedWith_PHP  1.807925e+06
# 277         rank_diff_AssessJob_AssessJob8_AssessJob10  1.803830e+06
# 278                          svd_FrameworkWorkedWith_1  1.803536e+06
# 279                        ohe_LanguageWorkedWith_HTML  1.798891e+06
# 280          rank_diff_AssessJob_AssessJob1_AssessJob5  1.796546e+06
# 281           rel_agg_mean_CompanySize_AssessBenefits2  1.795560e+06
# 282                             sum_answer_Methodology  1.794334e+06
# 283         agg_std_Country_ohe_LanguageWorkedWith_PHP  1.781300e+06
# 284                                     te_CheckInCode  1.781194e+06
# 285                                te_EducationParents  1.766730e+06
# 286       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.758613e+06
# 287                      agg_std_SalaryType_AssessJob4  1.749397e+06
# 288  te_CurrencySymbol__ohe_EducationTypes_Contribu...  1.749318e+06
# 289  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.736765e+06
# 290            rel_agg_mean_Employment_AssessBenefits2  1.733931e+06
# 291  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.730555e+06
# 292  te_Age__ohe_EducationTypes_Contributed_to_open...  1.727310e+06
# 293  rank_diff_JobContactPriorities_JobContactPrior...  1.721388e+06
# 294  te_SalaryType__ohe_RaceEthnicity_White_or_of_E...  1.720819e+06
# 295          rank_diff_AssessJob_AssessJob2_AssessJob5  1.715591e+06
# 296          rank_diff_AssessJob_AssessJob1_AssessJob2  1.715144e+06
# 297               diff_agg_mean_CompanySize_AssessJob5  1.697544e+06
# 298                   diff_agg_mean_Country_AssessJob5  1.695314e+06
# 299  rank_diff_AdsPriorities_AdsPriorities2_AdsPrio...  1.692966e+06

# %%
len(use_cols)
# Out:
# 2495

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 67009.81912294,  92135.5313852 ,  88839.76947468, ...,
#         87734.87153176,  82006.80647988, 116536.53579364])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
# sub_df.to_csv("../predict/024_col_shuffle_20186.csv", index=False)
