# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # SVD
    svd = TruncatedSVD(n_components=2)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 507), (11259, 506))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3573

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 22719.6	valid_1's rmse: 23058.4
# [200]	training's rmse: 20894.1	valid_1's rmse: 21683.2
# [300]	training's rmse: 20148.8	valid_1's rmse: 21248.7
# [400]	training's rmse: 19684.1	valid_1's rmse: 21040
# [500]	training's rmse: 19344.3	valid_1's rmse: 20893
# [600]	training's rmse: 19044.7	valid_1's rmse: 20794.9
# [700]	training's rmse: 18792.1	valid_1's rmse: 20739.5
# [800]	training's rmse: 18540.5	valid_1's rmse: 20689.8
# [900]	training's rmse: 18327.5	valid_1's rmse: 20653.5
# [1000]	training's rmse: 18120.1	valid_1's rmse: 20611.7
# [1100]	training's rmse: 17936.5	valid_1's rmse: 20585.5
# [1200]	training's rmse: 17753.9	valid_1's rmse: 20551.7
# [1300]	training's rmse: 17583.2	valid_1's rmse: 20528.4
# [1400]	training's rmse: 17422.5	valid_1's rmse: 20506.6
# [1500]	training's rmse: 17240.9	valid_1's rmse: 20505.9
# [1600]	training's rmse: 17085.6	valid_1's rmse: 20486.7
# [1700]	training's rmse: 16926.5	valid_1's rmse: 20469.8
# [1800]	training's rmse: 16755.1	valid_1's rmse: 20459.6
# [1900]	training's rmse: 16615.8	valid_1's rmse: 20453.5
# [2000]	training's rmse: 16468.1	valid_1's rmse: 20443.7
# [2100]	training's rmse: 16318.9	valid_1's rmse: 20434.1
# [2200]	training's rmse: 16185.5	valid_1's rmse: 20427.2
# [2300]	training's rmse: 16051.5	valid_1's rmse: 20434
# Early stopping, best iteration is:
# [2229]	training's rmse: 16153.7	valid_1's rmse: 20423.8
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 22662.3	valid_1's rmse: 23262.2
# [200]	training's rmse: 20867	valid_1's rmse: 21745.8
# [300]	training's rmse: 20146.1	valid_1's rmse: 21234.2
# [400]	training's rmse: 19701	valid_1's rmse: 20994
# [500]	training's rmse: 19353	valid_1's rmse: 20837.1
# [600]	training's rmse: 19064	valid_1's rmse: 20728.3
# [700]	training's rmse: 18812.8	valid_1's rmse: 20645
# [800]	training's rmse: 18593.8	valid_1's rmse: 20575.4
# [900]	training's rmse: 18386.3	valid_1's rmse: 20522.4
# [1000]	training's rmse: 18175.3	valid_1's rmse: 20463.8
# [1100]	training's rmse: 18001.1	valid_1's rmse: 20427.9
# [1200]	training's rmse: 17812	valid_1's rmse: 20376.3
# [1300]	training's rmse: 17649.8	valid_1's rmse: 20338.5
# [1400]	training's rmse: 17481.6	valid_1's rmse: 20313.9
# [1500]	training's rmse: 17319.2	valid_1's rmse: 20293.9
# [1600]	training's rmse: 17163.9	valid_1's rmse: 20279.3
# [1700]	training's rmse: 17002.3	valid_1's rmse: 20258.6
# [1800]	training's rmse: 16862.5	valid_1's rmse: 20239.1
# [1900]	training's rmse: 16714.9	valid_1's rmse: 20221
# [2000]	training's rmse: 16579.2	valid_1's rmse: 20213.5
# [2100]	training's rmse: 16439.8	valid_1's rmse: 20210.7
# [2200]	training's rmse: 16310.1	valid_1's rmse: 20196.9
# [2300]	training's rmse: 16164.7	valid_1's rmse: 20187
# [2400]	training's rmse: 16036.6	valid_1's rmse: 20182.3
# [2500]	training's rmse: 15889.9	valid_1's rmse: 20162.8
# [2600]	training's rmse: 15752	valid_1's rmse: 20153.4
# [2700]	training's rmse: 15627.5	valid_1's rmse: 20145.9
# [2800]	training's rmse: 15500.8	valid_1's rmse: 20135.3
# [2900]	training's rmse: 15369.7	valid_1's rmse: 20135.3
# Early stopping, best iteration is:
# [2824]	training's rmse: 15466.5	valid_1's rmse: 20131
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 22757	valid_1's rmse: 23076.1
# [200]	training's rmse: 20905	valid_1's rmse: 21562.8
# [300]	training's rmse: 20158.3	valid_1's rmse: 21160.1
# [400]	training's rmse: 19675.8	valid_1's rmse: 20954.5
# [500]	training's rmse: 19323.6	valid_1's rmse: 20852.8
# [600]	training's rmse: 19029.8	valid_1's rmse: 20777.6
# [700]	training's rmse: 18788	valid_1's rmse: 20726.3
# [800]	training's rmse: 18553.8	valid_1's rmse: 20683.1
# [900]	training's rmse: 18331.6	valid_1's rmse: 20639.7
# [1000]	training's rmse: 18131.1	valid_1's rmse: 20614.5
# [1100]	training's rmse: 17942.3	valid_1's rmse: 20592.6
# [1200]	training's rmse: 17753.5	valid_1's rmse: 20564
# [1300]	training's rmse: 17572	valid_1's rmse: 20542.8
# [1400]	training's rmse: 17394.3	valid_1's rmse: 20528.5
# [1500]	training's rmse: 17239	valid_1's rmse: 20506.2
# [1600]	training's rmse: 17088.4	valid_1's rmse: 20495.1
# [1700]	training's rmse: 16924	valid_1's rmse: 20487.6
# [1800]	training's rmse: 16774.8	valid_1's rmse: 20480.2
# [1900]	training's rmse: 16629.9	valid_1's rmse: 20477.4
# [2000]	training's rmse: 16485.4	valid_1's rmse: 20476.7
# Early stopping, best iteration is:
# [1974]	training's rmse: 16522.5	valid_1's rmse: 20470.4
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 22703.9	valid_1's rmse: 23082.1
# [200]	training's rmse: 20890.7	valid_1's rmse: 21643.7
# [300]	training's rmse: 20134.6	valid_1's rmse: 21205.6
# [400]	training's rmse: 19673.8	valid_1's rmse: 20982.1
# [500]	training's rmse: 19332.1	valid_1's rmse: 20840.1
# [600]	training's rmse: 19052.4	valid_1's rmse: 20743.5
# [700]	training's rmse: 18823.1	valid_1's rmse: 20664.1
# [800]	training's rmse: 18588.7	valid_1's rmse: 20603.1
# [900]	training's rmse: 18396.7	valid_1's rmse: 20552.1
# [1000]	training's rmse: 18206.7	valid_1's rmse: 20496.1
# [1100]	training's rmse: 18003.2	valid_1's rmse: 20443.3
# [1200]	training's rmse: 17819.8	valid_1's rmse: 20414.2
# [1300]	training's rmse: 17643.2	valid_1's rmse: 20378.6
# [1400]	training's rmse: 17477.4	valid_1's rmse: 20354.7
# [1500]	training's rmse: 17310.5	valid_1's rmse: 20326.2
# [1600]	training's rmse: 17155.6	valid_1's rmse: 20303.6
# [1700]	training's rmse: 16994.6	valid_1's rmse: 20289.9
# [1800]	training's rmse: 16854.2	valid_1's rmse: 20266.8
# [1900]	training's rmse: 16700.8	valid_1's rmse: 20250.6
# [2000]	training's rmse: 16567.1	valid_1's rmse: 20230.6
# [2100]	training's rmse: 16421.2	valid_1's rmse: 20229.7
# [2200]	training's rmse: 16283.7	valid_1's rmse: 20214.7
# [2300]	training's rmse: 16153	valid_1's rmse: 20205.5
# [2400]	training's rmse: 16026.4	valid_1's rmse: 20195.7
# [2500]	training's rmse: 15893.6	valid_1's rmse: 20189.4
# [2600]	training's rmse: 15764.5	valid_1's rmse: 20177.6
# [2700]	training's rmse: 15637.7	valid_1's rmse: 20171.9
# [2800]	training's rmse: 15520.5	valid_1's rmse: 20171.1
# Early stopping, best iteration is:
# [2744]	training's rmse: 15586.3	valid_1's rmse: 20166.2
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 22743.6	valid_1's rmse: 23021.5
# [200]	training's rmse: 20946.8	valid_1's rmse: 21357.2
# [300]	training's rmse: 20225.2	valid_1's rmse: 20860
# [400]	training's rmse: 19776.6	valid_1's rmse: 20602.3
# [500]	training's rmse: 19440.9	valid_1's rmse: 20456
# [600]	training's rmse: 19131	valid_1's rmse: 20341.2
# [700]	training's rmse: 18869.5	valid_1's rmse: 20260.3
# [800]	training's rmse: 18642.7	valid_1's rmse: 20211.7
# [900]	training's rmse: 18419.1	valid_1's rmse: 20151.4
# [1000]	training's rmse: 18216.4	valid_1's rmse: 20105.8
# [1100]	training's rmse: 18033.1	valid_1's rmse: 20073.9
# [1200]	training's rmse: 17873.6	valid_1's rmse: 20034.6
# [1300]	training's rmse: 17703.8	valid_1's rmse: 20015
# [1400]	training's rmse: 17539.5	valid_1's rmse: 19990.8
# [1500]	training's rmse: 17380.3	valid_1's rmse: 19956.7
# [1600]	training's rmse: 17216	valid_1's rmse: 19938.2
# [1700]	training's rmse: 17068.4	valid_1's rmse: 19925.6
# [1800]	training's rmse: 16935	valid_1's rmse: 19914.6
# [1900]	training's rmse: 16792.3	valid_1's rmse: 19902.6
# [2000]	training's rmse: 16648.4	valid_1's rmse: 19887.6
# [2100]	training's rmse: 16515.1	valid_1's rmse: 19877.3
# [2200]	training's rmse: 16373.4	valid_1's rmse: 19866.1
# [2300]	training's rmse: 16238.8	valid_1's rmse: 19863.6
# [2400]	training's rmse: 16114.2	valid_1's rmse: 19847.4
# [2500]	training's rmse: 15985.3	valid_1's rmse: 19839.3
# [2600]	training's rmse: 15865.6	valid_1's rmse: 19833.7
# Early stopping, best iteration is:
# [2596]	training's rmse: 15872.5	valid_1's rmse: 19832.6

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20206.12839792405

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                      te_Country__ohe_DevType_Student  5.553646e+08
# 1                          te_Country__YearsCodingProf  5.214864e+08
# 2                                      te_Country__Age  3.637578e+08
# 3                               te_Country__Employment  2.616970e+08
# 4               te_Country__ohe_LanguageWorkedWith_PHP  2.515998e+08
# 5                               te_Country__Dependents  2.468676e+08
# 6                              te_Country__YearsCoding  2.406878e+08
# 7                   te_YearsCodingProf__CurrencySymbol  2.264621e+08
# 8                       te_YearsCodingProf__MilitaryUS  1.582847e+08
# 9                           te_Country__CurrencySymbol  1.493069e+08
# 10                        te_YearsCodingProf__Currency  1.291971e+08
# 11                      te_YearsCodingProf__SalaryType  1.176608e+08
# 12                              te_Country__SalaryType  1.169761e+08
# 13   te_Country__ohe_EducationTypes_Contributed_to_...  1.119547e+08
# 14                             te_Country__CompanySize  1.080059e+08
# 15                      te_Country__CareerSatisfaction  1.026529e+08
# 16   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  7.955644e+07
# 17                         te_Country__OperatingSystem  7.575198e+07
# 18                       te_Employment__CurrencySymbol  6.828323e+07
# 19                  te_SalaryType__ohe_DevType_Student  6.787516e+07
# 20              te_CurrencySymbol__ohe_DevType_Student  6.511643e+07
# 21                         te_Country__FormalEducation  6.129755e+07
# 22                              te_CurrencySymbol__Age  5.750685e+07
# 23               te_CareerSatisfaction__CurrencySymbol  5.462412e+07
# 24                     te_CompanySize__YearsCodingProf  5.445963e+07
# 25                       te_SalaryType__CurrencySymbol  5.141900e+07
# 26                   te_Country__ohe_Methodology_Agile  4.922763e+07
# 27   agg_mean_Country_ohe_EducationTypes_Contribute...  4.380052e+07
# 28                           te_Employment__SalaryType  4.208090e+07
# 29                 te_YearsCodingProf__OperatingSystem  4.197653e+07
# 30                            te_YearsCoding__Currency  3.722342e+07
# 31   agg_mean_YearsCodingProf_ohe_CommunicationTool...  3.669008e+07
# 32   te_YearsCodingProf__ohe_CommunicationTools_Con...  3.626750e+07
# 33                     te_YearsCoding__OperatingSystem  3.535069e+07
# 34                          te_YearsCoding__MilitaryUS  3.377903e+07
# 35                 te_FormalEducation__YearsCodingProf  3.221025e+07
# 36                      te_YearsCoding__CurrencySymbol  2.981840e+07
# 37   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.916242e+07
# 38                       te_CurrencySymbol__MilitaryUS  2.881176e+07
# 39                             te_Employment__Currency  2.853467e+07
# 40                                  te_Employment__Age  2.795046e+07
# 41             te_YearsCodingProf__ohe_DevType_Student  2.736677e+07
# 42      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  2.685825e+07
# 43      agg_std_Country_ohe_LanguageDesireNextYear_PHP  2.370963e+07
# 44   agg_std_Country_ohe_CommunicationTools_Confluence  2.136332e+07
# 45              te_YearsCodingProf__CareerSatisfaction  2.032157e+07
# 46                      te_Employment__YearsCodingProf  1.850955e+07
# 47                     te_CompanySize__OperatingSystem  1.799217e+07
# 48                    te_Currency__ohe_DevType_Student  1.742801e+07
# 49   agg_mean_YearsCodingProf_ohe_EducationTypes_Co...  1.739858e+07
# 50               te_CompanySize__ohe_Methodology_Agile  1.666825e+07
# 51                     te_YearsCoding__YearsCodingProf  1.556040e+07
# 52                            svd_CommunicationTools_0  1.516385e+07
# 53                             te_YearsCodingProf__Age  1.491587e+07
# 54   te_CompanySize__ohe_CommunicationTools_Confluence  1.473016e+07
# 55                  te_CurrencySymbol__OperatingSystem  1.467587e+07
# 56                                       te_LastNewJob  1.458412e+07
# 57                                te_Country__Currency  1.451452e+07
# 58                                  te_SalaryType__Age  1.433456e+07
# 59                      te_FormalEducation__SalaryType  1.405923e+07
# 60                           te_Employment__MilitaryUS  1.396082e+07
# 61                  te_Employment__ohe_DevType_Student  1.386713e+07
# 62      te_Employment__ohe_DevType_Engineering_manager  1.253128e+07
# 63                  te_CompanySize__CareerSatisfaction  1.238715e+07
# 64                      te_Employment__OperatingSystem  1.212717e+07
# 65        agg_mean_YearsCodingProf_ohe_DevType_Student  1.212311e+07
# 66   te_CurrencySymbol__ohe_EducationTypes_Contribu...  1.170515e+07
# 67                  te_YearsCoding__CareerSatisfaction  1.165627e+07
# 68                                 te_CompanySize__Age  1.117270e+07
# 69                          te_Employment__YearsCoding  1.115006e+07
# 70                      te_Employment__FormalEducation  1.083387e+07
# 71   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.043267e+07
# 72                          te_Employment__CompanySize  1.008222e+07
# 73                      te_CompanySize__CurrencySymbol  1.003606e+07
# 74                 agg_mean_Employment_AssessBenefits2  9.974826e+06
# 75   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  9.828605e+06
# 76                te_Employment__ohe_Methodology_Agile  9.758785e+06
# 77                                          te_Country  9.672202e+06
# 78   te_CareerSatisfaction__ohe_DevType_Engineering...  9.657952e+06
# 79                             te_FormalEducation__Age  9.645733e+06
# 80   te_CareerSatisfaction__ohe_CommunicationTools_...  9.349578e+06
# 81                              te_Country__MilitaryUS  9.299553e+06
# 82                                    te_Currency__Age  9.259463e+06
# 83           te_YearsCodingProf__ohe_Methodology_Agile  9.255230e+06
# 84                  te_FormalEducation__CurrencySymbol  9.005725e+06
# 85                          te_CareerSatisfaction__Age  8.911756e+06
# 86   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  8.837766e+06
# 87            te_CurrencySymbol__ohe_Methodology_Agile  8.837697e+06
# 88                                 te_YearsCoding__Age  8.449137e+06
# 89     te_CompanySize__ohe_DevType_Engineering_manager  8.325206e+06
# 90                      te_YearsCodingProf__Dependents  8.305250e+06
# 91              te_CareerSatisfaction__OperatingSystem  8.173967e+06
# 92   te_CurrencySymbol__ohe_CommunicationTools_Conf...  7.887159e+06
# 93    te_Employment__ohe_CommunicationTools_Confluence  7.675625e+06
# 94                         te_CompanySize__YearsCoding  7.587507e+06
# 95       te_Country__ohe_CommunicationTools_Confluence  7.209370e+06
# 96   te_YearsCoding__ohe_CommunicationTools_Confluence  7.100881e+06
# 97                 te_FormalEducation__OperatingSystem  6.931485e+06
# 98   te_ohe_DevType_Engineering_manager__ohe_DevTyp...  6.907858e+06
# 99           te_Employment__ohe_LanguageWorkedWith_PHP  6.900756e+06
# 100        agg_std_YearsCodingProf_ohe_DevType_Student  6.567531e+06
# 101  diff_agg_mean_CompanySize_ohe_DevType_Engineer...  6.452941e+06
# 102                        te_Age__ohe_DevType_Student  6.386267e+06
# 103                            te_Currency__SalaryType  6.262217e+06
# 104             agg_mean_Country_ohe_Methodology_Agile  6.165504e+06
# 105          te_FormalEducation__ohe_Methodology_Agile  6.156195e+06
# 106                  te_Employment__CareerSatisfaction  6.130865e+06
# 107                te_YearsCoding__ohe_DevType_Student  6.123904e+06
# 108                                 te_Age__MilitaryUS  6.058563e+06
# 109                           svd_LanguageWorkedWith_1  5.832245e+06
# 110                te_CompanySize__ohe_DevType_Student  5.814380e+06
# 111                         te_CompanySize__Dependents  5.708527e+06
# 112             diff_agg_mean_Currency_AssessBenefits2  5.668605e+06
# 113   diff_agg_mean_CurrencySymbol_ohe_DevType_Student  5.636455e+06
# 114          diff_agg_mean_CompanySize_AssessBenefits2  5.484740e+06
# 115        te_Country__ohe_DevType_Engineering_manager  5.459107e+06
# 116               rel_agg_mean_Country_AssessBenefits2  5.422659e+06
# 117                     te_SalaryType__OperatingSystem  5.361804e+06
# 118  te_CompanySize__ohe_EducationTypes_Contributed...  5.262561e+06
# 119                         te_CompanySize__SalaryType  5.259654e+06
# 120                                  svd_Methodology_0  5.231737e+06
# 121        rel_agg_mean_SalaryType_ohe_DevType_Student  5.172434e+06
# 122              rel_agg_mean_Currency_AssessBenefits2  4.995915e+06
# 123    agg_mean_Employment_ohe_CommunicationTools_Jira  4.859742e+06
# 124                         te_YearsCoding__SalaryType  4.834112e+06
# 125             te_FormalEducation__CareerSatisfaction  4.808948e+06
# 126  agg_mean_YearsCodingProf_ohe_RaceEthnicity_Whi...  4.645855e+06
# 127          te_SalaryType__ohe_LanguageWorkedWith_PHP  4.626793e+06
# 128                            te_OperatingSystem__Age  4.597347e+06
# 129  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  4.539429e+06
# 130                    te_FormalEducation__CompanySize  4.498112e+06
# 131              te_YearsCoding__ohe_Methodology_Agile  4.485522e+06
# 132  te_Employment__ohe_EducationTypes_Contributed_...  4.484879e+06
# 133              diff_agg_mean_Country_AssessBenefits2  4.482025e+06
# 134        rel_agg_mean_NumberMonitors_AssessBenefits2  4.480944e+06
# 135   te_SalaryType__ohe_CommunicationTools_Confluence  4.432649e+06
# 136         te_YearsCoding__ohe_LanguageWorkedWith_PHP  4.400038e+06
# 137                 te_Currency__ohe_Methodology_Agile  4.330780e+06
# 138                          ohe_LanguageWorkedWith_Go  4.276245e+06
# 139  te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  4.271384e+06
# 140                               svd_VersionControl_1  4.262592e+06
# 141     te_Currency__ohe_CommunicationTools_Confluence  4.229795e+06
# 142                       svd_DatabaseDesireNextYear_1  4.206227e+06
# 143  te_FormalEducation__ohe_EducationTypes_Contrib...  4.153211e+06
# 144               te_SalaryType__ohe_Methodology_Agile  4.135097e+06
# 145            te_FormalEducation__ohe_DevType_Student  4.079196e+06
# 146        rel_agg_mean_CurrencySymbol_AssessBenefits2  4.069047e+06
# 147                           svd_DatabaseWorkedWith_1  4.067152e+06
# 148  te_FormalEducation__ohe_CommunicationTools_Con...  4.063017e+06
# 149     te_FormalEducation__ohe_LanguageWorkedWith_PHP  4.046827e+06
# 150                       te_Currency__OperatingSystem  4.046080e+06
# 151  te_OperatingSystem__ohe_DevType_Engineering_ma...  4.043707e+06
# 152          agg_mean_Employment_ohe_Methodology_Agile  4.022338e+06
# 153         te_CompanySize__ohe_LanguageWorkedWith_PHP  4.005369e+06
# 154      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  3.933733e+06
# 155                                        te_UpdateCV  3.861797e+06
# 156                      te_CurrencySymbol__Dependents  3.857405e+06
# 157                               ohe_DevType_Designer  3.837643e+06
# 158                           te_CompanySize__Currency  3.823977e+06
# 159          diff_agg_mean_Country_ohe_DevType_Student  3.821020e+06
# 160  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  3.710541e+06
# 161  te_FormalEducation__ohe_DevType_Engineering_ma...  3.653264e+06
# 162                  te_CareerSatisfaction__SalaryType  3.652498e+06
# 163  agg_mean_Employment_ohe_CommunicationTools_Con...  3.639449e+06
# 164  te_ohe_CommunicationTools_Confluence__ohe_Lang...  3.612176e+06
# 165                 te_Age__ohe_LanguageWorkedWith_PHP  3.582551e+06
# 166         te_CareerSatisfaction__ohe_DevType_Student  3.557570e+06
# 167                          te_Employment__Dependents  3.549933e+06
# 168                                JobEmailPriorities5  3.541784e+06
# 169  diff_agg_mean_YearsCodingProf_ohe_DevType_Student  3.505705e+06
# 170       diff_agg_mean_NumberMonitors_AssessBenefits2  3.397611e+06
# 171                              te_HypotheticalTools2  3.392676e+06
# 172                       te_FormalEducation__Currency  3.352305e+06
# 173  te_CareerSatisfaction__ohe_EducationTypes_Cont...  3.333833e+06
# 174  agg_mean_Country_ohe_CommunicationTools_Conflu...  3.313578e+06
# 175                    agg_std_Country_AssessBenefits2  3.274127e+06
# 176                      te_Age__ohe_Methodology_Agile  3.260712e+06
# 177  diff_agg_mean_Dependents_ohe_EducationTypes_Pa...  3.144897e+06
# 178  agg_std_Employment_ohe_CommunicationTools_Conf...  3.129810e+06
# 179                       ohe_DatabaseWorkedWith_Redis  3.095118e+06
# 180       rel_agg_mean_JobSatisfaction_AssessBenefits2  3.075627e+06
# 181  te_CurrencySymbol__ohe_DevType_Engineering_man...  3.075000e+06
# 182  agg_mean_YearsCodingProf_ohe_LanguageDesireNex...  3.053653e+06
# 183                              JobContactPriorities1  3.031636e+06
# 184                                        te_WakeTime  2.964437e+06
# 185       rel_agg_mean_FormalEducation_AssessBenefits2  2.960574e+06
# 186                                  te_CurrencySymbol  2.953641e+06
# 187           rel_agg_mean_CompanySize_AssessBenefits2  2.935254e+06
# 188                                   ohe_IDE_NetBeans  2.894235e+06
# 189                                        AssessJob10  2.861635e+06
# 190  diff_agg_mean_ohe_DevType_Engineering_manager_...  2.857192e+06
# 191  te_OperatingSystem__ohe_CommunicationTools_Con...  2.855483e+06
# 192       agg_mean_Age_ohe_DevType_Engineering_manager  2.785765e+06
# 193                           svd_DatabaseWorkedWith_0  2.729786e+06
# 194                         ohe_LanguageWorkedWith_CSS  2.687130e+06
# 195  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  2.674596e+06
# 196  diff_agg_mean_Employment_ohe_EducationTypes_Pa...  2.652410e+06
# 197                                      svd_DevType_0  2.618414e+06
# 198                              JobContactPriorities4  2.617570e+06
# 199            agg_mean_Employment_ohe_DevType_Student  2.616557e+06
# 200               te_Dependents__ohe_Methodology_Agile  2.607889e+06
# 201  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  2.601218e+06
# 202        ohe_DevType_Educator_or_academic_researcher  2.590376e+06
# 203  te_Employment__ohe_RaceEthnicity_White_or_of_E...  2.584622e+06
# 204  te_Age__ohe_EducationTypes_Contributed_to_open...  2.536500e+06
# 205  diff_agg_mean_Country_ohe_RaceEthnicity_White_...  2.529538e+06
# 206                                    AssessBenefits1  2.517938e+06
# 207          te_Age__ohe_CommunicationTools_Confluence  2.504269e+06
# 208  rel_agg_mean_ohe_DevType_Engineering_manager_o...  2.382853e+06
# 209                                          svd_IDE_1  2.367315e+06
# 210       diff_agg_mean_UndergradMajor_AssessBenefits2  2.320812e+06
# 211  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  2.319662e+06
# 212      diff_agg_mean_FormalEducation_AssessBenefits2  2.247509e+06
# 213  agg_std_YearsCodingProf_ohe_EducationTypes_Con...  2.220935e+06
# 214                     ohe_FrameworkWorkedWith_Hadoop  2.215537e+06
# 215                    ohe_DevType_Front_end_developer  2.209782e+06
# 216                              JobContactPriorities3  2.201741e+06
# 217  agg_std_SalaryType_ohe_CommunicationTools_Conf...  2.197826e+06
# 218  te_ohe_CommunicationTools_Confluence__ohe_Meth...  2.186572e+06
# 219                      sum_answer_DatabaseWorkedWith  2.159557e+06
# 220       diff_agg_mean_CurrencySymbol_AssessBenefits2  2.140403e+06
# 221                         agg_std_Country_AssessJob8  2.132765e+06
# 222  te_YearsCoding__ohe_EducationTypes_Contributed...  2.128003e+06
# 223           diff_agg_mean_SalaryType_AssessBenefits2  2.123104e+06
# 224  agg_std_Employment_ohe_DevType_Engineering_man...  2.106164e+06
# 225      te_ohe_DevType_Student__ohe_Methodology_Agile  2.103355e+06
# 226              agg_std_Country_ohe_Methodology_Agile  2.101448e+06
# 227                       ohe_PlatformWorkedWith_Azure  2.098576e+06
# 228  agg_std_Country_ohe_EducationTypes_Contributed...  2.089563e+06
# 229                    te_FormalEducation__YearsCoding  2.087930e+06
# 230                             svd_HackathonReasons_1  2.077054e+06
# 231                                        te_Exercise  2.074337e+06
# 232                       svd_LanguageDesireNextYear_0  2.046993e+06
# 233                               svd_EducationTypes_0  2.024637e+06
# 234      diff_agg_mean_JobSatisfaction_AssessBenefits2  2.020815e+06
# 235  te_Age__ohe_RaceEthnicity_White_or_of_European...  2.017828e+06
# 236  diff_agg_mean_TimeFullyProductive_AssessBenefits2  1.986001e+06
# 237                agg_std_Country_ohe_DevType_Student  1.984015e+06
# 238                                         AssessJob6  1.979852e+06
# 239     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.978651e+06
# 240  agg_mean_HopeFiveYears_ohe_EducationTypes_Cont...  1.978002e+06
# 241                    te_CareerSatisfaction__Currency  1.971535e+06
# 242                                te_EducationParents  1.970064e+06
# 243                   rel_agg_mean_Age_AssessBenefits2  1.950536e+06
# 244                       svd_DatabaseDesireNextYear_0  1.932496e+06
# 245  diff_agg_mean_TimeFullyProductive_ohe_DevType_...  1.919916e+06
# 246  te_SalaryType__ohe_RaceEthnicity_White_or_of_E...  1.907171e+06
# 247                                JobEmailPriorities6  1.903788e+06
# 248            rel_agg_mean_SalaryType_AssessBenefits2  1.879380e+06
# 249  rel_agg_mean_Country_ohe_RaceEthnicity_White_o...  1.876226e+06
# 250                                      te_Employment  1.871531e+06
# 251                     te_OperatingSystem__Dependents  1.859539e+06
# 252                          svd_FrameworkWorkedWith_1  1.852946e+06
# 253       te_CareerSatisfaction__ohe_Methodology_Agile  1.848291e+06
# 254       rel_agg_mean_OperatingSystem_AssessBenefits2  1.838494e+06
# 255           diff_agg_mean_MilitaryUS_AssessBenefits2  1.827600e+06
# 256          diff_agg_mean_YearsCoding_AssessBenefits2  1.822502e+06
# 257            rel_agg_mean_JobSatisfaction_AssessJob5  1.807092e+06
# 258                 ohe_DevType_Database_administrator  1.782165e+06
# 259          te_OperatingSystem__ohe_Methodology_Agile  1.750875e+06
# 260                          te_SalaryType__Dependents  1.727221e+06
# 261                   diff_agg_mean_Country_AssessJob5  1.714743e+06
# 262  diff_agg_mean_Country_ohe_EducationTypes_Contr...  1.711889e+06
# 263  diff_agg_mean_Country_ohe_LanguageDesireNextYe...  1.693878e+06
# 264  diff_agg_mean_AgreeDisagree3_ohe_ErgonomicDevi...  1.688076e+06
# 265  agg_mean_HopeFiveYears_ohe_DevType_Engineering...  1.677615e+06
# 266  agg_std_Employment_ohe_ErgonomicDevices_Standi...  1.676567e+06
# 267                       svd_LanguageDesireNextYear_1  1.659184e+06
# 268                                     te_CheckInCode  1.653456e+06
# 269                                  ohe_IDE_Notepad__  1.646589e+06
# 270                      te_StackOverflowJobsRecommend  1.642178e+06
# 271                                         AssessJob1  1.639205e+06
# 272           diff_agg_mean_JobSatisfaction_AssessJob5  1.634478e+06
# 273  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.634046e+06
# 274             agg_std_SalaryType_ohe_DevType_Student  1.623030e+06
# 275                                      svd_DevType_1  1.600058e+06
# 276                                    AssessBenefits3  1.590832e+06
# 277        diff_agg_mean_CareerSatisfaction_AssessJob5  1.582159e+06
# 278                        te_Currency__CurrencySymbol  1.578367e+06
# 279                      ohe_LanguageDesireNextYear_F_  1.573116e+06
# 280           diff_agg_mean_Dependents_AssessBenefits2  1.560454e+06
# 281  rel_agg_mean_ohe_DevType_Engineering_manager_o...  1.555676e+06
# 282               ohe_DatabaseWorkedWith_Elasticsearch  1.551715e+06
# 283    rel_agg_mean_CurrencySymbol_ohe_DevType_Student  1.550053e+06
# 284           rel_agg_mean_YearsCoding_AssessBenefits2  1.542009e+06
# 285                           svd_LanguageWorkedWith_0  1.541725e+06
# 286                rel_agg_mean_CompanySize_AssessJob5  1.526181e+06
# 287                  diff_agg_mean_Age_AssessBenefits2  1.524790e+06
# 288                           svd_PlatformWorkedWith_1  1.522027e+06
# 289                                     AdsPriorities2  1.518835e+06
# 290                  te_CareerSatisfaction__Dependents  1.498789e+06
# 291                             svd_AdBlockerReasons_1  1.490016e+06
# 292      diff_agg_mean_YearsCodingProf_AssessBenefits2  1.478590e+06
# 293                 ohe_PlatformDesireNextYear_Android  1.476786e+06
# 294                                    te_HoursOutside  1.470881e+06
# 295  diff_agg_mean_ohe_LanguageDesireNextYear_PHP_o...  1.465519e+06
# 296           ohe_Methodology_Extreme_programming__XP_  1.465048e+06
# 297             ohe_DatabaseWorkedWith_Amazon_Redshift  1.458576e+06
# 298   rel_agg_mean_TimeFullyProductive_AssessBenefits2  1.456696e+06
# 299         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.452938e+06

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 68411.88130743,  92661.57205548,  84165.54809898, ...,
#         87668.37705269,  84250.84739589, 119990.25627675])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/018_poisson_20206.csv", index=False)
