# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Preprocess

# %%
def preprocess(train_df, test_df):
    
    ###########################
    # Functions of preprocess
    ###########################
    def get_multi_cat_cols(train_df):
        tmp = train_df.iloc[:1000]
        multi_cols = []
        for c in train_df.columns:
            sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
            if sep_num > 10:
                multi_cols.append(c)
        return multi_cols

    def add_rank_feature(df):
        rank_prefix_list = [
            "AssessBenefits",
            "AssessJob",
            "JobContactPriorities",
            "JobEmailPriorities",
            "AdsPriorities",
        ]
        for prefix in tqdm(rank_prefix_list):
            rank_cols = [c for c in df.columns if prefix in c]
            col_pairs = itertools.combinations(rank_cols, 2)
            for col_a, col_b in col_pairs:
                df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
        return df

    def get_basic_importance_cols(use_num=50):
        # basicなモデルのimportanceを読み込み
        importance_df = pd.read_csv("../data/importance/003_importance.csv")
        imp_feats = importance_df["feature"].iloc[:use_num].tolist()
        return imp_feats

    def make_agg_feature(train_df, test_df):
        imp_feats = get_basic_importance_cols(use_num=50)
        imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
        imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
        print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
        #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
        all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
        for cat_col in tqdm(imp_cat_cols):
            for nume_col in imp_nume_cols:
                # one-hotは同じカテゴリの場合がある
                if cat_col == nume_col:
                    continue
                all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                    all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
                all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                    all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
                all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                    all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
                all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                    all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
                all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                    all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
                all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                    all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
        train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
        test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
        del all_df
        gc.collect()
        return train_df, test_df

    @feature_cache(reset=False)
    def target_encoding(train_df, test_df):
        te_cols = [c for c in train_df.columns if c in cat_cols]
        for c in tqdm(te_cols):
            new_col = "te_" + c
            train_df[new_col] = 0
            test_df[new_col] = 0
            for trn_idx, val_idx in fold_idx_list:
                mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
                train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
                test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
            train_df[new_col] = train_df[new_col].astype(np.float32)
            test_df[new_col] = test_df[new_col].astype(np.float32)
        return train_df, test_df

    @feature_cache(reset=False)
    def multiple_target_encoding(train_df, test_df):
         # multiple target encoding
        multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
        imp_feats = get_basic_importance_cols(use_num=30)
        multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
        combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

        for col_a, col_b in tqdm(combi_multi_te_cols):
            new_col = "te_" + col_a + "__" + col_b
            train_df[new_col] = 0
            test_df[new_col] = 0
            train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
            test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
            for trn_idx, val_idx in fold_idx_list:
                mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
                train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
                test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
            train_df[new_col] = train_df[new_col].astype(np.float32)
            test_df[new_col] = test_df[new_col].astype(np.float32)
            del train_df["tmp"], test_df["tmp"]
            gc.collect()
        return train_df, test_df   
    
    ################################
    # Columns infomation
    ################################
    original_cols = train_df.columns.tolist()
    multi_cat_cols = get_multi_cat_cols(train_df)

    nume_cols = [
        c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
        if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
    ]

    cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

    non_basic_nume_cols = []
    non_basic_cat_cols = []

    ################################
    #  Make feature
    ################################    
    
    # rank feature
    train_df = add_rank_feature(train_df)
    test_df = add_rank_feature(test_df)

    # multi -category encoding 
    for c in tqdm(multi_cat_cols):
        binarizer = MultiLabelBinarizer()
        train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
        test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
        train_arr = binarizer.fit_transform(train_multi_srs)
        test_arr = binarizer.transform(test_multi_srs)
        feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
        train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
        test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
        all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
        train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
        test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
        train_df = pd.concat([train_df, train_feat_df], axis=1)
        test_df = pd.concat([test_df, test_feat_df], axis=1)
        # ohe_featureはcategoryとnumerical両方として扱う
        nume_cols += feat_cols
        cat_cols += feat_cols
        # non_basic_nume_cols.append(f"sum_answer_{c}")
        # SVD
        svd = TruncatedSVD(n_components=2, random_state=2020)
        all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
        train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
        test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
    
    # simple category encoding
    for c in cat_cols:
        train_df[c], uniques = pd.factorize(train_df[c], sort=True)
        test_df[c] = uniques.get_indexer(test_df[c])
    
    # reduce memory
    # numerical cols
    for c in nume_cols:
        if train_df[c].nunique() > 1000:
            train_df[c] = train_df[c].astype(np.float32)
            test_df[c] = test_df[c].astype(np.float32)
        else:
            train_df[c] = train_df[c].astype(np.float16)
            test_df[c] = test_df[c].astype(np.float16)
    # category cols
    for c in cat_cols:
        if train_df[c].max() > 32767:
            train_df[c] = train_df[c].astype(np.int32)
            test_df[c] = test_df[c].astype(np.int32)
        else:
            train_df[c] = train_df[c].astype(np.int16)
            test_df[c] = test_df[c].astype(np.int16)
    
    # change columns name
    train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
    test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]
   
    # aggregate feature
    train_df, test_df = make_agg_feature(train_df, test_df)

    # make train/validation index list for target encoding
    folds = KFold(n_splits=5, random_state=2020, shuffle=True)
    fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]
    
    # target encoding
    train_df, test_df = target_encoding(train_df, test_df)

    # multiple category target encoding 
    train_df, test_df = multiple_target_encoding(train_df, test_df)
    
    # make use columns list
    use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
    print(len(use_cols))
    
    return train_df, test_df, use_cols, fold_idx_list

# %% [markdown]
# ## Training

# %%
def train(train_df, test_df, use_cols, fold_idx_list):

    lgb_params = {
                'objective': 'poisson',
                "metric": "rmse",
                "verbosity": -1,
                "boosting": "gbdt",
                'learning_rate': 0.05,
                'num_leaves': 64,
                'min_data_in_leaf': 80, 
                'max_depth': 4,
                "bagging_freq": 5,
                "bagging_fraction": 0.8,
                "lambda_l1": 0.5,
                "lambda_l2": 0.5,
                "feature_fraction": 0.1,
                "seed": 2020,
                "num_threads": -1,
                "max_bins": 30
    }
    def feature_selection(train_df, use_cols, n_features=1000):
        df = train_df.sample(30000, random_state=2020)
        train_dataset = lgb.Dataset(
            df.loc[:, use_cols],
            label = df.loc[:, "Salary"]
        )
        model = lgb.train(
                    lgb_params,
                    train_dataset,
                    2000,
                    valid_sets = [train_dataset],
                    verbose_eval=200,
                    early_stopping_rounds = None,
        )
        imp_df = pd.DataFrame()
        imp_df['feature'] = use_cols
        imp_df['gain'] = model.feature_importance(importance_type="gain")
        select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
        return select_features
    
    def lgb_train(train_df, fold_idx_list, use_cols, feature_select=None, seed=None, *args, **kwargs):
        importances = pd.DataFrame()
        oof_preds = np.zeros(len(train_df))
        models = []
        if feature_select is not None and isinstance(feature_select, int):
            _use_cols = feature_selection(train_df, use_cols, n_features=feature_select)
        else:
            _use_cols = use_cols.copy()
        _lgb_params = lgb_params.copy()
        if seed is not None:
            _lgb_params["seed"] = seed

        for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
            print(f"Fold {fold_i+1}")
            train_dataset = lgb.Dataset(
                train_df.loc[trn_idx, _use_cols],
                label = train_df.loc[trn_idx, "Salary"]
            )
            valid_dataset = lgb.Dataset(
                train_df.loc[val_idx, _use_cols],
                label = train_df.loc[val_idx, "Salary"]
            )
            model = lgb.train(
                        _lgb_params,
                        train_dataset,
                        30000,
                        valid_sets = [train_dataset, valid_dataset],
                        verbose_eval=500,
                        early_stopping_rounds = 500,
                        #feval = eval_f1,
                        #callbacks = [log_callback],
            )
            imp_df = pd.DataFrame()
            imp_df['feature'] = _use_cols
            imp_df['gain'] = model.feature_importance(importance_type="gain")
            importances = pd.concat([importances, imp_df], axis=0, sort=False)
            # oof predict
            oof_preds[val_idx] = model.predict(train_df.loc[val_idx, _use_cols])
            models.append(model)

        oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
        print(f"OOF Score: {oof_score}")
        return models, oof_preds, importances, oof_score, _use_cols
    
    training_list = [
        {
            "n_features": None,
            "seed": 2020,
            "weight": 0.2
        },
        {
            "n_features": None,
            "seed": 3020,
            "weight": 0.2
        },
        {
            "n_features": None,
            "seed": 4020,
            "weight": 0.2
        },
        {
            "n_features": None,
            "seed": 5020,
            "weight": 0.2
        },
        {
            "n_features": None,
            "seed": 6020,
            "weight": 0.2
        }    
    ]
    output_list = []
    for train_config in training_list: 
        _models, _oof_preds, _importances, _oof_score, _use_cols = \
            lgb_train(train_df, fold_idx_list, use_cols, **train_config)
        output_list.append(
            {
                "models": _models,
                "oof_preds": _oof_preds,
                "importances": _importances,
                "oof_score": _oof_score,
                "use_cols": _use_cols,
                "weight": train_config["weight"]
            }
        )
    # calc total oof score
    oof_preds = np.zeros(len(train_df))
    importance_list = []
    for output in output_list:
        oof_preds += output["oof_preds"] * output["weight"]
        importance_list.append(output["importances"])
    
    oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
    print(f"Total OOF Score: {oof_score}")    
    
    display(
        pd.concat(importance_list, axis=0).groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:50]
    )

    return train_df, test_df, output_list, oof_score

# %% [markdown]
# ## Prediction

# %%
def predict(test_df, output_list, oof_score):
    test_pred = np.zeros(len(test_df))
    for output in tqdm(output_list):
        models = output["models"]
        use_cols = output["use_cols"]
        weight = output["weight"]
        for model in models:
            test_pred += (model.predict(test_df[use_cols]) / len(models)) * weight
    
    # make submit file
    sub_df = pd.read_csv("../input/submit.csv")
    sub_df["Salary"] = test_pred
    sub_df.to_csv(f"../predict/{model_title}_{oof_score}.csv", index=False)

# %% [markdown]
# ## EndPoint

# %%
model_title = "039_seed_averaging"

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
train_df, test_df, use_cols, fold_idx_list = preprocess(train_df, test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))
# 2495

# %%
train_df, test_df, output_list, oof_score = train(train_df, test_df, use_cols, fold_idx_list)
# Out:
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19249.2	valid_1's rmse: 20820.9
# [1000]	training's rmse: 18010.4	valid_1's rmse: 20497
# [1500]	training's rmse: 17070.6	valid_1's rmse: 20349.8
# [2000]	training's rmse: 16288.7	valid_1's rmse: 20294.1
# [2500]	training's rmse: 15569.3	valid_1's rmse: 20242.6
# [3000]	training's rmse: 14908.8	valid_1's rmse: 20219.9
# [3500]	training's rmse: 14277.9	valid_1's rmse: 20215
# Early stopping, best iteration is:
# [3386]	training's rmse: 14415.1	valid_1's rmse: 20206.8
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19287.2	valid_1's rmse: 20823.7
# [1000]	training's rmse: 18069	valid_1's rmse: 20486.1
# [1500]	training's rmse: 17189.8	valid_1's rmse: 20344
# [2000]	training's rmse: 16394	valid_1's rmse: 20243.8
# [2500]	training's rmse: 15681.9	valid_1's rmse: 20207.5
# [3000]	training's rmse: 15009.5	valid_1's rmse: 20194.3
# [3500]	training's rmse: 14364.3	valid_1's rmse: 20177.7
# [4000]	training's rmse: 13767.2	valid_1's rmse: 20157.8
# [4500]	training's rmse: 13209.9	valid_1's rmse: 20142.5
# Early stopping, best iteration is:
# [4276]	training's rmse: 13467.3	valid_1's rmse: 20139.8
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19251.2	valid_1's rmse: 20841.6
# [1000]	training's rmse: 18050.4	valid_1's rmse: 20617.2
# [1500]	training's rmse: 17159.9	valid_1's rmse: 20512.9
# [2000]	training's rmse: 16400.7	valid_1's rmse: 20463.9
# [2500]	training's rmse: 15689.6	valid_1's rmse: 20460.5
# [3000]	training's rmse: 15021.8	valid_1's rmse: 20449.2
# [3500]	training's rmse: 14396.3	valid_1's rmse: 20445.3
# Early stopping, best iteration is:
# [3467]	training's rmse: 14435.8	valid_1's rmse: 20441.1
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19324.6	valid_1's rmse: 20862.4
# [1000]	training's rmse: 18094.4	valid_1's rmse: 20490.2
# [1500]	training's rmse: 17194.3	valid_1's rmse: 20339.4
# [2000]	training's rmse: 16409.8	valid_1's rmse: 20255.6
# [2500]	training's rmse: 15719.2	valid_1's rmse: 20208.8
# [3000]	training's rmse: 15070.7	valid_1's rmse: 20189.4
# [3500]	training's rmse: 14442	valid_1's rmse: 20173.6
# [4000]	training's rmse: 13835.2	valid_1's rmse: 20176.8
# Early stopping, best iteration is:
# [3753]	training's rmse: 14141	valid_1's rmse: 20159.7
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19359.2	valid_1's rmse: 20559.4
# [1000]	training's rmse: 18143.9	valid_1's rmse: 20237.6
# [1500]	training's rmse: 17281.8	valid_1's rmse: 20110.9
# [2000]	training's rmse: 16481.1	valid_1's rmse: 20046.4
# [2500]	training's rmse: 15782.8	valid_1's rmse: 20000.1
# [3000]	training's rmse: 15141	valid_1's rmse: 19984.9
# [3500]	training's rmse: 14506.9	valid_1's rmse: 19989.6
# Early stopping, best iteration is:
# [3072]	training's rmse: 15048	valid_1's rmse: 19981.7
# OOF Score: 20186.360716338484
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19259.7	valid_1's rmse: 20823.4
# [1000]	training's rmse: 18006.2	valid_1's rmse: 20508.9
# [1500]	training's rmse: 17108	valid_1's rmse: 20381
# [2000]	training's rmse: 16311.2	valid_1's rmse: 20303.3
# [2500]	training's rmse: 15579.1	valid_1's rmse: 20256.2
# [3000]	training's rmse: 14899.9	valid_1's rmse: 20237.7
# [3500]	training's rmse: 14272.8	valid_1's rmse: 20222.9
# Early stopping, best iteration is:
# [3322]	training's rmse: 14483	valid_1's rmse: 20218.6
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19290	valid_1's rmse: 20811.3
# [1000]	training's rmse: 18098.7	valid_1's rmse: 20423.8
# [1500]	training's rmse: 17226.3	valid_1's rmse: 20278.9
# [2000]	training's rmse: 16426.8	valid_1's rmse: 20215.2
# [2500]	training's rmse: 15722.9	valid_1's rmse: 20156.1
# [3000]	training's rmse: 15062.5	valid_1's rmse: 20131.4
# [3500]	training's rmse: 14425.3	valid_1's rmse: 20118.1
# Early stopping, best iteration is:
# [3221]	training's rmse: 14766.9	valid_1's rmse: 20109.4
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19238.4	valid_1's rmse: 20864.6
# [1000]	training's rmse: 18044.2	valid_1's rmse: 20616.9
# [1500]	training's rmse: 17144.5	valid_1's rmse: 20548.8
# [2000]	training's rmse: 16346.8	valid_1's rmse: 20520.1
# [2500]	training's rmse: 15639.2	valid_1's rmse: 20491.3
# [3000]	training's rmse: 14961.9	valid_1's rmse: 20482.6
# Early stopping, best iteration is:
# [2926]	training's rmse: 15065.5	valid_1's rmse: 20479
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19252	valid_1's rmse: 20865.2
# [1000]	training's rmse: 18046.6	valid_1's rmse: 20516.2
# [1500]	training's rmse: 17171.4	valid_1's rmse: 20359.9
# [2000]	training's rmse: 16399	valid_1's rmse: 20293.4
# [2500]	training's rmse: 15666.4	valid_1's rmse: 20245
# [3000]	training's rmse: 14995.2	valid_1's rmse: 20237.6
# [3500]	training's rmse: 14370.2	valid_1's rmse: 20218.4
# [4000]	training's rmse: 13794.4	valid_1's rmse: 20205.7
# Early stopping, best iteration is:
# [3829]	training's rmse: 13998.6	valid_1's rmse: 20200.4
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19366.4	valid_1's rmse: 20449.8
# [1000]	training's rmse: 18114.4	valid_1's rmse: 20132.9
# [1500]	training's rmse: 17222	valid_1's rmse: 20012.4
# [2000]	training's rmse: 16454.2	valid_1's rmse: 19931.6
# [2500]	training's rmse: 15746.4	valid_1's rmse: 19900.7
# [3000]	training's rmse: 15094.2	valid_1's rmse: 19885.6
# [3500]	training's rmse: 14463.6	valid_1's rmse: 19885
# Early stopping, best iteration is:
# [3239]	training's rmse: 14775	valid_1's rmse: 19872.8
# OOF Score: 20176.983445594902
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19285.3	valid_1's rmse: 20802.9
# [1000]	training's rmse: 17988.1	valid_1's rmse: 20482.8
# [1500]	training's rmse: 17067.1	valid_1's rmse: 20354.3
# [2000]	training's rmse: 16263.1	valid_1's rmse: 20291
# [2500]	training's rmse: 15552.5	valid_1's rmse: 20252.3
# [3000]	training's rmse: 14900.1	valid_1's rmse: 20236
# [3500]	training's rmse: 14280.3	valid_1's rmse: 20213.8
# [4000]	training's rmse: 13690.8	valid_1's rmse: 20191.2
# [4500]	training's rmse: 13122.6	valid_1's rmse: 20197.9
# Early stopping, best iteration is:
# [4228]	training's rmse: 13417.4	valid_1's rmse: 20184.4
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19335.7	valid_1's rmse: 20835.4
# [1000]	training's rmse: 18160.4	valid_1's rmse: 20508
# [1500]	training's rmse: 17220.3	valid_1's rmse: 20351.6
# [2000]	training's rmse: 16438.5	valid_1's rmse: 20285.2
# [2500]	training's rmse: 15742.1	valid_1's rmse: 20241.6
# [3000]	training's rmse: 15072	valid_1's rmse: 20219.5
# [3500]	training's rmse: 14449.6	valid_1's rmse: 20208.2
# [4000]	training's rmse: 13849.8	valid_1's rmse: 20183.3
# [4500]	training's rmse: 13273.7	valid_1's rmse: 20170.1
# [5000]	training's rmse: 12743.2	valid_1's rmse: 20170.4
# Early stopping, best iteration is:
# [4817]	training's rmse: 12921.3	valid_1's rmse: 20166.4
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19264.9	valid_1's rmse: 20900.2
# [1000]	training's rmse: 18039.9	valid_1's rmse: 20648.4
# [1500]	training's rmse: 17147	valid_1's rmse: 20549
# [2000]	training's rmse: 16370	valid_1's rmse: 20480.4
# [2500]	training's rmse: 15661.2	valid_1's rmse: 20457.1
# [3000]	training's rmse: 14995.4	valid_1's rmse: 20443
# Early stopping, best iteration is:
# [2879]	training's rmse: 15140.6	valid_1's rmse: 20437.8
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19313.8	valid_1's rmse: 20880
# [1000]	training's rmse: 18095.2	valid_1's rmse: 20537
# [1500]	training's rmse: 17197.9	valid_1's rmse: 20361.8
# [2000]	training's rmse: 16418	valid_1's rmse: 20261.9
# [2500]	training's rmse: 15712.7	valid_1's rmse: 20216.7
# [3000]	training's rmse: 15053.5	valid_1's rmse: 20173.3
# [3500]	training's rmse: 14428.3	valid_1's rmse: 20162.1
# [4000]	training's rmse: 13837.8	valid_1's rmse: 20152.3
# [4500]	training's rmse: 13279.6	valid_1's rmse: 20140.9
# Early stopping, best iteration is:
# [4468]	training's rmse: 13320.9	valid_1's rmse: 20138.9
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19357.5	valid_1's rmse: 20501
# [1000]	training's rmse: 18112	valid_1's rmse: 20153.6
# [1500]	training's rmse: 17234	valid_1's rmse: 20045.8
# [2000]	training's rmse: 16470.2	valid_1's rmse: 19992.8
# [2500]	training's rmse: 15754.7	valid_1's rmse: 19943.3
# [3000]	training's rmse: 15096.6	valid_1's rmse: 19925.8
# [3500]	training's rmse: 14469.8	valid_1's rmse: 19935.5
# Early stopping, best iteration is:
# [3117]	training's rmse: 14949	valid_1's rmse: 19922.1
# OOF Score: 20170.60335460138
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19282.4	valid_1's rmse: 20789.9
# [1000]	training's rmse: 18040.7	valid_1's rmse: 20497.9
# [1500]	training's rmse: 17139	valid_1's rmse: 20371.5
# [2000]	training's rmse: 16356.9	valid_1's rmse: 20310.6
# [2500]	training's rmse: 15640.9	valid_1's rmse: 20267.1
# [3000]	training's rmse: 14984.4	valid_1's rmse: 20251.6
# [3500]	training's rmse: 14332.7	valid_1's rmse: 20254.2
# Early stopping, best iteration is:
# [3048]	training's rmse: 14920.6	valid_1's rmse: 20244
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19325.9	valid_1's rmse: 20805
# [1000]	training's rmse: 18103.7	valid_1's rmse: 20431.7
# [1500]	training's rmse: 17227.5	valid_1's rmse: 20294.4
# [2000]	training's rmse: 16462.1	valid_1's rmse: 20218
# [2500]	training's rmse: 15759.3	valid_1's rmse: 20163.9
# [3000]	training's rmse: 15081.4	valid_1's rmse: 20147.9
# [3500]	training's rmse: 14444.1	valid_1's rmse: 20142.4
# [4000]	training's rmse: 13829.9	valid_1's rmse: 20129.2
# [4500]	training's rmse: 13269.9	valid_1's rmse: 20127.2
# [5000]	training's rmse: 12752.6	valid_1's rmse: 20111.2
# Early stopping, best iteration is:
# [4958]	training's rmse: 12797.1	valid_1's rmse: 20106.8
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19241.8	valid_1's rmse: 20837
# [1000]	training's rmse: 18028.6	valid_1's rmse: 20582.9
# [1500]	training's rmse: 17122.4	valid_1's rmse: 20509.3
# [2000]	training's rmse: 16366.7	valid_1's rmse: 20463.3
# [2500]	training's rmse: 15654.6	valid_1's rmse: 20442.3
# Early stopping, best iteration is:
# [2444]	training's rmse: 15735.6	valid_1's rmse: 20436.6
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19293.5	valid_1's rmse: 20874.6
# [1000]	training's rmse: 18089.8	valid_1's rmse: 20537.5
# [1500]	training's rmse: 17196	valid_1's rmse: 20390.5
# [2000]	training's rmse: 16394.9	valid_1's rmse: 20311.8
# [2500]	training's rmse: 15670.4	valid_1's rmse: 20262.3
# [3000]	training's rmse: 14982	valid_1's rmse: 20241.2
# [3500]	training's rmse: 14383.5	valid_1's rmse: 20231.3
# [4000]	training's rmse: 13816.1	valid_1's rmse: 20221.7
# [4500]	training's rmse: 13270.6	valid_1's rmse: 20231.3
# Early stopping, best iteration is:
# [4188]	training's rmse: 13618.3	valid_1's rmse: 20215
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19352	valid_1's rmse: 20540.5
# [1000]	training's rmse: 18144.9	valid_1's rmse: 20220
# [1500]	training's rmse: 17257.7	valid_1's rmse: 20088.3
# [2000]	training's rmse: 16462.9	valid_1's rmse: 20028
# [2500]	training's rmse: 15776.6	valid_1's rmse: 19992.6
# [3000]	training's rmse: 15132.3	valid_1's rmse: 19986.2
# [3500]	training's rmse: 14493.7	valid_1's rmse: 19982.4
# Early stopping, best iteration is:
# [3374]	training's rmse: 14650.6	valid_1's rmse: 19974
# OOF Score: 20195.870445577755
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19305.3	valid_1's rmse: 20865.1
# [1000]	training's rmse: 18055.2	valid_1's rmse: 20554.2
# [1500]	training's rmse: 17106.8	valid_1's rmse: 20410.5
# [2000]	training's rmse: 16324.7	valid_1's rmse: 20344
# [2500]	training's rmse: 15597.6	valid_1's rmse: 20314.6
# [3000]	training's rmse: 14906.4	valid_1's rmse: 20290.2
# [3500]	training's rmse: 14251.5	valid_1's rmse: 20285.7
# [4000]	training's rmse: 13667.7	valid_1's rmse: 20267.6
# [4500]	training's rmse: 13118.1	valid_1's rmse: 20265.8
# Early stopping, best iteration is:
# [4211]	training's rmse: 13422.3	valid_1's rmse: 20255.4
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19335.9	valid_1's rmse: 20886.3
# [1000]	training's rmse: 18129.8	valid_1's rmse: 20533.7
# [1500]	training's rmse: 17235.1	valid_1's rmse: 20362.9
# [2000]	training's rmse: 16459.7	valid_1's rmse: 20298.1
# [2500]	training's rmse: 15734	valid_1's rmse: 20260.8
# [3000]	training's rmse: 15042.7	valid_1's rmse: 20234.9
# [3500]	training's rmse: 14402.3	valid_1's rmse: 20223.2
# [4000]	training's rmse: 13804.3	valid_1's rmse: 20220.9
# Early stopping, best iteration is:
# [3699]	training's rmse: 14150	valid_1's rmse: 20216.9
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19239.3	valid_1's rmse: 20847.2
# [1000]	training's rmse: 18029.2	valid_1's rmse: 20575.5
# [1500]	training's rmse: 17138.3	valid_1's rmse: 20505.8
# [2000]	training's rmse: 16360	valid_1's rmse: 20456.3
# [2500]	training's rmse: 15647.3	valid_1's rmse: 20447.5
# [3000]	training's rmse: 14967.5	valid_1's rmse: 20428.6
# [3500]	training's rmse: 14359.7	valid_1's rmse: 20424
# [4000]	training's rmse: 13785.3	valid_1's rmse: 20425.1
# Early stopping, best iteration is:
# [3782]	training's rmse: 14030.7	valid_1's rmse: 20412.4
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19299.7	valid_1's rmse: 20909.1
# [1000]	training's rmse: 18077.6	valid_1's rmse: 20559.3
# [1500]	training's rmse: 17183.4	valid_1's rmse: 20414.4
# [2000]	training's rmse: 16402.1	valid_1's rmse: 20318.4
# [2500]	training's rmse: 15707.7	valid_1's rmse: 20285.4
# [3000]	training's rmse: 15033.1	valid_1's rmse: 20254.3
# [3500]	training's rmse: 14407.1	valid_1's rmse: 20245.6
# [4000]	training's rmse: 13825	valid_1's rmse: 20247.8
# Early stopping, best iteration is:
# [3794]	training's rmse: 14056.3	valid_1's rmse: 20236.4
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19387	valid_1's rmse: 20473.2
# [1000]	training's rmse: 18143.8	valid_1's rmse: 20153.7
# [1500]	training's rmse: 17281.4	valid_1's rmse: 20051.3
# [2000]	training's rmse: 16478.2	valid_1's rmse: 20011.9
# [2500]	training's rmse: 15777.5	valid_1's rmse: 19964.6
# [3000]	training's rmse: 15100.3	valid_1's rmse: 19939.2
# [3500]	training's rmse: 14469.7	valid_1's rmse: 19942
# Early stopping, best iteration is:
# [3155]	training's rmse: 14889.8	valid_1's rmse: 19936.1
# OOF Score: 20212.02652758701
# Total OOF Score: 20106.718970392358
#                                               feature          gain
# 0                         te_Country__YearsCodingProf  5.846378e+08
# 1                              te_Country__Employment  3.552574e+08
# 2                     te_Country__ohe_DevType_Student  3.538621e+08
# 3                                     te_Country__Age  3.462413e+08
# 4                  te_YearsCodingProf__CurrencySymbol  3.305678e+08
# 5                             te_Country__YearsCoding  3.186065e+08
# 6                              te_Country__SalaryType  2.515849e+08
# 7                         te_Country__FormalEducation  2.117862e+08
# 8                        te_YearsCodingProf__Currency  1.601094e+08
# 9                      te_Country__CareerSatisfaction  1.472825e+08
# 10                  te_Country__ohe_Methodology_Agile  1.256890e+08
# 11  te_Country__ohe_EducationTypes_Contributed_to_...  1.162034e+08
# 12                      te_SalaryType__CurrencySymbol  1.009338e+08
# 13      te_Country__ohe_CommunicationTools_Confluence  8.765600e+07
# 14                     te_YearsCoding__CurrencySymbol  8.362195e+07
# 15                             te_Country__Dependents  7.974456e+07
# 16                             te_CurrencySymbol__Age  7.937294e+07
# 17                      te_Employment__CurrencySymbol  7.527862e+07
# 18                         te_Country__CurrencySymbol  7.405698e+07
# 19             te_CurrencySymbol__ohe_DevType_Student  6.858784e+07
# 20                     te_YearsCodingProf__SalaryType  6.341883e+07
# 21             te_Country__ohe_LanguageWorkedWith_PHP  6.108420e+07
# 22                     te_YearsCodingProf__MilitaryUS  5.739255e+07
# 23        te_Country__ohe_DevType_Engineering_manager  5.649923e+07
# 24                            te_Country__CompanySize  5.434510e+07
# 25                te_YearsCodingProf__OperatingSystem  5.152442e+07
# 26                                         te_Country  4.994145e+07
# 27                    te_CompanySize__YearsCodingProf  4.683189e+07
# 28     te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  4.514387e+07
# 29                                   te_Currency__Age  4.183436e+07
# 30                            te_Currency__SalaryType  4.158025e+07
# 31                     te_Employment__YearsCodingProf  4.153600e+07
# 32                        te_Country__OperatingSystem  3.413452e+07
# 33  te_YearsCodingProf__ohe_RaceEthnicity_White_or...  3.386633e+07
# 34                                 te_SalaryType__Age  3.363560e+07
# 35            te_YearsCodingProf__ohe_DevType_Student  3.026513e+07
# 36                te_FormalEducation__YearsCodingProf  2.975536e+07
# 37  te_YearsCodingProf__ohe_CommunicationTools_Con...  2.783803e+07
# 38                             te_Country__MilitaryUS  2.610097e+07
# 39                           te_YearsCoding__Currency  2.596897e+07
# 40                          te_Employment__SalaryType  2.471742e+07
# 41                            te_Employment__Currency  2.435526e+07
# 42  te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.366313e+07
# 43             te_YearsCodingProf__CareerSatisfaction  2.329900e+07
# 44                    te_CompanySize__OperatingSystem  2.317478e+07
# 45                                 te_Employment__Age  2.254319e+07
# 46                         te_YearsCoding__MilitaryUS  2.128124e+07
# 47          te_YearsCodingProf__ohe_Methodology_Agile  2.030350e+07
# 48                            te_YearsCodingProf__Age  1.863965e+07
# 49                 te_Employment__ohe_DevType_Student  1.723688e+07

# %%
predict(test_df, output_list, oof_score)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
