# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %%
train_null_pred = pd.read_csv("../data/train_null_pred.csv")
test_null_pred = pd.read_csv("../data/test_null_pred.csv")

# %%
for c in train_null_pred.columns:
    train_df[c] = train_null_pred[c]
    test_df[c] = test_null_pred[c]

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding_after_imputation(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding_after_imputation(train_df, test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=229.0), HTML(value='')))

# %%
@feature_cache(reset=False)
def multiple_target_encoding_after_imputation(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding_after_imputation(train_df, test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=210.0), HTML(value='')))

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 2659

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df.sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                2000,
                valid_sets = [train_dataset],
                verbose_eval=200,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
def null_preds(train_df, test_df, use_cols):
    target_cols = [
        "SalaryType",
        "YearsCodingProf",
        "Age",
    ]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    _lgb_params = lgb_params.copy()
    _lgb_params["objective"] = "multiclass"
    _lgb_params["metric"] = "multi_logloss" 
    for target_col in target_cols:
        print("-"*30)
        print(target_col)
        print("-"*30)

        _use_cols = [c for c in use_cols if c != target_col]
        trnval_idx = all_df[all_df[target_col] >= 0].index
        null_idx = all_df[all_df[target_col] == -1].index
        _train_df = all_df.loc[trnval_idx].reset_index(drop=True)
        _train_X, _valid_X, _train_y, _valid_y = train_test_split(
            _train_df[_use_cols], _train_df[target_col], test_size=0.2, shuffle=True, random_state=2020)
        _lgb_params["num_classes"] = _train_y.nunique()
        print(_train_y.nunique())
        train_dataset = lgb.Dataset(
            _train_X,
            label = _train_y
        )
        valid_dataset = lgb.Dataset(
            _valid_X,
            label = _valid_y
        )
        model = lgb.train(
                    _lgb_params,
                    train_dataset,
                    10000,
                    valid_sets = [train_dataset, valid_dataset],
                    verbose_eval=100,
                    early_stopping_rounds = 300,
                    #feval = eval_f1,
                    #callbacks = [log_callback],
        )
        all_df.loc[null_idx, target_col] = model.predict(all_df.loc[null_idx, _use_cols]).argmax(axis=1)
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    return train_df, test_df

# %%
# train_df, test_df = null_preds(train_df, test_df, use_cols)

# %%
"""
null_pred_cols = [
    "SalaryType",
    "YearsCodingProf",
    "Age",
]
train_df[null_pred_cols].to_csv("../data/train_null_pred.csv", index=False)
test_df[null_pred_cols].to_csv("../data/test_null_pred.csv", index=False)
"""
# Out:
# '\nnull_pred_cols = [\n    "SalaryType",\n    "YearsCodingProf",\n    "Age",\n]\ntrain_df[null_pred_cols].to_csv("../data/train_null_pred.csv", index=False)\ntest_df[null_pred_cols].to_csv("../data/test_null_pred.csv", index=False)\n'

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

# use_cols = feature_selection(train_df, use_cols, n_features=1000)


for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                10000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 300,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22735.7	valid_1's rmse: 23067.4
# [200]	training's rmse: 20869.2	valid_1's rmse: 21640.3
# [300]	training's rmse: 20102.1	valid_1's rmse: 21204.6
# [400]	training's rmse: 19612	valid_1's rmse: 20988.6
# [500]	training's rmse: 19263.3	valid_1's rmse: 20844.5
# [600]	training's rmse: 18949.5	valid_1's rmse: 20749.2
# [700]	training's rmse: 18684.5	valid_1's rmse: 20673.8
# [800]	training's rmse: 18425.8	valid_1's rmse: 20614.3
# [900]	training's rmse: 18203.3	valid_1's rmse: 20557.7
# [1000]	training's rmse: 17999.3	valid_1's rmse: 20517.7
# [1100]	training's rmse: 17792.9	valid_1's rmse: 20491.6
# [1200]	training's rmse: 17597.2	valid_1's rmse: 20461.1
# [1300]	training's rmse: 17410.2	valid_1's rmse: 20441.9
# [1400]	training's rmse: 17243.1	valid_1's rmse: 20429.9
# [1500]	training's rmse: 17070	valid_1's rmse: 20408.8
# [1600]	training's rmse: 16912.5	valid_1's rmse: 20396.3
# [1700]	training's rmse: 16752	valid_1's rmse: 20378.4
# [1800]	training's rmse: 16599.4	valid_1's rmse: 20359.5
# [1900]	training's rmse: 16442.6	valid_1's rmse: 20362.4
# [2000]	training's rmse: 16292.4	valid_1's rmse: 20350.5
# [2100]	training's rmse: 16140.5	valid_1's rmse: 20338.8
# [2200]	training's rmse: 16004.4	valid_1's rmse: 20331.3
# [2300]	training's rmse: 15861.7	valid_1's rmse: 20323.2
# [2400]	training's rmse: 15727.5	valid_1's rmse: 20317.2
# [2500]	training's rmse: 15585.5	valid_1's rmse: 20312.3
# [2600]	training's rmse: 15454.6	valid_1's rmse: 20310.5
# [2700]	training's rmse: 15325.2	valid_1's rmse: 20302.3
# [2800]	training's rmse: 15201.1	valid_1's rmse: 20288.8
# [2900]	training's rmse: 15073	valid_1's rmse: 20286
# [3000]	training's rmse: 14936.3	valid_1's rmse: 20285.1
# [3100]	training's rmse: 14802.1	valid_1's rmse: 20280.3
# [3200]	training's rmse: 14675.5	valid_1's rmse: 20274.4
# [3300]	training's rmse: 14548.4	valid_1's rmse: 20259.5
# [3400]	training's rmse: 14425.7	valid_1's rmse: 20266
# [3500]	training's rmse: 14312.3	valid_1's rmse: 20263.8
# Early stopping, best iteration is:
# [3296]	training's rmse: 14553.5	valid_1's rmse: 20258.4
# Fold 2
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22695	valid_1's rmse: 23269.1
# [200]	training's rmse: 20867.6	valid_1's rmse: 21699.3
# [300]	training's rmse: 20099.6	valid_1's rmse: 21172.9
# [400]	training's rmse: 19647.4	valid_1's rmse: 20914
# [500]	training's rmse: 19301.4	valid_1's rmse: 20762.2
# [600]	training's rmse: 19010.3	valid_1's rmse: 20646.8
# [700]	training's rmse: 18750.3	valid_1's rmse: 20567.2
# [800]	training's rmse: 18515.5	valid_1's rmse: 20511.7
# [900]	training's rmse: 18285.7	valid_1's rmse: 20457.5
# [1000]	training's rmse: 18072.9	valid_1's rmse: 20411.4
# [1100]	training's rmse: 17873.3	valid_1's rmse: 20375.5
# [1200]	training's rmse: 17688.1	valid_1's rmse: 20337.8
# [1300]	training's rmse: 17502	valid_1's rmse: 20306.7
# [1400]	training's rmse: 17337.4	valid_1's rmse: 20287.4
# [1500]	training's rmse: 17174.8	valid_1's rmse: 20268.2
# [1600]	training's rmse: 16998.3	valid_1's rmse: 20248.9
# [1700]	training's rmse: 16839.1	valid_1's rmse: 20235
# [1800]	training's rmse: 16695.6	valid_1's rmse: 20214
# [1900]	training's rmse: 16541.3	valid_1's rmse: 20198.1
# [2000]	training's rmse: 16387.2	valid_1's rmse: 20184.2
# [2100]	training's rmse: 16242.9	valid_1's rmse: 20171.4
# [2200]	training's rmse: 16105.1	valid_1's rmse: 20157.4
# [2300]	training's rmse: 15965.6	valid_1's rmse: 20152.2
# [2400]	training's rmse: 15824.6	valid_1's rmse: 20145.2
# [2500]	training's rmse: 15684.4	valid_1's rmse: 20141.8
# [2600]	training's rmse: 15539.2	valid_1's rmse: 20132
# [2700]	training's rmse: 15401.7	valid_1's rmse: 20122.9
# [2800]	training's rmse: 15256.9	valid_1's rmse: 20118.8
# [2900]	training's rmse: 15115.9	valid_1's rmse: 20107.3
# [3000]	training's rmse: 14978.2	valid_1's rmse: 20095.4
# [3100]	training's rmse: 14848.6	valid_1's rmse: 20084.9
# [3200]	training's rmse: 14718.1	valid_1's rmse: 20086.5
# [3300]	training's rmse: 14587.6	valid_1's rmse: 20083.1
# [3400]	training's rmse: 14463.3	valid_1's rmse: 20080.5
# [3500]	training's rmse: 14336.2	valid_1's rmse: 20077.1
# [3600]	training's rmse: 14224.2	valid_1's rmse: 20068.3
# [3700]	training's rmse: 14117	valid_1's rmse: 20073.3
# [3800]	training's rmse: 13999.3	valid_1's rmse: 20072
# [3900]	training's rmse: 13879.5	valid_1's rmse: 20070.1
# Early stopping, best iteration is:
# [3601]	training's rmse: 14224	valid_1's rmse: 20067.9
# Fold 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22757.3	valid_1's rmse: 23088.2
# [200]	training's rmse: 20867.5	valid_1's rmse: 21549.5
# [300]	training's rmse: 20071.7	valid_1's rmse: 21102.8
# [400]	training's rmse: 19586.3	valid_1's rmse: 20911.4
# [500]	training's rmse: 19239	valid_1's rmse: 20800.4
# [600]	training's rmse: 18950	valid_1's rmse: 20727
# [700]	training's rmse: 18693	valid_1's rmse: 20676
# [800]	training's rmse: 18446.5	valid_1's rmse: 20625.4
# [900]	training's rmse: 18231.8	valid_1's rmse: 20601.3
# [1000]	training's rmse: 18025.7	valid_1's rmse: 20577.7
# [1100]	training's rmse: 17825.2	valid_1's rmse: 20545.5
# [1200]	training's rmse: 17644.4	valid_1's rmse: 20516.7
# [1300]	training's rmse: 17467.5	valid_1's rmse: 20505.9
# [1400]	training's rmse: 17306	valid_1's rmse: 20491.9
# [1500]	training's rmse: 17147.3	valid_1's rmse: 20484.5
# [1600]	training's rmse: 16987.6	valid_1's rmse: 20471.8
# [1700]	training's rmse: 16812.7	valid_1's rmse: 20461.4
# [1800]	training's rmse: 16658.9	valid_1's rmse: 20455.4
# [1900]	training's rmse: 16524.7	valid_1's rmse: 20452.4
# [2000]	training's rmse: 16384	valid_1's rmse: 20450
# [2100]	training's rmse: 16242.9	valid_1's rmse: 20451.3
# [2200]	training's rmse: 16100.6	valid_1's rmse: 20437.6
# [2300]	training's rmse: 15965.8	valid_1's rmse: 20429
# [2400]	training's rmse: 15828.5	valid_1's rmse: 20424
# [2500]	training's rmse: 15672.2	valid_1's rmse: 20414.7
# [2600]	training's rmse: 15545.6	valid_1's rmse: 20414.8
# [2700]	training's rmse: 15400.9	valid_1's rmse: 20410.3
# [2800]	training's rmse: 15263.7	valid_1's rmse: 20410.7
# [2900]	training's rmse: 15135.9	valid_1's rmse: 20412.2
# Early stopping, best iteration is:
# [2629]	training's rmse: 15501.4	valid_1's rmse: 20408
# Fold 4
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22701.3	valid_1's rmse: 23116.4
# [200]	training's rmse: 20841	valid_1's rmse: 21637
# [300]	training's rmse: 20089.9	valid_1's rmse: 21229.5
# [400]	training's rmse: 19619.6	valid_1's rmse: 21017.5
# [500]	training's rmse: 19256.4	valid_1's rmse: 20865.7
# [600]	training's rmse: 18949.7	valid_1's rmse: 20772.8
# [700]	training's rmse: 18698.7	valid_1's rmse: 20683.8
# [800]	training's rmse: 18471.4	valid_1's rmse: 20628.3
# [900]	training's rmse: 18256.1	valid_1's rmse: 20565.4
# [1000]	training's rmse: 18058.3	valid_1's rmse: 20530.6
# [1100]	training's rmse: 17869	valid_1's rmse: 20490.3
# [1200]	training's rmse: 17681.6	valid_1's rmse: 20455.2
# [1300]	training's rmse: 17520.8	valid_1's rmse: 20424.4
# [1400]	training's rmse: 17362.9	valid_1's rmse: 20406.6
# [1500]	training's rmse: 17189.8	valid_1's rmse: 20380.2
# [1600]	training's rmse: 17035.5	valid_1's rmse: 20366.8
# [1700]	training's rmse: 16866.7	valid_1's rmse: 20352.5
# [1800]	training's rmse: 16714.1	valid_1's rmse: 20334.1
# [1900]	training's rmse: 16563.8	valid_1's rmse: 20314.6
# [2000]	training's rmse: 16425	valid_1's rmse: 20300.6
# [2100]	training's rmse: 16277.1	valid_1's rmse: 20291.5
# [2200]	training's rmse: 16128.8	valid_1's rmse: 20278.4
# [2300]	training's rmse: 15980.8	valid_1's rmse: 20259.7
# [2400]	training's rmse: 15839.5	valid_1's rmse: 20248.8
# [2500]	training's rmse: 15705.4	valid_1's rmse: 20240.2
# [2600]	training's rmse: 15582.8	valid_1's rmse: 20233.4
# [2700]	training's rmse: 15456.3	valid_1's rmse: 20227.9
# [2800]	training's rmse: 15331.4	valid_1's rmse: 20227.1
# [2900]	training's rmse: 15205.8	valid_1's rmse: 20229.2
# [3000]	training's rmse: 15070.6	valid_1's rmse: 20224.3
# [3100]	training's rmse: 14949.5	valid_1's rmse: 20215.9
# [3200]	training's rmse: 14830.1	valid_1's rmse: 20214.1
# [3300]	training's rmse: 14700.2	valid_1's rmse: 20205.4
# [3400]	training's rmse: 14578.4	valid_1's rmse: 20202.3
# [3500]	training's rmse: 14456.6	valid_1's rmse: 20196.5
# [3600]	training's rmse: 14351	valid_1's rmse: 20196.6
# [3700]	training's rmse: 14238.5	valid_1's rmse: 20196.7
# Early stopping, best iteration is:
# [3486]	training's rmse: 14470.7	valid_1's rmse: 20194.4
# Fold 5
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22762.3	valid_1's rmse: 23051.2
# [200]	training's rmse: 20934.5	valid_1's rmse: 21395.7
# [300]	training's rmse: 20175.8	valid_1's rmse: 20885.7
# [400]	training's rmse: 19689.3	valid_1's rmse: 20617.9
# [500]	training's rmse: 19326.1	valid_1's rmse: 20459.5
# [600]	training's rmse: 19019.7	valid_1's rmse: 20360.5
# [700]	training's rmse: 18759	valid_1's rmse: 20281.1
# [800]	training's rmse: 18520.7	valid_1's rmse: 20226.6
# [900]	training's rmse: 18294.9	valid_1's rmse: 20170
# [1000]	training's rmse: 18094.1	valid_1's rmse: 20134.6
# [1100]	training's rmse: 17897	valid_1's rmse: 20092.9
# [1200]	training's rmse: 17717.1	valid_1's rmse: 20066.6
# [1300]	training's rmse: 17540	valid_1's rmse: 20053.4
# [1400]	training's rmse: 17375.2	valid_1's rmse: 20027.5
# [1500]	training's rmse: 17218.4	valid_1's rmse: 20021.6
# [1600]	training's rmse: 17066.5	valid_1's rmse: 20009.2
# [1700]	training's rmse: 16914.7	valid_1's rmse: 19997.9
# [1800]	training's rmse: 16765.1	valid_1's rmse: 19984.8
# [1900]	training's rmse: 16615.9	valid_1's rmse: 19977.6
# [2000]	training's rmse: 16456.8	valid_1's rmse: 19967.5
# [2100]	training's rmse: 16305.5	valid_1's rmse: 19957.8
# [2200]	training's rmse: 16164.5	valid_1's rmse: 19951.3
# [2300]	training's rmse: 16026.5	valid_1's rmse: 19939.6
# [2400]	training's rmse: 15897.5	valid_1's rmse: 19941.7
# [2500]	training's rmse: 15766.1	valid_1's rmse: 19930.9
# [2600]	training's rmse: 15630.9	valid_1's rmse: 19922.9
# [2700]	training's rmse: 15493.8	valid_1's rmse: 19920
# [2800]	training's rmse: 15347.3	valid_1's rmse: 19910.2
# [2900]	training's rmse: 15215.2	valid_1's rmse: 19907
# [3000]	training's rmse: 15084.8	valid_1's rmse: 19900.2
# [3100]	training's rmse: 14967.4	valid_1's rmse: 19902.9
# [3200]	training's rmse: 14846.2	valid_1's rmse: 19904.8
# [3300]	training's rmse: 14713.2	valid_1's rmse: 19896.8
# [3400]	training's rmse: 14601.2	valid_1's rmse: 19891.3
# [3500]	training's rmse: 14486	valid_1's rmse: 19890
# [3600]	training's rmse: 14364.2	valid_1's rmse: 19887.6
# [3700]	training's rmse: 14253	valid_1's rmse: 19889.1
# [3800]	training's rmse: 14135.4	valid_1's rmse: 19897.7
# [3900]	training's rmse: 14010.7	valid_1's rmse: 19905.9
# Early stopping, best iteration is:
# [3660]	training's rmse: 14301	valid_1's rmse: 19885.7

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20163.675773404197

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                                      te_Country__Age  5.416772e+08
# 1                      te_Country__ohe_DevType_Student  4.058566e+08
# 2                          te_Country__YearsCodingProf  3.392185e+08
# 3                   te_YearsCodingProf__CurrencySymbol  2.667667e+08
# 4        te_Country__ohe_CommunicationTools_Confluence  2.275610e+08
# 5                              te_Country__CompanySize  1.918541e+08
# 6                              te_Country__YearsCoding  1.815849e+08
# 7                          te_Country__FormalEducation  1.725222e+08
# 8                               te_Country__Dependents  1.588446e+08
# 9                               te_Country__Employment  1.586645e+08
# 10                              te_Country__SalaryType  1.536765e+08
# 11                         te_Country__OperatingSystem  1.477454e+08
# 12   te_Country__ohe_EducationTypes_Contributed_to_...  1.150554e+08
# 13              te_CurrencySymbol__ohe_DevType_Student  1.067066e+08
# 14                                te_Country__Currency  1.022019e+08
# 15                              te_CurrencySymbol__Age  9.901944e+07
# 16   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  9.334696e+07
# 17                       te_Employment__CurrencySymbol  7.467044e+07
# 18   te_YearsCodingProf__ohe_CommunicationTools_Con...  6.590671e+07
# 19                   te_Country__ohe_Methodology_Agile  6.384903e+07
# 20                      te_Country__CareerSatisfaction  6.340990e+07
# 21                      te_YearsCodingProf__SalaryType  6.294148e+07
# 22                                  te_SalaryType__Age  6.252237e+07
# 23         te_Country__ohe_DevType_Engineering_manager  6.120654e+07
# 24                          te_Country__CurrencySymbol  5.759701e+07
# 25                 te_YearsCodingProf__OperatingSystem  5.380060e+07
# 26                                    te_Currency__Age  5.126379e+07
# 27                            te_YearsCoding__Currency  4.828608e+07
# 28   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  4.671433e+07
# 29   agg_mean_YearsCodingProf_ohe_CommunicationTool...  4.647025e+07
# 30              te_Country__ohe_LanguageWorkedWith_PHP  4.639450e+07
# 31                             te_Currency__SalaryType  4.574886e+07
# 32                      te_Employment__YearsCodingProf  4.529035e+07
# 33                             te_Employment__Currency  4.230730e+07
# 34                     te_CompanySize__YearsCodingProf  3.755574e+07
# 35                       te_SalaryType__CurrencySymbol  3.705314e+07
# 36                          te_YearsCoding__MilitaryUS  3.652099e+07
# 37                              te_Country__MilitaryUS  3.553001e+07
# 38                             te_YearsCodingProf__Age  3.468496e+07
# 39                  te_FormalEducation__CurrencySymbol  3.344182e+07
# 40      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  3.081851e+07
# 41   te_YearsCodingProf__ohe_EducationTypes_Contrib...  3.008461e+07
# 42                          te_YearsCoding__SalaryType  2.914394e+07
# 43                      te_YearsCodingProf__MilitaryUS  2.913723e+07
# 44                     te_YearsCoding__YearsCodingProf  2.878979e+07
# 45              te_YearsCodingProf__CareerSatisfaction  2.866932e+07
# 46                                   te_CurrencySymbol  2.768025e+07
# 47                     te_CompanySize__OperatingSystem  2.662720e+07
# 48           te_YearsCodingProf__ohe_Methodology_Agile  2.605038e+07
# 49                      te_YearsCoding__CurrencySymbol  2.595143e+07
# 50                        te_YearsCodingProf__Currency  2.503189e+07
# 51                  te_CompanySize__CareerSatisfaction  2.383430e+07
# 52                           te_Employment__MilitaryUS  2.345419e+07
# 53      te_Employment__ohe_DevType_Engineering_manager  2.294653e+07
# 54               te_CareerSatisfaction__CurrencySymbol  2.127614e+07
# 55                      te_Employment__FormalEducation  2.123760e+07
# 56                                  te_Age__MilitaryUS  2.107516e+07
# 57                                  te_Employment__Age  2.105223e+07
# 58                    te_Currency__ohe_DevType_Student  2.034987e+07
# 59                 te_FormalEducation__YearsCodingProf  1.895947e+07
# 60                     te_YearsCoding__OperatingSystem  1.876481e+07
# 61          te_YearsCoding__ohe_LanguageWorkedWith_PHP  1.661776e+07
# 62                           te_Employment__SalaryType  1.645541e+07
# 63                                       te_LastNewJob  1.490024e+07
# 64                            svd_CommunicationTools_0  1.439988e+07
# 65             te_YearsCodingProf__ohe_DevType_Student  1.336941e+07
# 66                  te_SalaryType__ohe_DevType_Student  1.335867e+07
# 67            te_CurrencySymbol__ohe_Methodology_Agile  1.277539e+07
# 68           te_Employment__ohe_LanguageWorkedWith_PHP  1.271034e+07
# 69        agg_mean_YearsCodingProf_ohe_DevType_Student  1.223118e+07
# 70                         te_Age__ohe_DevType_Student  1.212455e+07
# 71                  te_MilitaryUS__ohe_DevType_Student  1.194643e+07
# 72                 agg_mean_YearsCodingProf_AssessJob8  1.184162e+07
# 73                   te_Employment__CareerSatisfaction  1.153765e+07
# 74                  te_Employment__ohe_DevType_Student  1.107237e+07
# 75               te_CompanySize__ohe_Methodology_Agile  1.092734e+07
# 76                   te_CareerSatisfaction__SalaryType  1.077692e+07
# 77                      te_YearsCodingProf__Dependents  1.069624e+07
# 78                      agg_mean_SalaryType_AssessJob5  1.051423e+07
# 79                      te_Employment__OperatingSystem  1.009589e+07
# 80        te_Currency__ohe_DevType_Engineering_manager  9.957614e+06
# 81                         te_CompanySize__YearsCoding  9.919479e+06
# 82     te_CompanySize__ohe_DevType_Engineering_manager  9.834923e+06
# 83              te_CareerSatisfaction__OperatingSystem  9.648076e+06
# 84   te_YearsCoding__ohe_CommunicationTools_Confluence  9.515820e+06
# 85                  te_CurrencySymbol__OperatingSystem  9.384821e+06
# 86             te_FormalEducation__ohe_DevType_Student  9.364179e+06
# 87   agg_mean_CurrencySymbol_ohe_CommunicationTools...  9.306383e+06
# 88   te_CareerSatisfaction__ohe_DevType_Engineering...  9.286204e+06
# 89                                 te_CompanySize__Age  9.111790e+06
# 90                te_Employment__ohe_Methodology_Agile  9.067337e+06
# 91                          te_Employment__CompanySize  8.956621e+06
# 92                      te_CompanySize__CurrencySymbol  8.636381e+06
# 93       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  8.575512e+06
# 94                 te_CompanySize__ohe_DevType_Student  8.394477e+06
# 95                          te_Employment__YearsCoding  8.077671e+06
# 96                       agg_std_Employment_AssessJob5  7.885932e+06
# 97                          te_CompanySize__Dependents  7.818533e+06
# 98   agg_std_YearsCodingProf_ohe_CommunicationTools...  7.632455e+06
# 99              diff_agg_mean_Currency_AssessBenefits2  7.617041e+06
# 100              agg_std_Country_ohe_Methodology_Agile  7.574071e+06
# 101  agg_std_CurrencySymbol_ohe_LanguageDesireNextY...  7.529236e+06
# 102  te_Employment__ohe_EducationTypes_Contributed_...  7.452747e+06
# 103  te_CompanySize__ohe_CommunicationTools_Confluence  7.335035e+06
# 104                 te_YearsCoding__CareerSatisfaction  7.083641e+06
# 105                       te_FormalEducation__Currency  7.078956e+06
# 106  te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  7.076428e+06
# 107   te_Employment__ohe_CommunicationTools_Confluence  6.805594e+06
# 108  te_CareerSatisfaction__ohe_CommunicationTools_...  6.560858e+06
# 109                       te_Currency__OperatingSystem  6.533446e+06
# 110  rank_diff_AssessBenefits_AssessBenefits2_Asses...  6.503802e+06
# 111             te_FormalEducation__CareerSatisfaction  6.465762e+06
# 112  te_YearsCodingProf__ohe_DevType_Engineering_ma...  6.221947e+06
# 113               te_SalaryType__ohe_Methodology_Agile  6.193960e+06
# 114                     te_FormalEducation__SalaryType  6.124556e+06
# 115                         te_CareerSatisfaction__Age  6.049154e+06
# 116              rel_agg_mean_Currency_AssessBenefits2  5.985246e+06
# 117              te_YearsCoding__ohe_Methodology_Agile  5.960310e+06
# 118  te_FormalEducation__ohe_DevType_Engineering_ma...  5.905219e+06
# 119                                         te_Country  5.724409e+06
# 120                       svd_DatabaseDesireNextYear_1  5.722855e+06
# 121  te_CompanySize__ohe_EducationTypes_Contributed...  5.531651e+06
# 122  te_YearsCoding__ohe_RaceEthnicity_White_or_of_...  5.511938e+06
# 123                    te_FormalEducation__CompanySize  5.414385e+06
# 124  te_CurrencySymbol__ohe_CommunicationTools_Conf...  5.264501e+06
# 125                te_YearsCoding__ohe_DevType_Student  5.256527e+06
# 126                                te_YearsCoding__Age  5.193470e+06
# 127                     te_SalaryType__OperatingSystem  5.129209e+06
# 128  te_OperatingSystem__ohe_CommunicationTools_Con...  5.097610e+06
# 129  te_Employment__ohe_RaceEthnicity_White_or_of_E...  5.081943e+06
# 130                 agg_std_YearsCodingProf_AssessJob4  4.953602e+06
# 131                agg_mean_YearsCodingProf_AssessJob5  4.881521e+06
# 132           agg_mean_YearsCodingProf_AssessBenefits2  4.861399e+06
# 133              diff_agg_mean_Country_AssessBenefits2  4.816179e+06
# 134  te_CurrencySymbol__ohe_DevType_Engineering_man...  4.780390e+06
# 135  te_Age__ohe_RaceEthnicity_White_or_of_European...  4.712888e+06
# 136                           svd_LanguageWorkedWith_1  4.667383e+06
# 137          te_FormalEducation__ohe_Methodology_Agile  4.654484e+06
# 138          diff_agg_mean_CompanySize_AssessBenefits2  4.601494e+06
# 139                               svd_VersionControl_1  4.552500e+06
# 140                                    YearsCodingProf  4.543493e+06
# 141                      te_CurrencySymbol__MilitaryUS  4.536466e+06
# 142  te_CareerSatisfaction__ohe_EducationTypes_Cont...  4.467292e+06
# 143      diff_agg_mean_FormalEducation_AssessBenefits2  4.356226e+06
# 144  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  4.316088e+06
# 145                     agg_mean_Employment_AssessJob5  4.310637e+06
# 146                           te_CompanySize__Currency  4.275278e+06
# 147                te_FormalEducation__OperatingSystem  4.254321e+06
# 148  agg_std_Employment_ohe_CommunicationTools_Conf...  4.199493e+06
# 149  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  4.170014e+06
# 150                        te_Currency__CurrencySymbol  4.169841e+06
# 151       diff_agg_mean_NumberMonitors_AssessBenefits2  4.147848e+06
# 152        rel_agg_mean_CurrencySymbol_AssessBenefits2  4.138845e+06
# 153             agg_mean_HopeFiveYears_AssessBenefits2  4.103541e+06
# 154  agg_std_YearsCodingProf_ohe_LanguageWorkedWith...  4.032674e+06
# 155  diff_agg_mean_Employment_ohe_LanguageDesireNex...  3.977195e+06
# 156  rank_diff_JobContactPriorities_JobContactPrior...  3.947343e+06
# 157                            te_FormalEducation__Age  3.945019e+06
# 158       te_CareerSatisfaction__ohe_Methodology_Agile  3.942703e+06
# 159               rel_agg_mean_Country_AssessBenefits2  3.936718e+06
# 160         diff_agg_mean_Currency_ohe_DevType_Student  3.884093e+06
# 161                            te_OperatingSystem__Age  3.832194e+06
# 162  diff_agg_mean_OperatingSystem_ohe_LanguageWork...  3.808661e+06
# 163                                        te_UpdateCV  3.760358e+06
# 164      te_ohe_DevType_Student__ohe_Methodology_Agile  3.755786e+06
# 165  diff_agg_mean_JobSatisfaction_ohe_DevType_Student  3.658159e+06
# 166                                  svd_Methodology_0  3.637723e+06
# 167       diff_agg_mean_CurrencySymbol_AssessBenefits2  3.636920e+06
# 168  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.627662e+06
# 169               te_Dependents__ohe_Methodology_Agile  3.598721e+06
# 170  te_FormalEducation__ohe_CommunicationTools_Con...  3.545477e+06
# 171                           svd_DatabaseWorkedWith_1  3.424811e+06
# 172  rank_diff_AssessBenefits_AssessBenefits2_Asses...  3.390048e+06
# 173                    te_ohe_DatabaseWorkedWith_Redis  3.354582e+06
# 174         rank_diff_AssessJob_AssessJob4_AssessJob10  3.342237e+06
# 175                                         SalaryType  3.336052e+06
# 176        rel_agg_mean_UndergradMajor_AssessBenefits2  3.279730e+06
# 177         rank_diff_AssessJob_AssessJob1_AssessJob10  3.277512e+06
# 178        rel_agg_mean_NumberMonitors_AssessBenefits2  3.256537e+06
# 179                 te_Age__ohe_LanguageWorkedWith_PHP  3.220369e+06
# 180  te_CurrencySymbol__ohe_EducationTypes_Contribu...  3.218613e+06
# 181   rel_agg_mean_TimeFullyProductive_AssessBenefits2  3.215119e+06
# 182  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.213930e+06
# 183                          te_Employment__Dependents  3.149619e+06
# 184                              te_HypotheticalTools2  3.147736e+06
# 185            te_Currency__ohe_LanguageWorkedWith_PHP  3.120711e+06
# 186     agg_std_Employment_ohe_CommunicationTools_Jira  3.084695e+06
# 187  te_ohe_CommunicationTools_Confluence__ohe_Lang...  3.047952e+06
# 188  rank_diff_JobContactPriorities_JobContactPrior...  3.023581e+06
# 189                         te_CompanySize__SalaryType  3.010743e+06
# 190         te_CareerSatisfaction__ohe_DevType_Student  3.006978e+06
# 191                      te_CurrencySymbol__Dependents  3.002054e+06
# 192                                        te_WakeTime  2.951516e+06
# 193                                ohe_DevType_Student  2.940364e+06
# 194                      te_Age__ohe_Methodology_Agile  2.899426e+06
# 195     te_FormalEducation__ohe_LanguageWorkedWith_PHP  2.886123e+06
# 196  te_FormalEducation__ohe_EducationTypes_Contrib...  2.875674e+06
# 197          rank_diff_AssessJob_AssessJob4_AssessJob5  2.864710e+06
# 198  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.855264e+06
# 199            agg_mean_Employment_ohe_DevType_Student  2.844923e+06
# 200          diff_agg_mean_Country_ohe_DevType_Student  2.825781e+06
# 201                                      svd_DevType_0  2.824936e+06
# 202                            te_ohe_DevType_Designer  2.799837e+06
# 203                               ohe_DevType_Designer  2.681455e+06
# 204  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.658672e+06
# 205                           svd_DatabaseWorkedWith_0  2.618032e+06
# 206                       te_ohe_LanguageWorkedWith_Go  2.599462e+06
# 207                    te_CareerSatisfaction__Currency  2.592242e+06
# 208                agg_mean_Employment_AssessBenefits2  2.580045e+06
# 209  te_ohe_EducationTypes_Contributed_to_open_sour...  2.577871e+06
# 210   te_SalaryType__ohe_CommunicationTools_Confluence  2.574298e+06
# 211   diff_agg_mean_Age_ohe_LanguageDesireNextYear_PHP  2.556332e+06
# 212         te_CompanySize__ohe_LanguageWorkedWith_PHP  2.523519e+06
# 213  te_SalaryType__ohe_EducationTypes_Contributed_...  2.522034e+06
# 214  agg_mean_SalaryType_ohe_LanguageDesireNextYear...  2.505187e+06
# 215                         agg_std_Country_AssessJob8  2.504644e+06
# 216                          ohe_LanguageWorkedWith_Go  2.482046e+06
# 217  te_ohe_DevType_Engineering_manager__ohe_Commun...  2.423450e+06
# 218  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.418521e+06
# 219          te_SalaryType__ohe_LanguageWorkedWith_PHP  2.406023e+06
# 220                       agg_mean_Currency_AssessJob8  2.384497e+06
# 221  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.367904e+06
# 222           rel_agg_mean_YearsCoding_AssessBenefits2  2.360980e+06
# 223                    te_FormalEducation__YearsCoding  2.347655e+06
# 224                   agg_mean_Country_AssessBenefits2  2.341317e+06
# 225  te_ohe_DevType_Student__ohe_CommunicationTools...  2.317618e+06
# 226                             svd_HackathonReasons_1  2.314810e+06
# 227                                          svd_IDE_1  2.282739e+06
# 228        ohe_DevType_Educator_or_academic_researcher  2.276736e+06
# 229  rank_diff_AssessBenefits_AssessBenefits1_Asses...  2.267384e+06
# 230           rel_agg_mean_Country_ohe_DevType_Student  2.264163e+06
# 231         rank_diff_AssessJob_AssessJob6_AssessJob10  2.258727e+06
# 232  rank_diff_JobContactPriorities_JobContactPrior...  2.255144e+06
# 233                   rel_agg_mean_Age_AssessBenefits2  2.249905e+06
# 234                               svd_EducationTypes_0  2.242227e+06
# 235                  te_CareerSatisfaction__Dependents  2.231856e+06
# 236          rank_diff_AssessJob_AssessJob1_AssessJob5  2.212573e+06
# 237                     te_OperatingSystem__Dependents  2.205727e+06
# 238  te_ohe_CommunicationTools_Confluence__ohe_Meth...  2.175850e+06
# 239                 ohe_ErgonomicDevices_Standing_desk  2.169326e+06
# 240          diff_agg_mean_Student_ohe_DevType_Student  2.167159e+06
# 241                                      te_Employment  2.141940e+06
# 242     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  2.126835e+06
# 243  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.094403e+06
# 244                agg_mean_YearsCodingProf_AssessJob4  2.090847e+06
# 245  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.084815e+06
# 246  te_SalaryType__ohe_RaceEthnicity_White_or_of_E...  2.078828e+06
# 247                                        te_Exercise  2.074536e+06
# 248  te_OperatingSystem__ohe_EducationTypes_Contrib...  2.068818e+06
# 249           rel_agg_mean_CompanySize_AssessBenefits2  2.057526e+06
# 250  te_ohe_DevType_Engineering_manager__ohe_Educat...  2.057111e+06
# 251                       ohe_DatabaseWorkedWith_Redis  2.034598e+06
# 252                                 te_Age__Dependents  2.013542e+06
# 253  rank_diff_JobContactPriorities_JobContactPrior...  2.003921e+06
# 254                      te_StackOverflowJobsRecommend  2.003529e+06
# 255                        agg_mean_Country_AssessJob5  2.000866e+06
# 256                     agg_mean_SalaryType_AssessJob8  2.000021e+06
# 257               rel_agg_mean_Student_AssessBenefits2  1.981839e+06
# 258  agg_mean_Employment_ohe_LanguageDesireNextYear...  1.980817e+06
# 259          rank_diff_AssessJob_AssessJob5_AssessJob7  1.970186e+06
# 260     ohe_EducationTypes_Participated_in_a_hackathon  1.967866e+06
# 261  te_ohe_DevType_Engineering_manager__ohe_Langua...  1.957142e+06
# 262         rank_diff_AssessJob_AssessJob8_AssessJob10  1.955535e+06
# 263                agg_std_Country_ohe_DevType_Student  1.954535e+06
# 264  rank_diff_AdsPriorities_AdsPriorities2_AdsPrio...  1.949338e+06
# 265                  te_CareerSatisfaction__MilitaryUS  1.937284e+06
# 266  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.936557e+06
# 267                       svd_LanguageDesireNextYear_0  1.935300e+06
# 268                                      svd_DevType_1  1.929161e+06
# 269                         ohe_LanguageWorkedWith_CSS  1.925946e+06
# 270          rank_diff_AssessJob_AssessJob2_AssessJob5  1.925851e+06
# 271                     te_OperatingSystem__MilitaryUS  1.922111e+06
# 272                       svd_LanguageDesireNextYear_1  1.919667e+06
# 273  rank_diff_AssessBenefits_AssessBenefits6_Asses...  1.908758e+06
# 274  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  1.908117e+06
# 275            rel_agg_mean_SalaryType_AssessBenefits2  1.882431e+06
# 276                      sum_answer_DatabaseWorkedWith  1.877922e+06
# 277                 te_Dependents__ohe_DevType_Student  1.866026e+06
# 278  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.862496e+06
# 279                 ohe_DevType_Database_administrator  1.861817e+06
# 280          rank_diff_AssessJob_AssessJob7_AssessJob9  1.857606e+06
# 281                             sum_answer_Methodology  1.852822e+06
# 282                                   te_HopeFiveYears  1.850567e+06
# 283                                  svd_Methodology_1  1.850123e+06
# 284  diff_agg_mean_TimeFullyProductive_AssessBenefits2  1.840154e+06
# 285                                     te_CheckInCode  1.825192e+06
# 286          rel_agg_mean_Currency_ohe_DevType_Student  1.818560e+06
# 287                          svd_FrameworkWorkedWith_1  1.816512e+06
# 288  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.804925e+06
# 289                                  ohe_IDE_Notepad__  1.803237e+06
# 290       diff_agg_mean_Employment_ohe_DevType_Student  1.798926e+06
# 291  rank_diff_AssessBenefits_AssessBenefits8_Asses...  1.794916e+06
# 292                                 te_YearsCodingProf  1.794419e+06
# 293  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.793615e+06
# 294                                te_EducationParents  1.791561e+06
# 295  te_Age__ohe_EducationTypes_Contributed_to_open...  1.784804e+06
# 296  te_OperatingSystem__ohe_DevType_Engineering_ma...  1.776228e+06
# 297  rank_diff_AssessBenefits_AssessBenefits3_Asses...  1.770928e+06
# 298  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.768408e+06
# 299  rank_diff_AssessBenefits_AssessBenefits1_Asses...  1.767541e+06

# %%
len(use_cols)
# Out:
# 2659

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 68333.80367045,  92730.29528771,  84960.24614034, ...,
#         88306.23995344,  82873.72413037, 120223.86727425])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/032_null_pred_20163.csv", index=False)
