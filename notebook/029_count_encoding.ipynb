# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def triple_count_encoding(train_df, test_df):
     # triple target encoding
    triple_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    triple_te_cols = [c for c in triple_te_cols if c in imp_feats]
    combi_triple_te_cols = list(itertools.combinations(triple_te_cols, 3))
    
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

    
    for col_a, col_b, col_c in tqdm(combi_triple_te_cols):
        all_df["tmp"] = all_df[col_a].fillna("").astype(str) + all_df[col_b].fillna("").astype(str) + all_df[col_c].fillna("").astype(str)
        new_col = "triple_count_" + col_a + "__" + col_b + "__" + col_c
        count = all_df["tmp"].value_counts()
        all_df[new_col] = all_df["tmp"].map(count)
    del all_df["tmp"]
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    return train_df, test_df

# %%
train_df, test_df = triple_count_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3825

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df  # .sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                4000,
                valid_sets = [train_dataset],
                verbose_eval=200,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

use_cols = feature_selection(train_df, use_cols, n_features=1000)

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                10000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 500,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# [200]	training's rmse: 20963
# [400]	training's rmse: 19751
# [600]	training's rmse: 19100.7
# [800]	training's rmse: 18587.4
# [1000]	training's rmse: 18138
# [1200]	training's rmse: 17770.3
# [1400]	training's rmse: 17419.1
# [1600]	training's rmse: 17108.2
# [1800]	training's rmse: 16820.6
# [2000]	training's rmse: 16517.3
# [2200]	training's rmse: 16240.2
# [2400]	training's rmse: 15959.2
# [2600]	training's rmse: 15706.7
# [2800]	training's rmse: 15452.3
# [3000]	training's rmse: 15199.3
# [3200]	training's rmse: 14973.7
# [3400]	training's rmse: 14743
# [3600]	training's rmse: 14517.8
# [3800]	training's rmse: 14282.3
# [4000]	training's rmse: 14059.1
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22689.5	valid_1's rmse: 22959.9
# [200]	training's rmse: 20889.8	valid_1's rmse: 21631.3
# [300]	training's rmse: 20112.2	valid_1's rmse: 21213.3
# [400]	training's rmse: 19617.8	valid_1's rmse: 20994.9
# [500]	training's rmse: 19240.7	valid_1's rmse: 20840.1
# [600]	training's rmse: 18920.9	valid_1's rmse: 20754.3
# [700]	training's rmse: 18641.3	valid_1's rmse: 20690
# [800]	training's rmse: 18384.4	valid_1's rmse: 20626
# [900]	training's rmse: 18156.7	valid_1's rmse: 20571.7
# [1000]	training's rmse: 17921.3	valid_1's rmse: 20548.3
# [1100]	training's rmse: 17721.6	valid_1's rmse: 20510.6
# [1200]	training's rmse: 17527	valid_1's rmse: 20478
# [1300]	training's rmse: 17343.1	valid_1's rmse: 20449.1
# [1400]	training's rmse: 17170.9	valid_1's rmse: 20416.8
# [1500]	training's rmse: 16998.4	valid_1's rmse: 20403.6
# [1600]	training's rmse: 16852.9	valid_1's rmse: 20387.6
# [1700]	training's rmse: 16688.1	valid_1's rmse: 20364
# [1800]	training's rmse: 16530	valid_1's rmse: 20347.3
# [1900]	training's rmse: 16381	valid_1's rmse: 20331.2
# [2000]	training's rmse: 16230.2	valid_1's rmse: 20326
# [2100]	training's rmse: 16075.8	valid_1's rmse: 20311.9
# [2200]	training's rmse: 15928.1	valid_1's rmse: 20297.9
# [2300]	training's rmse: 15781.7	valid_1's rmse: 20287.9
# [2400]	training's rmse: 15636.2	valid_1's rmse: 20278.2
# [2500]	training's rmse: 15502	valid_1's rmse: 20273.3
# [2600]	training's rmse: 15370	valid_1's rmse: 20263.1
# [2700]	training's rmse: 15229.6	valid_1's rmse: 20256.3
# [2800]	training's rmse: 15103.5	valid_1's rmse: 20256.9
# [2900]	training's rmse: 14971.9	valid_1's rmse: 20254.4
# [3000]	training's rmse: 14840	valid_1's rmse: 20250.8
# [3100]	training's rmse: 14716.1	valid_1's rmse: 20242.6
# [3200]	training's rmse: 14589.3	valid_1's rmse: 20240.5
# [3300]	training's rmse: 14461.5	valid_1's rmse: 20234.8
# [3400]	training's rmse: 14344.3	valid_1's rmse: 20233.2
# [3500]	training's rmse: 14213.6	valid_1's rmse: 20236.9
# [3600]	training's rmse: 14096.4	valid_1's rmse: 20244.6
# [3700]	training's rmse: 13985.9	valid_1's rmse: 20242.5
# Early stopping, best iteration is:
# [3283]	training's rmse: 14481.9	valid_1's rmse: 20231.8
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22625.2	valid_1's rmse: 23233.1
# [200]	training's rmse: 20882.3	valid_1's rmse: 21769.4
# [300]	training's rmse: 20134.3	valid_1's rmse: 21251.9
# [400]	training's rmse: 19668.4	valid_1's rmse: 21013.6
# [500]	training's rmse: 19293.7	valid_1's rmse: 20876.3
# [600]	training's rmse: 18969.5	valid_1's rmse: 20775.1
# [700]	training's rmse: 18711.2	valid_1's rmse: 20699.9
# [800]	training's rmse: 18474.7	valid_1's rmse: 20628.9
# [900]	training's rmse: 18247.8	valid_1's rmse: 20575.9
# [1000]	training's rmse: 18040.9	valid_1's rmse: 20531.2
# [1100]	training's rmse: 17845.6	valid_1's rmse: 20502.2
# [1200]	training's rmse: 17654.3	valid_1's rmse: 20460.5
# [1300]	training's rmse: 17475.4	valid_1's rmse: 20437
# [1400]	training's rmse: 17294.7	valid_1's rmse: 20407.7
# [1500]	training's rmse: 17123.9	valid_1's rmse: 20377.7
# [1600]	training's rmse: 16955.7	valid_1's rmse: 20344.4
# [1700]	training's rmse: 16795.7	valid_1's rmse: 20333.9
# [1800]	training's rmse: 16635.4	valid_1's rmse: 20313.7
# [1900]	training's rmse: 16493.2	valid_1's rmse: 20301.8
# [2000]	training's rmse: 16341.5	valid_1's rmse: 20278.8
# [2100]	training's rmse: 16205.7	valid_1's rmse: 20272.7
# [2200]	training's rmse: 16062.2	valid_1's rmse: 20250.9
# [2300]	training's rmse: 15924.9	valid_1's rmse: 20238.8
# [2400]	training's rmse: 15795.8	valid_1's rmse: 20230.7
# [2500]	training's rmse: 15649.2	valid_1's rmse: 20213.2
# [2600]	training's rmse: 15509	valid_1's rmse: 20201.2
# [2700]	training's rmse: 15374.1	valid_1's rmse: 20190
# [2800]	training's rmse: 15240.4	valid_1's rmse: 20190
# [2900]	training's rmse: 15098.2	valid_1's rmse: 20180.9
# [3000]	training's rmse: 14968.8	valid_1's rmse: 20187.9
# [3100]	training's rmse: 14838.3	valid_1's rmse: 20166.6
# [3200]	training's rmse: 14719.5	valid_1's rmse: 20159.9
# [3300]	training's rmse: 14590.2	valid_1's rmse: 20156.8
# [3400]	training's rmse: 14464.4	valid_1's rmse: 20156.4
# [3500]	training's rmse: 14337.3	valid_1's rmse: 20158.3
# [3600]	training's rmse: 14208.6	valid_1's rmse: 20160.3
# [3700]	training's rmse: 14095.7	valid_1's rmse: 20154.3
# [3800]	training's rmse: 13975.3	valid_1's rmse: 20145
# [3900]	training's rmse: 13854.1	valid_1's rmse: 20139
# [4000]	training's rmse: 13741.9	valid_1's rmse: 20140.1
# [4100]	training's rmse: 13621.3	valid_1's rmse: 20142
# [4200]	training's rmse: 13517.1	valid_1's rmse: 20142.7
# [4300]	training's rmse: 13401.1	valid_1's rmse: 20149.5
# Early stopping, best iteration is:
# [3863]	training's rmse: 13899	valid_1's rmse: 20137.8
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22675.4	valid_1's rmse: 23089.1
# [200]	training's rmse: 20893.2	valid_1's rmse: 21608.5
# [300]	training's rmse: 20103	valid_1's rmse: 21167.7
# [400]	training's rmse: 19602.2	valid_1's rmse: 20959.1
# [500]	training's rmse: 19232.6	valid_1's rmse: 20843.2
# [600]	training's rmse: 18913.6	valid_1's rmse: 20772.9
# [700]	training's rmse: 18656.6	valid_1's rmse: 20710.9
# [800]	training's rmse: 18400.1	valid_1's rmse: 20656.8
# [900]	training's rmse: 18180.9	valid_1's rmse: 20610.9
# [1000]	training's rmse: 17972.6	valid_1's rmse: 20584.4
# [1100]	training's rmse: 17778.6	valid_1's rmse: 20555.3
# [1200]	training's rmse: 17564.6	valid_1's rmse: 20537
# [1300]	training's rmse: 17389.8	valid_1's rmse: 20513.1
# [1400]	training's rmse: 17211.1	valid_1's rmse: 20498.3
# [1500]	training's rmse: 17053.3	valid_1's rmse: 20485.6
# [1600]	training's rmse: 16897.9	valid_1's rmse: 20462.3
# [1700]	training's rmse: 16725.1	valid_1's rmse: 20457.8
# [1800]	training's rmse: 16564.7	valid_1's rmse: 20438.3
# [1900]	training's rmse: 16407	valid_1's rmse: 20430.4
# [2000]	training's rmse: 16250	valid_1's rmse: 20426
# [2100]	training's rmse: 16107.9	valid_1's rmse: 20418.9
# [2200]	training's rmse: 15959.1	valid_1's rmse: 20415
# [2300]	training's rmse: 15820.9	valid_1's rmse: 20416.2
# [2400]	training's rmse: 15671.9	valid_1's rmse: 20413.5
# [2500]	training's rmse: 15539	valid_1's rmse: 20402.8
# [2600]	training's rmse: 15409.9	valid_1's rmse: 20400.3
# [2700]	training's rmse: 15270.7	valid_1's rmse: 20396.8
# [2800]	training's rmse: 15135.5	valid_1's rmse: 20392.1
# [2900]	training's rmse: 15007.4	valid_1's rmse: 20391.8
# [3000]	training's rmse: 14880.7	valid_1's rmse: 20385.8
# [3100]	training's rmse: 14760.5	valid_1's rmse: 20377.1
# [3200]	training's rmse: 14631.5	valid_1's rmse: 20382.9
# [3300]	training's rmse: 14504.8	valid_1's rmse: 20371.4
# [3400]	training's rmse: 14381.2	valid_1's rmse: 20378.7
# [3500]	training's rmse: 14260.4	valid_1's rmse: 20380.2
# [3600]	training's rmse: 14139.8	valid_1's rmse: 20381
# [3700]	training's rmse: 14017.8	valid_1's rmse: 20385.3
# [3800]	training's rmse: 13899.3	valid_1's rmse: 20387.5
# Early stopping, best iteration is:
# [3303]	training's rmse: 14501.3	valid_1's rmse: 20371
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22666.1	valid_1's rmse: 23082.6
# [200]	training's rmse: 20892.3	valid_1's rmse: 21695.4
# [300]	training's rmse: 20131.8	valid_1's rmse: 21249.5
# [400]	training's rmse: 19651.4	valid_1's rmse: 21027.1
# [500]	training's rmse: 19260.6	valid_1's rmse: 20876.3
# [600]	training's rmse: 18962.3	valid_1's rmse: 20762
# [700]	training's rmse: 18706.6	valid_1's rmse: 20685.6
# [800]	training's rmse: 18463.7	valid_1's rmse: 20624.1
# [900]	training's rmse: 18236	valid_1's rmse: 20560.6
# [1000]	training's rmse: 18026.5	valid_1's rmse: 20520.5
# [1100]	training's rmse: 17812	valid_1's rmse: 20466.3
# [1200]	training's rmse: 17598.5	valid_1's rmse: 20432.7
# [1300]	training's rmse: 17427.6	valid_1's rmse: 20407.1
# [1400]	training's rmse: 17255.8	valid_1's rmse: 20386.8
# [1500]	training's rmse: 17074.8	valid_1's rmse: 20351
# [1600]	training's rmse: 16918	valid_1's rmse: 20325.3
# [1700]	training's rmse: 16769.8	valid_1's rmse: 20296.9
# [1800]	training's rmse: 16619.6	valid_1's rmse: 20270.6
# [1900]	training's rmse: 16470.4	valid_1's rmse: 20243.9
# [2000]	training's rmse: 16318.4	valid_1's rmse: 20221.3
# [2100]	training's rmse: 16169.3	valid_1's rmse: 20203.7
# [2200]	training's rmse: 16016	valid_1's rmse: 20184.7
# [2300]	training's rmse: 15871.7	valid_1's rmse: 20174.5
# [2400]	training's rmse: 15734.3	valid_1's rmse: 20167.5
# [2500]	training's rmse: 15594.9	valid_1's rmse: 20159.5
# [2600]	training's rmse: 15467.9	valid_1's rmse: 20150.7
# [2700]	training's rmse: 15329.8	valid_1's rmse: 20136.8
# [2800]	training's rmse: 15199.9	valid_1's rmse: 20137.1
# [2900]	training's rmse: 15070.7	valid_1's rmse: 20133.9
# [3000]	training's rmse: 14941.1	valid_1's rmse: 20123.4
# [3100]	training's rmse: 14810.6	valid_1's rmse: 20116.2
# [3200]	training's rmse: 14694.2	valid_1's rmse: 20107.1
# [3300]	training's rmse: 14566.8	valid_1's rmse: 20091.4
# [3400]	training's rmse: 14441.4	valid_1's rmse: 20097.4
# [3500]	training's rmse: 14322.5	valid_1's rmse: 20091
# [3600]	training's rmse: 14204.1	valid_1's rmse: 20087.9
# [3700]	training's rmse: 14090.1	valid_1's rmse: 20086.8
# [3800]	training's rmse: 13967.2	valid_1's rmse: 20086.6
# [3900]	training's rmse: 13860.3	valid_1's rmse: 20084.5
# [4000]	training's rmse: 13745.8	valid_1's rmse: 20085.5
# [4100]	training's rmse: 13632.3	valid_1's rmse: 20088.6
# [4200]	training's rmse: 13519.8	valid_1's rmse: 20090.1
# [4300]	training's rmse: 13407.9	valid_1's rmse: 20093.5
# [4400]	training's rmse: 13296.8	valid_1's rmse: 20086.8
# Early stopping, best iteration is:
# [3939]	training's rmse: 13813.1	valid_1's rmse: 20078.2
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22735.2	valid_1's rmse: 23012.6
# [200]	training's rmse: 20950.7	valid_1's rmse: 21402.2
# [300]	training's rmse: 20203	valid_1's rmse: 20903.7
# [400]	training's rmse: 19716.4	valid_1's rmse: 20627.5
# [500]	training's rmse: 19363.3	valid_1's rmse: 20491.1
# [600]	training's rmse: 19048.4	valid_1's rmse: 20377.4
# [700]	training's rmse: 18782.2	valid_1's rmse: 20292.1
# [800]	training's rmse: 18541.2	valid_1's rmse: 20227.4
# [900]	training's rmse: 18315.7	valid_1's rmse: 20173.8
# [1000]	training's rmse: 18102.6	valid_1's rmse: 20129.4
# [1100]	training's rmse: 17911.2	valid_1's rmse: 20087.6
# [1200]	training's rmse: 17724.6	valid_1's rmse: 20056.8
# [1300]	training's rmse: 17550.5	valid_1's rmse: 20018.6
# [1400]	training's rmse: 17380	valid_1's rmse: 20007.7
# [1500]	training's rmse: 17198.8	valid_1's rmse: 19983.4
# [1600]	training's rmse: 17031.5	valid_1's rmse: 19970.3
# [1700]	training's rmse: 16868.2	valid_1's rmse: 19951.7
# [1800]	training's rmse: 16727.2	valid_1's rmse: 19936
# [1900]	training's rmse: 16579.3	valid_1's rmse: 19921.7
# [2000]	training's rmse: 16424	valid_1's rmse: 19907.1
# [2100]	training's rmse: 16276.3	valid_1's rmse: 19892.9
# [2200]	training's rmse: 16127.5	valid_1's rmse: 19883.9
# [2300]	training's rmse: 15984.3	valid_1's rmse: 19878.6
# [2400]	training's rmse: 15847	valid_1's rmse: 19881.3
# [2500]	training's rmse: 15706.5	valid_1's rmse: 19875.9
# [2600]	training's rmse: 15572.1	valid_1's rmse: 19874
# [2700]	training's rmse: 15438.2	valid_1's rmse: 19879.3
# [2800]	training's rmse: 15315.2	valid_1's rmse: 19880
# [2900]	training's rmse: 15181.4	valid_1's rmse: 19879.3
# [3000]	training's rmse: 15057.2	valid_1's rmse: 19868.8
# [3100]	training's rmse: 14926.8	valid_1's rmse: 19869.5
# [3200]	training's rmse: 14800.5	valid_1's rmse: 19867.5
# [3300]	training's rmse: 14670	valid_1's rmse: 19868.7
# [3400]	training's rmse: 14546.2	valid_1's rmse: 19876
# [3500]	training's rmse: 14444.4	valid_1's rmse: 19877.4
# [3600]	training's rmse: 14322.1	valid_1's rmse: 19878.9
# Early stopping, best iteration is:
# [3192]	training's rmse: 14812.5	valid_1's rmse: 19865.1

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
# 20163.75685666844
# 20149.25682888747
oof_score
# Out:
# 20137.459107025625

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                              te_Country__YearsCoding  7.787194e+08
# 1                               te_Country__Employment  5.403997e+08
# 2                          te_Country__YearsCodingProf  3.541210e+08
# 3                               te_Country__SalaryType  3.509425e+08
# 4                      te_Country__ohe_DevType_Student  3.187572e+08
# 5                   te_YearsCodingProf__CurrencySymbol  2.950031e+08
# 6                                      te_Country__Age  2.687154e+08
# 7                               te_Country__Dependents  2.292798e+08
# 8        te_Country__ohe_CommunicationTools_Confluence  1.753809e+08
# 9                        te_SalaryType__CurrencySymbol  1.632129e+08
# 10                        te_YearsCodingProf__Currency  1.267044e+08
# 11   triple_count_YearsCodingProf__MilitaryUS__ohe_...  1.032126e+08
# 12                      te_YearsCodingProf__MilitaryUS  1.014865e+08
# 13                         te_Country__FormalEducation  7.508046e+07
# 14                   te_Country__ohe_Methodology_Agile  6.991498e+07
# 15              te_CurrencySymbol__ohe_DevType_Student  6.073411e+07
# 16                       te_Employment__CurrencySymbol  5.584185e+07
# 17             te_YearsCodingProf__ohe_DevType_Student  5.290545e+07
# 18   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  5.182538e+07
# 19                          te_YearsCoding__SalaryType  4.830062e+07
# 20                      te_YearsCodingProf__SalaryType  4.620788e+07
# 21                      te_Country__CareerSatisfaction  4.378387e+07
# 22                     te_CompanySize__YearsCodingProf  4.118135e+07
# 23           te_YearsCodingProf__ohe_Methodology_Agile  3.750253e+07
# 24                                          te_Country  3.670875e+07
# 25                              te_Country__MilitaryUS  3.431153e+07
# 26                             te_Employment__Currency  3.316258e+07
# 27              te_Country__ohe_LanguageWorkedWith_PHP  3.231887e+07
# 28                              te_CurrencySymbol__Age  3.144861e+07
# 29              te_YearsCodingProf__CareerSatisfaction  3.064617e+07
# 30            te_CurrencySymbol__ohe_Methodology_Agile  3.064457e+07
# 31                      te_Employment__YearsCodingProf  2.996435e+07
# 32      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  2.955200e+07
# 33                          te_YearsCoding__MilitaryUS  2.918966e+07
# 34         te_Country__ohe_DevType_Engineering_manager  2.887528e+07
# 35   te_YearsCodingProf__ohe_CommunicationTools_Con...  2.863137e+07
# 36   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.363776e+07
# 37                         te_Country__OperatingSystem  2.273345e+07
# 38                             te_Country__CompanySize  2.059311e+07
# 39   te_Country__ohe_EducationTypes_Contributed_to_...  1.957557e+07
# 40                                  te_Employment__Age  1.948867e+07
# 41   triple_count_Country__ohe_DevType_Student__ohe...  1.944471e+07
# 42                            te_YearsCoding__Currency  1.918686e+07
# 43                 te_YearsCodingProf__OperatingSystem  1.795522e+07
# 44                          te_CareerSatisfaction__Age  1.794670e+07
# 45                     te_CompanySize__OperatingSystem  1.761716e+07
# 46                te_SalaryType__ohe_Methodology_Agile  1.660457e+07
# 47                                       te_LastNewJob  1.619263e+07
# 48   te_CurrencySymbol__ohe_DevType_Engineering_man...  1.600481e+07
# 49   triple_count_ohe_DevType_Student__ohe_Language...  1.579751e+07
# 50                           te_Employment__SalaryType  1.571159e+07
# 51                  te_CompanySize__CareerSatisfaction  1.524263e+07
# 52      te_Currency__ohe_CommunicationTools_Confluence  1.461321e+07
# 53                      te_CompanySize__CurrencySymbol  1.415350e+07
# 54                             te_YearsCodingProf__Age  1.368873e+07
# 55                  te_SalaryType__ohe_DevType_Student  1.367961e+07
# 56      agg_std_Country_ohe_LanguageDesireNextYear_PHP  1.351936e+07
# 57                 te_FormalEducation__YearsCodingProf  1.342435e+07
# 58   te_CurrencySymbol__ohe_CommunicationTools_Conf...  1.304165e+07
# 59                                  te_SalaryType__Age  1.297776e+07
# 60                      te_YearsCoding__CurrencySymbol  1.296204e+07
# 61                                 te_YearsCoding__Age  1.246202e+07
# 62   triple_count_Employment__ohe_DevType_Student__...  1.223035e+07
# 63                      te_YearsCodingProf__Dependents  1.221335e+07
# 64                                 te_CompanySize__Age  1.176511e+07
# 65   triple_count_Employment__ohe_DevType_Student__...  1.175379e+07
# 66   te_Currency__ohe_RaceEthnicity_White_or_of_Eur...  1.174575e+07
# 67                  te_FormalEducation__CurrencySymbol  1.169915e+07
# 68   agg_std_Country_ohe_CommunicationTools_Confluence  1.162947e+07
# 69              te_CareerSatisfaction__OperatingSystem  1.136458e+07
# 70                                  te_Age__MilitaryUS  1.115800e+07
# 71   triple_count_Employment__ohe_DevType_Student__...  1.094990e+07
# 72                      te_Employment__OperatingSystem  1.014503e+07
# 73   te_CompanySize__ohe_CommunicationTools_Confluence  9.471768e+06
# 74   triple_count_Employment__CompanySize__ohe_DevT...  9.223496e+06
# 75   triple_count_YearsCodingProf__ohe_DevType_Engi...  9.133406e+06
# 76           te_Employment__ohe_LanguageWorkedWith_PHP  8.800281e+06
# 77               te_CompanySize__ohe_Methodology_Agile  8.370656e+06
# 78                  te_CurrencySymbol__OperatingSystem  8.369812e+06
# 79   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  8.206712e+06
# 80   triple_count_Employment__ohe_DevType_Engineeri...  8.177717e+06
# 81                  te_Employment__ohe_DevType_Student  8.081809e+06
# 82                      te_FormalEducation__SalaryType  7.995020e+06
# 83   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  7.867413e+06
# 84                     te_YearsCoding__YearsCodingProf  7.776311e+06
# 85   triple_count_Country__Employment__ohe_Language...  7.711750e+06
# 86                            svd_CommunicationTools_0  7.679582e+06
# 87   agg_std_CurrencySymbol_ohe_CommunicationTools_...  7.648120e+06
# 88                         te_CompanySize__YearsCoding  7.323895e+06
# 89              te_FormalEducation__CareerSatisfaction  7.321419e+06
# 90   triple_count_YearsCodingProf__OperatingSystem_...  7.249697e+06
# 91                            te_CompanySize__Currency  7.124815e+06
# 92      te_Employment__ohe_DevType_Engineering_manager  7.122505e+06
# 93                 te_FormalEducation__OperatingSystem  7.065501e+06
# 94   triple_count_YearsCodingProf__SalaryType__ohe_...  7.042183e+06
# 95                          te_Employment__CompanySize  7.019783e+06
# 96       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  6.990180e+06
# 97               te_CareerSatisfaction__CurrencySymbol  6.802676e+06
# 98                                  te_YearsCodingProf  6.713943e+06
# 99               rel_agg_mean_Currency_AssessBenefits2  6.616390e+06
# 100                         te_CompanySize__SalaryType  6.567517e+06
# 101  triple_count_CompanySize__YearsCodingProf__ohe...  6.511751e+06
# 102                         te_Country__CurrencySymbol  6.469383e+06
# 103  rank_diff_AssessBenefits_AssessBenefits2_Asses...  6.448721e+06
# 104  triple_count_YearsCodingProf__MilitaryUS__ohe_...  6.390005e+06
# 105                  te_Employment__CareerSatisfaction  6.121100e+06
# 106        rel_agg_mean_NumberMonitors_AssessBenefits2  6.021762e+06
# 107                            te_Currency__SalaryType  6.005818e+06
# 108                    te_FormalEducation__CompanySize  5.917169e+06
# 109  te_CompanySize__ohe_EducationTypes_Contributed...  5.846844e+06
# 110             diff_agg_mean_Currency_AssessBenefits2  5.835565e+06
# 111  triple_count_CareerSatisfaction__ohe_DevType_S...  5.805020e+06
# 112  triple_count_YearsCoding__MilitaryUS__ohe_DevT...  5.790632e+06
# 113                        te_Age__ohe_DevType_Student  5.698474e+06
# 114                           svd_LanguageWorkedWith_1  5.607518e+06
# 115                    te_YearsCoding__OperatingSystem  5.538357e+06
# 116                               te_Country__Currency  5.533472e+06
# 117  te_CareerSatisfaction__ohe_CommunicationTools_...  5.495959e+06
# 118  triple_count_Employment__OperatingSystem__ohe_...  5.391747e+06
# 119                 te_YearsCoding__CareerSatisfaction  5.387778e+06
# 120     te_FormalEducation__ohe_LanguageWorkedWith_PHP  5.331122e+06
# 121         te_YearsCoding__ohe_LanguageWorkedWith_PHP  5.284567e+06
# 122        rel_agg_mean_CurrencySymbol_AssessBenefits2  5.246484e+06
# 123                         te_CompanySize__Dependents  5.146743e+06
# 124   te_Employment__ohe_CommunicationTools_Confluence  5.003675e+06
# 125              diff_agg_mean_Country_AssessBenefits2  4.980138e+06
# 126    te_CompanySize__ohe_DevType_Engineering_manager  4.961703e+06
# 127                            te_FormalEducation__Age  4.930798e+06
# 128                               svd_VersionControl_1  4.928979e+06
# 129          te_FormalEducation__ohe_Methodology_Agile  4.911944e+06
# 130       diff_agg_mean_NumberMonitors_AssessBenefits2  4.872613e+06
# 131               rel_agg_mean_Country_AssessBenefits2  4.870587e+06
# 132                         te_Employment__YearsCoding  4.812984e+06
# 133  triple_count_YearsCodingProf__MilitaryUS__ohe_...  4.772238e+06
# 134                                  svd_Methodology_0  4.703906e+06
# 135  te_CareerSatisfaction__ohe_DevType_Engineering...  4.694274e+06
# 136  triple_count_ohe_DevType_Student__ohe_Communic...  4.663564e+06
# 137  triple_count_YearsCodingProf__OperatingSystem_...  4.607491e+06
# 138               te_Employment__ohe_Methodology_Agile  4.536585e+06
# 139  triple_count_Employment__ohe_LanguageWorkedWit...  4.522750e+06
# 140                            te_OperatingSystem__Age  4.504769e+06
# 141                te_CompanySize__ohe_DevType_Student  4.476186e+06
# 142  te_FormalEducation__ohe_EducationTypes_Contrib...  4.474358e+06
# 143  triple_count_Employment__MilitaryUS__ohe_DevTy...  4.426048e+06
# 144                               ohe_DevType_Designer  4.419138e+06
# 145                te_YearsCoding__ohe_DevType_Student  4.370406e+06
# 146                       svd_DatabaseDesireNextYear_1  4.339252e+06
# 147  rank_diff_JobContactPriorities_JobContactPrior...  4.334426e+06
# 148  triple_count_CompanySize__Dependents__ohe_Comm...  4.327530e+06
# 149                          ohe_LanguageWorkedWith_Go  4.298287e+06
# 150  triple_count_Employment__Age__ohe_DevType_Student  4.275488e+06
# 151                       te_FormalEducation__Currency  4.231109e+06
# 152  te_Employment__ohe_EducationTypes_Contributed_...  4.192637e+06
# 153  triple_count_CareerSatisfaction__ohe_LanguageW...  4.182964e+06
# 154                       ohe_DatabaseWorkedWith_Redis  4.139404e+06
# 155  triple_count_CompanySize__YearsCodingProf__Mil...  4.118487e+06
# 156  te_FormalEducation__ohe_DevType_Engineering_ma...  4.096259e+06
# 157  triple_count_OperatingSystem__MilitaryUS__ohe_...  4.094705e+06
# 158                       te_Currency__OperatingSystem  4.069274e+06
# 159                                   te_Currency__Age  4.065181e+06
# 160      diff_agg_mean_FormalEducation_AssessBenefits2  4.033429e+06
# 161         te_CompanySize__ohe_LanguageWorkedWith_PHP  3.985399e+06
# 162  te_OperatingSystem__ohe_CommunicationTools_Con...  3.980294e+06
# 163         rank_diff_AssessJob_AssessJob4_AssessJob10  3.966695e+06
# 164       diff_agg_mean_CurrencySymbol_AssessBenefits2  3.952757e+06
# 165                                        te_UpdateCV  3.932937e+06
# 166                      te_CurrencySymbol__Dependents  3.921206e+06
# 167                     te_Employment__FormalEducation  3.847513e+06
# 168         rank_diff_AssessJob_AssessJob1_AssessJob10  3.798707e+06
# 169              te_YearsCoding__ohe_Methodology_Agile  3.787378e+06
# 170                              te_HypotheticalTools2  3.784769e+06
# 171  triple_count_Employment__OperatingSystem__ohe_...  3.768490e+06
# 172  triple_count_YearsCodingProf__SalaryType__ohe_...  3.765089e+06
# 173      diff_agg_mean_JobSatisfaction_AssessBenefits2  3.745638e+06
# 174             agg_mean_HopeFiveYears_AssessBenefits2  3.728389e+06
# 175  te_OperatingSystem__ohe_DevType_Engineering_ma...  3.678490e+06
# 176                      te_Age__ohe_Methodology_Agile  3.536074e+06
# 177  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.532998e+06
# 178                   rel_agg_mean_Age_AssessBenefits2  3.516230e+06
# 179  te_CareerSatisfaction__ohe_EducationTypes_Cont...  3.511662e+06
# 180                     te_SalaryType__OperatingSystem  3.471041e+06
# 181  triple_count_Employment__CareerSatisfaction__o...  3.457607e+06
# 182  triple_count_Country__Currency__ohe_Methodolog...  3.417991e+06
# 183  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  3.351464e+06
# 184  te_YearsCodingProf__ohe_DevType_Engineering_ma...  3.336540e+06
# 185  triple_count_Employment__YearsCodingProf__ohe_...  3.330682e+06
# 186          diff_agg_mean_Country_ohe_DevType_Student  3.330233e+06
# 187  agg_mean_YearsCodingProf_ohe_CommunicationTool...  3.309670e+06
# 188          rank_diff_AssessJob_AssessJob4_AssessJob5  3.302875e+06
# 189  triple_count_Employment__ohe_DevType_Engineeri...  3.267388e+06
# 190   te_SalaryType__ohe_CommunicationTools_Confluence  3.257415e+06
# 191  triple_count_MilitaryUS__ohe_CommunicationTool...  3.227840e+06
# 192  triple_count_Dependents__ohe_DevType_Engineeri...  3.213868e+06
# 193                                  te_CurrencySymbol  3.197818e+06
# 194  triple_count_Country__Employment__ohe_DevType_...  3.136825e+06
# 195  triple_count_Employment__CareerSatisfaction__o...  3.136179e+06
# 196                           svd_DatabaseWorkedWith_1  3.110887e+06
# 197         te_CareerSatisfaction__ohe_DevType_Student  3.034896e+06
# 198                 te_Age__ohe_LanguageWorkedWith_PHP  3.032861e+06
# 199  diff_agg_mean_Country_ohe_LanguageDesireNextYe...  3.026264e+06
# 200                                        te_WakeTime  2.976738e+06
# 201  triple_count_YearsCodingProf__SalaryType__Mili...  2.974600e+06
# 202                                   ohe_IDE_NetBeans  2.971101e+06
# 203  rank_diff_JobEmailPriorities_JobEmailPrioritie...  2.970950e+06
# 204  triple_count_YearsCoding__MilitaryUS__ohe_Comm...  2.968571e+06
# 205                       svd_LanguageDesireNextYear_0  2.954862e+06
# 206      te_ohe_DevType_Student__ohe_Methodology_Agile  2.940357e+06
# 207  triple_count_OperatingSystem__ohe_DevType_Engi...  2.933443e+06
# 208  triple_count_SalaryType__OperatingSystem__Mili...  2.917368e+06
# 209  triple_count_Employment__SalaryType__ohe_DevTy...  2.910993e+06
# 210                           svd_DatabaseWorkedWith_0  2.905272e+06
# 211                         ohe_LanguageWorkedWith_CSS  2.880847e+06
# 212  triple_count_ohe_DevType_Engineering_manager__...  2.842855e+06
# 213  triple_count_Employment__YearsCodingProf__ohe_...  2.826335e+06
# 214  triple_count_YearsCoding__OperatingSystem__ohe...  2.823388e+06
# 215  diff_agg_mean_CurrencySymbol_ohe_LanguageDesir...  2.818181e+06
# 216               rel_agg_mean_Student_AssessBenefits2  2.810493e+06
# 217  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.763687e+06
# 218                    ohe_DevType_Front_end_developer  2.740457e+06
# 219  triple_count_ohe_DevType_Student__ohe_Educatio...  2.729578e+06
# 220  triple_count_ohe_DevType_Student__ohe_Language...  2.644180e+06
# 221  triple_count_YearsCodingProf__OperatingSystem_...  2.643565e+06
# 222                                          svd_IDE_1  2.615792e+06
# 223                               svd_EducationTypes_0  2.581683e+06
# 224  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.579158e+06
# 225       rel_agg_mean_FormalEducation_AssessBenefits2  2.572322e+06
# 226  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.564134e+06
# 227  rank_diff_JobContactPriorities_JobContactPrior...  2.557963e+06
# 228                             svd_HackathonReasons_1  2.546785e+06
# 229  triple_count_Employment__FormalEducation__ohe_...  2.542503e+06
# 230  te_Age__ohe_RaceEthnicity_White_or_of_European...  2.530609e+06
# 231          rank_diff_AssessJob_AssessJob1_AssessJob5  2.512842e+06
# 232                    te_CareerSatisfaction__Currency  2.510729e+06
# 233          te_OperatingSystem__ohe_Methodology_Agile  2.509227e+06
# 234  triple_count_Employment__ohe_DevType_Engineeri...  2.473897e+06
# 235  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.467239e+06
# 236  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.462237e+06
# 237    triple_count_Employment__SalaryType__MilitaryUS  2.437630e+06
# 238  triple_count_ohe_DevType_Student__ohe_Methodol...  2.437116e+06
# 239  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.429449e+06
# 240                       ohe_PlatformWorkedWith_Azure  2.415392e+06
# 241  te_FormalEducation__ohe_CommunicationTools_Con...  2.409452e+06
# 242                          svd_FrameworkWorkedWith_1  2.405023e+06
# 243         rank_diff_AssessJob_AssessJob8_AssessJob10  2.397283e+06
# 244  triple_count_OperatingSystem__ohe_DevType_Engi...  2.379494e+06
# 245                  te_CareerSatisfaction__MilitaryUS  2.378995e+06
# 246                 te_Currency__ohe_Methodology_Agile  2.363305e+06
# 247  rank_diff_JobContactPriorities_JobContactPrior...  2.355912e+06
# 248                                      svd_DevType_0  2.354317e+06
# 249                      te_CurrencySymbol__MilitaryUS  2.351599e+06
# 250                             sum_answer_Methodology  2.342933e+06
# 251  triple_count_Employment__OperatingSystem__Mili...  2.341654e+06
# 252  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.340411e+06
# 253           rel_agg_mean_CompanySize_AssessBenefits2  2.330606e+06
# 254            rel_agg_mean_SalaryType_AssessBenefits2  2.321741e+06
# 255  triple_count_ohe_LanguageWorkedWith_PHP__ohe_M...  2.305252e+06
# 256  te_CurrencySymbol__ohe_EducationTypes_Contribu...  2.294732e+06
# 257        ohe_DevType_Educator_or_academic_researcher  2.292886e+06
# 258                 agg_std_YearsCodingProf_AssessJob5  2.289231e+06
# 259  triple_count_Employment__MilitaryUS__ohe_DevTy...  2.285925e+06
# 260  triple_count_Employment__FormalEducation__ohe_...  2.253191e+06
# 261  triple_count_Country__Employment__ohe_DevType_...  2.251468e+06
# 262                       svd_LanguageDesireNextYear_1  2.251431e+06
# 263       rel_agg_mean_YearsCodingProf_AssessBenefits2  2.231043e+06
# 264  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  2.227047e+06
# 265                  te_CareerSatisfaction__SalaryType  2.222167e+06
# 266  triple_count_Employment__CareerSatisfaction__o...  2.219201e+06
# 267  rel_agg_mean_ohe_Methodology_Agile_AssessBenef...  2.208105e+06
# 268                                     te_CheckInCode  2.203812e+06
# 269          diff_agg_mean_Student_ohe_DevType_Student  2.202348e+06
# 270                agg_mean_YearsCodingProf_AssessJob5  2.196446e+06
# 271                 ohe_ErgonomicDevices_Standing_desk  2.178031e+06
# 272  triple_count_SalaryType__ohe_DevType_Student__...  2.167338e+06
# 273          rank_diff_AssessJob_AssessJob5_AssessJob7  2.167296e+06
# 274  rank_diff_JobContactPriorities_JobContactPrior...  2.152674e+06
# 275  triple_count_YearsCoding__ohe_DevType_Engineer...  2.152433e+06
# 276                agg_std_Country_ohe_DevType_Student  2.147371e+06
# 277                     ohe_FrameworkWorkedWith_Hadoop  2.133132e+06
# 278                                      svd_DevType_1  2.131747e+06
# 279           diff_agg_mean_MilitaryUS_AssessBenefits2  2.130520e+06
# 280  triple_count_Employment__CareerSatisfaction__S...  2.125668e+06
# 281     ohe_EducationTypes_Participated_in_a_hackathon  2.125506e+06
# 282         rank_diff_AssessJob_AssessJob6_AssessJob10  2.123940e+06
# 283                 ohe_DevType_Database_administrator  2.117736e+06
# 284                  te_CareerSatisfaction__Dependents  2.101567e+06
# 285          te_Age__ohe_CommunicationTools_Confluence  2.088198e+06
# 286  triple_count_Employment__SalaryType__ohe_Commu...  2.083295e+06
# 287       te_CareerSatisfaction__ohe_Methodology_Agile  2.062892e+06
# 288            rel_agg_mean_JobSatisfaction_AssessJob5  2.057790e+06
# 289       agg_mean_FormalEducation_ohe_DevType_Student  2.051171e+06
# 290               agg_mean_Country_ohe_DevType_Student  2.049584e+06
# 291                      sum_answer_DatabaseWorkedWith  2.046157e+06
# 292  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  2.037180e+06
# 293  rank_diff_AssessBenefits_AssessBenefits1_Asses...  2.034198e+06
# 294            te_OperatingSystem__ohe_DevType_Student  2.027763e+06
# 295            te_FormalEducation__ohe_DevType_Student  2.026514e+06
# 296  triple_count_Employment__FormalEducation__ohe_...  2.017100e+06
# 297  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.992040e+06
# 298  te_ohe_CommunicationTools_Confluence__ohe_Meth...  1.986634e+06
# 299                          te_Employment__Dependents  1.981128e+06

# %%
len(use_cols)
# Out:
# 1000

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 65637.2790103 ,  90371.35902599,  89529.49841641, ...,
#         89006.56913433,  81966.22421095, 121793.79093455])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/029_count_encoding_20137.csv", index=False)
