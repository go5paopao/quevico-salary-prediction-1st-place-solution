# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %%
other_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols)) if c not in ["Salary", "No"]
]

# %%
cat_cols = []
for c in tqdm(other_cols):
    if "float" in train_df[c].dtype.name:
        if train_df[c].nunique() > 1000:
            train_df[c] = train_df[c].astype(np.float32)
            test_df[c] = test_df[c].astype(np.float32)
        else:
            train_df[c] = train_df[c].astype(np.float16)
            test_df[c] = test_df[c].astype(np.float16)
    else:
        train_df[c], uniques = pd.factorize(train_df[c], sort=True)
        test_df[c] = uniques.get_indexer(test_df[c])
        if train_df[c].max() > 32767:
            train_df[c] = train_df[c].astype(np.int32)
            test_df[c] = test_df[c].astype(np.int32)
        else:
            train_df[c] = train_df[c].astype(np.int16)
            test_df[c] = test_df[c].astype(np.int16)            
        cat_cols.append(c)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=105.0), HTML(value='')))

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 465), (11259, 464))

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %%
# basicなモデルのimportanceを読み込み
importance_df = pd.read_csv("../data/importance/003_importance.csv")

# %%
imp_feats = importance_df["feature"].iloc[:50].tolist()
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c not in cat_cols and c not in multi_cat_cols]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 61

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
te_cols = [c for c in use_cols if (not "agg_" in c) and train_df[c].nunique() >= 5]

# %%
for c in tqdm(te_cols):
    new_col = "te_" + c
    train_df[new_col] = 0
    test_df[new_col] = 0
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=109.0), HTML(value='')))

# %%
# multiple target encoding
te_cols2 = [c for c in use_cols if (not "agg_" in c)]
te_imp_feats = importance_df["feature"].iloc[:30].tolist()
multi_te_cols = [c for c in te_cols2 if c in te_imp_feats]
combi_cols = list(itertools.combinations(multi_te_cols, 2))

# %%
for col_a, col_b in tqdm(combi_cols):
    new_col = "te_" + col_a + "__" + col_b
    train_df[new_col] = 0
    test_df[new_col] = 0
    train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
    test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
    del train_df["tmp"], test_df["tmp"]
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=231.0), HTML(value='')))

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3662

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'regression',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20766.2	valid_1's rmse: 21644
# [200]	training's rmse: 19636.5	valid_1's rmse: 21075.8
# [300]	training's rmse: 18996.6	valid_1's rmse: 20861.7
# [400]	training's rmse: 18484.7	valid_1's rmse: 20729.5
# [500]	training's rmse: 18052.6	valid_1's rmse: 20636.9
# [600]	training's rmse: 17691.5	valid_1's rmse: 20572.2
# [700]	training's rmse: 17343.1	valid_1's rmse: 20522
# [800]	training's rmse: 17023.3	valid_1's rmse: 20492.4
# [900]	training's rmse: 16742	valid_1's rmse: 20470.3
# [1000]	training's rmse: 16481.4	valid_1's rmse: 20451.2
# [1100]	training's rmse: 16225.9	valid_1's rmse: 20456.2
# Early stopping, best iteration is:
# [1065]	training's rmse: 16310.9	valid_1's rmse: 20451.1
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20723.6	valid_1's rmse: 21739.6
# [200]	training's rmse: 19613.3	valid_1's rmse: 21051.5
# [300]	training's rmse: 18949	valid_1's rmse: 20790.8
# [400]	training's rmse: 18469.3	valid_1's rmse: 20632
# [500]	training's rmse: 18061.8	valid_1's rmse: 20534.3
# [600]	training's rmse: 17712.7	valid_1's rmse: 20464.9
# [700]	training's rmse: 17378	valid_1's rmse: 20421.8
# [800]	training's rmse: 17058.4	valid_1's rmse: 20374.7
# [900]	training's rmse: 16745.2	valid_1's rmse: 20349.4
# [1000]	training's rmse: 16460.8	valid_1's rmse: 20323.6
# [1100]	training's rmse: 16191.2	valid_1's rmse: 20297.3
# [1200]	training's rmse: 15934.7	valid_1's rmse: 20274.7
# [1300]	training's rmse: 15676.8	valid_1's rmse: 20254.9
# [1400]	training's rmse: 15442.4	valid_1's rmse: 20257.6
# Early stopping, best iteration is:
# [1331]	training's rmse: 15601.3	valid_1's rmse: 20250.3
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20774.1	valid_1's rmse: 21610.3
# [200]	training's rmse: 19606.6	valid_1's rmse: 21022.9
# [300]	training's rmse: 18960.1	valid_1's rmse: 20853.1
# [400]	training's rmse: 18444.5	valid_1's rmse: 20758.7
# [500]	training's rmse: 17997.3	valid_1's rmse: 20698.9
# [600]	training's rmse: 17606.7	valid_1's rmse: 20652.4
# [700]	training's rmse: 17264.9	valid_1's rmse: 20612
# [800]	training's rmse: 16947.6	valid_1's rmse: 20601.6
# [900]	training's rmse: 16658.2	valid_1's rmse: 20591.4
# [1000]	training's rmse: 16383.9	valid_1's rmse: 20582
# [1100]	training's rmse: 16106.7	valid_1's rmse: 20570.2
# [1200]	training's rmse: 15869	valid_1's rmse: 20576.9
# [1300]	training's rmse: 15626.5	valid_1's rmse: 20568.3
# [1400]	training's rmse: 15374.9	valid_1's rmse: 20557.7
# [1500]	training's rmse: 15152.5	valid_1's rmse: 20545.3
# [1600]	training's rmse: 14939.1	valid_1's rmse: 20535.7
# [1700]	training's rmse: 14723	valid_1's rmse: 20532.3
# [1800]	training's rmse: 14537.7	valid_1's rmse: 20537.2
# Early stopping, best iteration is:
# [1730]	training's rmse: 14661.3	valid_1's rmse: 20527.6
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20782	valid_1's rmse: 21597.9
# [200]	training's rmse: 19643.5	valid_1's rmse: 21037.1
# [300]	training's rmse: 18967.1	valid_1's rmse: 20788.3
# [400]	training's rmse: 18473.4	valid_1's rmse: 20629.6
# [500]	training's rmse: 18066.5	valid_1's rmse: 20531.4
# [600]	training's rmse: 17681.9	valid_1's rmse: 20460.5
# [700]	training's rmse: 17341	valid_1's rmse: 20393.7
# [800]	training's rmse: 17027.3	valid_1's rmse: 20369
# [900]	training's rmse: 16721.8	valid_1's rmse: 20330.1
# [1000]	training's rmse: 16421.7	valid_1's rmse: 20302.5
# [1100]	training's rmse: 16172.6	valid_1's rmse: 20291.6
# Early stopping, best iteration is:
# [1060]	training's rmse: 16264.5	valid_1's rmse: 20288
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20845.8	valid_1's rmse: 21439.5
# [200]	training's rmse: 19717.5	valid_1's rmse: 20777.5
# [300]	training's rmse: 19066.7	valid_1's rmse: 20539.1
# [400]	training's rmse: 18546	valid_1's rmse: 20388.9
# [500]	training's rmse: 18112.1	valid_1's rmse: 20294.3
# [600]	training's rmse: 17720.8	valid_1's rmse: 20228.7
# [700]	training's rmse: 17378.4	valid_1's rmse: 20178.6
# [800]	training's rmse: 17046.9	valid_1's rmse: 20147.4
# [900]	training's rmse: 16764.5	valid_1's rmse: 20118.3
# [1000]	training's rmse: 16484.6	valid_1's rmse: 20093.9
# [1100]	training's rmse: 16229	valid_1's rmse: 20082.2
# [1200]	training's rmse: 15980.4	valid_1's rmse: 20072.6
# [1300]	training's rmse: 15747	valid_1's rmse: 20057.6
# [1400]	training's rmse: 15506.3	valid_1's rmse: 20065.6
# Early stopping, best iteration is:
# [1303]	training's rmse: 15738.2	valid_1's rmse: 20053.7

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
#20824.817522627924
#20794.69950160029
#20548.806990829173
#20366.916244725206
#20352.221759954566
# Out:
# 20314.83204271973

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                               te_Country__Employment  3.136888e+13
# 1                              te_Country__YearsCoding  2.624246e+13
# 2                          te_Country__YearsCodingProf  2.086237e+13
# 3                                      te_Country__Age  1.929733e+13
# 4                               te_Country__SalaryType  1.609979e+13
# 5               te_Country__ohe_LanguageWorkedWith_PHP  1.588576e+13
# 6    te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.215222e+13
# 7                         te_YearsCodingProf__Currency  1.111535e+13
# 8                          te_Country__OperatingSystem  1.008412e+13
# 9        te_Country__ohe_CommunicationTools_Confluence  9.896917e+12
# 10                     te_Country__ohe_DevType_Student  9.750732e+12
# 11                              te_Country__Dependents  9.309645e+12
# 12                  te_YearsCodingProf__CurrencySymbol  6.796443e+12
# 13                             te_Country__CompanySize  5.617859e+12
# 14                         te_Country__FormalEducation  4.724389e+12
# 15                      te_YearsCodingProf__SalaryType  4.443805e+12
# 16                      te_Employment__YearsCodingProf  3.975773e+12
# 17                     te_CompanySize__YearsCodingProf  3.938835e+12
# 18                 te_YearsCodingProf__AssessBenefits2  3.832253e+12
# 19                                    te_Currency__Age  3.817172e+12
# 20                          te_Country__CurrencySymbol  3.695906e+12
# 21              te_CurrencySymbol__ohe_DevType_Student  3.629925e+12
# 22                       te_Employment__CurrencySymbol  3.451332e+12
# 23                             te_Currency__SalaryType  3.255199e+12
# 24           te_YearsCodingProf__ohe_Methodology_Agile  2.934862e+12
# 25                 agg_mean_YearsCodingProf_AssessJob5  2.832182e+12
# 26                 te_FormalEducation__YearsCodingProf  2.674299e+12
# 27         te_Country__ohe_DevType_Engineering_manager  2.664699e+12
# 28   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  2.552510e+12
# 29                 te_YearsCodingProf__OperatingSystem  2.437356e+12
# 30                              te_Country__MilitaryUS  2.121134e+12
# 31                   te_Country__ohe_Methodology_Agile  2.067312e+12
# 32   te_YearsCodingProf__ohe_CommunicationTools_Con...  1.985280e+12
# 33                      te_YearsCodingProf__MilitaryUS  1.706385e+12
# 34                      te_Country__CareerSatisfaction  1.701465e+12
# 35   te_YearsCodingProf__ohe_EducationTypes_Contrib...  1.605944e+12
# 36                             te_YearsCodingProf__Age  1.439302e+12
# 37                         te_CompanySize__YearsCoding  1.430575e+12
# 38   te_Country__ohe_EducationTypes_Contributed_to_...  1.377328e+12
# 39                  te_FormalEducation__CurrencySymbol  1.373048e+12
# 40                                  te_Employment__Age  1.319126e+12
# 41                       te_SalaryType__CurrencySymbol  1.284451e+12
# 42                          te_YearsCoding__SalaryType  1.259561e+12
# 43                  te_YearsCoding__CareerSatisfaction  1.258991e+12
# 44            agg_mean_YearsCodingProf_AssessBenefits2  1.238367e+12
# 45      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  1.196748e+12
# 46                            te_YearsCoding__Currency  1.176349e+12
# 47                  te_Employment__ohe_DevType_Student  1.130447e+12
# 48              te_YearsCodingProf__CareerSatisfaction  1.065420e+12
# 49                  te_CurrencySymbol__OperatingSystem  1.044128e+12
# 50   te_CompanySize__ohe_CommunicationTools_Confluence  9.613715e+11
# 51                     te_YearsCoding__AssessBenefits2  9.443336e+11
# 52                                te_Country__Currency  9.190189e+11
# 53                                  te_SalaryType__Age  9.157909e+11
# 54                          te_YearsCoding__MilitaryUS  8.792081e+11
# 55                           te_Employment__SalaryType  8.673147e+11
# 56                          te_CompanySize__SalaryType  8.162641e+11
# 57   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  7.901142e+11
# 58   agg_std_YearsCodingProf_ohe_DevType_Engineerin...  7.679066e+11
# 59                     te_CompanySize__OperatingSystem  7.500971e+11
# 60   agg_std_YearsCodingProf_ohe_RaceEthnicity_Whit...  7.482251e+11
# 61              te_CareerSatisfaction__AssessBenefits2  7.472764e+11
# 62                     te_YearsCoding__YearsCodingProf  7.422110e+11
# 63                  te_CompanySize__CareerSatisfaction  7.286385e+11
# 64              te_CareerSatisfaction__OperatingSystem  7.219828e+11
# 65     te_CompanySize__ohe_DevType_Engineering_manager  7.206360e+11
# 66                          te_Employment__CompanySize  7.186192e+11
# 67             te_YearsCodingProf__ohe_DevType_Student  7.087535e+11
# 68   te_YearsCoding__ohe_EducationTypes_Contributed...  6.960939e+11
# 69                  te_SalaryType__ohe_DevType_Student  6.891807e+11
# 70                     te_YearsCoding__OperatingSystem  6.463345e+11
# 71                      te_Employment__OperatingSystem  6.421190e+11
# 72                                 te_YearsCoding__Age  6.277397e+11
# 73               rel_agg_mean_Currency_AssessBenefits2  5.861212e+11
# 74                      te_YearsCoding__CurrencySymbol  5.848779e+11
# 75                      te_Employment__FormalEducation  5.841497e+11
# 76                 te_FormalEducation__OperatingSystem  5.724698e+11
# 77                 te_CompanySize__ohe_DevType_Student  5.713986e+11
# 78                        te_FormalEducation__Currency  5.675899e+11
# 79      te_Employment__ohe_DevType_Engineering_manager  5.413630e+11
# 80   te_AssessBenefits2__ohe_DevType_Engineering_ma...  5.356304e+11
# 81                  te_AssessBenefits2__CurrencySymbol  5.347197e+11
# 82   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  5.283816e+11
# 83   te_CareerSatisfaction__ohe_DevType_Engineering...  5.264926e+11
# 84         agg_std_YearsCodingProf_ohe_DevType_Student  5.131526e+11
# 85                     te_CompanySize__AssessBenefits2  5.096587e+11
# 86                             te_Employment__Currency  4.863005e+11
# 87                        te_Currency__OperatingSystem  4.667136e+11
# 88                      te_YearsCodingProf__Dependents  4.634103e+11
# 89   te_CareerSatisfaction__ohe_EducationTypes_Cont...  4.607689e+11
# 90     agg_std_Country_ohe_DevType_Engineering_manager  4.584569e+11
# 91      te_AssessBenefits2__ohe_LanguageWorkedWith_PHP  4.500228e+11
# 92                  te_MilitaryUS__ohe_DevType_Student  4.486384e+11
# 93                te_Employment__ohe_Methodology_Agile  4.452663e+11
# 94                           te_Employment__MilitaryUS  4.314687e+11
# 95   te_OperatingSystem__ohe_CommunicationTools_Con...  4.303205e+11
# 96                         te_Country__AssessBenefits2  4.219460e+11
# 97   te_CompanySize__ohe_EducationTypes_Contributed...  4.191865e+11
# 98   te_OperatingSystem__ohe_DevType_Engineering_ma...  4.072656e+11
# 99                          te_Employment__YearsCoding  4.015099e+11
# 100  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  3.966399e+11
# 101                          ohe_LanguageWorkedWith_Go  3.909728e+11
# 102                te_AssessBenefits2__OperatingSystem  3.890914e+11
# 103                           te_CompanySize__Currency  3.823722e+11
# 104                    te_FormalEducation__CompanySize  3.766759e+11
# 105        rel_agg_mean_CurrencySymbol_AssessBenefits2  3.737474e+11
# 106                     te_CompanySize__CurrencySymbol  3.631777e+11
# 107   diff_agg_mean_CurrencySymbol_ohe_DevType_Student  3.613061e+11
# 108             te_FormalEducation__CareerSatisfaction  3.575742e+11
# 109                  te_Employment__CareerSatisfaction  3.520736e+11
# 110              te_CompanySize__ohe_Methodology_Agile  3.425312e+11
# 111                         te_CareerSatisfaction__Age  3.406188e+11
# 112              te_CareerSatisfaction__CurrencySymbol  3.345897e+11
# 113                       ohe_DatabaseWorkedWith_Redis  3.309312e+11
# 114                            te_AssessBenefits2__Age  3.305635e+11
# 115                         te_CompanySize__Dependents  3.278232e+11
# 116  te_CurrencySymbol__ohe_DevType_Engineering_man...  3.250978e+11
# 117           te_CurrencySymbol__ohe_Methodology_Agile  3.241433e+11
# 118                te_FormalEducation__AssessBenefits2  3.151688e+11
# 119                   rel_agg_mean_Age_AssessBenefits2  3.138218e+11
# 120       diff_agg_mean_NumberMonitors_AssessBenefits2  3.128107e+11
# 121                agg_mean_Employment_AssessBenefits2  3.109229e+11
# 122                               ohe_DevType_Designer  3.087890e+11
# 123  te_FormalEducation__ohe_CommunicationTools_Con...  2.970661e+11
# 124       diff_agg_mean_CurrencySymbol_AssessBenefits2  2.966266e+11
# 125          te_Employment__ohe_LanguageWorkedWith_PHP  2.958099e+11
# 126  te_CareerSatisfaction__ohe_CommunicationTools_...  2.943211e+11
# 127   agg_mean_Country_ohe_DevType_Engineering_manager  2.924907e+11
# 128  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  2.888194e+11
# 129                             te_CurrencySymbol__Age  2.815513e+11
# 130  te_FormalEducation__ohe_DevType_Engineering_ma...  2.802753e+11
# 131        rel_agg_mean_NumberMonitors_AssessBenefits2  2.798268e+11
# 132  diff_agg_mean_TimeFullyProductive_AssessBenefits2  2.734519e+11
# 133       rel_agg_mean_FormalEducation_AssessBenefits2  2.697434e+11
# 134  te_YearsCodingProf__ohe_DevType_Engineering_ma...  2.666972e+11
# 135          te_FormalEducation__ohe_Methodology_Agile  2.652701e+11
# 136          diff_agg_mean_Country_ohe_DevType_Student  2.646761e+11
# 137                     te_FormalEducation__MilitaryUS  2.643849e+11
# 138                                        te_UpdateCV  2.573025e+11
# 139                    te_CareerSatisfaction__Currency  2.564797e+11
# 140                              te_HypotheticalTools2  2.490398e+11
# 141             ohe_DatabaseWorkedWith_Amazon_Redshift  2.457016e+11
# 142  diff_agg_mean_CompanySize_ohe_DevType_Engineer...  2.395645e+11
# 143                            te_OperatingSystem__Age  2.393044e+11
# 144   te_Employment__ohe_CommunicationTools_Confluence  2.341112e+11
# 145  te_Employment__ohe_EducationTypes_Contributed_...  2.316843e+11
# 146           rel_agg_mean_CompanySize_AssessBenefits2  2.291942e+11
# 147                                      te_LastNewJob  2.273332e+11
# 148                     te_AssessBenefits2__MilitaryUS  2.213531e+11
# 149                     te_FormalEducation__SalaryType  2.159643e+11
# 150  te_ohe_DevType_Engineering_manager__ohe_Commun...  2.116840e+11
# 151              diff_agg_mean_Country_AssessBenefits2  2.080987e+11
# 152                  te_CareerSatisfaction__SalaryType  2.053920e+11
# 153  diff_agg_mean_Employment_ohe_EducationTypes_Pa...  2.050051e+11
# 154          diff_agg_mean_CompanySize_AssessBenefits2  2.048215e+11
# 155                 ohe_DevType_Database_administrator  2.041641e+11
# 156           ohe_Methodology_Extreme_programming__XP_  2.024737e+11
# 157                agg_mean_SalaryType_AssessBenefits2  2.023564e+11
# 158         te_CompanySize__ohe_LanguageWorkedWith_PHP  2.017654e+11
# 159                         ohe_LanguageWorkedWith_CSS  1.998678e+11
# 160                           te_JobContactPriorities1  1.988386e+11
# 161           diff_agg_mean_SalaryType_AssessBenefits2  1.954822e+11
# 162                                         te_Country  1.954110e+11
# 163  te_AssessBenefits2__ohe_EducationTypes_Contrib...  1.943907e+11
# 164                                te_CompanySize__Age  1.906527e+11
# 165  te_CurrencySymbol__ohe_EducationTypes_Contribu...  1.902650e+11
# 166  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  1.875364e+11
# 167  agg_mean_Employment_ohe_EducationTypes_Contrib...  1.862686e+11
# 168            te_FormalEducation__ohe_DevType_Student  1.846876e+11
# 169         agg_std_Country_ohe_LanguageWorkedWith_PHP  1.828684e+11
# 170                          te_sum_answer_Methodology  1.821874e+11
# 171         te_CareerSatisfaction__ohe_DevType_Student  1.819297e+11
# 172                       te_AssessBenefits2__Currency  1.801610e+11
# 173  diff_agg_mean_YearsCodingProf_ohe_LanguageWork...  1.780357e+11
# 174  agg_std_ohe_DevType_Student_ohe_RaceEthnicity_...  1.752236e+11
# 175       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.747744e+11
# 176               ohe_DatabaseWorkedWith_Elasticsearch  1.706984e+11
# 177                   te_sum_answer_DatabaseWorkedWith  1.702226e+11
# 178  te_YearsCoding__ohe_CommunicationTools_Confluence  1.665478e+11
# 179     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.661559e+11
# 180                     ohe_FrameworkWorkedWith_Hadoop  1.616200e+11
# 181        ohe_DevType_Educator_or_academic_researcher  1.606306e+11
# 182  te_CurrencySymbol__ohe_CommunicationTools_Conf...  1.600885e+11
# 183                       ohe_PlatformWorkedWith_Azure  1.597413e+11
# 184                       ohe_CommunicationTools_Slack  1.579914e+11
# 185       diff_agg_mean_SalaryType_ohe_DevType_Student  1.574510e+11
# 186     te_FormalEducation__ohe_LanguageWorkedWith_PHP  1.546952e+11
# 187          te_Age__ohe_CommunicationTools_Confluence  1.523310e+11
# 188                             te_JobEmailPriorities5  1.473630e+11
# 189  agg_mean_HopeFiveYears_ohe_DevType_Engineering...  1.466972e+11
# 190               te_SalaryType__ohe_Methodology_Agile  1.436653e+11
# 191                                        AssessJob10  1.431535e+11
# 192  te_FormalEducation__ohe_EducationTypes_Contrib...  1.423342e+11
# 193  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  1.412772e+11
# 194  diff_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_E...  1.402235e+11
# 195                         ohe_PlatformWorkedWith_AWS  1.387056e+11
# 196  agg_mean_Employment_ohe_DevType_Engineering_ma...  1.382627e+11
# 197  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  1.379685e+11
# 198         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.377763e+11
# 199             ohe_DatabaseWorkedWith_Google_BigQuery  1.373115e+11
# 200  rel_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_Ed...  1.366488e+11
# 201                       ohe_LanguageWorkedWith_Scala  1.361405e+11
# 202                     te_AssessBenefits2__SalaryType  1.353365e+11
# 203            rel_agg_mean_JobSatisfaction_AssessJob5  1.352310e+11
# 204                                        te_WakeTime  1.350259e+11
# 205  diff_agg_mean_TimeFullyProductive_ohe_Communic...  1.341853e+11
# 206  diff_agg_mean_ohe_LanguageDesireNextYear_PHP_o...  1.331313e+11
# 207                        te_Age__ohe_DevType_Student  1.322129e+11
# 208              te_YearsCoding__ohe_Methodology_Agile  1.316808e+11
# 209  te_Age__ohe_EducationTypes_Contributed_to_open...  1.314947e+11
# 210                   ohe_DatabaseWorkedWith_Cassandra  1.311492e+11
# 211      diff_agg_mean_FormalEducation_AssessBenefits2  1.308108e+11
# 212                         te_CompanySize__MilitaryUS  1.302676e+11
# 213               diff_agg_mean_CompanySize_AssessJob5  1.287889e+11
# 214                                 sum_answer_DevType  1.283140e+11
# 215                      te_StackOverflowJobsRecommend  1.280859e+11
# 216                     agg_mean_Employment_AssessJob5  1.280309e+11
# 217                   ohe_DevType_System_administrator  1.276701e+11
# 218         te_YearsCoding__ohe_LanguageWorkedWith_PHP  1.264476e+11
# 219                                JobEmailPriorities5  1.260596e+11
# 220               rel_agg_mean_Country_AssessBenefits2  1.254515e+11
# 221                                      te_AssessJob6  1.243630e+11
# 222                        ohe_LanguageWorkedWith_HTML  1.240524e+11
# 223                      sum_answer_DatabaseWorkedWith  1.237923e+11
# 224                              te_StackOverflowVisit  1.222808e+11
# 225                                  ohe_IDE_Notepad__  1.218362e+11
# 226                 agg_std_Employment_AssessBenefits2  1.215648e+11
# 227  diff_agg_mean_Employment_ohe_LanguageDesireNex...  1.214861e+11
# 228                     te_OperatingSystem__MilitaryUS  1.209749e+11
# 229        diff_agg_mean_Country_ohe_Methodology_Agile  1.208023e+11
# 230                                     te_AssessJob10  1.193384e+11
# 231                          te_Employment__Dependents  1.189027e+11
# 232            te_Currency__ohe_LanguageWorkedWith_PHP  1.188340e+11
# 233      te_ohe_DevType_Student__ohe_Methodology_Agile  1.182478e+11
# 234   rel_agg_mean_TimeFullyProductive_AssessBenefits2  1.179535e+11
# 235      diff_agg_mean_OperatingSystem_AssessBenefits2  1.175499e+11
# 236  agg_std_HopeFiveYears_ohe_EducationTypes_Contr...  1.166995e+11
# 237                                 te_Age__MilitaryUS  1.166634e+11
# 238                              JobContactPriorities1  1.162279e+11
# 239      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  1.150805e+11
# 240    diff_agg_mean_CompanySize_ohe_Methodology_Agile  1.144347e+11
# 241                                te_EducationParents  1.142120e+11
# 242                    te_FormalEducation__YearsCoding  1.130536e+11
# 243  ohe_AdsActions_Paid_to_access_a_website_advert...  1.123672e+11
# 244  diff_agg_mean_SalaryType_ohe_DevType_Engineeri...  1.115501e+11
# 245            te_AssessBenefits2__ohe_DevType_Student  1.114140e+11
# 246                             sum_answer_Methodology  1.109268e+11
# 247                                         AssessJob6  1.104619e+11
# 248  diff_agg_mean_Currency_ohe_CommunicationTools_...  1.104066e+11
# 249  diff_agg_mean_TimeFullyProductive_ohe_DevType_...  1.089364e+11
# 250                              JobContactPriorities4  1.084393e+11
# 251                                 te_AssessBenefits7  1.082955e+11
# 252                  te_CareerSatisfaction__MilitaryUS  1.077668e+11
# 253  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.064649e+11
# 254                                        te_Exercise  1.064408e+11
# 255                      te_Age__ohe_Methodology_Agile  1.063323e+11
# 256  diff_agg_mean_Currency_ohe_EducationTypes_Part...  1.059668e+11
# 257             ohe_DatabaseWorkedWith_Amazon_DynamoDB  1.058324e+11
# 258                     te_AssessBenefits2__Dependents  1.054043e+11
# 259                     te_Employment__AssessBenefits2  1.053120e+11
# 260          diff_agg_mean_YearsCoding_AssessBenefits2  1.052302e+11
# 261                agg_std_Country_ohe_DevType_Student  1.049957e+11
# 262  te_Currency__ohe_EducationTypes_Contributed_to...  1.038360e+11
# 263  te_ohe_Methodology_Agile__ohe_RaceEthnicity_Wh...  1.036787e+11
# 264        diff_agg_mean_CareerSatisfaction_AssessJob5  1.030344e+11
# 265                      ohe_LanguageDesireNextYear_F_  1.024917e+11
# 266  te_SalaryType__ohe_EducationTypes_Contributed_...  1.022492e+11
# 267                    rel_agg_mean_Country_AssessJob5  1.021340e+11
# 268                     te_sum_answer_HackathonReasons  1.020549e+11
# 269  diff_agg_mean_CurrencySymbol_ohe_EducationType...  1.016133e+11
# 270                                      te_AssessJob7  1.014430e+11
# 271                                te_AssessBenefits10  1.012410e+11
# 272  rel_agg_mean_TimeFullyProductive_ohe_Communica...  1.009813e+11
# 273                         te_YearsCoding__Dependents  1.006459e+11
# 274    te_YearsCoding__ohe_DevType_Engineering_manager  9.996339e+10
# 275                diff_agg_mean_Employment_AssessJob5  9.978199e+10
# 276                    ohe_DevType_Front_end_developer  9.970216e+10
# 277     agg_mean_Employment_ohe_LanguageWorkedWith_PHP  9.880632e+10
# 278                                      te_Employment  9.824448e+10
# 279                      te_CurrencySymbol__Dependents  9.805383e+10
# 280                rel_agg_mean_CompanySize_AssessJob5  9.720926e+10
# 281     ohe_DevType_C_suite_executive__CEO__CTO__etc__  9.709881e+10
# 282                             te_JobEmailPriorities6  9.684244e+10
# 283                                    AssessBenefits8  9.678483e+10
# 284               agg_mean_CompanySize_AssessBenefits2  9.675027e+10
# 285  diff_agg_mean_Country_ohe_DevType_Engineering_...  9.664504e+10
# 286  diff_agg_mean_SalaryType_ohe_ErgonomicDevices_...  9.655510e+10
# 287  rel_agg_mean_CompanySize_ohe_DevType_Engineeri...  9.638530e+10
# 288                              te_sum_answer_DevType  9.576523e+10
# 289                                      te_AssessJob1  9.549483e+10
# 290          agg_mean_Employment_ohe_Methodology_Agile  9.513918e+10
# 291                 agg_std_OperatingSystem_AssessJob8  9.441668e+10
# 292                                  te_AdsPriorities2  9.413205e+10
# 293                     te_SalaryType__OperatingSystem  9.367263e+10
# 294                   ohe_DevType_QA_or_test_developer  9.351606e+10
# 295               agg_mean_Country_ohe_DevType_Student  9.240021e+10
# 296                           te_JobContactPriorities4  9.231753e+10
# 297  te_AssessBenefits2__ohe_CommunicationTools_Con...  9.206687e+10
# 298                                   AssessBenefits11  9.180173e+10
# 299                          te_SalaryType__Dependents  9.086341e+10

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 67029.27544594,  92505.61951239,  86365.18732588, ...,
#         89653.80253788,  79590.28224945, 115565.61211034])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/012_multi_te_20314.csv", index=False)
