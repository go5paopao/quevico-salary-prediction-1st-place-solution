# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 465), (11259, 464))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
# te_cols = [c for c in use_cols if "agg_" not in c and train_df[c].nunique() >= 5]
te_cols = [c for c in train_df.columns if c in cat_cols]

# %%
for c in tqdm(te_cols):
    new_col = "te_" + c
    train_df[new_col] = 0
    test_df[new_col] = 0
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=65.0), HTML(value='')))

# %%
# multiple target encoding
multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
imp_feats = get_importance_cols(use_num=30)
multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))

# %%
for col_a, col_b in tqdm(combi_multi_te_cols):
    new_col = "te_" + col_a + "__" + col_b
    train_df[new_col] = 0
    test_df[new_col] = 0
    train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
    test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
    del train_df["tmp"], test_df["tmp"]
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=210.0), HTML(value='')))

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3531

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'regression',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20796.9	valid_1's rmse: 21673.7
# [200]	training's rmse: 19668.3	valid_1's rmse: 21116.3
# [300]	training's rmse: 19044.1	valid_1's rmse: 20895.7
# [400]	training's rmse: 18550.8	valid_1's rmse: 20751.5
# [500]	training's rmse: 18140.1	valid_1's rmse: 20685.7
# [600]	training's rmse: 17760.2	valid_1's rmse: 20628.6
# [700]	training's rmse: 17447	valid_1's rmse: 20624.9
# [800]	training's rmse: 17132.9	valid_1's rmse: 20598.8
# [900]	training's rmse: 16853.6	valid_1's rmse: 20566.4
# [1000]	training's rmse: 16583.2	valid_1's rmse: 20560.3
# [1100]	training's rmse: 16327.6	valid_1's rmse: 20548.3
# [1200]	training's rmse: 16078.9	valid_1's rmse: 20548.4
# Early stopping, best iteration is:
# [1129]	training's rmse: 16249.5	valid_1's rmse: 20537.6
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20778.3	valid_1's rmse: 21771.6
# [200]	training's rmse: 19659.2	valid_1's rmse: 21088.4
# [300]	training's rmse: 19004.3	valid_1's rmse: 20798.5
# [400]	training's rmse: 18512.6	valid_1's rmse: 20641
# [500]	training's rmse: 18112.6	valid_1's rmse: 20535.2
# [600]	training's rmse: 17733.3	valid_1's rmse: 20452.1
# [700]	training's rmse: 17401.4	valid_1's rmse: 20398
# [800]	training's rmse: 17098.9	valid_1's rmse: 20340.5
# [900]	training's rmse: 16817.3	valid_1's rmse: 20303.8
# [1000]	training's rmse: 16554	valid_1's rmse: 20280.8
# [1100]	training's rmse: 16283.1	valid_1's rmse: 20257.3
# [1200]	training's rmse: 16045.1	valid_1's rmse: 20237.3
# [1300]	training's rmse: 15805.5	valid_1's rmse: 20223.6
# [1400]	training's rmse: 15568.8	valid_1's rmse: 20214.9
# [1500]	training's rmse: 15326.4	valid_1's rmse: 20196.6
# [1600]	training's rmse: 15119.9	valid_1's rmse: 20194.9
# [1700]	training's rmse: 14921.5	valid_1's rmse: 20194.7
# [1800]	training's rmse: 14739.3	valid_1's rmse: 20182.7
# [1900]	training's rmse: 14542.2	valid_1's rmse: 20175.8
# [2000]	training's rmse: 14355.9	valid_1's rmse: 20175.9
# [2100]	training's rmse: 14168.3	valid_1's rmse: 20171
# Early stopping, best iteration is:
# [2021]	training's rmse: 14310.3	valid_1's rmse: 20165.5
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20819.1	valid_1's rmse: 21622.1
# [200]	training's rmse: 19659.5	valid_1's rmse: 21066.9
# [300]	training's rmse: 19005.5	valid_1's rmse: 20902
# [400]	training's rmse: 18514.5	valid_1's rmse: 20793.3
# [500]	training's rmse: 18098.3	valid_1's rmse: 20731.2
# [600]	training's rmse: 17727.2	valid_1's rmse: 20692.1
# [700]	training's rmse: 17399	valid_1's rmse: 20667.3
# [800]	training's rmse: 17068.3	valid_1's rmse: 20620.7
# [900]	training's rmse: 16763.9	valid_1's rmse: 20597.9
# [1000]	training's rmse: 16498	valid_1's rmse: 20574.4
# [1100]	training's rmse: 16246.5	valid_1's rmse: 20562.8
# Early stopping, best iteration is:
# [1095]	training's rmse: 16257.7	valid_1's rmse: 20560.4
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20834.8	valid_1's rmse: 21668.3
# [200]	training's rmse: 19699.8	valid_1's rmse: 21066.8
# [300]	training's rmse: 19062.6	valid_1's rmse: 20794.2
# [400]	training's rmse: 18565.7	valid_1's rmse: 20625.8
# [500]	training's rmse: 18153.8	valid_1's rmse: 20549.9
# [600]	training's rmse: 17803.6	valid_1's rmse: 20473.3
# [700]	training's rmse: 17480.1	valid_1's rmse: 20408.3
# [800]	training's rmse: 17185	valid_1's rmse: 20361.2
# [900]	training's rmse: 16903.5	valid_1's rmse: 20315.9
# [1000]	training's rmse: 16627.6	valid_1's rmse: 20296.5
# [1100]	training's rmse: 16367.2	valid_1's rmse: 20269.5
# Early stopping, best iteration is:
# [1099]	training's rmse: 16369.7	valid_1's rmse: 20268.2
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20890.9	valid_1's rmse: 21405
# [200]	training's rmse: 19770.9	valid_1's rmse: 20697.6
# [300]	training's rmse: 19108.3	valid_1's rmse: 20441
# [400]	training's rmse: 18601.8	valid_1's rmse: 20306.8
# [500]	training's rmse: 18173.5	valid_1's rmse: 20226.2
# [600]	training's rmse: 17819.8	valid_1's rmse: 20165.9
# [700]	training's rmse: 17495.8	valid_1's rmse: 20113.8
# [800]	training's rmse: 17187.2	valid_1's rmse: 20086.5
# [900]	training's rmse: 16907.8	valid_1's rmse: 20082
# [1000]	training's rmse: 16645.8	valid_1's rmse: 20064.4
# [1100]	training's rmse: 16404.8	valid_1's rmse: 20045.6
# [1200]	training's rmse: 16171.4	valid_1's rmse: 20031.1
# [1300]	training's rmse: 15940.6	valid_1's rmse: 20028.2
# Early stopping, best iteration is:
# [1253]	training's rmse: 16052.4	valid_1's rmse: 20024.6

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20312.330026819403

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  4.448626e+13
# 1                               te_Country__Employment  2.135811e+13
# 2                                      te_Country__Age  2.116322e+13
# 3                      te_Country__ohe_DevType_Student  1.960813e+13
# 4                               te_Country__SalaryType  1.609062e+13
# 5                         te_YearsCodingProf__Currency  1.447356e+13
# 6                              te_Country__YearsCoding  1.440868e+13
# 7                        te_SalaryType__CurrencySymbol  1.440829e+13
# 8                   te_YearsCodingProf__CurrencySymbol  1.371565e+13
# 9          te_Country__ohe_DevType_Engineering_manager  8.650644e+12
# 10                    te_Currency__ohe_DevType_Student  8.299641e+12
# 11                      te_YearsCoding__CurrencySymbol  5.251836e+12
# 12              te_Country__ohe_LanguageWorkedWith_PHP  4.745358e+12
# 13                              te_Country__MilitaryUS  4.279969e+12
# 14                                    te_Currency__Age  3.845606e+12
# 15                              te_CurrencySymbol__Age  3.778275e+12
# 16              te_YearsCodingProf__CareerSatisfaction  3.637475e+12
# 17                     te_CompanySize__YearsCodingProf  3.392551e+12
# 18                             te_Country__CompanySize  3.329597e+12
# 19                         te_Country__FormalEducation  3.143835e+12
# 20   agg_std_Country_ohe_EducationTypes_Contributed...  3.042216e+12
# 21   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.945099e+12
# 22                         te_Country__OperatingSystem  2.884974e+12
# 23                      te_YearsCodingProf__MilitaryUS  2.741675e+12
# 24                                  te_Age__MilitaryUS  2.676785e+12
# 25                                te_Country__Currency  2.665694e+12
# 26                 te_YearsCodingProf__OperatingSystem  2.632773e+12
# 27                   te_Country__ohe_Methodology_Agile  2.602417e+12
# 28                          te_YearsCoding__MilitaryUS  2.595801e+12
# 29                       te_Employment__CurrencySymbol  2.517953e+12
# 30                      te_YearsCodingProf__SalaryType  2.407166e+12
# 31   te_YearsCodingProf__ohe_CommunicationTools_Con...  2.378533e+12
# 32   te_Country__ohe_EducationTypes_Contributed_to_...  2.298990e+12
# 33                  te_Employment__ohe_DevType_Student  2.204648e+12
# 34              te_CurrencySymbol__ohe_DevType_Student  2.089201e+12
# 35                         te_CompanySize__YearsCoding  1.695551e+12
# 36                     te_CompanySize__OperatingSystem  1.655053e+12
# 37   te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  1.521363e+12
# 38   agg_std_YearsCodingProf_ohe_CommunicationTools...  1.464486e+12
# 39             te_YearsCodingProf__ohe_DevType_Student  1.461010e+12
# 40                             te_Employment__Currency  1.382868e+12
# 41   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.382118e+12
# 42                             te_YearsCodingProf__Age  1.264415e+12
# 43                     te_YearsCoding__OperatingSystem  1.189708e+12
# 44                      te_Employment__YearsCodingProf  1.186642e+12
# 45                 te_FormalEducation__YearsCodingProf  1.182802e+12
# 46   te_CompanySize__ohe_CommunicationTools_Confluence  1.145509e+12
# 47                          te_Country__CurrencySymbol  1.126135e+12
# 48                     te_YearsCoding__YearsCodingProf  1.083377e+12
# 49                  te_FormalEducation__CurrencySymbol  1.047639e+12
# 50      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  1.043799e+12
# 51   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  1.033286e+12
# 52   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  9.731841e+11
# 53                                  te_Employment__Age  9.149663e+11
# 54                           te_Employment__MilitaryUS  8.982494e+11
# 55                          te_YearsCoding__SalaryType  8.894938e+11
# 56                      te_Employment__FormalEducation  8.891050e+11
# 57                  te_YearsCoding__CareerSatisfaction  8.546950e+11
# 58                            te_YearsCoding__Currency  8.428073e+11
# 59                           te_Employment__SalaryType  8.085416e+11
# 60      te_Employment__ohe_DevType_Engineering_manager  7.968250e+11
# 61         rel_agg_mean_CurrencySymbol_AssessBenefits2  7.829326e+11
# 62                      te_Country__CareerSatisfaction  7.605341e+11
# 63                                          te_Country  7.567893e+11
# 64               te_CompanySize__ohe_Methodology_Agile  7.420764e+11
# 65                  te_CompanySize__CareerSatisfaction  7.129841e+11
# 66           te_YearsCodingProf__ohe_Methodology_Agile  7.041103e+11
# 67                              te_Country__Dependents  7.026652e+11
# 68     te_CompanySize__ohe_DevType_Engineering_manager  6.719486e+11
# 69              te_FormalEducation__CareerSatisfaction  6.627139e+11
# 70                        te_FormalEducation__Currency  6.174234e+11
# 71   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  6.130729e+11
# 72               te_YearsCoding__ohe_Methodology_Agile  6.030316e+11
# 73                te_SalaryType__ohe_Methodology_Agile  5.920185e+11
# 74       te_Country__ohe_CommunicationTools_Confluence  5.378447e+11
# 75        diff_agg_mean_CurrencySymbol_AssessBenefits2  5.241101e+11
# 76                      te_CompanySize__CurrencySymbol  5.146744e+11
# 77                   te_Employment__CareerSatisfaction  5.037037e+11
# 78                  te_CurrencySymbol__OperatingSystem  5.018199e+11
# 79                      te_Employment__OperatingSystem  4.713019e+11
# 80   te_CompanySize__ohe_EducationTypes_Contributed...  4.458711e+11
# 81                      te_OperatingSystem__MilitaryUS  4.450601e+11
# 82            rel_agg_mean_CompanySize_AssessBenefits2  4.347381e+11
# 83              te_CareerSatisfaction__OperatingSystem  4.270442e+11
# 84   te_CareerSatisfaction__ohe_DevType_Engineering...  4.138091e+11
# 85   agg_mean_YearsCodingProf_ohe_DevType_Engineeri...  3.944915e+11
# 86                           ohe_LanguageWorkedWith_Go  3.902596e+11
# 87   te_ohe_DevType_Student__ohe_LanguageWorkedWith...  3.771905e+11
# 88           te_Employment__ohe_LanguageWorkedWith_PHP  3.706398e+11
# 89              diff_agg_mean_Currency_AssessBenefits2  3.682065e+11
# 90                            te_CompanySize__Currency  3.622174e+11
# 91   te_OperatingSystem__ohe_CommunicationTools_Con...  3.590603e+11
# 92                          te_CompanySize__Dependents  3.494540e+11
# 93          te_CompanySize__ohe_LanguageWorkedWith_PHP  3.452620e+11
# 94                  te_SalaryType__ohe_DevType_Student  3.451859e+11
# 95                         te_Age__ohe_DevType_Student  3.341850e+11
# 96                          te_CompanySize__SalaryType  3.285154e+11
# 97   diff_agg_mean_ohe_RaceEthnicity_White_or_of_Eu...  3.250967e+11
# 98                      te_FormalEducation__SalaryType  3.248332e+11
# 99                     te_FormalEducation__CompanySize  3.239874e+11
# 100                te_CompanySize__ohe_DevType_Student  3.233091e+11
# 101  te_YearsCodingProf__ohe_DevType_Engineering_ma...  3.217244e+11
# 102                  te_CareerSatisfaction__SalaryType  3.165932e+11
# 103  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  3.164102e+11
# 104  te_OperatingSystem__ohe_DevType_Engineering_ma...  3.143994e+11
# 105                agg_mean_SalaryType_AssessBenefits2  3.113180e+11
# 106                                 te_SalaryType__Age  3.098440e+11
# 107  te_FormalEducation__ohe_CommunicationTools_Con...  3.096386e+11
# 108          diff_agg_mean_YearsCoding_AssessBenefits2  3.085202e+11
# 109                       te_Currency__OperatingSystem  3.064919e+11
# 110      diff_agg_mean_FormalEducation_AssessBenefits2  3.049291e+11
# 111  te_Employment__ohe_EducationTypes_Contributed_...  3.046870e+11
# 112                       ohe_DatabaseWorkedWith_Redis  2.993938e+11
# 113  diff_agg_mean_CompanySize_ohe_DevType_Engineer...  2.981476e+11
# 114  te_CareerSatisfaction__ohe_EducationTypes_Cont...  2.975553e+11
# 115  te_YearsCoding__ohe_CommunicationTools_Confluence  2.969931e+11
# 116       diff_agg_mean_NumberMonitors_AssessBenefits2  2.964720e+11
# 117  agg_mean_MilitaryUS_ohe_RaceEthnicity_White_or...  2.936110e+11
# 118              te_CareerSatisfaction__CurrencySymbol  2.934181e+11
# 119   te_SalaryType__ohe_CommunicationTools_Confluence  2.913860e+11
# 120  agg_mean_YearsCodingProf_ohe_RaceEthnicity_Whi...  2.879184e+11
# 121          agg_mean_Employment_ohe_Methodology_Agile  2.814389e+11
# 122       rel_agg_mean_FormalEducation_AssessBenefits2  2.791308e+11
# 123              rel_agg_mean_Currency_AssessBenefits2  2.778594e+11
# 124                te_FormalEducation__OperatingSystem  2.778272e+11
# 125                         te_Employment__YearsCoding  2.764021e+11
# 126                              te_HypotheticalTools2  2.732598e+11
# 127                            te_Currency__SalaryType  2.714897e+11
# 128                     te_SalaryType__OperatingSystem  2.669501e+11
# 129                            te_OperatingSystem__Age  2.665799e+11
# 130  te_FormalEducation__ohe_DevType_Engineering_ma...  2.655868e+11
# 131           diff_agg_mean_SalaryType_AssessBenefits2  2.655107e+11
# 132               te_Employment__ohe_Methodology_Agile  2.615456e+11
# 133  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  2.609387e+11
# 134                         te_Employment__CompanySize  2.595582e+11
# 135  te_CareerSatisfaction__ohe_CommunicationTools_...  2.579816e+11
# 136                   rel_agg_mean_Age_AssessBenefits2  2.555188e+11
# 137       te_Currency__ohe_DevType_Engineering_manager  2.527580e+11
# 138  te_ohe_CommunicationTools_Confluence__ohe_Lang...  2.522062e+11
# 139  te_CurrencySymbol__ohe_EducationTypes_Contribu...  2.503959e+11
# 140  diff_agg_mean_Employment_ohe_EducationTypes_Pa...  2.497737e+11
# 141  te_ohe_DevType_Engineering_manager__ohe_Commun...  2.470904e+11
# 142         te_YearsCoding__ohe_LanguageWorkedWith_PHP  2.446736e+11
# 143                     te_YearsCodingProf__Dependents  2.405683e+11
# 144  te_FormalEducation__ohe_EducationTypes_Contrib...  2.375311e+11
# 145                                        te_UpdateCV  2.374627e+11
# 146                                      te_LastNewJob  2.370375e+11
# 147        agg_std_YearsCodingProf_ohe_DevType_Student  2.321354e+11
# 148                  diff_agg_mean_Age_AssessBenefits2  2.303855e+11
# 149                              JobContactPriorities1  2.267067e+11
# 150                         te_CareerSatisfaction__Age  2.255017e+11
# 151                               ohe_DevType_Designer  2.222551e+11
# 152  agg_mean_Employment_ohe_CommunicationTools_Con...  2.220409e+11
# 153     te_FormalEducation__ohe_LanguageWorkedWith_PHP  2.152995e+11
# 154                      te_CurrencySymbol__MilitaryUS  2.135344e+11
# 155   rel_agg_mean_TimeFullyProductive_AssessBenefits2  2.120564e+11
# 156  diff_agg_mean_TimeFullyProductive_AssessBenefits2  2.119291e+11
# 157                      sum_answer_DatabaseWorkedWith  2.114314e+11
# 158                            te_FormalEducation__Age  2.080122e+11
# 159      diff_agg_mean_JobSatisfaction_AssessBenefits2  2.072268e+11
# 160               rel_agg_mean_Country_AssessBenefits2  2.069451e+11
# 161              diff_agg_mean_Country_AssessBenefits2  2.035677e+11
# 162                       ohe_LanguageWorkedWith_Scala  2.010866e+11
# 163  diff_agg_mean_TimeFullyProductive_ohe_Communic...  2.003885e+11
# 164   te_Employment__ohe_CommunicationTools_Confluence  1.981824e+11
# 165                                 sum_answer_DevType  1.943600e+11
# 166               ohe_DatabaseWorkedWith_Elasticsearch  1.940232e+11
# 167                                JobEmailPriorities5  1.916250e+11
# 168                         ohe_LanguageWorkedWith_CSS  1.890710e+11
# 169                        agg_mean_Country_AssessJob5  1.884587e+11
# 170                         ohe_PlatformWorkedWith_AWS  1.854568e+11
# 171          te_Age__ohe_CommunicationTools_Confluence  1.849913e+11
# 172             ohe_DatabaseWorkedWith_Amazon_Redshift  1.823936e+11
# 173    te_YearsCoding__ohe_DevType_Engineering_manager  1.822566e+11
# 174                                te_CompanySize__Age  1.776765e+11
# 175       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.763726e+11
# 176                         te_CompanySize__MilitaryUS  1.751118e+11
# 177  diff_agg_mean_SalaryType_ohe_DevType_Engineeri...  1.714944e+11
# 178  diff_agg_mean_Employment_ohe_LanguageDesireNex...  1.706107e+11
# 179          diff_agg_mean_CompanySize_AssessBenefits2  1.696884e+11
# 180   rel_agg_mean_ohe_DevType_Student_AssessBenefits2  1.682328e+11
# 181       te_CareerSatisfaction__ohe_Methodology_Agile  1.676342e+11
# 182  agg_mean_HopeFiveYears_ohe_EducationTypes_Cont...  1.647733e+11
# 183            rel_agg_mean_MilitaryUS_AssessBenefits2  1.643337e+11
# 184                       ohe_CommunicationTools_Slack  1.629472e+11
# 185                     ohe_FrameworkWorkedWith_Hadoop  1.628609e+11
# 186                                        AssessJob10  1.613140e+11
# 187                              JobContactPriorities4  1.609063e+11
# 188         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.595200e+11
# 189     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.590897e+11
# 190        ohe_DevType_Educator_or_academic_researcher  1.566290e+11
# 191           ohe_Methodology_Extreme_programming__XP_  1.564923e+11
# 192                      agg_std_Employment_AssessJob4  1.560043e+11
# 193  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  1.555509e+11
# 194                             sum_answer_Methodology  1.549611e+11
# 195  agg_mean_Country_ohe_CommunicationTools_Conflu...  1.525271e+11
# 196  diff_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_E...  1.524261e+11
# 197           te_CurrencySymbol__ohe_Methodology_Agile  1.493894e+11
# 198              diff_agg_mean_Student_AssessBenefits2  1.481035e+11
# 199                    ohe_DevType_Front_end_developer  1.454609e+11
# 200  diff_agg_mean_TimeFullyProductive_ohe_Communic...  1.440938e+11
# 201  te_Employment__ohe_RaceEthnicity_White_or_of_E...  1.440077e+11
# 202        rel_agg_mean_UndergradMajor_AssessBenefits2  1.433497e+11
# 203                     te_FormalEducation__MilitaryUS  1.433380e+11
# 204                  te_CareerSatisfaction__Dependents  1.419583e+11
# 205                                te_YearsCoding__Age  1.419410e+11
# 206                       ohe_PlatformWorkedWith_Azure  1.415741e+11
# 207  te_OperatingSystem__ohe_EducationTypes_Contrib...  1.392937e+11
# 208                      te_StackOverflowJobsRecommend  1.388913e+11
# 209  rel_agg_mean_Employment_ohe_CommunicationTools...  1.381923e+11
# 210                                        te_WakeTime  1.372239e+11
# 211        rel_agg_mean_TimeFullyProductive_AssessJob5  1.362817e+11
# 212                                         AssessJob6  1.361109e+11
# 213        rel_agg_mean_NumberMonitors_AssessBenefits2  1.358012e+11
# 214       diff_agg_mean_AgreeDisagree3_AssessBenefits2  1.341720e+11
# 215                 ohe_DevType_Database_administrator  1.333908e+11
# 216      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  1.325872e+11
# 217             ohe_DatabaseWorkedWith_Google_BigQuery  1.323342e+11
# 218  diff_agg_mean_ohe_DevType_Engineering_manager_...  1.306332e+11
# 219                    te_FormalEducation__YearsCoding  1.302447e+11
# 220                                te_EducationParents  1.272729e+11
# 221                      te_Age__ohe_Methodology_Agile  1.238412e+11
# 222                              te_StackOverflowVisit  1.236316e+11
# 223                   ohe_DevType_System_administrator  1.231935e+11
# 224                                    AssessBenefits2  1.228837e+11
# 225  diff_agg_mean_CurrencySymbol_ohe_EducationType...  1.219328e+11
# 226         rel_agg_mean_CareerSatisfaction_AssessJob5  1.217706e+11
# 227  agg_std_HopeFiveYears_ohe_DevType_Engineering_...  1.215671e+11
# 228                te_YearsCoding__ohe_DevType_Student  1.214159e+11
# 229                      te_CurrencySymbol__Dependents  1.206692e+11
# 230  agg_mean_HopeFiveYears_ohe_DevType_Engineering...  1.199793e+11
# 231           diff_agg_mean_MilitaryUS_AssessBenefits2  1.196797e+11
# 232       diff_agg_mean_UndergradMajor_AssessBenefits2  1.195776e+11
# 233                                    AssessBenefits8  1.195350e+11
# 234  te_ohe_CommunicationTools_Confluence__ohe_Meth...  1.173651e+11
# 235  diff_agg_mean_Country_ohe_LanguageDesireNextYe...  1.169931e+11
# 236  te_CurrencySymbol__ohe_DevType_Engineering_man...  1.159843e+11
# 237                                   AssessBenefits11  1.153332e+11
# 238                          te_SalaryType__Dependents  1.151692e+11
# 239           rel_agg_mean_Country_ohe_DevType_Student  1.142525e+11
# 240   te_Dependents__ohe_CommunicationTools_Confluence  1.136943e+11
# 241                          te_SalaryType__MilitaryUS  1.135067e+11
# 242                                        te_Exercise  1.135011e+11
# 243            rel_agg_mean_JobSatisfaction_AssessJob5  1.129896e+11
# 244  diff_agg_mean_Country_ohe_EducationTypes_Parti...  1.129507e+11
# 245  diff_agg_mean_ohe_LanguageWorkedWith_PHP_Asses...  1.122903e+11
# 246                   ohe_DatabaseWorkedWith_Cassandra  1.119784e+11
# 247                 agg_std_OperatingSystem_AssessJob8  1.112176e+11
# 248                                JobEmailPriorities6  1.111796e+11
# 249         te_CareerSatisfaction__ohe_DevType_Student  1.100301e+11
# 250                         te_YearsCoding__Dependents  1.098028e+11
# 251  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.097698e+11
# 252  agg_mean_Employment_ohe_EducationTypes_Partici...  1.094456e+11
# 253           agg_mean_OperatingSystem_AssessBenefits2  1.090772e+11
# 254                      ohe_LanguageDesireNextYear_F_  1.085733e+11
# 255           diff_agg_mean_Employment_AssessBenefits2  1.068870e+11
# 256  agg_std_YearsCodingProf_ohe_RaceEthnicity_Whit...  1.068622e+11
# 257           diff_agg_mean_JobSatisfaction_AssessJob5  1.068087e+11
# 258                                    te_HoursOutside  1.059856e+11
# 259  diff_agg_mean_Country_ohe_DevType_Engineering_...  1.057801e+11
# 260                              JobContactPriorities3  1.044002e+11
# 261                      ohe_FrameworkWorkedWith_React  1.037859e+11
# 262                   diff_agg_mean_Country_AssessJob5  1.037852e+11
# 263                                    AssessBenefits1  1.035878e+11
# 264            rel_agg_mean_Employment_AssessBenefits2  1.028173e+11
# 265               diff_agg_mean_CompanySize_AssessJob5  1.026156e+11
# 266                 te_Age__ohe_LanguageWorkedWith_PHP  1.018319e+11
# 267                                  ohe_IDE_Notepad__  1.016990e+11
# 268  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  1.013235e+11
# 269             agg_mean_HopeFiveYears_AssessBenefits2  1.009597e+11
# 270  ohe_AdsActions_Paid_to_access_a_website_advert...  1.008789e+11
# 271                              te_HypotheticalTools1  1.008755e+11
# 272                        ohe_LanguageWorkedWith_HTML  9.943063e+10
# 273  diff_agg_mean_CurrencySymbol_ohe_Communication...  9.891771e+10
# 274                                     AdsPriorities2  9.866436e+10
# 275                    ohe_LanguageDesireNextYear_HTML  9.828433e+10
# 276  agg_mean_Employment_ohe_DevType_Engineering_ma...  9.758590e+10
# 277  diff_agg_mean_AgreeDisagree3_ohe_ErgonomicDevi...  9.746475e+10
# 278  diff_agg_mean_Country_ohe_ErgonomicDevices_Sta...  9.711547e+10
# 279  te_YearsCoding__ohe_EducationTypes_Contributed...  9.709291e+10
# 280  rel_agg_mean_ohe_DevType_Engineering_manager_o...  9.507274e+10
# 281          te_FormalEducation__ohe_Methodology_Agile  9.469489e+10
# 282                                         AssessJob1  9.377458e+10
# 283                                   te_SurveyTooLong  9.365692e+10
# 284  diff_agg_mean_Currency_ohe_EducationTypes_Part...  9.333808e+10
# 285            rel_agg_mean_Dependents_AssessBenefits2  9.287907e+10
# 286  te_Currency__ohe_EducationTypes_Contributed_to...  9.245564e+10
# 287        diff_agg_mean_CareerSatisfaction_AssessJob5  9.178868e+10
# 288      diff_agg_mean_YearsCodingProf_AssessBenefits2  9.148239e+10
# 289  diff_agg_mean_YearsCodingProf_ohe_Communicatio...  9.130616e+10
# 290                                 te_Age__Dependents  9.087380e+10
# 291          te_OperatingSystem__ohe_Methodology_Agile  9.085271e+10
# 292                agg_std_Country_ohe_DevType_Student  9.065691e+10
# 293  rel_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_Ed...  9.029733e+10
# 294                 te_Dependents__ohe_DevType_Student  9.013707e+10
# 295                   ohe_DevType_QA_or_test_developer  8.948667e+10
# 296       diff_agg_mean_SalaryType_ohe_DevType_Student  8.878427e+10
# 297                                JobEmailPriorities4  8.871996e+10
# 298                                     te_AIDangerous  8.869345e+10
# 299                      ohe_DevType_DevOps_specialist  8.852623e+10

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 66563.44051278,  90402.52214667,  84160.00187695, ...,
#         91410.89121156,  81970.64371795, 118028.1532839 ])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/013_clean_code_20312.csv", index=False)
