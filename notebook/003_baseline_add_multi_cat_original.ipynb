# %% [markdown]
# ## Prepare and read data

# %%
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %%
label_cols = [
    c for c in original_cols if c not in ["Salary", "No"]
]

# %%
for c in tqdm(label_cols):
    if train_df[c].dtype.name == "float":
        continue
    else:
        train_df[c], uniques = pd.factorize(train_df[c])
        test_df[c] = uniques.get_indexer(test_df[c])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=126.0), HTML(value='')))

# %%
train_df.shape
# Out:
# (33857, 444)

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]

# %%
use_cols = [c for c in train_df.columns if c not in ["Salary", "No"]]

# %% [markdown]
# ## Training

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)

# %%
lgb_params = {
            'objective': 'regression',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 128,
            'min_data_in_leaf': 30, 
            'max_depth': 6,
            "bagging_freq": 10,
            "bagging_fraction": 0.4,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.7,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))

for fold_i, (trn_idx, val_idx) in enumerate(folds.split(train_df, train_df["Salary"])):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21416.2	valid_1's rmse: 23249.3
# [200]	training's rmse: 19391.7	valid_1's rmse: 22562.1
# [300]	training's rmse: 18163	valid_1's rmse: 22312.5
# [400]	training's rmse: 17189.1	valid_1's rmse: 22235.9
# [500]	training's rmse: 16270.6	valid_1's rmse: 22177.8
# [600]	training's rmse: 15467.6	valid_1's rmse: 22144.2
# [700]	training's rmse: 14792.9	valid_1's rmse: 22119.2
# [800]	training's rmse: 14068	valid_1's rmse: 22095.5
# [900]	training's rmse: 13424.7	valid_1's rmse: 22112.6
# Early stopping, best iteration is:
# [824]	training's rmse: 13904.2	valid_1's rmse: 22089.5
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21502.7	valid_1's rmse: 23021.3
# [200]	training's rmse: 19714.2	valid_1's rmse: 22225.3
# [300]	training's rmse: 18476.2	valid_1's rmse: 21942.4
# [400]	training's rmse: 17445.7	valid_1's rmse: 21823.5
# [500]	training's rmse: 16538.2	valid_1's rmse: 21742.7
# [600]	training's rmse: 15778.8	valid_1's rmse: 21734.2
# Early stopping, best iteration is:
# [546]	training's rmse: 16197.3	valid_1's rmse: 21714
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21442.9	valid_1's rmse: 23409.2
# [200]	training's rmse: 19457.8	valid_1's rmse: 22643.4
# [300]	training's rmse: 18197.1	valid_1's rmse: 22415.5
# [400]	training's rmse: 17176.4	valid_1's rmse: 22311.1
# [500]	training's rmse: 16292.7	valid_1's rmse: 22257.7
# [600]	training's rmse: 15580.9	valid_1's rmse: 22218
# Early stopping, best iteration is:
# [593]	training's rmse: 15625.9	valid_1's rmse: 22210.6
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21436.7	valid_1's rmse: 22937.9
# [200]	training's rmse: 19446.8	valid_1's rmse: 22206.9
# [300]	training's rmse: 18283.7	valid_1's rmse: 22010.2
# [400]	training's rmse: 17277.6	valid_1's rmse: 21881.5
# [500]	training's rmse: 16371.3	valid_1's rmse: 21788.7
# [600]	training's rmse: 15559.5	valid_1's rmse: 21749.8
# [700]	training's rmse: 14830.2	valid_1's rmse: 21711.9
# [800]	training's rmse: 14093.4	valid_1's rmse: 21714.3
# Early stopping, best iteration is:
# [716]	training's rmse: 14695.3	valid_1's rmse: 21698.9
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 21447.7	valid_1's rmse: 23048
# [200]	training's rmse: 19461.5	valid_1's rmse: 22063.4
# [300]	training's rmse: 18237.9	valid_1's rmse: 21849.2
# [400]	training's rmse: 17225.9	valid_1's rmse: 21714.1
# [500]	training's rmse: 16381.4	valid_1's rmse: 21695.3
# Early stopping, best iteration is:
# [473]	training's rmse: 16572.5	valid_1's rmse: 21680.6

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 21879.878828725617

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index()
# Out:
#                                                feature          gain
# 0                                           MilitaryUS  3.910242e+13
# 1                                              Country  2.273533e+13
# 2                                      YearsCodingProf  2.235771e+13
# 3                                       CurrencySymbol  1.604069e+13
# 4                                           SalaryType  9.762817e+12
# 5                                          YearsCoding  8.217953e+12
# 6                                  ohe_DevType_Student  6.323186e+12
# 7                                           Employment  5.856388e+12
# 8                                             Currency  5.335072e+12
# 9                                                  Age  4.921390e+12
# 10      ohe_RaceEthnicity_White_or_of_European_descent  4.298958e+12
# 11                                     AssessBenefits2  3.629470e+12
# 12                                         CompanySize  3.207787e+12
# 13                                     OperatingSystem  2.522312e+12
# 14                                  CareerSatisfaction  2.276674e+12
# 15                   ohe_CommunicationTools_Confluence  1.869212e+12
# 16                                  CommunicationTools  1.843975e+12
# 17                                  DatabaseWorkedWith  1.750681e+12
# 18                     ohe_DevType_Engineering_manager  1.691191e+12
# 19                                         Methodology  1.538948e+12
# 20                                             DevType  1.478139e+12
# 21                                  LanguageWorkedWith  1.197365e+12
# 22                                                 IDE  1.147137e+12
# 23                          ohe_LanguageWorkedWith_PHP  1.121150e+12
# 24                                     FormalEducation  1.111568e+12
# 25                               ohe_Methodology_Agile  1.090684e+12
# 26                              LanguageDesireNextYear  1.080515e+12
# 27                                          Dependents  1.050094e+12
# 28                                      EducationTypes  1.036778e+12
# 29   ohe_EducationTypes_Contributed_to_open_source_...  9.789317e+11
# 30                                  PlatformWorkedWith  9.648888e+11
# 31                              DatabaseDesireNextYear  9.034268e+11
# 32                                 TimeFullyProductive  8.976534e+11
# 33                                             Student  8.569686e+11
# 34                              PlatformDesireNextYear  8.544730e+11
# 35                                     SelfTaughtTypes  8.215226e+11
# 36                                 FrameworkWorkedWith  8.100043e+11
# 37                                      NumberMonitors  7.190978e+11
# 38                                       HopeFiveYears  7.148476e+11
# 39                             FrameworkDesireNextYear  7.133851e+11
# 40                                      AgreeDisagree3  7.105700e+11
# 41                                          AssessJob5  6.997394e+11
# 42                                          AssessJob8  6.169126e+11
# 43                                     JobSatisfaction  6.125764e+11
# 44                         ohe_CommunicationTools_Jira  6.085234e+11
# 45                      ohe_LanguageDesireNextYear_PHP  6.052478e+11
# 46                                          AssessJob4  5.965450e+11
# 47                                      UndergradMajor  5.744302e+11
# 48      ohe_EducationTypes_Participated_in_a_hackathon  5.735715e+11
# 49                  ohe_ErgonomicDevices_Standing_desk  5.693546e+11
# 50                                    HackathonReasons  5.459785e+11
# 51                                      VersionControl  5.439051e+11
# 52                               JobContactPriorities1  5.428597e+11
# 53                                 JobEmailPriorities6  5.414090e+11
# 54                                          AdsActions  5.323083e+11
# 55                                     AssessBenefits8  5.251452e+11
# 56                               ohe_Methodology_Scrum  5.250828e+11
# 57                                    ErgonomicDevices  5.217140e+11
# 58                                            UpdateCV  5.194647e+11
# 59                                    AssessBenefits11  5.168062e+11
# 60                          StackOverflowJobsRecommend  5.148261e+11
# 61                                          AssessJob1  4.961428e+11
# 62                                  StackOverflowVisit  4.742508e+11
# 63                                          AssessJob7  4.665164e+11
# 64                                         AssessJob10  4.651422e+11
# 65                                       RaceEthnicity  4.645669e+11
# 66                                          AssessJob6  4.608872e+11
# 67                                    AssessBenefits10  4.555856e+11
# 68                                    EducationParents  4.553866e+11
# 69                           ohe_LanguageWorkedWith_Go  4.419832e+11
# 70                                          AssessJob3  4.378929e+11
# 71                                            WakeTime  4.364640e+11
# 72                              ohe_Methodology_Kanban  4.313693e+11
# 73                                     AssessBenefits3  4.302596e+11
# 74                                     AssessBenefits6  4.082807e+11
# 75                                          AssessJob9  4.036729e+11
# 76                                     AssessBenefits7  4.017763e+11
# 77                       ohe_RaceEthnicity_South_Asian  4.006717e+11
# 78                                     AssessBenefits4  3.995633e+11
# 79                                    AdBlockerReasons  3.987787e+11
# 80                          ohe_PlatformWorkedWith_AWS  3.987573e+11
# 81                                          AssessJob2  3.811852e+11
# 82                                     AssessBenefits5  3.809217e+11
# 83                                     AssessBenefits9  3.696082e+11
# 84                                          LastNewJob  3.659551e+11
# 85                                     AssessBenefits1  3.634977e+11
# 86                          ohe_LanguageWorkedWith_CSS  3.592608e+11
# 87                                  HypotheticalTools2  3.588692e+11
# 88                        ohe_DatabaseWorkedWith_MySQL  3.544664e+11
# 89                                            Exercise  3.496301e+11
# 90                                 JobEmailPriorities4  3.443838e+11
# 91            ohe_Methodology_Extreme_programming__XP_  3.408928e+11
# 92                                      AdsPriorities1  3.398249e+11
# 93                                   AdsAgreeDisagree2  3.264892e+11
# 94                                      AdsPriorities5  3.255140e+11
# 95                    ohe_Methodology_Pair_programming  3.225305e+11
# 96                               JobContactPriorities3  3.207919e+11
# 97                                      AdsPriorities3  3.202007e+11
# 98                                        HoursOutside  3.041383e+11
# 99                                      AdsPriorities2  3.031074e+11
# 100                           StackOverflowParticipate  2.963897e+11
# 101                                JobEmailPriorities5  2.950172e+11
# 102                                     AdsPriorities7  2.946783e+11
# 103                                     AdsPriorities4  2.928776e+11
# 104                                        AIDangerous  2.879434e+11
# 105                                 HypotheticalTools5  2.878490e+11
# 106                                JobEmailPriorities1  2.872874e+11
# 107                                 HypotheticalTools3  2.870082e+11
# 108                                      AIResponsible  2.861632e+11
# 109             ohe_DatabaseWorkedWith_Google_BigQuery  2.780305e+11
# 110                             StackOverflowRecommend  2.696601e+11
# 111                                     AgreeDisagree2  2.688714e+11
# 112     ohe_DevType_C_suite_executive__CEO__CTO__etc__  2.649083e+11
# 113                               ohe_DevType_Designer  2.641421e+11
# 114                                     AdsPriorities6  2.641235e+11
# 115               ohe_DatabaseWorkedWith_Elasticsearch  2.639237e+11
# 116                                 HypotheticalTools4  2.630340e+11
# 117                                 HypotheticalTools1  2.611207e+11
# 118                                JobEmailPriorities3  2.596409e+11
# 119                                JobEmailPriorities2  2.594636e+11
# 120                 ohe_DevType_Database_administrator  2.590060e+11
# 121                       ohe_PlatformWorkedWith_Azure  2.587387e+11
# 122                                  AdsAgreeDisagree3  2.561630e+11
# 123                              JobContactPriorities4  2.519122e+11
# 124                                    JobSearchStatus  2.518532e+11
# 125                       ohe_DatabaseWorkedWith_Redis  2.490537e+11
# 126                                         OpenSource  2.471262e+11
# 127                                JobEmailPriorities7  2.431738e+11
# 128                 ohe_DatabaseDesireNextYear_MongoDB  2.343273e+11
# 129                                  ohe_IDE_Notepad__  2.338370e+11
# 130                                  AdsAgreeDisagree1  2.298126e+11
# 131                       ohe_LanguageWorkedWith_Scala  2.269552e+11
# 132                    ohe_DevType_Front_end_developer  2.266728e+11
# 133                                       EthicsReport  2.187738e+11
# 134  ohe_CommunicationTools_Office___productivity_s...  2.120782e+11
# 135                                      HoursComputer  2.111620e+11
# 136                                      AIInteresting  2.057457e+11
# 137                       ohe_CommunicationTools_Slack  2.001512e+11
# 138                              StackOverflowDevStory  1.991892e+11
# 139                                        ohe_IDE_Vim  1.989232e+11
# 140                 ohe_PlatformDesireNextYear_Android  1.979370e+11
# 141                      ohe_DevType_DevOps_specialist  1.968401e+11
# 142                              JobContactPriorities5  1.948745e+11
# 143                      ohe_PlatformWorkedWith_Mac_OS  1.926691e+11
# 144                        StackOverflowConsiderMember  1.889868e+11
# 145             ohe_DatabaseWorkedWith_Amazon_DynamoDB  1.873651e+11
# 146                   ohe_DatabaseDesireNextYear_MySQL  1.862933e+11
# 147                        ohe_LanguageWorkedWith_HTML  1.834217e+11
# 148                   ohe_DevType_System_administrator  1.786777e+11
# 149                                      SurveyTooLong  1.755956e+11
# 150  ohe_AdsActions_Paid_to_access_a_website_advert...  1.754750e+11
# 151  ohe_SelfTaughtTypes_A_book_or_e_book_from_O_Re...  1.749960e+11
# 152                                   ohe_IDE_IntelliJ  1.733486e+11
# 153                                       EthicsChoice  1.718881e+11
# 154                                         SurveyEasy  1.674994e+11
# 155                                     AgreeDisagree1  1.651350e+11
# 156                   ohe_DatabaseWorkedWith_Cassandra  1.624379e+11
# 157                   ohe_PlatformWorkedWith_WordPress  1.622972e+11
# 158                                   AdBlockerDisable  1.586908e+11
# 159  ohe_DevType_Data_scientist_or_machine_learning...  1.530993e+11
# 160              ohe_LanguageDesireNextYear_JavaScript  1.487974e+11
# 161                              JobContactPriorities2  1.473477e+11
# 162                   ohe_DatabaseWorkedWith_Memcached  1.471959e+11
# 163             ohe_DatabaseWorkedWith_Amazon_Redshift  1.464296e+11
# 164                      ohe_LanguageDesireNextYear_F_  1.457612e+11
# 165                                  EthicsResponsible  1.420284e+11
# 166                  ohe_LanguageWorkedWith_Bash_Shell  1.395645e+11
# 167  ohe_CommunicationTools_Other_wiki_tool__Github...  1.393226e+11
# 168                                        CheckInCode  1.374660e+11
# 169                         ohe_LanguageWorkedWith_C__  1.373836e+11
# 170                               ohe_Methodology_Lean  1.347136e+11
# 171                                          SkipMeals  1.326845e+11
# 172                      ohe_FrameworkWorkedWith_React  1.316169e+11
# 173                  ohe_PlatformWorkedWith_Serverless  1.263858e+11
# 174   ohe_HackathonReasons_Because_I_find_it_enjoyable  1.258229e+11
# 175  ohe_DatabaseWorkedWith_Microsoft_Azure__Tables...  1.223754e+11
# 176                        ohe_LanguageWorkedWith_Java  1.212433e+11
# 177                     ohe_LanguageDesireNextYear_CSS  1.208402e+11
# 178  ohe_EducationTypes_Taken_an_online_course_in_p...  1.185974e+11
# 179                   ohe_DevType_Full_stack_developer  1.185365e+11
# 180  ohe_AdBlockerReasons_I_wanted_to_support_the_w...  1.181943e+11
# 181                  ohe_DatabaseWorkedWith_SQL_Server  1.160013e+11
# 182                ohe_FrameworkDesireNextYear_Angular  1.158468e+11
# 183              ohe_PlatformDesireNextYear_Serverless  1.153929e+11
# 184                      ohe_CommunicationTools_Trello  1.149804e+11
# 185                      ohe_LanguageWorkedWith_Python  1.137652e+11
# 186                         ohe_LanguageWorkedWith_SQL  1.130976e+11
# 187                ohe_FrameworkDesireNextYear_Node_js  1.111488e+11
# 188                     ohe_DatabaseWorkedWith_MariaDB  1.110433e+11
# 189                                  StackOverflowJobs  1.106469e+11
# 190                                   ohe_IDE_NetBeans  1.088521e+11
# 191        ohe_DevType_Educator_or_academic_researcher  1.074535e+11
# 192                     ohe_FrameworkWorkedWith_Hadoop  1.049976e+11
# 193                    ohe_LanguageDesireNextYear_HTML  1.045672e+11
# 194  ohe_AdsActions_Stopped_going_to_a_website_beca...  1.027809e+11
# 195                                           AIFuture  1.024045e+11
# 196                  ohe_LanguageWorkedWith_JavaScript  1.018144e+11
# 197  ohe_SelfTaughtTypes_Online_developer_communiti...  1.005110e+11
# 198                                      ohe_IDE_Emacs  9.933245e+10
# 199  ohe_EducationTypes_Received_on_the_job_trainin...  9.915932e+10
# 200  ohe_SelfTaughtTypes_The_technology_s_online_he...  9.905287e+10
# 201                                EthicalImplications  9.767209e+10
# 202                   ohe_DevType_QA_or_test_developer  9.714111e+10
# 203                  ohe_DatabaseWorkedWith_PostgreSQL  9.692771e+10
# 204                       ohe_PlatformWorkedWith_Linux  9.655110e+10
# 205                   ohe_PlatformDesireNextYear_Linux  9.616701e+10
# 206                 ohe_FrameworkWorkedWith_TensorFlow  9.485311e+10
# 207                  ohe_LanguageWorkedWith_TypeScript  9.442597e+10
# 208                                          AdBlocker  9.166122e+10
# 209                     ohe_LanguageDesireNextYear_SQL  8.983998e+10
# 210        ohe_CommunicationTools_Google_Hangouts_Chat  8.907905e+10
# 211                  ohe_LanguageDesireNextYear_Python  8.901132e+10
# 212                ohe_DatabaseWorkedWith_Apache_HBase  8.838190e+10
# 213                     ohe_PlatformWorkedWith_Android  8.784203e+10
# 214                       ohe_RaceEthnicity_East_Asian  8.697435e+10
# 215  ohe_EducationTypes_Completed_an_industry_certi...  8.606048e+10
# 216                        ohe_DevType_Product_manager  8.604754e+10
# 217                           ohe_LanguageWorkedWith_C  8.493278e+10
# 218                     ohe_DevType_Back_end_developer  8.468705e+10
# 219  ohe_PlatformWorkedWith_Google_Cloud_Platform_A...  8.397702e+10
# 220  ohe_AdsActions_Saw_an_online_advertisement_and...  8.379111e+10
# 221                 ohe_FrameworkDesireNextYear_Django  8.376354e+10
# 222                         ohe_IDE_Visual_Studio_Code  8.370017e+10
# 223                             ohe_VersionControl_Git  8.301949e+10
# 224  ohe_HackathonReasons_To_improve_my_ability_to_...  8.191911e+10
# 225                                  SexualOrientation  8.165411e+10
# 226                       ohe_DevType_Mobile_developer  7.861111e+10
# 227                    ohe_LanguageDesireNextYear_Rust  7.815511e+10
# 228             ohe_FrameworkDesireNextYear_TensorFlow  7.746059e+10
# 229                      ohe_FrameworkWorkedWith_Spark  7.744728e+10
# 230              ohe_LanguageDesireNextYear_Bash_Shell  7.710420e+10
# 231                    ohe_FrameworkWorkedWith_Node_js  7.677302e+10
# 232                                             Gender  7.669562e+10
# 233                                  TimeAfterBootcamp  7.614355e+10
# 234              ohe_DatabaseDesireNextYear_PostgreSQL  7.543177e+10
# 235         ohe_DatabaseDesireNextYear_Amazon_Redshift  7.308295e+10
# 236                      ohe_DatabaseWorkedWith_SQLite  7.234564e+10
# 237   ohe_ErgonomicDevices_Ergonomic_keyboard_or_mouse  7.205739e+10
# 238                              ohe_IDE_Visual_Studio  7.098821e+10
# 239                   ohe_PlatformDesireNextYear_Azure  7.030531e+10
# 240           ohe_DatabaseWorkedWith_Amazon_RDS_Aurora  6.987168e+10
# 241                             ohe_IDE_Android_Studio  6.741714e+10
# 242                   ohe_DatabaseDesireNextYear_Redis  6.707206e+10
# 243                      ohe_LanguageDesireNextYear_Go  6.603709e+10
# 244                           ohe_LanguageWorkedWith_R  6.486783e+10
# 245                     ohe_PlatformDesireNextYear_AWS  6.485960e+10
# 246                   ohe_LanguageDesireNextYear_Ocaml  6.434027e+10
# 247                          ohe_LanguageWorkedWith_C_  6.317451e+10
# 248                        ohe_LanguageWorkedWith_Ruby  6.307768e+10
# 249                          ohe_IDE_IPython___Jupyter  6.299534e+10
# 250                 ohe_DatabaseWorkedWith_Apache_Hive  6.224141e+10
# 251   ohe_PlatformWorkedWith_Windows_Desktop_or_Server  6.194176e+10
# 252               ohe_DevType_Data_or_business_analyst  6.143934e+10
# 253                      ohe_LanguageDesireNextYear_C_  6.111495e+10
# 254  ohe_CommunicationTools_Other_chat_system__IRC_...  6.040954e+10
# 255               ohe_VersionControl_Zip_file_back_ups  6.021250e+10
# 256                  ohe_PlatformDesireNextYear_Mac_OS  6.001631e+10
# 257                  ohe_FrameworkDesireNextYear_React  5.970186e+10
# 258                       ohe_LanguageDesireNextYear_C  5.850991e+10
# 259                 ohe_LanguageWorkedWith_Objective_C  5.725578e+10
# 260  ohe_AdsActions_Clicked_on_an_online_advertisement  5.665475e+10
# 261  ohe_DevType_Desktop_or_enterprise_applications...  5.599286e+10
# 262  ohe_AdBlockerReasons_The_website_I_was_visitin...  5.544031e+10
# 263                      ohe_LanguageWorkedWith_VB_NET  5.432790e+10
# 264  ohe_AdBlockerReasons_The_ad_blocking_software_...  5.427969e+10
# 265                ohe_PlatformDesireNextYear_Firebase  5.401411e+10
# 266                                    ohe_IDE_Eclipse  5.383801e+10
# 267              ohe_LanguageWorkedWith_Visual_Basic_6  5.379768e+10
# 268           ohe_DatabaseDesireNextYear_Elasticsearch  5.351621e+10
# 269                                       ohe_IDE_Atom  5.255592e+10
# 270                    ohe_CommunicationTools_Facebook  5.145208e+10
# 271  ohe_EducationTypes_Taught_yourself_a_new_langu...  5.071505e+10
# 272  ohe_EducationTypes_Taken_a_part_time_in_person...  5.065424e+10
# 273                      ohe_DatabaseWorkedWith_Oracle  5.028252e+10
# 274                  ohe_DatabaseDesireNextYear_SQLite  5.005285e+10
# 275  ohe_SelfTaughtTypes_Tapping_your_network_of_fr...  4.956157e+10
# 276     ohe_SexualOrientation_Straight_or_heterosexual  4.899999e+10
# 277              ohe_FrameworkDesireNextYear__NET_Core  4.841721e+10
# 278                      ohe_LanguageWorkedWith_Groovy  4.810140e+10
# 279                  ohe_FrameworkDesireNextYear_Spark  4.743141e+10
# 280                    ohe_PlatformWorkedWith_Firebase  4.738865e+10
# 281                 ohe_PlatformDesireNextYear_Arduino  4.726376e+10
# 282            ohe_PlatformDesireNextYear_Raspberry_Pi  4.718174e+10
# 283  ohe_PlatformDesireNextYear_Google_Cloud_Platfo...  4.691123e+10
# 284                                   ohe_IDE_PHPStorm  4.675904e+10
# 285                       ohe_LanguageDesireNextYear_R  4.673850e+10
# 286                               ohe_IDE_Sublime_Text  4.669531e+10
# 287              ohe_LanguageDesireNextYear_TypeScript  4.651762e+10
# 288  ohe_DatabaseDesireNextYear_Microsoft_Azure__Ta...  4.630642e+10
# 289                                      ohe_IDE_Xcode  4.492855e+10
# 290                    ohe_LanguageDesireNextYear_Java  4.419823e+10
# 291                            ohe_Methodology_PRINCE2  4.402327e+10
# 292  ohe_HackathonReasons_To_improve_my_knowledge_o...  4.387383e+10
# 293                      ohe_PlatformWorkedWith_Drupal  4.249860e+10
# 294  ohe_EducationTypes_Participated_in_online_codi...  4.179670e+10
# 295     ohe_PlatformWorkedWith_Apple_Watch_or_Apple_TV  4.152502e+10
# 296                    ohe_FrameworkWorkedWith_Angular  4.135432e+10
# 297  ohe_SelfTaughtTypes_The_official_documentation...  4.128660e+10
# 298                    ohe_LanguageWorkedWith_Assembly  4.112554e+10
# 299  ohe_Methodology_Formal_standard_such_as_ISO_90...  4.102233e+10
# 300                 ohe_LanguageDesireNextYear_Haskell  4.071248e+10
# 301                   ohe_LanguageDesireNextYear_Swift  4.016729e+10
# 302   ohe_ErgonomicDevices_Fatigue_relieving_floor_mat  3.997714e+10
# 303             ohe_DevType_Game_or_graphics_developer  3.957265e+10
# 304                       ohe_LanguageWorkedWith_Swift  3.928774e+10
# 305       ohe_DatabaseDesireNextYear_Amazon_RDS_Aurora  3.883906e+10
# 306              ohe_DatabaseDesireNextYear_SQL_Server  3.832340e+10
# 307  ohe_SelfTaughtTypes_Questions___answers_on_Sta...  3.817572e+10
# 308                   ohe_RaceEthnicity_Middle_Eastern  3.797796e+10
# 309                          ohe_LanguageWorkedWith_F_  3.784991e+10
# 310  ohe_SelfTaughtTypes_Internal_Wikis__chat_rooms...  3.732054e+10
# 311                     ohe_DatabaseWorkedWith_MongoDB  3.728846e+10
# 312               ohe_DatabaseDesireNextYear_Memcached  3.569534e+10
# 313                     ohe_PlatformWorkedWith_Arduino  3.509135e+10
# 314                ohe_PlatformWorkedWith_Raspberry_Pi  3.497625e+10
# 315                  ohe_FrameworkWorkedWith__NET_Core  3.489802e+10
# 316                    ohe_LanguageDesireNextYear_Ruby  3.455001e+10
# 317  ohe_HackathonReasons_To_improve_my_general_tec...  3.398861e+10
# 318                         ohe_PlatformWorkedWith_iOS  3.396996e+10
# 319                   ohe_LanguageDesireNextYear_Scala  3.394323e+10
# 320  ohe_HackathonReasons_To_build_my_professional_...  3.391895e+10
# 321                     ohe_PlatformDesireNextYear_iOS  3.336467e+10
# 322                     ohe_CommunicationTools_HipChat  3.316599e+10
# 323                        ohe_LanguageWorkedWith_Rust  3.245309e+10
# 324              ohe_FrameworkWorkedWith_Torch_PyTorch  3.177241e+10
# 325                            StackOverflowHasAccount  3.171694e+10
# 326                ohe_LanguageDesireNextYear_Assembly  3.171455e+10
# 327                        ohe_LanguageWorkedWith_Perl  3.156655e+10
# 328                      ohe_VersionControl_Subversion  3.149872e+10
# 329  ohe_PlatformDesireNextYear_Windows_Desktop_or_...  3.107653e+10
# 330  ohe_SelfTaughtTypes_A_college_university_compu...  3.094559e+10
# 331     ohe_VersionControl_I_don_t_use_version_control  3.028345e+10
# 332                                              Hobby  3.001097e+10
# 333                 ohe_FrameworkDesireNextYear_Spring  3.000151e+10
# 334        ohe_DatabaseWorkedWith_Google_Cloud_Storage  2.964624e+10
# 335         ohe_DatabaseDesireNextYear_Amazon_DynamoDB  2.945136e+10
# 336                  ohe_PlatformDesireNextYear_Heroku  2.943064e+10
# 337  ohe_VersionControl_Team_Foundation_Version_Con...  2.895319e+10
# 338                      ohe_PlatformWorkedWith_Heroku  2.885940e+10
# 339  ohe_ErgonomicDevices_Wrist_hand_supports_or_br...  2.861676e+10
# 340        ohe_RaceEthnicity_Hispanic_or_Latino_Latina  2.861211e+10
# 341                 ohe_DatabaseDesireNextYear_MariaDB  2.625084e+10
# 342               ohe_PlatformDesireNextYear_WordPress  2.575590e+10
# 343                     ohe_FrameworkWorkedWith_Spring  2.573079e+10
# 344          ohe_FrameworkDesireNextYear_Torch_PyTorch  2.564917e+10
# 345                     ohe_LanguageDesireNextYear_C__  2.436798e+10
# 346  ohe_PlatformDesireNextYear_Apple_Watch_or_Appl...  2.436075e+10
# 347                                    ohe_IDE_PyCharm  2.428481e+10
# 348                                       ohe_IDE_Coda  2.369283e+10
# 349                  ohe_LanguageDesireNextYear_Kotlin  2.331582e+10
# 350        ohe_LanguageWorkedWith_Delphi_Object_Pascal  2.261381e+10
# 351  ohe_EducationTypes_Participated_in_a_full_time...  2.248623e+10
# 352                       ohe_LanguageWorkedWith_Ocaml  2.237518e+10
# 353             ohe_PlatformDesireNextYear_Amazon_Echo  2.225066e+10
# 354  ohe_HackathonReasons_To_help_me_find_new_job_o...  2.223377e+10
# 355    ohe_DatabaseDesireNextYear_Google_Cloud_Storage  2.191455e+10
# 356                   ohe_DatabaseDesireNextYear_Neo4j  2.177559e+10
# 357                      ohe_LanguageWorkedWith_Kotlin  2.091467e+10
# 358          ohe_PlatformDesireNextYear_Gaming_console  2.068808e+10
# 359                 ohe_PlatformWorkedWith_Amazon_Echo  2.024012e+10
# 360                                    ohe_IDE_RStudio  2.017320e+10
# 361  ohe_DevType_Embedded_applications_or_devices_d...  2.014665e+10
# 362                     ohe_LanguageWorkedWith_Haskell  2.004200e+10
# 363  ohe_AdBlockerReasons_The_website_I_was_visitin...  1.967393e+10
# 364                     ohe_LanguageDesireNextYear_Lua  1.948814e+10
# 365                       ohe_VersionControl_Mercurial  1.940506e+10
# 366                       ohe_DatabaseWorkedWith_Neo4j  1.899545e+10
# 367                 ohe_FrameworkDesireNextYear_Hadoop  1.850966e+10
# 368                     ohe_FrameworkWorkedWith_Django  1.825846e+10
# 369         ohe_DatabaseDesireNextYear_Google_BigQuery  1.806503e+10
# 370   ohe_CommunicationTools_Stack_Overflow_Enterprise  1.797274e+10
# 371                     ohe_LanguageWorkedWith_Clojure  1.759514e+10
# 372                   ohe_LanguageDesireNextYear_Julia  1.742149e+10
# 373                 ohe_LanguageDesireNextYear_Clojure  1.697738e+10
# 374                      ohe_LanguageWorkedWith_Matlab  1.639408e+10
# 375                    ohe_FrameworkWorkedWith_Cordova  1.638290e+10
# 376                    ohe_FrameworkWorkedWith_Xamarin  1.615261e+10
# 377             ohe_LanguageDesireNextYear_Objective_C  1.612499e+10
# 378    ohe_LanguageDesireNextYear_Delphi_Object_Pascal  1.581404e+10
# 379  ohe_VersionControl_Copying_and_pasting_files_t...  1.580297e+10
# 380                         ohe_LanguageWorkedWith_VBA  1.543278e+10
# 381                     ohe_DatabaseWorkedWith_IBM_Db2  1.521928e+10
# 382                ohe_LanguageWorkedWith_CoffeeScript  1.489611e+10
# 383                  ohe_PlatformWorkedWith_Salesforce  1.478827e+10
# 384  ohe_HackathonReasons_To_win_prizes_or_cash_awards  1.424380e+10
# 385                         ohe_LanguageWorkedWith_Lua  1.420921e+10
# 386        ohe_DevType_Marketing_or_sales_professional  1.378301e+10
# 387                  ohe_LanguageDesireNextYear_Groovy  1.369176e+10
# 388  ohe_Methodology_Evidence_based_software_engine...  1.361815e+10
# 389             ohe_PlatformDesireNextYear_Google_Home  1.360731e+10
# 390                  ohe_LanguageDesireNextYear_Erlang  1.333067e+10
# 391     ohe_PlatformDesireNextYear_IBM_Cloud_or_Watson  1.289955e+10
# 392                 ohe_PlatformDesireNextYear_ESP8266  1.266495e+10
# 393                ohe_FrameworkDesireNextYear_Xamarin  1.204377e+10
# 394                                   ohe_IDE_TextMate  1.201456e+10
# 395                  ohe_PlatformWorkedWith_SharePoint  1.191652e+10
# 396                    ohe_LanguageDesireNextYear_Perl  1.190936e+10
# 397               ohe_DatabaseDesireNextYear_Cassandra  1.165022e+10
# 398                     ohe_PlatformWorkedWith_ESP8266  1.146871e+10
# 399                  ohe_DatabaseDesireNextYear_Oracle  1.145396e+10
# 400            ohe_SexualOrientation_Bisexual_or_Queer  1.140130e+10
# 401             ohe_DatabaseDesireNextYear_Apache_Hive  1.124977e+10
# 402  ohe_AdBlockerReasons_The_website_I_was_visitin...  1.106467e+10
# 403          ohe_LanguageDesireNextYear_Visual_Basic_6  1.041132e+10
# 404               ohe_PlatformWorkedWith_Windows_Phone  1.027595e+10
# 405      ohe_RaceEthnicity_Black_or_of_African_descent  1.012287e+10
# 406                    ohe_Methodology_Mob_programming  8.616694e+09
# 407                    ohe_LanguageDesireNextYear_Hack  7.861792e+09
# 408            ohe_DatabaseDesireNextYear_Apache_HBase  7.807918e+09
# 409                       ohe_LanguageWorkedWith_Cobol  7.420160e+09
# 410                 ohe_PlatformWorkedWith_Google_Home  6.919712e+09
# 411                ohe_FrameworkDesireNextYear_Cordova  6.781204e+09
# 412         ohe_PlatformWorkedWith_IBM_Cloud_or_Watson  6.746163e+09
# 413  ohe_RaceEthnicity_Native_American__Pacific_Isl...  6.215522e+09
# 414                     ohe_LanguageDesireNextYear_VBA  5.939178e+09
# 415                  ohe_LanguageDesireNextYear_VB_NET  5.555512e+09
# 416  ohe_SelfTaughtTypes_Pre_scheduled_tutoring_or_...  5.484208e+09
# 417                   ohe_PlatformWorkedWith_Mainframe  5.467330e+09
# 418              ohe_PlatformDesireNextYear_SharePoint  5.107958e+09
# 419               ohe_SexualOrientation_Gay_or_Lesbian  5.045928e+09
# 420                      ohe_SexualOrientation_Asexual  4.710870e+09
# 421                                   ohe_IDE_RubyMine  4.298908e+09
# 422              ohe_PlatformWorkedWith_Gaming_console  4.085050e+09
# 423              ohe_PlatformDesireNextYear_Salesforce  3.752438e+09
# 424            ohe_LanguageDesireNextYear_CoffeeScript  3.550722e+09
# 425                  ohe_LanguageDesireNextYear_Matlab  3.502332e+09
# 426                      ohe_LanguageWorkedWith_Erlang  2.867406e+09
# 427                       ohe_LanguageWorkedWith_Julia  2.566712e+09
# 428           ohe_PlatformDesireNextYear_Windows_Phone  2.551780e+09
# 429  ohe_AdBlockerReasons_I_wanted_to_view_a_specif...  2.320402e+09
# 430               ohe_PlatformDesireNextYear_Mainframe  1.899910e+09
# 431                  ohe_PlatformDesireNextYear_Drupal  1.465364e+09
# 432                                     ohe_IDE_Komodo  1.099008e+09
# 433                        ohe_LanguageWorkedWith_Hack  8.429940e+08
# 434                 ohe_DatabaseDesireNextYear_IBM_Db2  3.694200e+08
# 435                ohe_PlatformDesireNextYear_ESP_8266  0.000000e+00
# 436                  ohe_PlatformDesireNextYear_Predix  0.000000e+00
# 437                   ohe_LanguageDesireNextYear_Cobol  0.000000e+00
# 438                      ohe_PlatformWorkedWith_Predix  0.000000e+00
# 439                                ohe_IDE_Light_Table  0.000000e+00
# 440                    ohe_PlatformWorkedWith_ESP_8266  0.000000e+00
# 441                                       ohe_IDE_Zend  0.000000e+00

# %%
importance_df = \
    importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index()

# %%
importance_df.to_csv("../data/importance/003_importance.csv", index=False)
