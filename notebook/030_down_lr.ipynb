# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def triple_count_encoding(train_df, test_df):
     # triple target encoding
    triple_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    triple_te_cols = [c for c in triple_te_cols if c in imp_feats]
    combi_triple_te_cols = list(itertools.combinations(triple_te_cols, 3))
    
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

    
    for col_a, col_b, col_c in tqdm(combi_triple_te_cols):
        all_df["tmp"] = all_df[col_a].fillna("").astype(str) + all_df[col_b].fillna("").astype(str) + all_df[col_c].fillna("").astype(str)
        new_col = "triple_count_" + col_a + "__" + col_b + "__" + col_c
        count = all_df["tmp"].value_counts()
        all_df[new_col] = all_df["tmp"].map(count)
    del all_df["tmp"]
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    return train_df, test_df

# %%
train_df, test_df = triple_count_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3825

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.01,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df  # .sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    _lgb_params = lgb_params.copy()
    _lgb_params["learning_rate"] = 0.05
    
    model = lgb.train(
                _lgb_params,
                train_dataset,
                4000,
                valid_sets = [train_dataset],
                verbose_eval=500,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

use_cols = feature_selection(train_df, use_cols, n_features=1000)

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                50000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=200,
                early_stopping_rounds = 500,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# [500]	training's rmse: 19474.4
# [1000]	training's rmse: 18320.5
# [1500]	training's rmse: 17526.5
# [2000]	training's rmse: 16843.1
# [2500]	training's rmse: 16232.6
# [3000]	training's rmse: 15681.3
# [3500]	training's rmse: 15155
# [4000]	training's rmse: 14667
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [200]	training's rmse: 28045	valid_1's rmse: 27912.4
# [400]	training's rmse: 23592.3	valid_1's rmse: 23757
# [600]	training's rmse: 22099	valid_1's rmse: 22470.6
# [800]	training's rmse: 21352.1	valid_1's rmse: 21919
# [1000]	training's rmse: 20841.5	valid_1's rmse: 21575.5
# [1200]	training's rmse: 20466.3	valid_1's rmse: 21353.9
# [1400]	training's rmse: 20174	valid_1's rmse: 21205.3
# [1600]	training's rmse: 19944.8	valid_1's rmse: 21099.3
# [1800]	training's rmse: 19746.6	valid_1's rmse: 21011
# [2000]	training's rmse: 19567.4	valid_1's rmse: 20934
# [2200]	training's rmse: 19409	valid_1's rmse: 20879.2
# [2400]	training's rmse: 19266	valid_1's rmse: 20824.5
# [2600]	training's rmse: 19129	valid_1's rmse: 20780.2
# [2800]	training's rmse: 19001.8	valid_1's rmse: 20740.7
# [3000]	training's rmse: 18883.8	valid_1's rmse: 20703.4
# [3200]	training's rmse: 18770.4	valid_1's rmse: 20670.9
# [3400]	training's rmse: 18662.5	valid_1's rmse: 20641.5
# [3600]	training's rmse: 18561.7	valid_1's rmse: 20612.9
# [3800]	training's rmse: 18462.9	valid_1's rmse: 20591
# [4000]	training's rmse: 18369.3	valid_1's rmse: 20570.3
# [4200]	training's rmse: 18274.6	valid_1's rmse: 20547.4
# [4400]	training's rmse: 18181.2	valid_1's rmse: 20522.9
# [4600]	training's rmse: 18091.7	valid_1's rmse: 20505.4
# [4800]	training's rmse: 18007	valid_1's rmse: 20485.1
# [5000]	training's rmse: 17923.9	valid_1's rmse: 20470
# [5200]	training's rmse: 17848.8	valid_1's rmse: 20455.5
# [5400]	training's rmse: 17768.2	valid_1's rmse: 20441.6
# [5600]	training's rmse: 17690.6	valid_1's rmse: 20429.3
# [5800]	training's rmse: 17615.4	valid_1's rmse: 20417.6
# [6000]	training's rmse: 17540.2	valid_1's rmse: 20406.6
# [6200]	training's rmse: 17468.1	valid_1's rmse: 20396.4
# [6400]	training's rmse: 17391.4	valid_1's rmse: 20389.8
# [6600]	training's rmse: 17322.3	valid_1's rmse: 20377.6
# [6800]	training's rmse: 17250.6	valid_1's rmse: 20369.2
# [7000]	training's rmse: 17181.6	valid_1's rmse: 20356.6
# [7200]	training's rmse: 17111.9	valid_1's rmse: 20346.9
# [7400]	training's rmse: 17049.2	valid_1's rmse: 20339.3
# [7600]	training's rmse: 16983.3	valid_1's rmse: 20331.6
# [7800]	training's rmse: 16914.7	valid_1's rmse: 20321.3
# [8000]	training's rmse: 16850.4	valid_1's rmse: 20314.3
# [8200]	training's rmse: 16785.5	valid_1's rmse: 20304
# [8400]	training's rmse: 16720.3	valid_1's rmse: 20297.7
# [8600]	training's rmse: 16655.5	valid_1's rmse: 20291.8
# [8800]	training's rmse: 16595.6	valid_1's rmse: 20285.8
# [9000]	training's rmse: 16530.2	valid_1's rmse: 20276.8
# [9200]	training's rmse: 16471.5	valid_1's rmse: 20271
# [9400]	training's rmse: 16413.7	valid_1's rmse: 20268.4
# [9600]	training's rmse: 16355	valid_1's rmse: 20264.2
# [9800]	training's rmse: 16297.7	valid_1's rmse: 20260.6
# [10000]	training's rmse: 16243.8	valid_1's rmse: 20256.1
# [10200]	training's rmse: 16185.9	valid_1's rmse: 20250.8
# [10400]	training's rmse: 16129.2	valid_1's rmse: 20245.4
# [10600]	training's rmse: 16076	valid_1's rmse: 20240.8
# [10800]	training's rmse: 16022.3	valid_1's rmse: 20236.5
# [11000]	training's rmse: 15966.9	valid_1's rmse: 20231.5
# [11200]	training's rmse: 15912	valid_1's rmse: 20225.6
# [11400]	training's rmse: 15856.1	valid_1's rmse: 20221.5
# [11600]	training's rmse: 15803.8	valid_1's rmse: 20217.5
# [11800]	training's rmse: 15750.5	valid_1's rmse: 20212.8
# [12000]	training's rmse: 15696.3	valid_1's rmse: 20208.6
# [12200]	training's rmse: 15642.1	valid_1's rmse: 20207.9
# [12400]	training's rmse: 15588.4	valid_1's rmse: 20204.5
# [12600]	training's rmse: 15538.3	valid_1's rmse: 20201.3
# [12800]	training's rmse: 15488.7	valid_1's rmse: 20199.3
# [13000]	training's rmse: 15436	valid_1's rmse: 20195.8
# [13200]	training's rmse: 15386	valid_1's rmse: 20193.5
# [13400]	training's rmse: 15335.3	valid_1's rmse: 20190.9
# [13600]	training's rmse: 15285.1	valid_1's rmse: 20186.4
# [13800]	training's rmse: 15234.7	valid_1's rmse: 20182.5
# [14000]	training's rmse: 15182.1	valid_1's rmse: 20179.8
# [14200]	training's rmse: 15130.7	valid_1's rmse: 20177.2
# [14400]	training's rmse: 15081.6	valid_1's rmse: 20173.9
# [14600]	training's rmse: 15034.7	valid_1's rmse: 20170.6
# [14800]	training's rmse: 14985	valid_1's rmse: 20169.2
# [15000]	training's rmse: 14934.4	valid_1's rmse: 20166.9
# [15200]	training's rmse: 14883.7	valid_1's rmse: 20163.6
# [15400]	training's rmse: 14833.3	valid_1's rmse: 20161.1
# [15600]	training's rmse: 14783.5	valid_1's rmse: 20161.5
# [15800]	training's rmse: 14735.5	valid_1's rmse: 20158.9
# [16000]	training's rmse: 14686.4	valid_1's rmse: 20154.6
# [16200]	training's rmse: 14638.4	valid_1's rmse: 20152.1
# [16400]	training's rmse: 14589.6	valid_1's rmse: 20151.3
# [16600]	training's rmse: 14543.4	valid_1's rmse: 20147.3
# [16800]	training's rmse: 14495.4	valid_1's rmse: 20143.4
# [17000]	training's rmse: 14446.1	valid_1's rmse: 20144.7
# [17200]	training's rmse: 14398.7	valid_1's rmse: 20145.3
# Early stopping, best iteration is:
# [16825]	training's rmse: 14488.1	valid_1's rmse: 20143
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [200]	training's rmse: 28019.8	valid_1's rmse: 28314
# [400]	training's rmse: 23550.6	valid_1's rmse: 24069.5
# [600]	training's rmse: 22061.4	valid_1's rmse: 22742.9
# [800]	training's rmse: 21327.1	valid_1's rmse: 22118.4
# [1000]	training's rmse: 20840	valid_1's rmse: 21727.7
# [1200]	training's rmse: 20480.7	valid_1's rmse: 21469.7
# [1400]	training's rmse: 20199.4	valid_1's rmse: 21281.9
# [1600]	training's rmse: 19971	valid_1's rmse: 21141.8
# [1800]	training's rmse: 19779.6	valid_1's rmse: 21039.3
# [2000]	training's rmse: 19607.6	valid_1's rmse: 20954.2
# [2200]	training's rmse: 19452.4	valid_1's rmse: 20887.2
# [2400]	training's rmse: 19304.9	valid_1's rmse: 20825.4
# [2600]	training's rmse: 19166.8	valid_1's rmse: 20770.6
# [2800]	training's rmse: 19041.5	valid_1's rmse: 20724.4
# [3000]	training's rmse: 18923.9	valid_1's rmse: 20683.6
# [3200]	training's rmse: 18807.8	valid_1's rmse: 20649.5
# [3400]	training's rmse: 18698.7	valid_1's rmse: 20615.1
# [3600]	training's rmse: 18598.4	valid_1's rmse: 20589
# [3800]	training's rmse: 18504.4	valid_1's rmse: 20561.6
# [4000]	training's rmse: 18407.9	valid_1's rmse: 20535.4
# [4200]	training's rmse: 18316.2	valid_1's rmse: 20513.9
# [4400]	training's rmse: 18231.9	valid_1's rmse: 20493.2
# [4600]	training's rmse: 18144.1	valid_1's rmse: 20473.2
# [4800]	training's rmse: 18061.3	valid_1's rmse: 20452.9
# [5000]	training's rmse: 17981.3	valid_1's rmse: 20432.6
# [5200]	training's rmse: 17903.9	valid_1's rmse: 20419.1
# [5400]	training's rmse: 17829.1	valid_1's rmse: 20403.5
# [5600]	training's rmse: 17751.9	valid_1's rmse: 20388.3
# [5800]	training's rmse: 17679.6	valid_1's rmse: 20371.2
# [6000]	training's rmse: 17609.8	valid_1's rmse: 20358.3
# [6200]	training's rmse: 17536.6	valid_1's rmse: 20344.8
# [6400]	training's rmse: 17468.4	valid_1's rmse: 20330.3
# [6600]	training's rmse: 17399.1	valid_1's rmse: 20318.3
# [6800]	training's rmse: 17331.4	valid_1's rmse: 20304.3
# [7000]	training's rmse: 17264.3	valid_1's rmse: 20292.6
# [7200]	training's rmse: 17198.6	valid_1's rmse: 20284.4
# [7400]	training's rmse: 17129.3	valid_1's rmse: 20276.4
# [7600]	training's rmse: 17062.1	valid_1's rmse: 20265.1
# [7800]	training's rmse: 16996.3	valid_1's rmse: 20256.5
# [8000]	training's rmse: 16937.4	valid_1's rmse: 20249.1
# [8200]	training's rmse: 16872.9	valid_1's rmse: 20240.9
# [8400]	training's rmse: 16810.7	valid_1's rmse: 20232
# [8600]	training's rmse: 16748	valid_1's rmse: 20223.5
# [8800]	training's rmse: 16688.8	valid_1's rmse: 20214.4
# [9000]	training's rmse: 16633.7	valid_1's rmse: 20204.5
# [9200]	training's rmse: 16576.8	valid_1's rmse: 20197.7
# [9400]	training's rmse: 16518.7	valid_1's rmse: 20192.2
# [9600]	training's rmse: 16460.1	valid_1's rmse: 20185
# [9800]	training's rmse: 16404.2	valid_1's rmse: 20180.3
# [10000]	training's rmse: 16346.8	valid_1's rmse: 20174.2
# [10200]	training's rmse: 16290.6	valid_1's rmse: 20169.7
# [10400]	training's rmse: 16233.7	valid_1's rmse: 20164.4
# [10600]	training's rmse: 16176.5	valid_1's rmse: 20158.6
# [10800]	training's rmse: 16121.6	valid_1's rmse: 20154.3
# [11000]	training's rmse: 16065	valid_1's rmse: 20151.1
# [11200]	training's rmse: 16008.9	valid_1's rmse: 20146.5
# [11400]	training's rmse: 15955.6	valid_1's rmse: 20143.2
# [11600]	training's rmse: 15903.6	valid_1's rmse: 20137.3
# [11800]	training's rmse: 15849.5	valid_1's rmse: 20133
# [12000]	training's rmse: 15796.2	valid_1's rmse: 20126.6
# [12200]	training's rmse: 15745.2	valid_1's rmse: 20120.2
# [12400]	training's rmse: 15693	valid_1's rmse: 20117.3
# [12600]	training's rmse: 15642.8	valid_1's rmse: 20112.6
# [12800]	training's rmse: 15591.8	valid_1's rmse: 20107.6
# [13000]	training's rmse: 15537.9	valid_1's rmse: 20102.4
# [13200]	training's rmse: 15486.9	valid_1's rmse: 20100.8
# [13400]	training's rmse: 15434	valid_1's rmse: 20095.9
# [13600]	training's rmse: 15386.8	valid_1's rmse: 20094.5
# [13800]	training's rmse: 15337.9	valid_1's rmse: 20090.3
# [14000]	training's rmse: 15287.7	valid_1's rmse: 20087.3
# [14200]	training's rmse: 15234.9	valid_1's rmse: 20083
# [14400]	training's rmse: 15182.6	valid_1's rmse: 20080.7
# [14600]	training's rmse: 15131.4	valid_1's rmse: 20078.8
# [14800]	training's rmse: 15084	valid_1's rmse: 20076.2
# [15000]	training's rmse: 15035.1	valid_1's rmse: 20072.8
# [15200]	training's rmse: 14987	valid_1's rmse: 20071.3
# [15400]	training's rmse: 14939.6	valid_1's rmse: 20068.2
# [15600]	training's rmse: 14891.7	valid_1's rmse: 20062.2
# [15800]	training's rmse: 14844	valid_1's rmse: 20061.3
# [16000]	training's rmse: 14793.9	valid_1's rmse: 20059.1
# [16200]	training's rmse: 14747.6	valid_1's rmse: 20055.2
# [16400]	training's rmse: 14699.1	valid_1's rmse: 20053.4
# [16600]	training's rmse: 14651.2	valid_1's rmse: 20052.1
# [16800]	training's rmse: 14601.8	valid_1's rmse: 20048.7
# [17000]	training's rmse: 14556.5	valid_1's rmse: 20046.9
# [17200]	training's rmse: 14508.2	valid_1's rmse: 20044.9
# [17400]	training's rmse: 14462.4	valid_1's rmse: 20041.5
# [17600]	training's rmse: 14417.3	valid_1's rmse: 20039.4
# [17800]	training's rmse: 14371.1	valid_1's rmse: 20037
# [18000]	training's rmse: 14326.5	valid_1's rmse: 20036.1
# [18200]	training's rmse: 14282.6	valid_1's rmse: 20034.6
# [18400]	training's rmse: 14235.3	valid_1's rmse: 20034
# [18600]	training's rmse: 14187.8	valid_1's rmse: 20034
# [18800]	training's rmse: 14144.9	valid_1's rmse: 20032.1
# [19000]	training's rmse: 14099.6	valid_1's rmse: 20032.1
# [19200]	training's rmse: 14055	valid_1's rmse: 20031.1
# [19400]	training's rmse: 14008.8	valid_1's rmse: 20030.1
# [19600]	training's rmse: 13967	valid_1's rmse: 20030.6
# [19800]	training's rmse: 13922.4	valid_1's rmse: 20028.2
# [20000]	training's rmse: 13878.6	valid_1's rmse: 20024.8
# [20200]	training's rmse: 13835.5	valid_1's rmse: 20024.9
# [20400]	training's rmse: 13795.3	valid_1's rmse: 20025.9
# [20600]	training's rmse: 13750.2	valid_1's rmse: 20024.5
# [20800]	training's rmse: 13709.2	valid_1's rmse: 20024.6
# [21000]	training's rmse: 13665.5	valid_1's rmse: 20024.7
# [21200]	training's rmse: 13620.6	valid_1's rmse: 20024.4
# Early stopping, best iteration is:
# [20712]	training's rmse: 13727.4	valid_1's rmse: 20023.6
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [200]	training's rmse: 28017.8	valid_1's rmse: 28318.3
# [400]	training's rmse: 23573.7	valid_1's rmse: 23926.9
# [600]	training's rmse: 22083.2	valid_1's rmse: 22538.8
# [800]	training's rmse: 21336.8	valid_1's rmse: 21930.6
# [1000]	training's rmse: 20833.2	valid_1's rmse: 21571.3
# [1200]	training's rmse: 20461.1	valid_1's rmse: 21343.8
# [1400]	training's rmse: 20171.2	valid_1's rmse: 21187.4
# [1600]	training's rmse: 19934.2	valid_1's rmse: 21077.3
# [1800]	training's rmse: 19730.5	valid_1's rmse: 20992.9
# [2000]	training's rmse: 19558	valid_1's rmse: 20930.5
# [2200]	training's rmse: 19400.5	valid_1's rmse: 20878.1
# [2400]	training's rmse: 19257.7	valid_1's rmse: 20827.4
# [2600]	training's rmse: 19118.5	valid_1's rmse: 20787.7
# [2800]	training's rmse: 18988.4	valid_1's rmse: 20753.6
# [3000]	training's rmse: 18870.7	valid_1's rmse: 20723.2
# [3200]	training's rmse: 18755.1	valid_1's rmse: 20694.5
# [3400]	training's rmse: 18648.4	valid_1's rmse: 20668.5
# [3600]	training's rmse: 18551.7	valid_1's rmse: 20647.4
# [3800]	training's rmse: 18459.5	valid_1's rmse: 20625.1
# [4000]	training's rmse: 18369.6	valid_1's rmse: 20603.9
# [4200]	training's rmse: 18279.8	valid_1's rmse: 20587.3
# [4400]	training's rmse: 18188.3	valid_1's rmse: 20567.6
# [4600]	training's rmse: 18106.5	valid_1's rmse: 20553.5
# [4800]	training's rmse: 18026.2	valid_1's rmse: 20539
# [5000]	training's rmse: 17940.2	valid_1's rmse: 20525.7
# [5200]	training's rmse: 17862.4	valid_1's rmse: 20511.3
# [5400]	training's rmse: 17786.5	valid_1's rmse: 20499.7
# [5600]	training's rmse: 17710.6	valid_1's rmse: 20488.8
# [5800]	training's rmse: 17632.3	valid_1's rmse: 20476.8
# [6000]	training's rmse: 17559.9	valid_1's rmse: 20468.6
# [6200]	training's rmse: 17489.8	valid_1's rmse: 20460.3
# [6400]	training's rmse: 17422.3	valid_1's rmse: 20450.4
# [6600]	training's rmse: 17354.4	valid_1's rmse: 20441.9
# [6800]	training's rmse: 17285.9	valid_1's rmse: 20433.8
# [7000]	training's rmse: 17219.1	valid_1's rmse: 20426
# [7200]	training's rmse: 17148.5	valid_1's rmse: 20415.6
# [7400]	training's rmse: 17085	valid_1's rmse: 20406.4
# [7600]	training's rmse: 17018.6	valid_1's rmse: 20400.3
# [7800]	training's rmse: 16956.6	valid_1's rmse: 20393
# [8000]	training's rmse: 16892.3	valid_1's rmse: 20387
# [8200]	training's rmse: 16831.5	valid_1's rmse: 20380.9
# [8400]	training's rmse: 16774.7	valid_1's rmse: 20374.8
# [8600]	training's rmse: 16715.1	valid_1's rmse: 20368
# [8800]	training's rmse: 16654.9	valid_1's rmse: 20364
# [9000]	training's rmse: 16595.9	valid_1's rmse: 20358.7
# [9200]	training's rmse: 16536	valid_1's rmse: 20353.9
# [9400]	training's rmse: 16480.6	valid_1's rmse: 20350.8
# [9600]	training's rmse: 16422.3	valid_1's rmse: 20344.3
# [9800]	training's rmse: 16363.4	valid_1's rmse: 20341.6
# [10000]	training's rmse: 16306.3	valid_1's rmse: 20338.2
# [10200]	training's rmse: 16250.4	valid_1's rmse: 20335.8
# [10400]	training's rmse: 16196.3	valid_1's rmse: 20330.5
# [10600]	training's rmse: 16139.1	valid_1's rmse: 20324.5
# [10800]	training's rmse: 16084.8	valid_1's rmse: 20322.5
# [11000]	training's rmse: 16026.5	valid_1's rmse: 20318.3
# [11200]	training's rmse: 15971.6	valid_1's rmse: 20314.9
# [11400]	training's rmse: 15915	valid_1's rmse: 20312.1
# [11600]	training's rmse: 15861.1	valid_1's rmse: 20309
# [11800]	training's rmse: 15804.4	valid_1's rmse: 20307.3
# [12000]	training's rmse: 15751.5	valid_1's rmse: 20304.7
# [12200]	training's rmse: 15697.1	valid_1's rmse: 20300.9
# [12400]	training's rmse: 15641.7	valid_1's rmse: 20298.5
# [12600]	training's rmse: 15587.1	valid_1's rmse: 20298.2
# [12800]	training's rmse: 15536.1	valid_1's rmse: 20296.7
# [13000]	training's rmse: 15485.2	valid_1's rmse: 20296.9
# [13200]	training's rmse: 15432.1	valid_1's rmse: 20294.9
# [13400]	training's rmse: 15380.1	valid_1's rmse: 20292.8
# [13600]	training's rmse: 15326.6	valid_1's rmse: 20294.1
# [13800]	training's rmse: 15276	valid_1's rmse: 20293.2
# [14000]	training's rmse: 15227.2	valid_1's rmse: 20291.6
# [14200]	training's rmse: 15176.6	valid_1's rmse: 20291.5
# [14400]	training's rmse: 15127.8	valid_1's rmse: 20288.5
# [14600]	training's rmse: 15077.1	valid_1's rmse: 20286.4
# [14800]	training's rmse: 15030.7	valid_1's rmse: 20286.7
# [15000]	training's rmse: 14979.9	valid_1's rmse: 20285.9
# [15200]	training's rmse: 14930.3	valid_1's rmse: 20284.5
# [15400]	training's rmse: 14878.9	valid_1's rmse: 20281.5
# [15600]	training's rmse: 14827.4	valid_1's rmse: 20282.1
# [15800]	training's rmse: 14779.3	valid_1's rmse: 20280.9
# [16000]	training's rmse: 14729.6	valid_1's rmse: 20280.1
# [16200]	training's rmse: 14682.6	valid_1's rmse: 20279.2
# [16400]	training's rmse: 14633.1	valid_1's rmse: 20277.1
# [16600]	training's rmse: 14584.4	valid_1's rmse: 20277.5
# [16800]	training's rmse: 14537.5	valid_1's rmse: 20276.3
# [17000]	training's rmse: 14489.8	valid_1's rmse: 20276.2
# [17200]	training's rmse: 14444.2	valid_1's rmse: 20275.7
# [17400]	training's rmse: 14398.8	valid_1's rmse: 20277.2
# Early stopping, best iteration is:
# [16923]	training's rmse: 14507.4	valid_1's rmse: 20275.6
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [200]	training's rmse: 28027.5	valid_1's rmse: 28152
# [400]	training's rmse: 23571.8	valid_1's rmse: 23848.6
# [600]	training's rmse: 22072.9	valid_1's rmse: 22519.5
# [800]	training's rmse: 21330.4	valid_1's rmse: 21936.7
# [1000]	training's rmse: 20836.9	valid_1's rmse: 21596.7
# [1200]	training's rmse: 20473.8	valid_1's rmse: 21370
# [1400]	training's rmse: 20187.6	valid_1's rmse: 21206.9
# [1600]	training's rmse: 19959.4	valid_1's rmse: 21093.1
# [1800]	training's rmse: 19763.3	valid_1's rmse: 21000.9
# [2000]	training's rmse: 19591.6	valid_1's rmse: 20924.3
# [2200]	training's rmse: 19434.5	valid_1's rmse: 20856.9
# [2400]	training's rmse: 19294.3	valid_1's rmse: 20802.8
# [2600]	training's rmse: 19161.8	valid_1's rmse: 20751.8
# [2800]	training's rmse: 19039.8	valid_1's rmse: 20707.4
# [3000]	training's rmse: 18922.2	valid_1's rmse: 20668.6
# [3200]	training's rmse: 18812.8	valid_1's rmse: 20627.3
# [3400]	training's rmse: 18704.8	valid_1's rmse: 20589.4
# [3600]	training's rmse: 18606.7	valid_1's rmse: 20555.3
# [3800]	training's rmse: 18510	valid_1's rmse: 20522.8
# [4000]	training's rmse: 18413.1	valid_1's rmse: 20492.4
# [4200]	training's rmse: 18323.4	valid_1's rmse: 20469.1
# [4400]	training's rmse: 18240.7	valid_1's rmse: 20449.4
# [4600]	training's rmse: 18159.4	valid_1's rmse: 20431.7
# [4800]	training's rmse: 18076.2	valid_1's rmse: 20411.4
# [5000]	training's rmse: 17999.1	valid_1's rmse: 20395.6
# [5200]	training's rmse: 17922.5	valid_1's rmse: 20375.8
# [5400]	training's rmse: 17847.6	valid_1's rmse: 20358.7
# [5600]	training's rmse: 17768.9	valid_1's rmse: 20342
# [5800]	training's rmse: 17694.4	valid_1's rmse: 20325.6
# [6000]	training's rmse: 17622.9	valid_1's rmse: 20312.3
# [6200]	training's rmse: 17549	valid_1's rmse: 20297.3
# [6400]	training's rmse: 17481.3	valid_1's rmse: 20285.6
# [6600]	training's rmse: 17410.5	valid_1's rmse: 20273.9
# [6800]	training's rmse: 17345.4	valid_1's rmse: 20261.2
# [7000]	training's rmse: 17277.4	valid_1's rmse: 20248.9
# [7200]	training's rmse: 17212.9	valid_1's rmse: 20236.8
# [7400]	training's rmse: 17152.6	valid_1's rmse: 20226.7
# [7600]	training's rmse: 17090.9	valid_1's rmse: 20213.2
# [7800]	training's rmse: 17029.4	valid_1's rmse: 20203.6
# [8000]	training's rmse: 16968.7	valid_1's rmse: 20192.9
# [8200]	training's rmse: 16907.4	valid_1's rmse: 20185.9
# [8400]	training's rmse: 16848.4	valid_1's rmse: 20178.9
# [8600]	training's rmse: 16793.1	valid_1's rmse: 20170.2
# [8800]	training's rmse: 16733.2	valid_1's rmse: 20162.7
# [9000]	training's rmse: 16680.9	valid_1's rmse: 20152.9
# [9200]	training's rmse: 16618.6	valid_1's rmse: 20144.6
# [9400]	training's rmse: 16558.8	valid_1's rmse: 20136.1
# [9600]	training's rmse: 16499.2	valid_1's rmse: 20131.1
# [9800]	training's rmse: 16441.7	valid_1's rmse: 20124.6
# [10000]	training's rmse: 16385.7	valid_1's rmse: 20118.5
# [10200]	training's rmse: 16332.6	valid_1's rmse: 20113
# [10400]	training's rmse: 16277.8	valid_1's rmse: 20105.8
# [10600]	training's rmse: 16222.2	valid_1's rmse: 20099.4
# [10800]	training's rmse: 16165.1	valid_1's rmse: 20094.3
# [11000]	training's rmse: 16107	valid_1's rmse: 20090
# [11200]	training's rmse: 16050.3	valid_1's rmse: 20084
# [11400]	training's rmse: 15997.2	valid_1's rmse: 20078.4
# [11600]	training's rmse: 15945.2	valid_1's rmse: 20073.6
# [11800]	training's rmse: 15891.5	valid_1's rmse: 20069.5
# [12000]	training's rmse: 15838.7	valid_1's rmse: 20065.5
# [12200]	training's rmse: 15786.3	valid_1's rmse: 20059.6
# [12400]	training's rmse: 15732.7	valid_1's rmse: 20056.8
# [12600]	training's rmse: 15679.5	valid_1's rmse: 20051.1
# [12800]	training's rmse: 15626.1	valid_1's rmse: 20048.8
# [13000]	training's rmse: 15574.9	valid_1's rmse: 20047
# [13200]	training's rmse: 15522.5	valid_1's rmse: 20045.8
# [13400]	training's rmse: 15470.2	valid_1's rmse: 20039
# [13600]	training's rmse: 15420.2	valid_1's rmse: 20036.8
# [13800]	training's rmse: 15371.7	valid_1's rmse: 20033.9
# [14000]	training's rmse: 15321.6	valid_1's rmse: 20032.2
# [14200]	training's rmse: 15269.3	valid_1's rmse: 20028.6
# [14400]	training's rmse: 15218	valid_1's rmse: 20028.6
# [14600]	training's rmse: 15168.5	valid_1's rmse: 20027.5
# [14800]	training's rmse: 15120.6	valid_1's rmse: 20021.8
# [15000]	training's rmse: 15071.4	valid_1's rmse: 20021.7
# [15200]	training's rmse: 15022.2	valid_1's rmse: 20022.5
# [15400]	training's rmse: 14971.3	valid_1's rmse: 20019.3
# [15600]	training's rmse: 14925.4	valid_1's rmse: 20018.4
# [15800]	training's rmse: 14876.6	valid_1's rmse: 20017.1
# [16000]	training's rmse: 14831.4	valid_1's rmse: 20014.5
# [16200]	training's rmse: 14784.5	valid_1's rmse: 20014.9
# [16400]	training's rmse: 14736.9	valid_1's rmse: 20011.5
# [16600]	training's rmse: 14687.4	valid_1's rmse: 20011.7
# [16800]	training's rmse: 14639.5	valid_1's rmse: 20009.9
# [17000]	training's rmse: 14593.9	valid_1's rmse: 20008.6
# [17200]	training's rmse: 14543	valid_1's rmse: 20006.8
# [17400]	training's rmse: 14497.5	valid_1's rmse: 20004.5
# [17600]	training's rmse: 14451.6	valid_1's rmse: 20004.1
# [17800]	training's rmse: 14403.8	valid_1's rmse: 20000.7
# [18000]	training's rmse: 14358.4	valid_1's rmse: 19999.5
# [18200]	training's rmse: 14310.6	valid_1's rmse: 19998.2
# [18400]	training's rmse: 14266.7	valid_1's rmse: 19997.7
# [18600]	training's rmse: 14224.8	valid_1's rmse: 19997.6
# [18800]	training's rmse: 14174.9	valid_1's rmse: 19994.3
# [19000]	training's rmse: 14128.7	valid_1's rmse: 19992.1
# [19200]	training's rmse: 14082.9	valid_1's rmse: 19994.1
# [19400]	training's rmse: 14037.9	valid_1's rmse: 19993.1
# Early stopping, best iteration is:
# [18994]	training's rmse: 14130.5	valid_1's rmse: 19991.9
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [200]	training's rmse: 28030.7	valid_1's rmse: 28295.7
# [400]	training's rmse: 23604	valid_1's rmse: 23861.3
# [600]	training's rmse: 22126.2	valid_1's rmse: 22422.8
# [800]	training's rmse: 21392.3	valid_1's rmse: 21758.6
# [1000]	training's rmse: 20897.4	valid_1's rmse: 21351.3
# [1200]	training's rmse: 20540.7	valid_1's rmse: 21084.8
# [1400]	training's rmse: 20259	valid_1's rmse: 20903.4
# [1600]	training's rmse: 20032.4	valid_1's rmse: 20770
# [1800]	training's rmse: 19837.5	valid_1's rmse: 20668.7
# [2000]	training's rmse: 19666.8	valid_1's rmse: 20581.7
# [2200]	training's rmse: 19514.6	valid_1's rmse: 20507.6
# [2400]	training's rmse: 19373.7	valid_1's rmse: 20451.2
# [2600]	training's rmse: 19236.6	valid_1's rmse: 20398.9
# [2800]	training's rmse: 19110.4	valid_1's rmse: 20351.1
# [3000]	training's rmse: 18994.1	valid_1's rmse: 20313.4
# [3200]	training's rmse: 18877.4	valid_1's rmse: 20272.5
# [3400]	training's rmse: 18766.5	valid_1's rmse: 20240.7
# [3600]	training's rmse: 18668.3	valid_1's rmse: 20209.6
# [3800]	training's rmse: 18572.8	valid_1's rmse: 20183.7
# [4000]	training's rmse: 18474.9	valid_1's rmse: 20157.9
# [4200]	training's rmse: 18389.6	valid_1's rmse: 20137.5
# [4400]	training's rmse: 18303	valid_1's rmse: 20114
# [4600]	training's rmse: 18212.8	valid_1's rmse: 20092.4
# [4800]	training's rmse: 18126.5	valid_1's rmse: 20072.4
# [5000]	training's rmse: 18043.5	valid_1's rmse: 20052
# [5200]	training's rmse: 17959.6	valid_1's rmse: 20035.1
# [5400]	training's rmse: 17885.7	valid_1's rmse: 20022.1
# [5600]	training's rmse: 17810.8	valid_1's rmse: 20004.1
# [5800]	training's rmse: 17733.3	valid_1's rmse: 19992.6
# [6000]	training's rmse: 17665.1	valid_1's rmse: 19982
# [6200]	training's rmse: 17593.3	valid_1's rmse: 19970.6
# [6400]	training's rmse: 17524.6	valid_1's rmse: 19957.9
# [6600]	training's rmse: 17455.5	valid_1's rmse: 19948.8
# [6800]	training's rmse: 17387.7	valid_1's rmse: 19937.6
# [7000]	training's rmse: 17318.5	valid_1's rmse: 19929.2
# [7200]	training's rmse: 17252.1	valid_1's rmse: 19922.6
# [7400]	training's rmse: 17189.3	valid_1's rmse: 19914.9
# [7600]	training's rmse: 17125.7	valid_1's rmse: 19908.4
# [7800]	training's rmse: 17064.1	valid_1's rmse: 19899.7
# [8000]	training's rmse: 17003.8	valid_1's rmse: 19892.1
# [8200]	training's rmse: 16943.3	valid_1's rmse: 19888
# [8400]	training's rmse: 16880.5	valid_1's rmse: 19882.2
# [8600]	training's rmse: 16819.8	valid_1's rmse: 19877.7
# [8800]	training's rmse: 16759	valid_1's rmse: 19870.7
# [9000]	training's rmse: 16701.9	valid_1's rmse: 19866.1
# [9200]	training's rmse: 16645.2	valid_1's rmse: 19860.5
# [9400]	training's rmse: 16587.7	valid_1's rmse: 19856.1
# [9600]	training's rmse: 16529.3	valid_1's rmse: 19849.9
# [9800]	training's rmse: 16469.3	valid_1's rmse: 19844.7
# [10000]	training's rmse: 16411	valid_1's rmse: 19843.1
# [10200]	training's rmse: 16353.4	valid_1's rmse: 19838.2
# [10400]	training's rmse: 16293.2	valid_1's rmse: 19833.9
# [10600]	training's rmse: 16238.1	valid_1's rmse: 19827.9
# [10800]	training's rmse: 16180.6	valid_1's rmse: 19826.7
# [11000]	training's rmse: 16125.4	valid_1's rmse: 19823.9
# [11200]	training's rmse: 16069.9	valid_1's rmse: 19821.3
# [11400]	training's rmse: 16015.1	valid_1's rmse: 19819.6
# [11600]	training's rmse: 15961.9	valid_1's rmse: 19819
# [11800]	training's rmse: 15909.5	valid_1's rmse: 19817.8
# [12000]	training's rmse: 15857.5	valid_1's rmse: 19816.1
# [12200]	training's rmse: 15805.3	valid_1's rmse: 19810.2
# [12400]	training's rmse: 15752.7	valid_1's rmse: 19807.1
# [12600]	training's rmse: 15699	valid_1's rmse: 19804.1
# [12800]	training's rmse: 15649.5	valid_1's rmse: 19804.9
# [13000]	training's rmse: 15596.9	valid_1's rmse: 19801.5
# [13200]	training's rmse: 15545.3	valid_1's rmse: 19797.9
# [13400]	training's rmse: 15494.5	valid_1's rmse: 19797.4
# [13600]	training's rmse: 15444.7	valid_1's rmse: 19795
# [13800]	training's rmse: 15396.5	valid_1's rmse: 19793.3
# [14000]	training's rmse: 15346.6	valid_1's rmse: 19789.4
# [14200]	training's rmse: 15298.7	valid_1's rmse: 19786.4
# [14400]	training's rmse: 15250.3	valid_1's rmse: 19783.6
# [14600]	training's rmse: 15199.5	valid_1's rmse: 19781
# [14800]	training's rmse: 15151.5	valid_1's rmse: 19780.9
# [15000]	training's rmse: 15100.1	valid_1's rmse: 19779.4
# [15200]	training's rmse: 15051.1	valid_1's rmse: 19779.8
# [15400]	training's rmse: 15002.5	valid_1's rmse: 19778.2
# [15600]	training's rmse: 14954.5	valid_1's rmse: 19779.2
# [15800]	training's rmse: 14905.2	valid_1's rmse: 19777.8
# [16000]	training's rmse: 14857.3	valid_1's rmse: 19779.1
# [16200]	training's rmse: 14811.9	valid_1's rmse: 19777.3
# [16400]	training's rmse: 14765.1	valid_1's rmse: 19777.5
# [16600]	training's rmse: 14716.6	valid_1's rmse: 19778.5
# [16800]	training's rmse: 14670.2	valid_1's rmse: 19779
# Early stopping, best iteration is:
# [16431]	training's rmse: 14757.7	valid_1's rmse: 19776.2

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
# 20163.75685666844
# 20149.25682888747
oof_score
# Out:
# 20042.749818620618

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  2.833671e+09
# 1                                      te_Country__Age  2.072152e+09
# 2                              te_Country__YearsCoding  1.841572e+09
# 3                               te_Country__Employment  1.444467e+09
# 4                          te_Country__FormalEducation  1.257990e+09
# 5                               te_Country__SalaryType  1.163065e+09
# 6                      te_Country__ohe_DevType_Student  1.136052e+09
# 7                         te_YearsCodingProf__Currency  1.041657e+09
# 8                   te_YearsCodingProf__CurrencySymbol  9.910435e+08
# 9                       te_Country__CareerSatisfaction  7.461272e+08
# 10                              te_Country__Dependents  6.621382e+08
# 11   te_Country__ohe_EducationTypes_Contributed_to_...  5.882134e+08
# 12                   te_Country__ohe_Methodology_Agile  5.727421e+08
# 13                       te_SalaryType__CurrencySymbol  5.524913e+08
# 14                      te_YearsCodingProf__MilitaryUS  4.664098e+08
# 15                       te_Employment__CurrencySymbol  4.633392e+08
# 16                              te_CurrencySymbol__Age  4.256332e+08
# 17              te_CurrencySymbol__ohe_DevType_Student  3.973443e+08
# 18       te_Country__ohe_CommunicationTools_Confluence  3.074417e+08
# 19                 te_YearsCodingProf__OperatingSystem  2.856822e+08
# 20                             te_Country__CompanySize  2.640781e+08
# 21                          te_Country__CurrencySymbol  2.592310e+08
# 22                      te_YearsCoding__CurrencySymbol  2.328282e+08
# 23                                te_Country__Currency  2.284043e+08
# 24                                  te_SalaryType__Age  2.153040e+08
# 25                             te_Employment__Currency  2.128156e+08
# 26                         te_Country__OperatingSystem  2.116392e+08
# 27      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  2.075666e+08
# 28                      te_YearsCodingProf__SalaryType  1.783681e+08
# 29   triple_count_YearsCodingProf__MilitaryUS__ohe_...  1.669705e+08
# 30                     te_CompanySize__YearsCodingProf  1.642332e+08
# 31              te_YearsCodingProf__CareerSatisfaction  1.488392e+08
# 32                            te_YearsCoding__Currency  1.477878e+08
# 33                 te_FormalEducation__YearsCodingProf  1.458479e+08
# 34                              te_Country__MilitaryUS  1.437046e+08
# 35                             te_Currency__SalaryType  1.420822e+08
# 36   te_YearsCodingProf__ohe_EducationTypes_Contrib...  1.392479e+08
# 37              te_Country__ohe_LanguageWorkedWith_PHP  1.339525e+08
# 38         te_Country__ohe_DevType_Engineering_manager  1.294179e+08
# 39                          te_YearsCoding__SalaryType  1.287692e+08
# 40   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.238829e+08
# 41   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  1.210832e+08
# 42                      te_Employment__YearsCodingProf  1.189900e+08
# 43                  te_FormalEducation__CurrencySymbol  1.159656e+08
# 44   triple_count_Country__Currency__ohe_DevType_St...  1.141984e+08
# 45                     te_YearsCoding__YearsCodingProf  1.139247e+08
# 46                             te_YearsCodingProf__Age  1.137566e+08
# 47                     te_CompanySize__OperatingSystem  1.080554e+08
# 48                                          te_Country  1.078008e+08
# 49   te_YearsCodingProf__ohe_CommunicationTools_Con...  1.019636e+08
# 50                           te_Employment__SalaryType  1.017385e+08
# 51                  te_CompanySize__CareerSatisfaction  8.409453e+07
# 52   triple_count_YearsCodingProf__MilitaryUS__ohe_...  8.375121e+07
# 53   te_CurrencySymbol__ohe_EducationTypes_Contribu...  8.201294e+07
# 54                                    te_Currency__Age  8.200648e+07
# 55           te_YearsCodingProf__ohe_Methodology_Agile  8.198545e+07
# 56                                       te_LastNewJob  8.115219e+07
# 57                          te_YearsCoding__MilitaryUS  7.602550e+07
# 58               te_CareerSatisfaction__CurrencySymbol  7.527480e+07
# 59                           te_Employment__MilitaryUS  7.239546e+07
# 60            te_CurrencySymbol__ohe_Methodology_Agile  7.055933e+07
# 61   triple_count_ohe_DevType_Student__ohe_Language...  6.957851e+07
# 62                  te_Employment__ohe_DevType_Student  6.697803e+07
# 63   te_CurrencySymbol__ohe_CommunicationTools_Conf...  6.558389e+07
# 64                                 te_CompanySize__Age  6.458124e+07
# 65                  te_CurrencySymbol__OperatingSystem  6.388585e+07
# 66                     te_YearsCoding__OperatingSystem  6.322324e+07
# 67                    te_Currency__ohe_DevType_Student  6.289450e+07
# 68   agg_mean_YearsCodingProf_ohe_CommunicationTool...  6.208131e+07
# 69   triple_count_Employment__ohe_DevType_Student__...  6.153028e+07
# 70                  te_SalaryType__ohe_DevType_Student  6.119775e+07
# 71               te_CompanySize__ohe_Methodology_Agile  5.781353e+07
# 72                                  te_Employment__Age  5.766460e+07
# 73             te_YearsCodingProf__ohe_DevType_Student  5.686468e+07
# 74                       te_CurrencySymbol__Dependents  5.580870e+07
# 75                            svd_CommunicationTools_0  5.247762e+07
# 76   triple_count_Country__CurrencySymbol__ohe_DevT...  5.149334e+07
# 77   te_CurrencySymbol__ohe_DevType_Engineering_man...  4.969320e+07
# 78                      te_Employment__FormalEducation  4.939365e+07
# 79   te_CompanySize__ohe_CommunicationTools_Confluence  4.854921e+07
# 80                      te_CompanySize__CurrencySymbol  4.718897e+07
# 81          te_YearsCoding__ohe_LanguageWorkedWith_PHP  4.693686e+07
# 82   triple_count_Employment__ohe_DevType_Student__...  4.681123e+07
# 83   triple_count_YearsCodingProf__SalaryType__Mili...  4.613278e+07
# 84   triple_count_YearsCodingProf__OperatingSystem_...  4.531330e+07
# 85                         te_CompanySize__YearsCoding  4.440869e+07
# 86                te_Employment__ohe_Methodology_Agile  4.412553e+07
# 87                          te_Employment__YearsCoding  4.406678e+07
# 88   te_YearsCodingProf__ohe_DevType_Engineering_ma...  4.371514e+07
# 89              te_CareerSatisfaction__OperatingSystem  4.088803e+07
# 90   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  4.035160e+07
# 91      te_Employment__ohe_DevType_Engineering_manager  3.983032e+07
# 92                                 te_YearsCoding__Age  3.972777e+07
# 93   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  3.956903e+07
# 94                  te_YearsCoding__CareerSatisfaction  3.885476e+07
# 95                          te_Employment__CompanySize  3.870122e+07
# 96   triple_count_Employment__ohe_DevType_Student__...  3.802519e+07
# 97   te_CompanySize__ohe_EducationTypes_Contributed...  3.654110e+07
# 98   triple_count_YearsCodingProf__MilitaryUS__ohe_...  3.627713e+07
# 99                   te_Employment__CareerSatisfaction  3.621796e+07
# 100  triple_count_CompanySize__YearsCodingProf__ohe...  3.580902e+07
# 101  te_YearsCoding__ohe_RaceEthnicity_White_or_of_...  3.559956e+07
# 102                         te_CareerSatisfaction__Age  3.513924e+07
# 103  te_CareerSatisfaction__ohe_DevType_Engineering...  3.376434e+07
# 104                     te_YearsCodingProf__Dependents  3.320813e+07
# 105       agg_mean_YearsCodingProf_ohe_DevType_Student  3.303962e+07
# 106  triple_count_Employment__CompanySize__ohe_DevT...  3.303323e+07
# 107  rank_diff_AssessBenefits_AssessBenefits2_Asses...  3.298885e+07
# 108  triple_count_YearsCodingProf__MilitaryUS__ohe_...  3.296923e+07
# 109                     te_Employment__OperatingSystem  3.135535e+07
# 110                     te_FormalEducation__SalaryType  3.095548e+07
# 111               te_SalaryType__ohe_Methodology_Agile  3.071221e+07
# 112          te_Employment__ohe_LanguageWorkedWith_PHP  3.042247e+07
# 113                           svd_LanguageWorkedWith_1  3.013288e+07
# 114                    te_FormalEducation__CompanySize  2.979284e+07
# 115             te_FormalEducation__CareerSatisfaction  2.940381e+07
# 116                te_CompanySize__ohe_DevType_Student  2.938403e+07
# 117  triple_count_Employment__ohe_DevType_Engineeri...  2.923483e+07
# 118                         te_CompanySize__SalaryType  2.914263e+07
# 119                         te_CompanySize__Dependents  2.909243e+07
# 120  triple_count_CareerSatisfaction__ohe_DevType_S...  2.862353e+07
# 121  triple_count_Country__Currency__ohe_Communicat...  2.849716e+07
# 122                       svd_DatabaseDesireNextYear_1  2.843954e+07
# 123                te_FormalEducation__OperatingSystem  2.842466e+07
# 124  agg_std_Country_ohe_CommunicationTools_Confluence  2.831590e+07
# 125              rel_agg_mean_Currency_AssessBenefits2  2.820090e+07
# 126                        te_Age__ohe_DevType_Student  2.731526e+07
# 127  triple_count_YearsCodingProf__OperatingSystem_...  2.722314e+07
# 128                            te_FormalEducation__Age  2.717735e+07
# 129      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  2.699501e+07
# 130    te_CompanySize__ohe_DevType_Engineering_manager  2.677113e+07
# 131  triple_count_Employment__ohe_DevType_Student__...  2.663239e+07
# 132                    te_CareerSatisfaction__Currency  2.586168e+07
# 133  triple_count_YearsCodingProf__OperatingSystem_...  2.563658e+07
# 134                te_YearsCoding__ohe_DevType_Student  2.532643e+07
# 135             diff_agg_mean_Currency_AssessBenefits2  2.518752e+07
# 136                               ohe_DevType_Designer  2.517017e+07
# 137  triple_count_YearsCodingProf__SalaryType__ohe_...  2.514357e+07
# 138  triple_count_YearsCodingProf__ohe_DevType_Engi...  2.486765e+07
# 139                            te_OperatingSystem__Age  2.444227e+07
# 140  triple_count_Country__Employment__YearsCodingProf  2.426217e+07
# 141  agg_std_YearsCodingProf_ohe_CommunicationTools...  2.381204e+07
# 142  triple_count_YearsCoding__MilitaryUS__ohe_Educ...  2.377199e+07
# 143  rank_diff_JobContactPriorities_JobContactPrior...  2.363415e+07
# 144                               svd_VersionControl_1  2.346776e+07
# 145                           te_CompanySize__Currency  2.340681e+07
# 146  triple_count_Employment__MilitaryUS__ohe_DevTy...  2.318545e+07
# 147                                 te_YearsCodingProf  2.298720e+07
# 148                  te_CareerSatisfaction__SalaryType  2.294757e+07
# 149                      te_Age__ohe_Methodology_Agile  2.292192e+07
# 150   te_Employment__ohe_CommunicationTools_Confluence  2.259657e+07
# 151          te_FormalEducation__ohe_Methodology_Agile  2.247667e+07
# 152                       te_FormalEducation__Currency  2.224350e+07
# 153             agg_mean_HopeFiveYears_AssessBenefits2  2.219751e+07
# 154  te_CareerSatisfaction__ohe_EducationTypes_Cont...  2.214869e+07
# 155                          ohe_LanguageWorkedWith_Go  2.202236e+07
# 156         rank_diff_AssessJob_AssessJob4_AssessJob10  2.195859e+07
# 157  triple_count_YearsCodingProf__ohe_DevType_Engi...  2.183124e+07
# 158  triple_count_Employment__Age__ohe_DevType_Student  2.181421e+07
# 159           rel_agg_mean_CompanySize_AssessBenefits2  2.179563e+07
# 160  triple_count_Employment__OperatingSystem__ohe_...  2.168720e+07
# 161               rel_agg_mean_Country_AssessBenefits2  2.158316e+07
# 162        rel_agg_mean_CurrencySymbol_AssessBenefits2  2.125583e+07
# 163                                        te_UpdateCV  2.105055e+07
# 164         triple_count_Country__Employment__Currency  2.092519e+07
# 165       triple_count_Country__Employment__SalaryType  2.086076e+07
# 166                                  svd_Methodology_0  2.072274e+07
# 167                       te_Currency__OperatingSystem  2.047608e+07
# 168       diff_agg_mean_CurrencySymbol_AssessBenefits2  1.977539e+07
# 169                              te_HypotheticalTools2  1.956778e+07
# 170  triple_count_Country__Employment__ohe_DevType_...  1.948974e+07
# 171       diff_agg_mean_NumberMonitors_AssessBenefits2  1.946951e+07
# 172   te_SalaryType__ohe_CommunicationTools_Confluence  1.922899e+07
# 173                 te_Age__ohe_LanguageWorkedWith_PHP  1.893387e+07
# 174  te_FormalEducation__ohe_EducationTypes_Contrib...  1.884539e+07
# 175         rank_diff_AssessJob_AssessJob1_AssessJob10  1.820786e+07
# 176  triple_count_CareerSatisfaction__ohe_LanguageW...  1.819093e+07
# 177                       ohe_DatabaseWorkedWith_Redis  1.816837e+07
# 178          rank_diff_AssessJob_AssessJob4_AssessJob5  1.809612e+07
# 179        rel_agg_mean_NumberMonitors_AssessBenefits2  1.795670e+07
# 180  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.788214e+07
# 181  triple_count_YearsCodingProf__MilitaryUS__ohe_...  1.779806e+07
# 182  triple_count_Employment__CurrencySymbol__ohe_D...  1.779498e+07
# 183           agg_mean_YearsCodingProf_AssessBenefits2  1.775448e+07
# 184  triple_count_ohe_DevType_Student__ohe_Language...  1.766254e+07
# 185  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.765783e+07
# 186  te_Employment__ohe_EducationTypes_Contributed_...  1.741694e+07
# 187  triple_count_YearsCoding__MilitaryUS__ohe_Comm...  1.738357e+07
# 188     te_FormalEducation__ohe_LanguageWorkedWith_PHP  1.733208e+07
# 189                                        te_WakeTime  1.720978e+07
# 190  te_OperatingSystem__ohe_CommunicationTools_Con...  1.718591e+07
# 191                           svd_DatabaseWorkedWith_1  1.716018e+07
# 192          diff_agg_mean_Country_ohe_DevType_Student  1.708787e+07
# 193          te_SalaryType__ohe_LanguageWorkedWith_PHP  1.708534e+07
# 194  triple_count_YearsCodingProf__MilitaryUS__ohe_...  1.668164e+07
# 195            te_FormalEducation__ohe_DevType_Student  1.667728e+07
# 196                          te_Employment__Dependents  1.663642e+07
# 197         te_CareerSatisfaction__ohe_DevType_Student  1.652494e+07
# 198  triple_count_Employment__CareerSatisfaction__o...  1.652230e+07
# 199  triple_count_CompanySize__Dependents__ohe_Comm...  1.645675e+07
# 200  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.617576e+07
# 201  te_FormalEducation__ohe_DevType_Engineering_ma...  1.584593e+07
# 202       rel_agg_mean_FormalEducation_AssessBenefits2  1.581007e+07
# 203  triple_count_OperatingSystem__MilitaryUS__ohe_...  1.558448e+07
# 204  triple_count_Country__ohe_DevType_Student__ohe...  1.553121e+07
# 205  triple_count_CareerSatisfaction__ohe_DevType_S...  1.547698e+07
# 206              diff_agg_mean_Country_AssessBenefits2  1.542844e+07
# 207  triple_count_ohe_DevType_Engineering_manager__...  1.537970e+07
# 208                           svd_DatabaseWorkedWith_0  1.532508e+07
# 209         te_CompanySize__ohe_LanguageWorkedWith_PHP  1.530398e+07
# 210  triple_count_Employment__YearsCodingProf__ohe_...  1.517751e+07
# 211              te_YearsCoding__ohe_Methodology_Agile  1.515783e+07
# 212  triple_count_YearsCodingProf__SalaryType__ohe_...  1.496264e+07
# 213  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.491563e+07
# 214                                   ohe_IDE_NetBeans  1.475642e+07
# 215  triple_count_YearsCoding__OperatingSystem__ohe...  1.472227e+07
# 216  te_YearsCoding__ohe_CommunicationTools_Confluence  1.460634e+07
# 217  triple_count_Employment__FormalEducation__ohe_...  1.455033e+07
# 218                       svd_LanguageDesireNextYear_0  1.429611e+07
# 219                                 te_Age__MilitaryUS  1.425630e+07
# 220  rank_diff_JobContactPriorities_JobContactPrior...  1.425207e+07
# 221  te_CareerSatisfaction__ohe_CommunicationTools_...  1.421178e+07
# 222  rank_diff_AssessBenefits_AssessBenefits7_Asses...  1.404971e+07
# 223  agg_mean_Country_ohe_CommunicationTools_Conflu...  1.399187e+07
# 224              agg_std_Country_ohe_Methodology_Agile  1.398578e+07
# 225          rank_diff_AssessJob_AssessJob1_AssessJob5  1.398162e+07
# 226  rank_diff_AssessBenefits_AssessBenefits7_Asses...  1.392383e+07
# 227  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.391402e+07
# 228                                          svd_IDE_1  1.378300e+07
# 229         rank_diff_AssessJob_AssessJob6_AssessJob10  1.373354e+07
# 230                  diff_agg_mean_Age_AssessBenefits2  1.355601e+07
# 231  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.337788e+07
# 232                         ohe_LanguageWorkedWith_CSS  1.335065e+07
# 233          diff_agg_mean_CompanySize_AssessBenefits2  1.329450e+07
# 234                             svd_HackathonReasons_1  1.327794e+07
# 235  te_FormalEducation__ohe_CommunicationTools_Con...  1.326749e+07
# 236  triple_count_ohe_DevType_Student__ohe_Educatio...  1.317219e+07
# 237     te_SalaryType__ohe_DevType_Engineering_manager  1.315339e+07
# 238                                      svd_DevType_0  1.313510e+07
# 239  te_SalaryType__ohe_RaceEthnicity_White_or_of_E...  1.305965e+07
# 240                               svd_EducationTypes_0  1.297861e+07
# 241                    te_FormalEducation__YearsCoding  1.271211e+07
# 242     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.270916e+07
# 243            te_Currency__ohe_LanguageWorkedWith_PHP  1.267855e+07
# 244                       svd_LanguageDesireNextYear_1  1.265976e+07
# 245  triple_count_Employment__MilitaryUS__ohe_DevTy...  1.262990e+07
# 246           rel_agg_mean_YearsCoding_AssessBenefits2  1.248307e+07
# 247                 te_Currency__ohe_Methodology_Agile  1.246242e+07
# 248  triple_count_Employment__ohe_LanguageWorkedWit...  1.243269e+07
# 249         rank_diff_AssessJob_AssessJob8_AssessJob10  1.242618e+07
# 250         triple_count_Country__Currency__SalaryType  1.240577e+07
# 251                       ohe_PlatformWorkedWith_Azure  1.234100e+07
# 252  triple_count_Employment__OperatingSystem__ohe_...  1.219607e+07
# 253                        agg_mean_Country_AssessJob5  1.217614e+07
# 254  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.213033e+07
# 255        ohe_DevType_Educator_or_academic_researcher  1.211909e+07
# 256  diff_agg_mean_Employment_ohe_LanguageDesireNex...  1.207430e+07
# 257          diff_agg_mean_Student_ohe_DevType_Student  1.203561e+07
# 258  rank_diff_AssessBenefits_AssessBenefits1_Asses...  1.197681e+07
# 259                     te_SalaryType__OperatingSystem  1.188555e+07
# 260          rank_diff_AssessJob_AssessJob8_AssessJob9  1.187423e+07
# 261  triple_count_Employment__ohe_DevType_Engineeri...  1.185694e+07
# 262          rank_diff_AssessJob_AssessJob7_AssessJob9  1.184694e+07
# 263                      sum_answer_DatabaseWorkedWith  1.183489e+07
# 264          rank_diff_AssessJob_AssessJob5_AssessJob7  1.182324e+07
# 265  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  1.181236e+07
# 266  triple_count_Employment__SalaryType__ohe_Commu...  1.178460e+07
# 267  triple_count_Employment__CareerSatisfaction__o...  1.175409e+07
# 268  te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  1.163746e+07
# 269  triple_count_CompanySize__OperatingSystem__ohe...  1.157689e+07
# 270        agg_std_Country_ohe_CommunicationTools_Jira  1.154136e+07
# 271  triple_count_ohe_DevType_Student__ohe_Educatio...  1.151936e+07
# 272         diff_agg_mean_Currency_ohe_DevType_Student  1.149361e+07
# 273  rank_diff_JobContactPriorities_JobContactPrior...  1.145413e+07
# 274  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.136115e+07
# 275                     ohe_FrameworkWorkedWith_Hadoop  1.136092e+07
# 276  diff_agg_mean_Country_ohe_LanguageDesireNextYe...  1.135741e+07
# 277                                     te_CheckInCode  1.132229e+07
# 278  rank_diff_AssessBenefits_AssessBenefits8_Asses...  1.132031e+07
# 279  triple_count_CompanySize__ohe_DevType_Student_...  1.131717e+07
# 280   triple_count_Country__Employment__CurrencySymbol  1.128494e+07
# 281                                        te_Exercise  1.126831e+07
# 282  rank_diff_AssessBenefits_AssessBenefits2_Asses...  1.125600e+07
# 283  triple_count_Employment__Dependents__ohe_DevTy...  1.125007e+07
# 284  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.123075e+07
# 285  triple_count_Employment__CareerSatisfaction__S...  1.121590e+07
# 286  triple_count_YearsCodingProf__ohe_Communicatio...  1.120719e+07
# 287  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.116186e+07
# 288  triple_count_SalaryType__ohe_DevType_Student__...  1.113912e+07
# 289       te_CareerSatisfaction__ohe_Methodology_Agile  1.112474e+07
# 290  rank_diff_AssessBenefits_AssessBenefits5_Asses...  1.111353e+07
# 291          rank_diff_AssessJob_AssessJob5_AssessJob8  1.110170e+07
# 292                          svd_FrameworkWorkedWith_1  1.109530e+07
# 293  rank_diff_JobContactPriorities_JobContactPrior...  1.106376e+07
# 294  triple_count_Employment__FormalEducation__Care...  1.104789e+07
# 295  triple_count_YearsCoding__ohe_DevType_Engineer...  1.104338e+07
# 296  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.100576e+07
# 297          rank_diff_AssessJob_AssessJob3_AssessJob6  1.098735e+07
# 298  rank_diff_JobEmailPriorities_JobEmailPrioritie...  1.098728e+07
# 299                   diff_agg_mean_Country_AssessJob5  1.097644e+07

# %%
len(use_cols)
# Out:
# 1000

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 65743.1318965 ,  90686.66694296,  89332.35542152, ...,
#         88280.23455145,  81325.33022908, 119296.33606853])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/030_down_lr_20042.csv", index=False)
