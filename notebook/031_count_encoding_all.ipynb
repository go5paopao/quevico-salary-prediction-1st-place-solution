# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def triple_count_encoding(train_df, test_df):
     # triple target encoding
    triple_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=30)
    triple_te_cols = [c for c in triple_te_cols if c in imp_feats]
    combi_triple_te_cols = list(itertools.combinations(triple_te_cols, 3))
    
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

    
    for col_a, col_b, col_c in tqdm(combi_triple_te_cols):
        all_df["tmp"] = all_df[col_a].fillna("").astype(str) + all_df[col_b].fillna("").astype(str) + all_df[col_c].fillna("").astype(str)
        new_col = "triple_count_" + col_a + "__" + col_b + "__" + col_c
        count = all_df["tmp"].value_counts()
        all_df[new_col] = all_df["tmp"].map(count)
    del all_df["tmp"]
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    return train_df, test_df

# %%
train_df, test_df = triple_count_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3825

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df  # .sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                4000,
                valid_sets = [train_dataset],
                verbose_eval=200,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

# use_cols = feature_selection(train_df, use_cols, n_features=1000)

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                10000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 500,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22705	valid_1's rmse: 23042.2
# [200]	training's rmse: 20853.1	valid_1's rmse: 21682.6
# [300]	training's rmse: 20028.4	valid_1's rmse: 21263.6
# [400]	training's rmse: 19516	valid_1's rmse: 21043.9
# [500]	training's rmse: 19121.9	valid_1's rmse: 20901.1
# [600]	training's rmse: 18791.7	valid_1's rmse: 20805.6
# [700]	training's rmse: 18494.6	valid_1's rmse: 20739.7
# [800]	training's rmse: 18225.9	valid_1's rmse: 20667
# [900]	training's rmse: 17989	valid_1's rmse: 20620.6
# [1000]	training's rmse: 17761.6	valid_1's rmse: 20582.5
# [1100]	training's rmse: 17553	valid_1's rmse: 20551.8
# [1200]	training's rmse: 17336.2	valid_1's rmse: 20522.1
# [1300]	training's rmse: 17155.6	valid_1's rmse: 20506.5
# [1400]	training's rmse: 16974.8	valid_1's rmse: 20484
# [1500]	training's rmse: 16787.9	valid_1's rmse: 20473.1
# [1600]	training's rmse: 16620.7	valid_1's rmse: 20458
# [1700]	training's rmse: 16447.8	valid_1's rmse: 20441.5
# [1800]	training's rmse: 16263.7	valid_1's rmse: 20425.6
# [1900]	training's rmse: 16090.9	valid_1's rmse: 20418.8
# [2000]	training's rmse: 15940.3	valid_1's rmse: 20412.9
# [2100]	training's rmse: 15776.4	valid_1's rmse: 20392.2
# [2200]	training's rmse: 15613.9	valid_1's rmse: 20384.8
# [2300]	training's rmse: 15452.3	valid_1's rmse: 20370.8
# [2400]	training's rmse: 15297.7	valid_1's rmse: 20368
# [2500]	training's rmse: 15147.3	valid_1's rmse: 20361.6
# [2600]	training's rmse: 14995.7	valid_1's rmse: 20371.7
# [2700]	training's rmse: 14846.3	valid_1's rmse: 20362.8
# [2800]	training's rmse: 14707.8	valid_1's rmse: 20359.5
# [2900]	training's rmse: 14560	valid_1's rmse: 20353.5
# [3000]	training's rmse: 14427.9	valid_1's rmse: 20346.3
# [3100]	training's rmse: 14293.5	valid_1's rmse: 20348.4
# [3200]	training's rmse: 14161.9	valid_1's rmse: 20341.3
# [3300]	training's rmse: 14037.3	valid_1's rmse: 20328.6
# [3400]	training's rmse: 13910.6	valid_1's rmse: 20326
# [3500]	training's rmse: 13776.8	valid_1's rmse: 20332.3
# [3600]	training's rmse: 13667.4	valid_1's rmse: 20330.1
# [3700]	training's rmse: 13549.8	valid_1's rmse: 20331.6
# [3800]	training's rmse: 13430.5	valid_1's rmse: 20323.3
# Early stopping, best iteration is:
# [3358]	training's rmse: 13956.6	valid_1's rmse: 20322.7
# Fold 2
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22690.3	valid_1's rmse: 23316.8
# [200]	training's rmse: 20872.7	valid_1's rmse: 21804.3
# [300]	training's rmse: 20059.2	valid_1's rmse: 21237.3
# [400]	training's rmse: 19539.8	valid_1's rmse: 21000.2
# [500]	training's rmse: 19162.4	valid_1's rmse: 20851.2
# [600]	training's rmse: 18830	valid_1's rmse: 20744.8
# [700]	training's rmse: 18535.6	valid_1's rmse: 20661.9
# [800]	training's rmse: 18289.6	valid_1's rmse: 20585.9
# [900]	training's rmse: 18039.9	valid_1's rmse: 20531.5
# [1000]	training's rmse: 17810.2	valid_1's rmse: 20482.4
# [1100]	training's rmse: 17600	valid_1's rmse: 20448.1
# [1200]	training's rmse: 17399.8	valid_1's rmse: 20400.9
# [1300]	training's rmse: 17209.9	valid_1's rmse: 20374.6
# [1400]	training's rmse: 17022.8	valid_1's rmse: 20352.9
# [1500]	training's rmse: 16844	valid_1's rmse: 20326.2
# [1600]	training's rmse: 16669.5	valid_1's rmse: 20309.8
# [1700]	training's rmse: 16500.8	valid_1's rmse: 20283.9
# [1800]	training's rmse: 16343.6	valid_1's rmse: 20260.2
# [1900]	training's rmse: 16173.7	valid_1's rmse: 20247.7
# [2000]	training's rmse: 16006.7	valid_1's rmse: 20232.9
# [2100]	training's rmse: 15860.6	valid_1's rmse: 20220.8
# [2200]	training's rmse: 15706.9	valid_1's rmse: 20220.9
# [2300]	training's rmse: 15550.3	valid_1's rmse: 20211.1
# [2400]	training's rmse: 15410.7	valid_1's rmse: 20207.4
# [2500]	training's rmse: 15250.8	valid_1's rmse: 20198.2
# [2600]	training's rmse: 15104	valid_1's rmse: 20196.6
# [2700]	training's rmse: 14961.7	valid_1's rmse: 20191.3
# [2800]	training's rmse: 14816.5	valid_1's rmse: 20188
# [2900]	training's rmse: 14674.5	valid_1's rmse: 20182.2
# [3000]	training's rmse: 14538.5	valid_1's rmse: 20176.4
# [3100]	training's rmse: 14399	valid_1's rmse: 20175.5
# [3200]	training's rmse: 14281.1	valid_1's rmse: 20166.6
# [3300]	training's rmse: 14149.7	valid_1's rmse: 20161.3
# [3400]	training's rmse: 14020.5	valid_1's rmse: 20159.6
# [3500]	training's rmse: 13897.4	valid_1's rmse: 20153.6
# [3600]	training's rmse: 13770.6	valid_1's rmse: 20153.4
# [3700]	training's rmse: 13653.2	valid_1's rmse: 20155.8
# [3800]	training's rmse: 13533.3	valid_1's rmse: 20154.3
# [3900]	training's rmse: 13406.1	valid_1's rmse: 20148
# [4000]	training's rmse: 13282.1	valid_1's rmse: 20148
# [4100]	training's rmse: 13150.6	valid_1's rmse: 20143.1
# [4200]	training's rmse: 13032.8	valid_1's rmse: 20148.9
# [4300]	training's rmse: 12917.1	valid_1's rmse: 20144
# [4400]	training's rmse: 12799.6	valid_1's rmse: 20150
# [4500]	training's rmse: 12675.8	valid_1's rmse: 20151.2
# [4600]	training's rmse: 12567.4	valid_1's rmse: 20153
# Early stopping, best iteration is:
# [4106]	training's rmse: 13144.6	valid_1's rmse: 20141.3
# Fold 3
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22658.6	valid_1's rmse: 23082
# [200]	training's rmse: 20833.5	valid_1's rmse: 21629.4
# [300]	training's rmse: 20051.2	valid_1's rmse: 21201.7
# [400]	training's rmse: 19523.5	valid_1's rmse: 21009.9
# [500]	training's rmse: 19129.3	valid_1's rmse: 20905.7
# [600]	training's rmse: 18814.1	valid_1's rmse: 20837
# [700]	training's rmse: 18525.6	valid_1's rmse: 20777.9
# [800]	training's rmse: 18248.3	valid_1's rmse: 20735.9
# [900]	training's rmse: 18015.6	valid_1's rmse: 20694.8
# [1000]	training's rmse: 17792	valid_1's rmse: 20662
# [1100]	training's rmse: 17580.6	valid_1's rmse: 20630.2
# [1200]	training's rmse: 17386.2	valid_1's rmse: 20608.3
# [1300]	training's rmse: 17182.3	valid_1's rmse: 20595.2
# [1400]	training's rmse: 16999.8	valid_1's rmse: 20565.9
# [1500]	training's rmse: 16816.8	valid_1's rmse: 20547.5
# [1600]	training's rmse: 16652	valid_1's rmse: 20534.2
# [1700]	training's rmse: 16458.4	valid_1's rmse: 20521.4
# [1800]	training's rmse: 16283.9	valid_1's rmse: 20516.9
# [1900]	training's rmse: 16117.7	valid_1's rmse: 20508
# [2000]	training's rmse: 15962.3	valid_1's rmse: 20498.1
# [2100]	training's rmse: 15801.5	valid_1's rmse: 20495.8
# [2200]	training's rmse: 15644.8	valid_1's rmse: 20500.5
# [2300]	training's rmse: 15496.4	valid_1's rmse: 20503.1
# [2400]	training's rmse: 15347.9	valid_1's rmse: 20493.4
# [2500]	training's rmse: 15192	valid_1's rmse: 20488.7
# [2600]	training's rmse: 15056.1	valid_1's rmse: 20487.3
# [2700]	training's rmse: 14928.6	valid_1's rmse: 20483
# [2800]	training's rmse: 14780.5	valid_1's rmse: 20475.8
# [2900]	training's rmse: 14650.7	valid_1's rmse: 20471
# [3000]	training's rmse: 14506.5	valid_1's rmse: 20470.4
# [3100]	training's rmse: 14368.3	valid_1's rmse: 20468.7
# [3200]	training's rmse: 14235.5	valid_1's rmse: 20463.7
# [3300]	training's rmse: 14103.9	valid_1's rmse: 20468.9
# [3400]	training's rmse: 13976.6	valid_1's rmse: 20465.1
# [3500]	training's rmse: 13847.4	valid_1's rmse: 20467.4
# [3600]	training's rmse: 13727.7	valid_1's rmse: 20469
# [3700]	training's rmse: 13609.6	valid_1's rmse: 20472.2
# Early stopping, best iteration is:
# [3222]	training's rmse: 14211.1	valid_1's rmse: 20461.2
# Fold 4
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22715.5	valid_1's rmse: 23089.1
# [200]	training's rmse: 20866	valid_1's rmse: 21639.1
# [300]	training's rmse: 20071.5	valid_1's rmse: 21203.9
# [400]	training's rmse: 19562.8	valid_1's rmse: 20977.5
# [500]	training's rmse: 19163.6	valid_1's rmse: 20837.5
# [600]	training's rmse: 18840.4	valid_1's rmse: 20761.1
# [700]	training's rmse: 18555.5	valid_1's rmse: 20685.8
# [800]	training's rmse: 18291.8	valid_1's rmse: 20618.9
# [900]	training's rmse: 18058.2	valid_1's rmse: 20571.1
# [1000]	training's rmse: 17833.4	valid_1's rmse: 20536.6
# [1100]	training's rmse: 17625	valid_1's rmse: 20493.6
# [1200]	training's rmse: 17430.6	valid_1's rmse: 20466.8
# [1300]	training's rmse: 17250.7	valid_1's rmse: 20439.9
# [1400]	training's rmse: 17063.7	valid_1's rmse: 20421.7
# [1500]	training's rmse: 16878.4	valid_1's rmse: 20409.5
# [1600]	training's rmse: 16702	valid_1's rmse: 20386.9
# [1700]	training's rmse: 16519.3	valid_1's rmse: 20369.8
# [1800]	training's rmse: 16338.6	valid_1's rmse: 20346.3
# [1900]	training's rmse: 16181.3	valid_1's rmse: 20330
# [2000]	training's rmse: 16030.3	valid_1's rmse: 20317.2
# [2100]	training's rmse: 15869.5	valid_1's rmse: 20310.3
# [2200]	training's rmse: 15723.4	valid_1's rmse: 20307.2
# [2300]	training's rmse: 15556.3	valid_1's rmse: 20299.6
# [2400]	training's rmse: 15411.5	valid_1's rmse: 20298.8
# [2500]	training's rmse: 15276.2	valid_1's rmse: 20293.9
# [2600]	training's rmse: 15128.7	valid_1's rmse: 20292.6
# [2700]	training's rmse: 14989.8	valid_1's rmse: 20275.4
# [2800]	training's rmse: 14857.6	valid_1's rmse: 20265.1
# [2900]	training's rmse: 14706.9	valid_1's rmse: 20262.8
# [3000]	training's rmse: 14568.4	valid_1's rmse: 20264.6
# [3100]	training's rmse: 14425	valid_1's rmse: 20259.9
# [3200]	training's rmse: 14291.4	valid_1's rmse: 20258.4
# [3300]	training's rmse: 14173.1	valid_1's rmse: 20260.8
# [3400]	training's rmse: 14032.6	valid_1's rmse: 20260.1
# [3500]	training's rmse: 13906.6	valid_1's rmse: 20250.6
# [3600]	training's rmse: 13787.6	valid_1's rmse: 20252.7
# [3700]	training's rmse: 13681.8	valid_1's rmse: 20249.5
# [3800]	training's rmse: 13561.5	valid_1's rmse: 20254.7
# [3900]	training's rmse: 13449.4	valid_1's rmse: 20261
# [4000]	training's rmse: 13326	valid_1's rmse: 20263
# Early stopping, best iteration is:
# [3542]	training's rmse: 13859	valid_1's rmse: 20246.4
# Fold 5
# Training until validation scores don't improve for 500 rounds
# [100]	training's rmse: 22773	valid_1's rmse: 23090.3
# [200]	training's rmse: 20936.5	valid_1's rmse: 21440.2
# [300]	training's rmse: 20138	valid_1's rmse: 20900.8
# [400]	training's rmse: 19633	valid_1's rmse: 20639.2
# [500]	training's rmse: 19254.9	valid_1's rmse: 20484.4
# [600]	training's rmse: 18926.9	valid_1's rmse: 20371.9
# [700]	training's rmse: 18618.2	valid_1's rmse: 20266
# [800]	training's rmse: 18355.9	valid_1's rmse: 20198.7
# [900]	training's rmse: 18118.6	valid_1's rmse: 20139.8
# [1000]	training's rmse: 17909.5	valid_1's rmse: 20107.9
# [1100]	training's rmse: 17691.1	valid_1's rmse: 20077.6
# [1200]	training's rmse: 17477.4	valid_1's rmse: 20032.4
# [1300]	training's rmse: 17296.3	valid_1's rmse: 20011.5
# [1400]	training's rmse: 17110.9	valid_1's rmse: 19987.7
# [1500]	training's rmse: 16925.1	valid_1's rmse: 19972.1
# [1600]	training's rmse: 16747.7	valid_1's rmse: 19952
# [1700]	training's rmse: 16575.9	valid_1's rmse: 19937.5
# [1800]	training's rmse: 16410.3	valid_1's rmse: 19932.5
# [1900]	training's rmse: 16244	valid_1's rmse: 19928
# [2000]	training's rmse: 16072.7	valid_1's rmse: 19919.1
# [2100]	training's rmse: 15908.2	valid_1's rmse: 19910.5
# [2200]	training's rmse: 15745.1	valid_1's rmse: 19906.5
# [2300]	training's rmse: 15606.1	valid_1's rmse: 19900.7
# [2400]	training's rmse: 15451	valid_1's rmse: 19890.2
# [2500]	training's rmse: 15314.7	valid_1's rmse: 19884.6
# [2600]	training's rmse: 15175.7	valid_1's rmse: 19883
# [2700]	training's rmse: 15038.3	valid_1's rmse: 19882.2
# [2800]	training's rmse: 14908.8	valid_1's rmse: 19883.4
# [2900]	training's rmse: 14780	valid_1's rmse: 19881.7
# [3000]	training's rmse: 14643	valid_1's rmse: 19884.8
# Early stopping, best iteration is:
# [2518]	training's rmse: 15289	valid_1's rmse: 19877.9

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
# 20163.75685666844
# 20149.25682888747
oof_score
# Out:
# 20210.87713104705

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  4.763024e+08
# 1                               te_Country__SalaryType  4.257446e+08
# 2                          te_Country__FormalEducation  3.246182e+08
# 3                              te_Country__CompanySize  2.602396e+08
# 4                              te_Country__YearsCoding  2.570938e+08
# 5                   te_YearsCodingProf__CurrencySymbol  2.286880e+08
# 6                      te_Country__ohe_DevType_Student  1.881781e+08
# 7                                      te_Country__Age  1.863671e+08
# 8                       te_Country__CareerSatisfaction  1.807659e+08
# 9                       te_YearsCodingProf__MilitaryUS  1.596145e+08
# 10                       te_Employment__CurrencySymbol  1.469693e+08
# 11                              te_Country__Employment  1.458428e+08
# 12   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.370807e+08
# 13                             te_Currency__SalaryType  1.098757e+08
# 14         te_Country__ohe_DevType_Engineering_manager  9.169796e+07
# 15                                te_Country__Currency  9.137914e+07
# 16                     te_CompanySize__YearsCodingProf  8.695746e+07
# 17                              te_Country__MilitaryUS  8.356981e+07
# 18                      te_Employment__YearsCodingProf  7.732314e+07
# 19                       te_SalaryType__CurrencySymbol  7.406566e+07
# 20                         te_Country__OperatingSystem  7.060368e+07
# 21                                          te_Country  6.270795e+07
# 22                      te_YearsCoding__CurrencySymbol  6.239045e+07
# 23   te_Country__ohe_EducationTypes_Contributed_to_...  6.072845e+07
# 24                              te_CurrencySymbol__Age  6.031831e+07
# 25                      te_YearsCodingProf__SalaryType  5.265576e+07
# 26   te_YearsCodingProf__ohe_CommunicationTools_Con...  4.695559e+07
# 27                    te_Currency__ohe_DevType_Student  4.354832e+07
# 28              te_CurrencySymbol__ohe_DevType_Student  3.858033e+07
# 29      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  3.857561e+07
# 30   triple_count_YearsCodingProf__MilitaryUS__ohe_...  3.704363e+07
# 31   triple_count_YearsCoding__MilitaryUS__ohe_DevT...  3.657209e+07
# 32              te_YearsCodingProf__CareerSatisfaction  3.439499e+07
# 33   triple_count_YearsCodingProf__MilitaryUS__ohe_...  3.072368e+07
# 34             te_YearsCodingProf__ohe_DevType_Student  2.892820e+07
# 35                   te_Country__ohe_Methodology_Agile  2.869137e+07
# 36   te_CurrencySymbol__ohe_DevType_Engineering_man...  2.755512e+07
# 37                                  te_SalaryType__Age  2.748235e+07
# 38                 te_YearsCodingProf__OperatingSystem  2.644780e+07
# 39                             te_YearsCodingProf__Age  2.623308e+07
# 40   triple_count_Country__ohe_DevType_Student__ohe...  2.574308e+07
# 41   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  2.376514e+07
# 42                                    te_Currency__Age  2.349224e+07
# 43                       te_CurrencySymbol__Dependents  2.311754e+07
# 44                  te_CurrencySymbol__OperatingSystem  2.289689e+07
# 45   triple_count_YearsCodingProf__SalaryType__Mili...  2.100137e+07
# 46                          te_Country__CurrencySymbol  2.064513e+07
# 47                           te_Employment__SalaryType  1.966908e+07
# 48                     te_YearsCoding__OperatingSystem  1.939562e+07
# 49                 te_FormalEducation__YearsCodingProf  1.911121e+07
# 50   triple_count_Employment__ohe_DevType_Student__...  1.910178e+07
# 51                        te_YearsCodingProf__Currency  1.850090e+07
# 52                                  te_Employment__Age  1.807933e+07
# 53                     te_CompanySize__OperatingSystem  1.765625e+07
# 54                                  te_Age__MilitaryUS  1.707087e+07
# 55                            te_YearsCoding__Currency  1.644741e+07
# 56                                       te_LastNewJob  1.629029e+07
# 57                 agg_mean_YearsCodingProf_AssessJob5  1.540449e+07
# 58                          te_Employment__YearsCoding  1.518313e+07
# 59                              te_Country__Dependents  1.480184e+07
# 60              te_Country__ohe_LanguageWorkedWith_PHP  1.429148e+07
# 61                                 te_YearsCoding__Age  1.362954e+07
# 62                             te_Employment__Currency  1.361046e+07
# 63       te_Country__ohe_CommunicationTools_Confluence  1.352269e+07
# 64            te_CurrencySymbol__ohe_Methodology_Agile  1.339142e+07
# 65   agg_std_YearsCodingProf_ohe_LanguageDesireNext...  1.261582e+07
# 66                      te_CompanySize__CurrencySymbol  1.230609e+07
# 67                  te_CompanySize__CareerSatisfaction  1.221427e+07
# 68   triple_count_Employment__FormalEducation__ohe_...  1.219260e+07
# 69   triple_count_Employment__ohe_DevType_Student__...  1.164885e+07
# 70                  te_FormalEducation__CurrencySymbol  1.131457e+07
# 71                  te_Employment__ohe_DevType_Student  1.128823e+07
# 72               te_CompanySize__ohe_Methodology_Agile  1.081580e+07
# 73   triple_count_ohe_DevType_Student__ohe_Language...  1.055817e+07
# 74                                  te_YearsCodingProf  1.028271e+07
# 75           te_YearsCodingProf__ohe_Methodology_Agile  1.015905e+07
# 76   te_YearsCoding__ohe_RaceEthnicity_White_or_of_...  1.007726e+07
# 77   triple_count_Country__ohe_LanguageWorkedWith_P...  9.945882e+06
# 78              te_CareerSatisfaction__OperatingSystem  9.792300e+06
# 79   te_YearsCoding__ohe_CommunicationTools_Confluence  9.692086e+06
# 80   triple_count_YearsCodingProf__MilitaryUS__ohe_...  9.534173e+06
# 81   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  9.513763e+06
# 82                                 te_CompanySize__Age  9.246494e+06
# 83                          te_Employment__CompanySize  9.081130e+06
# 84   te_YearsCoding__ohe_EducationTypes_Contributed...  9.055437e+06
# 85                            svd_CommunicationTools_0  8.981930e+06
# 86                te_Employment__ohe_Methodology_Agile  8.866570e+06
# 87   triple_count_YearsCodingProf__MilitaryUS__ohe_...  8.801293e+06
# 88   triple_count_Country__SalaryType__ohe_DevType_...  8.722728e+06
# 89   triple_count_Employment__CareerSatisfaction__o...  8.710245e+06
# 90                                   te_CurrencySymbol  8.275808e+06
# 91   triple_count_YearsCodingProf__ohe_DevType_Engi...  7.940609e+06
# 92   te_CompanySize__ohe_CommunicationTools_Confluence  7.874183e+06
# 93   rank_diff_AssessBenefits_AssessBenefits2_Asses...  7.809254e+06
# 94               te_CareerSatisfaction__CurrencySymbol  7.206639e+06
# 95   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  7.126226e+06
# 96                         te_Age__ohe_DevType_Student  7.070482e+06
# 97                            te_CompanySize__Currency  6.939527e+06
# 98                  te_SalaryType__ohe_DevType_Student  6.875970e+06
# 99     agg_mean_Country_ohe_LanguageDesireNextYear_PHP  6.821064e+06
# 100  triple_count_Country__Employment__ohe_DevType_...  6.722628e+06
# 101                         te_CareerSatisfaction__Age  6.710246e+06
# 102                     te_Employment__OperatingSystem  6.621825e+06
# 103    te_CompanySize__ohe_DevType_Engineering_manager  6.534056e+06
# 104                         te_YearsCoding__MilitaryUS  6.525453e+06
# 105                  te_Employment__CareerSatisfaction  6.482385e+06
# 106                                 CareerSatisfaction  6.343983e+06
# 107                te_CompanySize__ohe_DevType_Student  6.319419e+06
# 108  triple_count_Employment__Currency__ohe_DevType...  6.259056e+06
# 109  triple_count_CompanySize__YearsCodingProf__ohe...  5.801748e+06
# 110                        te_CompanySize__YearsCoding  5.751494e+06
# 111                     te_Employment__FormalEducation  5.704079e+06
# 112  triple_count_Employment__ohe_DevType_Student__...  5.695747e+06
# 113  te_Age__ohe_RaceEthnicity_White_or_of_European...  5.666991e+06
# 114                         te_YearsCoding__SalaryType  5.629008e+06
# 115  te_CareerSatisfaction__ohe_DevType_Engineering...  5.612623e+06
# 116  triple_count_YearsCodingProf__OperatingSystem_...  5.425612e+06
# 117              rel_agg_mean_Currency_AssessBenefits2  5.415635e+06
# 118  triple_count_YearsCodingProf__ohe_Communicatio...  5.400173e+06
# 119                  te_CareerSatisfaction__SalaryType  5.346810e+06
# 120                               svd_VersionControl_1  5.140659e+06
# 121                         te_CompanySize__Dependents  5.103206e+06
# 122         te_YearsCoding__ohe_LanguageWorkedWith_PHP  5.084299e+06
# 123  triple_count_Employment__ohe_DevType_Student__...  4.984528e+06
# 124              agg_std_Country_ohe_Methodology_Agile  4.976418e+06
# 125                 te_Age__ohe_LanguageWorkedWith_PHP  4.869319e+06
# 126                         te_CompanySize__SalaryType  4.740326e+06
# 127                               ohe_DevType_Designer  4.640314e+06
# 128                       svd_DatabaseDesireNextYear_1  4.630954e+06
# 129                    te_FormalEducation__CompanySize  4.623584e+06
# 130  triple_count_YearsCodingProf__SalaryType__ohe_...  4.580159e+06
# 131                 agg_std_YearsCodingProf_AssessJob5  4.579609e+06
# 132                te_FormalEducation__OperatingSystem  4.497355e+06
# 133          te_SalaryType__ohe_LanguageWorkedWith_PHP  4.475114e+06
# 134                           svd_LanguageWorkedWith_1  4.468002e+06
# 135                     te_FormalEducation__SalaryType  4.461093e+06
# 136  te_YearsCodingProf__ohe_EducationTypes_Contrib...  4.453943e+06
# 137  agg_mean_YearsCodingProf_ohe_CommunicationTool...  4.406516e+06
# 138     te_Employment__ohe_DevType_Engineering_manager  4.287459e+06
# 139          te_FormalEducation__ohe_Methodology_Agile  4.284005e+06
# 140  rank_diff_JobContactPriorities_JobContactPrior...  4.255292e+06
# 141             te_FormalEducation__CareerSatisfaction  4.199017e+06
# 142  agg_std_YearsCodingProf_ohe_CommunicationTools...  4.169295e+06
# 143                          te_Employment__MilitaryUS  4.160682e+06
# 144                     te_SalaryType__OperatingSystem  4.128874e+06
# 145     agg_mean_YearsCodingProf_ohe_Methodology_Agile  4.090954e+06
# 146  te_CurrencySymbol__ohe_EducationTypes_Contribu...  4.085186e+06
# 147  triple_count_OperatingSystem__MilitaryUS__ohe_...  4.082494e+06
# 148  triple_count_CareerSatisfaction__ohe_DevType_S...  4.059459e+06
# 149                            te_OperatingSystem__Age  3.999792e+06
# 150  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  3.969682e+06
# 151  te_FormalEducation__ohe_EducationTypes_Contrib...  3.961151e+06
# 152  te_CompanySize__ohe_EducationTypes_Contributed...  3.958706e+06
# 153       diff_agg_mean_CurrencySymbol_AssessBenefits2  3.921349e+06
# 154                te_YearsCoding__ohe_DevType_Student  3.920344e+06
# 155                                    YearsCodingProf  3.904660e+06
# 156                          ohe_LanguageWorkedWith_Go  3.870216e+06
# 157  triple_count_CareerSatisfaction__ohe_LanguageW...  3.777751e+06
# 158      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  3.768191e+06
# 159                 te_YearsCoding__CareerSatisfaction  3.748627e+06
# 160  triple_count_ohe_DevType_Student__ohe_Educatio...  3.725998e+06
# 161       diff_agg_mean_NumberMonitors_AssessBenefits2  3.725319e+06
# 162     te_FormalEducation__ohe_LanguageWorkedWith_PHP  3.701109e+06
# 163  triple_count_Employment__CompanySize__ohe_DevT...  3.671756e+06
# 164                                        te_UpdateCV  3.665793e+06
# 165  triple_count_Employment__OperatingSystem__ohe_...  3.656054e+06
# 166        rel_agg_mean_NumberMonitors_AssessBenefits2  3.655918e+06
# 167          te_Employment__ohe_LanguageWorkedWith_PHP  3.632582e+06
# 168             agg_mean_HopeFiveYears_AssessBenefits2  3.599220e+06
# 169           rel_agg_mean_YearsCoding_AssessBenefits2  3.564560e+06
# 170                       ohe_DatabaseWorkedWith_Redis  3.560450e+06
# 171                            te_FormalEducation__Age  3.478325e+06
# 172      agg_std_SalaryType_ohe_LanguageWorkedWith_PHP  3.472148e+06
# 173  triple_count_OperatingSystem__MilitaryUS__ohe_...  3.460124e+06
# 174                              te_HypotheticalTools2  3.448620e+06
# 175                    te_YearsCoding__YearsCodingProf  3.377349e+06
# 176  triple_count_CareerSatisfaction__ohe_DevType_S...  3.319263e+06
# 177                  diff_agg_mean_Age_AssessBenefits2  3.307960e+06
# 178  te_Employment__ohe_EducationTypes_Contributed_...  3.289355e+06
# 179             diff_agg_mean_Currency_AssessBenefits2  3.257229e+06
# 180                 te_Currency__ohe_Methodology_Agile  3.208486e+06
# 181               rel_agg_mean_Country_AssessBenefits2  3.182982e+06
# 182       triple_count_Country__Employment__SalaryType  3.159214e+06
# 183                      te_CurrencySymbol__MilitaryUS  3.126385e+06
# 184                       te_FormalEducation__Currency  3.106382e+06
# 185                      te_Age__ohe_Methodology_Agile  3.065900e+06
# 186  triple_count_Employment__OperatingSystem__Mili...  3.026203e+06
# 187  te_ohe_DevType_Engineering_manager__ohe_DevTyp...  3.023243e+06
# 188  triple_count_Employment__ohe_DevType_Engineeri...  3.016772e+06
# 189           rel_agg_mean_CompanySize_AssessBenefits2  3.002391e+06
# 190                           svd_DatabaseWorkedWith_1  2.949637e+06
# 191  te_OperatingSystem__ohe_DevType_Engineering_ma...  2.940816e+06
# 192         rank_diff_AssessJob_AssessJob4_AssessJob10  2.933086e+06
# 193  te_YearsCodingProf__ohe_DevType_Engineering_ma...  2.929949e+06
# 194                    te_CareerSatisfaction__Currency  2.928203e+06
# 195  te_CareerSatisfaction__ohe_EducationTypes_Cont...  2.905008e+06
# 196  triple_count_Country__Currency__ohe_DevType_St...  2.878847e+06
# 197  rank_diff_JobEmailPriorities_JobEmailPrioritie...  2.875040e+06
# 198                                  svd_Methodology_0  2.830610e+06
# 199         rank_diff_AssessJob_AssessJob1_AssessJob10  2.788561e+06
# 200                         ohe_LanguageWorkedWith_CSS  2.767165e+06
# 201                                   ohe_IDE_NetBeans  2.732962e+06
# 202               te_SalaryType__ohe_Methodology_Agile  2.721857e+06
# 203  triple_count_ohe_DevType_Student__ohe_Language...  2.720153e+06
# 204              diff_agg_mean_Country_AssessBenefits2  2.694126e+06
# 205  triple_count_Country__Employment__ohe_Educatio...  2.680692e+06
# 206  triple_count_YearsCoding__ohe_DevType_Engineer...  2.675317e+06
# 207  triple_count_ohe_DevType_Engineering_manager__...  2.633526e+06
# 208          diff_agg_mean_Country_ohe_DevType_Student  2.627556e+06
# 209                  te_CareerSatisfaction__Dependents  2.558422e+06
# 210                     te_YearsCodingProf__Dependents  2.534962e+06
# 211  triple_count_CompanySize__Dependents__ohe_Comm...  2.525209e+06
# 212            te_FormalEducation__ohe_DevType_Student  2.525015e+06
# 213  triple_count_YearsCodingProf__SalaryType__ohe_...  2.515501e+06
# 214  triple_count_YearsCodingProf__OperatingSystem_...  2.493770e+06
# 215                                    AssessBenefits2  2.482699e+06
# 216  triple_count_Employment__YearsCodingProf__ohe_...  2.474106e+06
# 217                                        te_WakeTime  2.454288e+06
# 218   rel_agg_mean_TimeFullyProductive_AssessBenefits2  2.450568e+06
# 219  triple_count_Country__Currency__ohe_Methodolog...  2.445756e+06
# 220  triple_count_YearsCodingProf__Currency__ohe_Co...  2.437847e+06
# 221        rel_agg_mean_CurrencySymbol_AssessBenefits2  2.436964e+06
# 222                 ohe_ErgonomicDevices_Standing_desk  2.417352e+06
# 223      diff_agg_mean_FormalEducation_AssessBenefits2  2.406232e+06
# 224  te_OperatingSystem__ohe_CommunicationTools_Con...  2.400966e+06
# 225   te_SalaryType__ohe_CommunicationTools_Confluence  2.375841e+06
# 226      diff_agg_mean_JobSatisfaction_AssessBenefits2  2.353160e+06
# 227   te_Employment__ohe_CommunicationTools_Confluence  2.345425e+06
# 228                          te_Employment__Dependents  2.314356e+06
# 229  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.305692e+06
# 230  triple_count_ohe_DevType_Student__ohe_Communic...  2.301072e+06
# 231        ohe_DevType_Educator_or_academic_researcher  2.296658e+06
# 232  triple_count_YearsCoding__OperatingSystem__ohe...  2.271000e+06
# 233  te_CareerSatisfaction__ohe_CommunicationTools_...  2.269392e+06
# 234  te_FormalEducation__ohe_DevType_Engineering_ma...  2.263516e+06
# 235       rel_agg_mean_JobSatisfaction_AssessBenefits2  2.258497e+06
# 236                          te_SalaryType__Dependents  2.254015e+06
# 237        rel_agg_mean_UndergradMajor_AssessBenefits2  2.248515e+06
# 238  triple_count_Employment__MilitaryUS__ohe_DevTy...  2.241423e+06
# 239  triple_count_Employment__ohe_EducationTypes_Co...  2.217387e+06
# 240         triple_count_Country__Currency__SalaryType  2.212484e+06
# 241  rank_diff_JobEmailPriorities_JobEmailPrioritie...  2.211371e+06
# 242  triple_count_Employment__Currency__ohe_Methodo...  2.203885e+06
# 243                       ohe_PlatformWorkedWith_Azure  2.197368e+06
# 244  triple_count_Employment__CareerSatisfaction__o...  2.192845e+06
# 245          agg_mean_Employment_ohe_Methodology_Agile  2.166232e+06
# 246                     ohe_FrameworkWorkedWith_Hadoop  2.165878e+06
# 247                      sum_answer_DatabaseWorkedWith  2.162711e+06
# 248  triple_count_YearsCodingProf__OperatingSystem_...  2.146895e+06
# 249  agg_std_YearsCodingProf_ohe_CommunicationTools...  2.140398e+06
# 250                                      svd_DevType_0  2.139249e+06
# 251                           svd_DatabaseWorkedWith_0  2.128311e+06
# 252                    ohe_DevType_Front_end_developer  2.106944e+06
# 253  rank_diff_JobContactPriorities_JobContactPrior...  2.087259e+06
# 254              diff_agg_mean_Student_AssessBenefits2  2.084564e+06
# 255  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.080638e+06
# 256  triple_count_SalaryType__OperatingSystem__Mili...  2.075388e+06
# 257  triple_count_Employment__SalaryType__ohe_Commu...  2.071079e+06
# 258                       te_Currency__OperatingSystem  2.070722e+06
# 259  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.057842e+06
# 260  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.056084e+06
# 261          agg_std_YearsCoding_ohe_Methodology_Agile  2.050564e+06
# 262                       svd_LanguageDesireNextYear_1  2.049385e+06
# 263          rank_diff_AssessJob_AssessJob4_AssessJob5  2.047199e+06
# 264                 ohe_DevType_Database_administrator  2.046327e+06
# 265                                          svd_IDE_1  2.043505e+06
# 266            rel_agg_mean_SalaryType_AssessBenefits2  2.011164e+06
# 267  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.010087e+06
# 268     ohe_EducationTypes_Participated_in_a_hackathon  2.006687e+06
# 269  triple_count_Employment__CareerSatisfaction__o...  1.983480e+06
# 270         te_CompanySize__ohe_LanguageWorkedWith_PHP  1.975950e+06
# 271       rel_agg_mean_FormalEducation_AssessBenefits2  1.949247e+06
# 272  te_CurrencySymbol__ohe_CommunicationTools_Conf...  1.929897e+06
# 273                                te_EducationParents  1.927849e+06
# 274                             svd_HackathonReasons_1  1.891594e+06
# 275               ohe_DatabaseWorkedWith_Elasticsearch  1.870133e+06
# 276  triple_count_ohe_DevType_Student__ohe_Communic...  1.862263e+06
# 277  rank_diff_AssessBenefits_AssessBenefits7_Asses...  1.856792e+06
# 278  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  1.842266e+06
# 279                       svd_LanguageDesireNextYear_0  1.837365e+06
# 280  diff_agg_mean_Employment_ohe_LanguageDesireNex...  1.834486e+06
# 281  triple_count_Employment__ohe_LanguageWorkedWit...  1.833501e+06
# 282  triple_count_Employment__MilitaryUS__ohe_Educa...  1.831260e+06
# 283  rank_diff_JobContactPriorities_JobContactPrior...  1.825990e+06
# 284  te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  1.822143e+06
# 285     agg_mean_Employment_ohe_LanguageWorkedWith_PHP  1.820074e+06
# 286  rank_diff_AssessBenefits_AssessBenefits1_Asses...  1.811038e+06
# 287                    te_FormalEducation__YearsCoding  1.802798e+06
# 288            rel_agg_mean_MilitaryUS_AssessBenefits2  1.790354e+06
# 289  rank_diff_AssessBenefits_AssessBenefits7_Asses...  1.789900e+06
# 290  diff_agg_mean_TimeFullyProductive_AssessBenefits2  1.784242e+06
# 291  triple_count_YearsCodingProf__ohe_Communicatio...  1.779689e+06
# 292  triple_count_Employment__FormalEducation__ohe_...  1.770215e+06
# 293                                        te_Exercise  1.768163e+06
# 294                         te_CompanySize__MilitaryUS  1.758107e+06
# 295         te_CareerSatisfaction__ohe_DevType_Student  1.757513e+06
# 296         rank_diff_AssessJob_AssessJob6_AssessJob10  1.742810e+06
# 297  triple_count_Country__Employment__FormalEducation  1.729648e+06
# 298       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.728088e+06
# 299  triple_count_CompanySize__OperatingSystem__ohe...  1.721336e+06

# %%
len(use_cols)
# Out:
# 3825

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 64209.31766166,  90473.61124646,  87570.89038877, ...,
#         86882.43641184,  81810.38495326, 118836.64024948])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
# sub_df.to_csv("../predict/029_count_encoding_20137.csv", index=False)
