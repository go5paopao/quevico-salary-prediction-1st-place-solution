# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
non_basic_nume_cols = []
non_basic_cat_cols = []

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### rank feature

# %%
def add_rank_feature(df):
    rank_prefix_list = [
        "AssessBenefits",
        "AssessJob",
        "JobContactPriorities",
        "JobEmailPriorities",
        "AdsPriorities",
    ]
    for prefix in tqdm(rank_prefix_list):
        rank_cols = [c for c in df.columns if prefix in c]
        col_pairs = itertools.combinations(rank_cols, 2)
        for col_a, col_b in col_pairs:
            df[f"rank_diff_{prefix}_{col_a}_{col_b}"] = (df[col_a] - df[col_b]) / np.log2(df[[col_a, col_b]].max(axis=1))
    return df

# %%
train_df = add_rank_feature(train_df)
test_df = add_rank_feature(test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # ohe_featureはcategoryとnumerical両方として扱う
    nume_cols += feat_cols
    cat_cols += feat_cols
    # non_basic_nume_cols.append(f"sum_answer_{c}")
    # SVD
    svd = TruncatedSVD(n_components=2, random_state=2020)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 659), (11259, 658))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_basic_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
def make_agg_feature(train_df, test_df):
    imp_feats = get_basic_importance_cols(use_num=50)
    imp_cat_cols = [c for c in cat_cols if c in imp_feats] + non_basic_cat_cols
    imp_nume_cols = [c for c in nume_cols if c in imp_feats] + non_basic_nume_cols
    print(f"use cat col: {len(imp_cat_cols)}  nume col: {len(imp_nume_cols)}")
    #imp_nume_cols += [c for c in train_df.columns if c[:8] == "sum_answ"]
    all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
    for cat_col in tqdm(imp_cat_cols):
        for nume_col in imp_nume_cols:
            # one-hotは同じカテゴリの場合がある
            if cat_col == nume_col:
                continue
            all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
            all_df[f"agg_std_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
            all_df[f"agg_max_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
            all_df[f"agg_min_{cat_col}_{nume_col}"] = \
                all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
            all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
            all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
                all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
    train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
    test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
    del all_df
    gc.collect()
    return train_df, test_df

# %%
train_df, test_df = make_agg_feature(train_df, test_df)
# Out:
# use cat col: 27  nume col: 10
# HBox(children=(FloatProgress(value=0.0, max=27.0), HTML(value='')))

# %% [markdown]
# ### Make fold index(for target encoding)

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=True)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_basic_importance_cols(use_num=100)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1275.0), HTML(value='')))

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3560

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'poisson',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
def feature_selection(train_df, use_cols, n_features=1000):
    df = train_df.sample(30000, random_state=2020)
    train_dataset = lgb.Dataset(
        df.loc[:, use_cols],
        label = df.loc[:, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                2000,
                valid_sets = [train_dataset],
                verbose_eval=200,
                early_stopping_rounds = None,
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    select_features = imp_df.sort_values(["gain"], ascending=False).iloc[: n_features]["feature"].tolist()
    return select_features

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

use_cols = feature_selection(train_df, use_cols, n_features=1000)

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                10000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 300,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# [200]	training's rmse: 20782.9
# [400]	training's rmse: 19618
# [600]	training's rmse: 19026.8
# [800]	training's rmse: 18526.3
# [1000]	training's rmse: 18126.5
# [1200]	training's rmse: 17743.4
# [1400]	training's rmse: 17352.9
# [1600]	training's rmse: 17006.5
# [1800]	training's rmse: 16680.1
# [2000]	training's rmse: 16347.7
# Fold 1
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22564.6	valid_1's rmse: 22966.4
# [200]	training's rmse: 20689.3	valid_1's rmse: 21591.9
# [300]	training's rmse: 19976.4	valid_1's rmse: 21198.8
# [400]	training's rmse: 19551	valid_1's rmse: 21001.7
# [500]	training's rmse: 19221.8	valid_1's rmse: 20866.2
# [600]	training's rmse: 18959.5	valid_1's rmse: 20786.7
# [700]	training's rmse: 18746.5	valid_1's rmse: 20727.6
# [800]	training's rmse: 18527.6	valid_1's rmse: 20672.3
# [900]	training's rmse: 18320.8	valid_1's rmse: 20621.2
# [1000]	training's rmse: 18124.6	valid_1's rmse: 20577
# [1100]	training's rmse: 17928.3	valid_1's rmse: 20537.3
# [1200]	training's rmse: 17746	valid_1's rmse: 20498.3
# [1300]	training's rmse: 17580.1	valid_1's rmse: 20470.8
# [1400]	training's rmse: 17406.9	valid_1's rmse: 20440.5
# [1500]	training's rmse: 17238	valid_1's rmse: 20421.3
# [1600]	training's rmse: 17075.8	valid_1's rmse: 20392.2
# [1700]	training's rmse: 16901.8	valid_1's rmse: 20369.3
# [1800]	training's rmse: 16743.1	valid_1's rmse: 20353.6
# [1900]	training's rmse: 16580.5	valid_1's rmse: 20339.4
# [2000]	training's rmse: 16430.2	valid_1's rmse: 20329.9
# [2100]	training's rmse: 16279.9	valid_1's rmse: 20308.1
# [2200]	training's rmse: 16130.4	valid_1's rmse: 20295.3
# [2300]	training's rmse: 15984.5	valid_1's rmse: 20284.2
# [2400]	training's rmse: 15842.2	valid_1's rmse: 20275.3
# [2500]	training's rmse: 15713.5	valid_1's rmse: 20270.9
# [2600]	training's rmse: 15576.2	valid_1's rmse: 20265.1
# [2700]	training's rmse: 15440.4	valid_1's rmse: 20257
# [2800]	training's rmse: 15311.4	valid_1's rmse: 20246.7
# [2900]	training's rmse: 15182	valid_1's rmse: 20237.3
# [3000]	training's rmse: 15049.4	valid_1's rmse: 20225.7
# [3100]	training's rmse: 14922.8	valid_1's rmse: 20217.6
# [3200]	training's rmse: 14794.5	valid_1's rmse: 20214.3
# [3300]	training's rmse: 14658.7	valid_1's rmse: 20208.3
# [3400]	training's rmse: 14536	valid_1's rmse: 20207.4
# [3500]	training's rmse: 14426	valid_1's rmse: 20207.6
# [3600]	training's rmse: 14313.8	valid_1's rmse: 20198.5
# [3700]	training's rmse: 14190.8	valid_1's rmse: 20198.6
# [3800]	training's rmse: 14071.9	valid_1's rmse: 20199.3
# [3900]	training's rmse: 13946.2	valid_1's rmse: 20197.8
# Early stopping, best iteration is:
# [3615]	training's rmse: 14293.3	valid_1's rmse: 20195
# Fold 2
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22544.3	valid_1's rmse: 23121.3
# [200]	training's rmse: 20693.9	valid_1's rmse: 21601.8
# [300]	training's rmse: 19990.2	valid_1's rmse: 21137.4
# [400]	training's rmse: 19545.8	valid_1's rmse: 20902.5
# [500]	training's rmse: 19243.9	valid_1's rmse: 20771
# [600]	training's rmse: 18964.6	valid_1's rmse: 20667.8
# [700]	training's rmse: 18726.6	valid_1's rmse: 20593
# [800]	training's rmse: 18529.3	valid_1's rmse: 20543.1
# [900]	training's rmse: 18326.8	valid_1's rmse: 20485.8
# [1000]	training's rmse: 18136.1	valid_1's rmse: 20444.7
# [1100]	training's rmse: 17935.1	valid_1's rmse: 20405.1
# [1200]	training's rmse: 17735.1	valid_1's rmse: 20360.3
# [1300]	training's rmse: 17567.3	valid_1's rmse: 20335.7
# [1400]	training's rmse: 17391.4	valid_1's rmse: 20300.2
# [1500]	training's rmse: 17231.8	valid_1's rmse: 20270
# [1600]	training's rmse: 17062	valid_1's rmse: 20245
# [1700]	training's rmse: 16897.6	valid_1's rmse: 20227.4
# [1800]	training's rmse: 16762.1	valid_1's rmse: 20213.1
# [1900]	training's rmse: 16608.5	valid_1's rmse: 20196.7
# [2000]	training's rmse: 16471	valid_1's rmse: 20180.7
# [2100]	training's rmse: 16314.9	valid_1's rmse: 20169
# [2200]	training's rmse: 16162.2	valid_1's rmse: 20158.3
# [2300]	training's rmse: 16020.2	valid_1's rmse: 20149.1
# [2400]	training's rmse: 15881.9	valid_1's rmse: 20132.1
# [2500]	training's rmse: 15751.7	valid_1's rmse: 20120.1
# [2600]	training's rmse: 15606.8	valid_1's rmse: 20102.8
# [2700]	training's rmse: 15485.4	valid_1's rmse: 20094.2
# [2800]	training's rmse: 15355.6	valid_1's rmse: 20090.2
# [2900]	training's rmse: 15218.9	valid_1's rmse: 20082.7
# [3000]	training's rmse: 15080.3	valid_1's rmse: 20077.4
# [3100]	training's rmse: 14949.7	valid_1's rmse: 20069.2
# [3200]	training's rmse: 14822.7	valid_1's rmse: 20060.2
# [3300]	training's rmse: 14694.8	valid_1's rmse: 20048.5
# [3400]	training's rmse: 14577	valid_1's rmse: 20044.8
# [3500]	training's rmse: 14449.3	valid_1's rmse: 20038.4
# [3600]	training's rmse: 14327	valid_1's rmse: 20035
# [3700]	training's rmse: 14193.5	valid_1's rmse: 20034.7
# [3800]	training's rmse: 14079.2	valid_1's rmse: 20043.1
# [3900]	training's rmse: 13958.3	valid_1's rmse: 20034.9
# [4000]	training's rmse: 13835	valid_1's rmse: 20034.3
# Early stopping, best iteration is:
# [3708]	training's rmse: 14184.6	valid_1's rmse: 20032
# Fold 3
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22570.7	valid_1's rmse: 23008.7
# [200]	training's rmse: 20666.6	valid_1's rmse: 21475.5
# [300]	training's rmse: 19935.1	valid_1's rmse: 21084.8
# [400]	training's rmse: 19481.2	valid_1's rmse: 20899.7
# [500]	training's rmse: 19128.3	valid_1's rmse: 20792.3
# [600]	training's rmse: 18853.1	valid_1's rmse: 20705
# [700]	training's rmse: 18623.7	valid_1's rmse: 20657
# [800]	training's rmse: 18408.1	valid_1's rmse: 20621.9
# [900]	training's rmse: 18201.6	valid_1's rmse: 20599
# [1000]	training's rmse: 18025.7	valid_1's rmse: 20563
# [1100]	training's rmse: 17845.3	valid_1's rmse: 20543
# [1200]	training's rmse: 17650.3	valid_1's rmse: 20519.1
# [1300]	training's rmse: 17470.1	valid_1's rmse: 20500.9
# [1400]	training's rmse: 17297.9	valid_1's rmse: 20487.4
# [1500]	training's rmse: 17146.2	valid_1's rmse: 20478.6
# [1600]	training's rmse: 16977.9	valid_1's rmse: 20459.7
# [1700]	training's rmse: 16816.4	valid_1's rmse: 20445.6
# [1800]	training's rmse: 16664.3	valid_1's rmse: 20430.3
# [1900]	training's rmse: 16508.8	valid_1's rmse: 20423.3
# [2000]	training's rmse: 16356.7	valid_1's rmse: 20417.8
# [2100]	training's rmse: 16204.7	valid_1's rmse: 20411.3
# [2200]	training's rmse: 16067.4	valid_1's rmse: 20412.3
# [2300]	training's rmse: 15936.2	valid_1's rmse: 20404.6
# [2400]	training's rmse: 15794.2	valid_1's rmse: 20398.5
# [2500]	training's rmse: 15647.7	valid_1's rmse: 20394.5
# [2600]	training's rmse: 15510.8	valid_1's rmse: 20389.5
# [2700]	training's rmse: 15375.6	valid_1's rmse: 20381.1
# [2800]	training's rmse: 15228.2	valid_1's rmse: 20368.3
# [2900]	training's rmse: 15099	valid_1's rmse: 20365.8
# [3000]	training's rmse: 14967.1	valid_1's rmse: 20357.7
# [3100]	training's rmse: 14848.1	valid_1's rmse: 20357.9
# [3200]	training's rmse: 14725.9	valid_1's rmse: 20356.5
# [3300]	training's rmse: 14588.4	valid_1's rmse: 20351.9
# [3400]	training's rmse: 14455	valid_1's rmse: 20348
# [3500]	training's rmse: 14326.3	valid_1's rmse: 20349.4
# [3600]	training's rmse: 14209.9	valid_1's rmse: 20348
# [3700]	training's rmse: 14099.5	valid_1's rmse: 20349.5
# [3800]	training's rmse: 13977.4	valid_1's rmse: 20350.8
# [3900]	training's rmse: 13864.4	valid_1's rmse: 20362.7
# Early stopping, best iteration is:
# [3616]	training's rmse: 14191.5	valid_1's rmse: 20344.9
# Fold 4
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22537.5	valid_1's rmse: 23022.5
# [200]	training's rmse: 20693.2	valid_1's rmse: 21583.7
# [300]	training's rmse: 19967.7	valid_1's rmse: 21171.2
# [400]	training's rmse: 19524.7	valid_1's rmse: 20962.6
# [500]	training's rmse: 19204.8	valid_1's rmse: 20841.8
# [600]	training's rmse: 18946.7	valid_1's rmse: 20747.9
# [700]	training's rmse: 18718.4	valid_1's rmse: 20678.2
# [800]	training's rmse: 18505.3	valid_1's rmse: 20628
# [900]	training's rmse: 18291.4	valid_1's rmse: 20581.7
# [1000]	training's rmse: 18095.3	valid_1's rmse: 20539.2
# [1100]	training's rmse: 17922.4	valid_1's rmse: 20502.9
# [1200]	training's rmse: 17726.3	valid_1's rmse: 20466.9
# [1300]	training's rmse: 17561.4	valid_1's rmse: 20444
# [1400]	training's rmse: 17397.4	valid_1's rmse: 20417.8
# [1500]	training's rmse: 17225.6	valid_1's rmse: 20386.4
# [1600]	training's rmse: 17054.2	valid_1's rmse: 20360.6
# [1700]	training's rmse: 16888.3	valid_1's rmse: 20346.7
# [1800]	training's rmse: 16734.5	valid_1's rmse: 20323.8
# [1900]	training's rmse: 16588.9	valid_1's rmse: 20299.2
# [2000]	training's rmse: 16435.7	valid_1's rmse: 20283.5
# [2100]	training's rmse: 16279.4	valid_1's rmse: 20264.5
# [2200]	training's rmse: 16136.1	valid_1's rmse: 20258
# [2300]	training's rmse: 15984.2	valid_1's rmse: 20241.9
# [2400]	training's rmse: 15843.4	valid_1's rmse: 20231.3
# [2500]	training's rmse: 15695.7	valid_1's rmse: 20224.7
# [2600]	training's rmse: 15561.7	valid_1's rmse: 20224.7
# [2700]	training's rmse: 15407.3	valid_1's rmse: 20208.2
# [2800]	training's rmse: 15279.5	valid_1's rmse: 20205.6
# [2900]	training's rmse: 15139.3	valid_1's rmse: 20196.9
# [3000]	training's rmse: 15011.7	valid_1's rmse: 20191.3
# [3100]	training's rmse: 14878.5	valid_1's rmse: 20187.4
# [3200]	training's rmse: 14761.4	valid_1's rmse: 20187.7
# [3300]	training's rmse: 14637.3	valid_1's rmse: 20182.1
# [3400]	training's rmse: 14503	valid_1's rmse: 20178
# [3500]	training's rmse: 14385.7	valid_1's rmse: 20175.9
# [3600]	training's rmse: 14283.2	valid_1's rmse: 20176
# [3700]	training's rmse: 14166.6	valid_1's rmse: 20168.7
# [3800]	training's rmse: 14036.1	valid_1's rmse: 20164
# [3900]	training's rmse: 13917.5	valid_1's rmse: 20166.4
# [4000]	training's rmse: 13795.1	valid_1's rmse: 20163.5
# [4100]	training's rmse: 13670.7	valid_1's rmse: 20165.3
# [4200]	training's rmse: 13563.5	valid_1's rmse: 20161.9
# Early stopping, best iteration is:
# [3978]	training's rmse: 13822.6	valid_1's rmse: 20159.7
# Fold 5
# Training until validation scores don't improve for 300 rounds
# [100]	training's rmse: 22620.3	valid_1's rmse: 22941.8
# [200]	training's rmse: 20784	valid_1's rmse: 21332.3
# [300]	training's rmse: 20067.4	valid_1's rmse: 20852
# [400]	training's rmse: 19615.6	valid_1's rmse: 20608.6
# [500]	training's rmse: 19283.9	valid_1's rmse: 20475.1
# [600]	training's rmse: 19016.8	valid_1's rmse: 20396.7
# [700]	training's rmse: 18785.6	valid_1's rmse: 20322
# [800]	training's rmse: 18567.8	valid_1's rmse: 20282.9
# [900]	training's rmse: 18344.1	valid_1's rmse: 20244
# [1000]	training's rmse: 18149.1	valid_1's rmse: 20203.9
# [1100]	training's rmse: 17956.8	valid_1's rmse: 20172.7
# [1200]	training's rmse: 17770.8	valid_1's rmse: 20145.3
# [1300]	training's rmse: 17608.3	valid_1's rmse: 20131.3
# [1400]	training's rmse: 17425.4	valid_1's rmse: 20104.2
# [1500]	training's rmse: 17264.3	valid_1's rmse: 20094.1
# [1600]	training's rmse: 17095.8	valid_1's rmse: 20079
# [1700]	training's rmse: 16935.4	valid_1's rmse: 20072.4
# [1800]	training's rmse: 16781.6	valid_1's rmse: 20059.7
# [1900]	training's rmse: 16616.5	valid_1's rmse: 20054.5
# [2000]	training's rmse: 16470	valid_1's rmse: 20052.1
# [2100]	training's rmse: 16330.5	valid_1's rmse: 20040.4
# [2200]	training's rmse: 16196.5	valid_1's rmse: 20036.2
# [2300]	training's rmse: 16054.7	valid_1's rmse: 20033.2
# [2400]	training's rmse: 15931.4	valid_1's rmse: 20016.2
# [2500]	training's rmse: 15795	valid_1's rmse: 20005.7
# [2600]	training's rmse: 15656.7	valid_1's rmse: 19995.9
# [2700]	training's rmse: 15524.5	valid_1's rmse: 19989
# [2800]	training's rmse: 15394.2	valid_1's rmse: 19977.7
# [2900]	training's rmse: 15262.3	valid_1's rmse: 19968
# [3000]	training's rmse: 15136.7	valid_1's rmse: 19963
# [3100]	training's rmse: 15006.8	valid_1's rmse: 19957.4
# [3200]	training's rmse: 14871.5	valid_1's rmse: 19957.9
# [3300]	training's rmse: 14738.9	valid_1's rmse: 19964
# [3400]	training's rmse: 14604.1	valid_1's rmse: 19947.8
# [3500]	training's rmse: 14483.5	valid_1's rmse: 19952.4
# [3600]	training's rmse: 14361	valid_1's rmse: 19948.7
# [3700]	training's rmse: 14240.3	valid_1's rmse: 19948.5
# [3800]	training's rmse: 14119.5	valid_1's rmse: 19951.3
# [3900]	training's rmse: 14007.7	valid_1's rmse: 19950
# Early stopping, best iteration is:
# [3660]	training's rmse: 14290.9	valid_1's rmse: 19943.6

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20135.536025470377

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  7.165385e+08
# 1                      te_Country__ohe_DevType_Student  5.661420e+08
# 2                   te_YearsCodingProf__CurrencySymbol  4.501808e+08
# 3                               te_Country__Employment  4.175006e+08
# 4                              te_Country__YearsCoding  2.072983e+08
# 5                                  te_Country__Student  1.897229e+08
# 6                               te_Country__SalaryType  1.868801e+08
# 7                          te_Country__FormalEducation  1.340320e+08
# 8                                      te_Country__Age  1.275258e+08
# 9                       te_Country__HypotheticalTools2  1.177782e+08
# 10                      te_Country__CareerSatisfaction  1.021492e+08
# 11                      te_YearsCoding__CurrencySymbol  9.728477e+07
# 12                         te_Country__JobSatisfaction  9.556473e+07
# 13                              te_CurrencySymbol__Age  9.431887e+07
# 14                                te_Country__WakeTime  8.331379e+07
# 15   te_Country__ohe_RaceEthnicity_White_or_of_Euro...  8.210225e+07
# 16                           te_Country__HopeFiveYears  7.817111e+07
# 17                     te_CompanySize__YearsCodingProf  6.868385e+07
# 18       te_Country__ohe_CommunicationTools_Confluence  6.814811e+07
# 19              te_CurrencySymbol__ohe_DevType_Student  6.425148e+07
# 20                        te_YearsCodingProf__Currency  6.378607e+07
# 21                          te_Country__UndergradMajor  6.133149e+07
# 22   te_Country__ohe_EducationTypes_Contributed_to_...  5.905766e+07
# 23                       te_SalaryType__CurrencySymbol  5.053835e+07
# 24                   te_Country__ohe_Methodology_Agile  3.890909e+07
# 25              te_Country__ohe_LanguageWorkedWith_CSS  3.735744e+07
# 26                             te_Employment__Currency  3.596344e+07
# 27                              te_Country__Dependents  3.589624e+07
# 28                      te_YearsCodingProf__SalaryType  3.421149e+07
# 29                      te_Employment__YearsCodingProf  3.330164e+07
# 30                                te_Country__Currency  3.141181e+07
# 31              te_YearsCodingProf__CareerSatisfaction  2.718075e+07
# 32                           te_Employment__SalaryType  2.667826e+07
# 33   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  2.644881e+07
# 34                             te_Currency__SalaryType  2.533437e+07
# 35                             te_Country__CompanySize  2.515863e+07
# 36                     te_YearsCoding__YearsCodingProf  2.492686e+07
# 37   te_YearsCodingProf__ohe_CommunicationTools_Con...  2.396355e+07
# 38      te_YearsCodingProf__StackOverflowJobsRecommend  2.325659e+07
# 39                       te_Employment__CurrencySymbol  2.313022e+07
# 40   te_YearsCodingProf__ohe_ErgonomicDevices_Stand...  2.298938e+07
# 41               te_Country__ohe_LanguageWorkedWith_Go  2.210755e+07
# 42                                  te_SalaryType__Age  2.179196e+07
# 43      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  2.103434e+07
# 44                          te_Country__CurrencySymbol  2.010312e+07
# 45                          te_YearsCoding__SalaryType  1.943095e+07
# 46                    te_Currency__ohe_DevType_Student  1.919975e+07
# 47                 te_YearsCodingProf__OperatingSystem  1.905700e+07
# 48   te_YearsCodingProf__ohe_LanguageDesireNextYear...  1.833092e+07
# 49                     te_CompanySize__OperatingSystem  1.602482e+07
# 50                             te_YearsCodingProf__Age  1.515241e+07
# 51                      te_Employment__OperatingSystem  1.487915e+07
# 52                  te_YearsCoding__CareerSatisfaction  1.434163e+07
# 53                            te_YearsCoding__Currency  1.393544e+07
# 54       te_Employment__ohe_LanguageDesireNextYear_PHP  1.339712e+07
# 55         te_CompanySize__ohe_CommunicationTools_Jira  1.337030e+07
# 56           te_YearsCodingProf__ohe_Methodology_Agile  1.273355e+07
# 57                                  te_Employment__Age  1.269767e+07
# 58                  te_CurrencySymbol__OperatingSystem  1.267818e+07
# 59                                 te_YearsCoding__Age  1.260161e+07
# 60                  te_Employment__ohe_DevType_Student  1.241337e+07
# 61                          te_CompanySize__SalaryType  1.226389e+07
# 62           te_YearsCodingProf__ohe_Methodology_Scrum  1.224721e+07
# 63   te_YearsCodingProf__ohe_EducationTypes_Partici...  1.216055e+07
# 64                         te_Country__OperatingSystem  1.214391e+07
# 65                        te_FormalEducation__Currency  1.212531e+07
# 66                 agg_mean_YearsCodingProf_AssessJob5  1.166866e+07
# 67                                    te_Currency__Age  1.159503e+07
# 68                   te_Country__ohe_Methodology_Scrum  1.138199e+07
# 69   te_CurrencySymbol__ohe_LanguageDesireNextYear_PHP  1.136718e+07
# 70      te_Employment__ohe_DevType_Engineering_manager  1.135840e+07
# 71              te_YearsCodingProf__HypotheticalTools2  1.097892e+07
# 72                     te_YearsCoding__OperatingSystem  1.074224e+07
# 73                    te_HopeFiveYears__CurrencySymbol  1.049976e+07
# 74                              te_Country__LastNewJob  1.044627e+07
# 75                          te_Employment__YearsCoding  1.025050e+07
# 76                  te_YearsCodingProf__NumberMonitors  1.009676e+07
# 77                  te_JobSatisfaction__CurrencySymbol  9.987660e+06
# 78                          te_Country__AgreeDisagree3  9.906071e+06
# 79                      te_Employment__FormalEducation  9.759408e+06
# 80                te_YearsCodingProf__EducationParents  9.745363e+06
# 81                           te_Employment__MilitaryUS  9.339533e+06
# 82        te_CurrencySymbol__ohe_LanguageWorkedWith_Go  9.023161e+06
# 83   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  8.946727e+06
# 84                  te_YearsCodingProf__AgreeDisagree3  8.936046e+06
# 85          te_Country__ohe_LanguageDesireNextYear_PHP  8.879125e+06
# 86                  te_SalaryType__ohe_DevType_Student  8.624899e+06
# 87                te_Employment__ohe_Methodology_Agile  8.338255e+06
# 88          te_CompanySize__ohe_PlatformWorkedWith_AWS  8.312335e+06
# 89                  te_UndergradMajor__YearsCodingProf  8.073432e+06
# 90                 te_YearsCodingProf__JobSatisfaction  8.024582e+06
# 91              te_Country__ohe_LanguageWorkedWith_PHP  8.013656e+06
# 92   te_YearsCodingProf__ohe_EducationTypes_Contrib...  7.901081e+06
# 93                       te_LastNewJob__CurrencySymbol  7.861051e+06
# 94                 te_FormalEducation__YearsCodingProf  7.686195e+06
# 95                   te_YearsCodingProf__HopeFiveYears  7.622757e+06
# 96                       te_Employment__UndergradMajor  7.594569e+06
# 97               te_CompanySize__ohe_Methodology_Agile  7.543924e+06
# 98                         te_Age__ohe_DevType_Student  7.503487e+06
# 99                     te_Country__TimeFullyProductive  7.396633e+06
# 100                 te_CompanySize__CareerSatisfaction  7.355288e+06
# 101               te_Employment__ohe_Methodology_Scrum  7.068438e+06
# 102    te_CompanySize__ohe_DevType_Engineering_manager  6.872012e+06
# 103                           svd_CommunicationTools_0  6.841310e+06
# 104                            te_LastNewJob__WakeTime  6.699368e+06
# 105              rel_agg_mean_Currency_AssessBenefits2  6.622462e+06
# 106  te_ohe_CommunicationTools_Confluence__ohe_Plat...  6.343248e+06
# 107    te_YearsCodingProf__ohe_CommunicationTools_Jira  6.250734e+06
# 108             te_CareerSatisfaction__OperatingSystem  6.085734e+06
# 109                     te_YearsCodingProf__LastNewJob  6.038000e+06
# 110         te_YearsCodingProf__ohe_Methodology_Kanban  6.026405e+06
# 111              te_CareerSatisfaction__CurrencySymbol  5.989432e+06
# 112          te_Employment__ohe_LanguageWorkedWith_PHP  5.974591e+06
# 113  te_OperatingSystem__ohe_CommunicationTools_Con...  5.968388e+06
# 114                  te_Employment__CareerSatisfaction  5.917753e+06
# 115  te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  5.896905e+06
# 116                te_FormalEducation__OperatingSystem  5.866347e+06
# 117  rank_diff_AssessBenefits_AssessBenefits2_Asses...  5.807610e+06
# 118  te_CareerSatisfaction__ohe_DevType_Engineering...  5.733608e+06
# 119                te_CompanySize__ohe_DevType_Student  5.704985e+06
# 120                     te_CompanySize__CurrencySymbol  5.689238e+06
# 121  te_YearsCodingProf__ohe_Methodology_Pair_progr...  5.649962e+06
# 122        rel_agg_mean_CurrencySymbol_AssessBenefits2  5.562825e+06
# 123                            te_FormalEducation__Age  5.546640e+06
# 124  te_YearsCodingProf__ohe_RaceEthnicity_South_Asian  5.509846e+06
# 125               rel_agg_mean_Country_AssessBenefits2  5.461255e+06
# 126                     te_FormalEducation__LastNewJob  5.459543e+06
# 127                      te_CurrencySymbol__Dependents  5.453164e+06
# 128  te_ohe_DevType_Student__ohe_LanguageDesireNext...  5.362083e+06
# 129               te_CareerSatisfaction__HopeFiveYears  5.296392e+06
# 130                          te_Employment__LastNewJob  5.282819e+06
# 131           te_Employment__ohe_LanguageWorkedWith_Go  5.239119e+06
# 132  te_FormalEducation__ohe_EducationTypes_Partici...  5.196680e+06
# 133             te_CompanySize__ohe_Methodology_Kanban  5.072192e+06
# 134                    te_FormalEducation__CompanySize  5.014951e+06
# 135              diff_agg_mean_Country_AssessBenefits2  4.997324e+06
# 136                        te_CompanySize__YearsCoding  4.989860e+06
# 137              te_CompanySize__ohe_Methodology_Scrum  4.979823e+06
# 138                                te_CompanySize__Age  4.947976e+06
# 139                          te_LastNewJob__SalaryType  4.931134e+06
# 140                 te_YearsCoding__HypotheticalTools2  4.857933e+06
# 141      te_YearsCodingProf__ohe_LanguageWorkedWith_Go  4.820139e+06
# 142                     te_JobSatisfaction__SalaryType  4.784934e+06
# 143  te_ohe_DevType_Engineering_manager__ohe_Langua...  4.773395e+06
# 144             te_Age__ohe_LanguageDesireNextYear_PHP  4.769054e+06
# 145                 te_SalaryType__TimeFullyProductive  4.663151e+06
# 146                        te_Student__YearsCodingProf  4.611620e+06
# 147          te_FormalEducation__ohe_Methodology_Agile  4.584853e+06
# 148                             te_Student__Employment  4.582091e+06
# 149                   rel_agg_mean_Age_AssessBenefits2  4.458149e+06
# 150                     te_SalaryType__OperatingSystem  4.434852e+06
# 151  te_CompanySize__ohe_CommunicationTools_Confluence  4.375143e+06
# 152                         te_CompanySize__Dependents  4.371213e+06
# 153    te_Employment__ohe_Methodology_Pair_programming  4.355455e+06
# 154  diff_agg_mean_Employment_ohe_LanguageDesireNex...  4.290661e+06
# 155                   te_WakeTime__ohe_DevType_Student  4.266042e+06
# 156           te_CurrencySymbol__ohe_Methodology_Agile  4.170871e+06
# 157        te_YearsCoding__ohe_CommunicationTools_Jira  4.146212e+06
# 158                  te_LastNewJob__StackOverflowVisit  4.127227e+06
# 159             diff_agg_mean_Currency_AssessBenefits2  4.113819e+06
# 160               te_SalaryType__ohe_Methodology_Agile  4.113047e+06
# 161      te_CurrencySymbol__ohe_PlatformWorkedWith_AWS  4.090152e+06
# 162                            te_Employment__WakeTime  4.083952e+06
# 163  te_Country__ohe_Methodology_Extreme_programmin...  4.083785e+06
# 164       diff_agg_mean_CurrencySymbol_AssessBenefits2  4.057515e+06
# 165                         te_CareerSatisfaction__Age  4.017525e+06
# 166                       te_Currency__OperatingSystem  4.003670e+06
# 167   te_SalaryType__ohe_CommunicationTools_Confluence  3.976233e+06
# 168                               svd_VersionControl_1  3.963631e+06
# 169     te_YearsCodingProf__ohe_LanguageWorkedWith_CSS  3.943664e+06
# 170                                 te_LastNewJob__Age  3.936139e+06
# 171            te_FormalEducation__ohe_DevType_Student  3.918587e+06
# 172                  te_Employment__StackOverflowVisit  3.906197e+06
# 173  te_FormalEducation__ohe_EducationTypes_Contrib...  3.905707e+06
# 174                     te_FormalEducation__SalaryType  3.835316e+06
# 175                  te_CareerSatisfaction__SalaryType  3.822287e+06
# 176      te_FormalEducation__ohe_LanguageWorkedWith_Go  3.795941e+06
# 177         te_CompanySize__ohe_LanguageWorkedWith_PHP  3.782432e+06
# 178                               ohe_DevType_Designer  3.782350e+06
# 179                 te_Age__ohe_LanguageWorkedWith_PHP  3.781548e+06
# 180                    te_Student__ohe_DevType_Student  3.780623e+06
# 181  rank_diff_JobContactPriorities_JobContactPrior...  3.764967e+06
# 182     te_FormalEducation__ohe_LanguageWorkedWith_PHP  3.758180e+06
# 183      diff_agg_mean_JobSatisfaction_AssessBenefits2  3.746766e+06
# 184                       svd_DatabaseDesireNextYear_1  3.742424e+06
# 185                         te_Country__NumberMonitors  3.736684e+06
# 186         rank_diff_AssessJob_AssessJob4_AssessJob10  3.725410e+06
# 187                 te_FormalEducation__CurrencySymbol  3.724334e+06
# 188                           svd_LanguageWorkedWith_1  3.715589e+06
# 189          diff_agg_mean_Country_ohe_DevType_Student  3.711994e+06
# 190                      te_LastNewJob__NumberMonitors  3.700544e+06
# 191             te_FormalEducation__CareerSatisfaction  3.693474e+06
# 192  te_Dependents__ohe_ErgonomicDevices_Standing_desk  3.685511e+06
# 193                 te_LastNewJob__TimeFullyProductive  3.675967e+06
# 194                     te_YearsCodingProf__MilitaryUS  3.663959e+06
# 195     te_CurrencySymbol__ohe_CommunicationTools_Jira  3.630656e+06
# 196   rel_agg_mean_TimeFullyProductive_AssessBenefits2  3.611013e+06
# 197                  te_SalaryType__HypotheticalTools2  3.598689e+06
# 198            te_Country__ohe_CommunicationTools_Jira  3.533482e+06
# 199  te_CareerSatisfaction__ohe_EducationTypes_Cont...  3.532996e+06
# 200           te_CurrencySymbol__ohe_Methodology_Scrum  3.527395e+06
# 201            te_YearsCodingProf__ohe_DevType_Student  3.517993e+06
# 202                    te_CompanySize__JobSatisfaction  3.481056e+06
# 203   te_Employment__ohe_CommunicationTools_Confluence  3.478594e+06
# 204                             te_Student__SalaryType  3.477860e+06
# 205  te_YearsCoding__ohe_CommunicationTools_Confluence  3.445917e+06
# 206                   te_YearsCodingProf__HoursOutside  3.436474e+06
# 207  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.412336e+06
# 208  te_Employment__ohe_EducationTypes_Contributed_...  3.394478e+06
# 209                        te_Employment__HoursOutside  3.391748e+06
# 210                           svd_DatabaseWorkedWith_1  3.375588e+06
# 211     te_YearsCodingProf__ohe_PlatformWorkedWith_AWS  3.360510e+06
# 212  rank_diff_JobEmailPriorities_JobEmailPrioritie...  3.320428e+06
# 213          rank_diff_AssessJob_AssessJob4_AssessJob5  3.280144e+06
# 214      te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  3.279709e+06
# 215  te_Employment__ohe_Methodology_Extreme_program...  3.270235e+06
# 216         te_CompanySize__StackOverflowJobsRecommend  3.209738e+06
# 217              te_YearsCoding__ohe_Methodology_Agile  3.207692e+06
# 218       te_HopeFiveYears__ohe_LanguageWorkedWith_PHP  3.197666e+06
# 219  te_ohe_CommunicationTools_Confluence__ohe_Lang...  3.192868e+06
# 220       te_Employment__ohe_RaceEthnicity_South_Asian  3.186618e+06
# 221         rank_diff_AssessJob_AssessJob1_AssessJob10  3.164637e+06
# 222                     te_JobSatisfaction__LastNewJob  3.132223e+06
# 223           rel_agg_mean_CompanySize_AssessBenefits2  3.117512e+06
# 224               te_SalaryType__ohe_Methodology_Scrum  3.107321e+06
# 225  te_ohe_CommunicationTools_Jira__ohe_Methodolog...  3.100242e+06
# 226                          te_Employment__Dependents  3.068612e+06
# 227  rank_diff_AssessBenefits_AssessBenefits2_Asses...  3.067786e+06
# 228                            te_JobSatisfaction__Age  3.057648e+06
# 229                 te_LastNewJob__ohe_DevType_Student  3.041583e+06
# 230       diff_agg_mean_NumberMonitors_AssessBenefits2  3.014600e+06
# 231  te_CareerSatisfaction__ohe_CommunicationTools_...  2.991490e+06
# 232                      te_Employment__AgreeDisagree3  2.962303e+06
# 233                            te_LastNewJob__Currency  2.957302e+06
# 234                         te_YearsCoding__LastNewJob  2.955723e+06
# 235                             te_Student__LastNewJob  2.951253e+06
# 236         te_YearsCoding__ohe_LanguageWorkedWith_PHP  2.945092e+06
# 237  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.936464e+06
# 238          diff_agg_mean_CompanySize_AssessBenefits2  2.929255e+06
# 239                 te_FormalEducation__AgreeDisagree3  2.876423e+06
# 240                            te_Student__CompanySize  2.859739e+06
# 241         te_Employment__ohe_CommunicationTools_Jira  2.857688e+06
# 242           diff_agg_mean_SalaryType_AssessBenefits2  2.847662e+06
# 243                       te_Country__EducationParents  2.844160e+06
# 244                            te_Employment__UpdateCV  2.838081e+06
# 245                                          svd_IDE_1  2.836307e+06
# 246  te_AgreeDisagree3__ohe_DevType_Engineering_man...  2.835821e+06
# 247  rank_diff_JobContactPriorities_JobContactPrior...  2.832779e+06
# 248  te_ohe_DevType_Engineering_manager__ohe_Ergono...  2.828589e+06
# 249  te_CompanySize__ohe_EducationTypes_Contributed...  2.825854e+06
# 250              te_Employment__ohe_Methodology_Kanban  2.796625e+06
# 251  te_ohe_LanguageWorkedWith_CSS__ohe_Methodology...  2.788203e+06
# 252     te_Country__ohe_ErgonomicDevices_Standing_desk  2.772442e+06
# 253                               te_Country__Exercise  2.758818e+06
# 254                 te_CompanySize__HypotheticalTools2  2.751835e+06
# 255  te_CareerSatisfaction__ohe_EducationTypes_Part...  2.744308e+06
# 256                te_YearsCoding__ohe_DevType_Student  2.744087e+06
# 257         te_SalaryType__ohe_CommunicationTools_Jira  2.733531e+06
# 258                    te_LastNewJob__EducationParents  2.719873e+06
# 259          te_Employment__StackOverflowJobsRecommend  2.717104e+06
# 260          te_CareerSatisfaction__HypotheticalTools2  2.714981e+06
# 261                       ohe_DatabaseWorkedWith_Redis  2.699720e+06
# 262      te_CurrencySymbol__StackOverflowJobsRecommend  2.654244e+06
# 263                            te_OperatingSystem__Age  2.649428e+06
# 264       rel_agg_mean_FormalEducation_AssessBenefits2  2.647436e+06
# 265                  te_CurrencySymbol__AgreeDisagree3  2.635833e+06
# 266                     te_UndergradMajor__CompanySize  2.628634e+06
# 267         rank_diff_AssessJob_AssessJob6_AssessJob10  2.626891e+06
# 268                 te_OperatingSystem__NumberMonitors  2.623878e+06
# 269     te_OperatingSystem__ohe_LanguageWorkedWith_CSS  2.597433e+06
# 270               te_Dependents__ohe_Methodology_Agile  2.586634e+06
# 271     te_JobSatisfaction__ohe_LanguageWorkedWith_PHP  2.573170e+06
# 272                    te_EducationParents__Dependents  2.511840e+06
# 273      diff_agg_mean_FormalEducation_AssessBenefits2  2.511095e+06
# 274  te_ohe_DevType_Engineering_manager__ohe_Method...  2.507359e+06
# 275                             te_NumberMonitors__Age  2.505182e+06
# 276                            te_UpdateCV__SalaryType  2.504851e+06
# 277         te_StackOverflowVisit__ohe_DevType_Student  2.498005e+06
# 278  te_ohe_DevType_Engineering_manager__ohe_Educat...  2.497968e+06
# 279                 te_Employment__TimeFullyProductive  2.494955e+06
# 280                     te_YearsCodingProf__Dependents  2.492959e+06
# 281                         te_HypotheticalTools2__Age  2.491727e+06
# 282                                  svd_Methodology_0  2.489374e+06
# 283                              te_HopeFiveYears__Age  2.481697e+06
# 284                     ohe_FrameworkWorkedWith_Hadoop  2.473811e+06
# 285                           te_CompanySize__UpdateCV  2.471479e+06
# 286  te_FormalEducation__ohe_DevType_Engineering_ma...  2.448554e+06
# 287             te_OperatingSystem__HypotheticalTools2  2.439378e+06
# 288                      te_Employment__NumberMonitors  2.435235e+06
# 289  te_OperatingSystem__ohe_ErgonomicDevices_Stand...  2.415460e+06
# 290  rank_diff_AssessBenefits_AssessBenefits2_Asses...  2.403417e+06
# 291                                   ohe_IDE_NetBeans  2.401574e+06
# 292      te_ohe_DevType_Student__ohe_Methodology_Agile  2.397192e+06
# 293  te_ohe_LanguageWorkedWith_Go__ohe_LanguageWork...  2.397183e+06
# 294                       te_Employment__HopeFiveYears  2.395951e+06
# 295                         te_Employment__CompanySize  2.391950e+06
# 296                           svd_DatabaseWorkedWith_0  2.373100e+06
# 297  rank_diff_AssessBenefits_AssessBenefits7_Asses...  2.361355e+06
# 298                           te_EducationParents__Age  2.356086e+06
# 299                            te_LastNewJob__UpdateCV  2.342197e+06

# %%
len(use_cols)
# Out:
# 1000

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 66281.40775142,  92408.90744987,  90357.71323066, ...,
#         88931.65694697,  82698.1536359 , 115928.99044748])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/023_rank_feature_20135.csv", index=False)
