# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # SVD
    svd = TruncatedSVD(n_components=2)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 507), (11259, 506))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3573

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'regression',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20785.2	valid_1's rmse: 21673.6
# [200]	training's rmse: 19659	valid_1's rmse: 21105.5
# [300]	training's rmse: 19004.5	valid_1's rmse: 20875.2
# [400]	training's rmse: 18502.4	valid_1's rmse: 20758.7
# [500]	training's rmse: 18055.5	valid_1's rmse: 20671.9
# [600]	training's rmse: 17685	valid_1's rmse: 20616.4
# [700]	training's rmse: 17326.2	valid_1's rmse: 20572.1
# [800]	training's rmse: 17003.8	valid_1's rmse: 20544.4
# [900]	training's rmse: 16713.2	valid_1's rmse: 20534.4
# [1000]	training's rmse: 16440.5	valid_1's rmse: 20526.9
# [1100]	training's rmse: 16174.5	valid_1's rmse: 20517.4
# Early stopping, best iteration is:
# [1065]	training's rmse: 16259.1	valid_1's rmse: 20509.6
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20753.5	valid_1's rmse: 21726.5
# [200]	training's rmse: 19651.1	valid_1's rmse: 21046.7
# [300]	training's rmse: 18981	valid_1's rmse: 20760.1
# [400]	training's rmse: 18503.2	valid_1's rmse: 20613.3
# [500]	training's rmse: 18063	valid_1's rmse: 20506.8
# [600]	training's rmse: 17687	valid_1's rmse: 20429.2
# [700]	training's rmse: 17361.2	valid_1's rmse: 20362.6
# [800]	training's rmse: 17051.3	valid_1's rmse: 20309.4
# [900]	training's rmse: 16749.9	valid_1's rmse: 20269.7
# [1000]	training's rmse: 16481.8	valid_1's rmse: 20264
# [1100]	training's rmse: 16221.7	valid_1's rmse: 20249
# [1200]	training's rmse: 15979.5	valid_1's rmse: 20218.4
# [1300]	training's rmse: 15742.5	valid_1's rmse: 20199.1
# [1400]	training's rmse: 15515.3	valid_1's rmse: 20189.9
# Early stopping, best iteration is:
# [1375]	training's rmse: 15570.2	valid_1's rmse: 20187.5
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20776.1	valid_1's rmse: 21598.7
# [200]	training's rmse: 19608.3	valid_1's rmse: 21025.1
# [300]	training's rmse: 18939.4	valid_1's rmse: 20849.5
# [400]	training's rmse: 18413.3	valid_1's rmse: 20770.8
# [500]	training's rmse: 17992.9	valid_1's rmse: 20695.2
# [600]	training's rmse: 17607	valid_1's rmse: 20633.8
# [700]	training's rmse: 17301	valid_1's rmse: 20602.4
# [800]	training's rmse: 16981	valid_1's rmse: 20588.8
# [900]	training's rmse: 16677.7	valid_1's rmse: 20568.8
# [1000]	training's rmse: 16388.1	valid_1's rmse: 20552.5
# [1100]	training's rmse: 16112.7	valid_1's rmse: 20532.7
# [1200]	training's rmse: 15873.1	valid_1's rmse: 20520.1
# [1300]	training's rmse: 15619.4	valid_1's rmse: 20509.5
# [1400]	training's rmse: 15391.6	valid_1's rmse: 20508.7
# [1500]	training's rmse: 15192	valid_1's rmse: 20493.3
# Early stopping, best iteration is:
# [1479]	training's rmse: 15238.4	valid_1's rmse: 20492.7
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20800.1	valid_1's rmse: 21576.6
# [200]	training's rmse: 19647.6	valid_1's rmse: 20960
# [300]	training's rmse: 19002.1	valid_1's rmse: 20723
# [400]	training's rmse: 18498.8	valid_1's rmse: 20562.8
# [500]	training's rmse: 18074.6	valid_1's rmse: 20452.2
# [600]	training's rmse: 17709.2	valid_1's rmse: 20397.4
# [700]	training's rmse: 17386.6	valid_1's rmse: 20334.6
# [800]	training's rmse: 17060.1	valid_1's rmse: 20299.6
# [900]	training's rmse: 16753.1	valid_1's rmse: 20270.5
# [1000]	training's rmse: 16488.5	valid_1's rmse: 20250.7
# [1100]	training's rmse: 16223.7	valid_1's rmse: 20225
# [1200]	training's rmse: 15960.2	valid_1's rmse: 20216.1
# [1300]	training's rmse: 15726.5	valid_1's rmse: 20188.8
# [1400]	training's rmse: 15491.1	valid_1's rmse: 20179.8
# [1500]	training's rmse: 15281.5	valid_1's rmse: 20174.2
# [1600]	training's rmse: 15062.5	valid_1's rmse: 20171.3
# [1700]	training's rmse: 14844	valid_1's rmse: 20156.2
# [1800]	training's rmse: 14629	valid_1's rmse: 20150.3
# [1900]	training's rmse: 14417.8	valid_1's rmse: 20138.5
# [2000]	training's rmse: 14204.6	valid_1's rmse: 20134.3
# Early stopping, best iteration is:
# [1954]	training's rmse: 14300.4	valid_1's rmse: 20131.4
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20867.8	valid_1's rmse: 21461.8
# [200]	training's rmse: 19715.9	valid_1's rmse: 20726.6
# [300]	training's rmse: 19079.7	valid_1's rmse: 20476.3
# [400]	training's rmse: 18562	valid_1's rmse: 20299.1
# [500]	training's rmse: 18143.8	valid_1's rmse: 20218.6
# [600]	training's rmse: 17761.9	valid_1's rmse: 20168.9
# [700]	training's rmse: 17444.6	valid_1's rmse: 20138.9
# [800]	training's rmse: 17130.3	valid_1's rmse: 20112.4
# [900]	training's rmse: 16832.9	valid_1's rmse: 20070.5
# [1000]	training's rmse: 16566.4	valid_1's rmse: 20057.4
# [1100]	training's rmse: 16289.2	valid_1's rmse: 20037
# [1200]	training's rmse: 16055.9	valid_1's rmse: 20026.8
# [1300]	training's rmse: 15819.1	valid_1's rmse: 20021.4
# [1400]	training's rmse: 15586.3	valid_1's rmse: 20011.6
# [1500]	training's rmse: 15365.3	valid_1's rmse: 19998.2
# [1600]	training's rmse: 15170.6	valid_1's rmse: 19997.1
# Early stopping, best iteration is:
# [1569]	training's rmse: 15237.9	valid_1's rmse: 19991.2

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20263.52125356026

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  3.456989e+13
# 1                      te_Country__ohe_DevType_Student  3.190895e+13
# 2               te_Country__ohe_LanguageWorkedWith_PHP  2.184349e+13
# 3                               te_Country__Dependents  2.113027e+13
# 4                                      te_Country__Age  1.910685e+13
# 5                       te_YearsCodingProf__MilitaryUS  1.275693e+13
# 6                               te_Country__Employment  1.103777e+13
# 7                              te_Country__YearsCoding  1.079144e+13
# 8                   te_YearsCodingProf__CurrencySymbol  1.055914e+13
# 9                       te_YearsCodingProf__SalaryType  7.164716e+12
# 10                        te_YearsCodingProf__Currency  6.848689e+12
# 11                  te_SalaryType__ohe_DevType_Student  6.237423e+12
# 12                              te_Country__SalaryType  6.189442e+12
# 13               te_CareerSatisfaction__CurrencySymbol  6.096531e+12
# 14   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  5.917329e+12
# 15                          te_Country__CurrencySymbol  5.826779e+12
# 16   te_Country__ohe_EducationTypes_Contributed_to_...  5.772453e+12
# 17                         te_Country__OperatingSystem  4.806361e+12
# 18                 te_YearsCodingProf__OperatingSystem  3.456613e+12
# 19   agg_mean_YearsCodingProf_ohe_CommunicationTool...  3.439301e+12
# 20                      te_Country__CareerSatisfaction  3.070235e+12
# 21   te_YearsCodingProf__ohe_CommunicationTools_Con...  2.883886e+12
# 22                   te_Country__ohe_Methodology_Agile  2.674314e+12
# 23                             te_Country__CompanySize  2.470803e+12
# 24   agg_mean_Country_ohe_EducationTypes_Contribute...  2.435073e+12
# 25                     te_CompanySize__YearsCodingProf  2.394492e+12
# 26                          te_YearsCoding__MilitaryUS  2.291616e+12
# 27              te_YearsCodingProf__CareerSatisfaction  2.243159e+12
# 28      agg_std_Country_ohe_LanguageDesireNextYear_PHP  2.171474e+12
# 29                    te_Currency__ohe_DevType_Student  2.074597e+12
# 30   te_YearsCodingProf__ohe_EducationTypes_Contrib...  2.045280e+12
# 31                            te_YearsCoding__Currency  1.922358e+12
# 32   agg_mean_YearsCodingProf_ohe_EducationTypes_Co...  1.888471e+12
# 33                       te_Employment__CurrencySymbol  1.813741e+12
# 34                 te_FormalEducation__YearsCodingProf  1.674752e+12
# 35                         te_Country__FormalEducation  1.619617e+12
# 36                     te_CompanySize__OperatingSystem  1.539773e+12
# 37                                  te_Employment__Age  1.494053e+12
# 38                     te_YearsCoding__OperatingSystem  1.444701e+12
# 39                     te_YearsCoding__YearsCodingProf  1.429719e+12
# 40                           te_Employment__SalaryType  1.407416e+12
# 41                      te_YearsCoding__CurrencySymbol  1.358805e+12
# 42   te_CompanySize__ohe_CommunicationTools_Confluence  1.306603e+12
# 43             te_YearsCodingProf__ohe_DevType_Student  1.302390e+12
# 44                           te_SalaryType__MilitaryUS  1.189320e+12
# 45                      te_Employment__FormalEducation  1.177512e+12
# 46           te_YearsCodingProf__ohe_Methodology_Agile  1.136249e+12
# 47                                  te_SalaryType__Age  1.047372e+12
# 48   te_CurrencySymbol__ohe_EducationTypes_Contribu...  1.025516e+12
# 49                             te_Employment__Currency  9.764558e+11
# 50                  te_CurrencySymbol__OperatingSystem  9.703770e+11
# 51                           te_Employment__MilitaryUS  9.298434e+11
# 52                      te_CompanySize__CurrencySymbol  9.177059e+11
# 53                  te_YearsCoding__CareerSatisfaction  9.046519e+11
# 54      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  8.169623e+11
# 55   te_CareerSatisfaction__ohe_DevType_Engineering...  7.850781e+11
# 56                            te_CompanySize__Currency  7.313890e+11
# 57                  te_CompanySize__CareerSatisfaction  7.117416e+11
# 58                        te_Currency__OperatingSystem  7.068971e+11
# 59                             te_YearsCodingProf__Age  7.012785e+11
# 60              diff_agg_mean_Currency_AssessBenefits2  6.769307e+11
# 61     te_CompanySize__ohe_DevType_Engineering_manager  6.631400e+11
# 62                       te_SalaryType__CurrencySymbol  6.448653e+11
# 63       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  6.413090e+11
# 64                 te_FormalEducation__OperatingSystem  6.325161e+11
# 65               te_CompanySize__ohe_Methodology_Agile  6.228684e+11
# 66   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  6.155999e+11
# 67                            svd_CommunicationTools_0  6.092963e+11
# 68              te_CurrencySymbol__ohe_DevType_Student  6.070242e+11
# 69   te_CareerSatisfaction__ohe_CommunicationTools_...  5.991879e+11
# 70               te_YearsCoding__ohe_Methodology_Agile  5.884198e+11
# 71     agg_mean_Employment_ohe_CommunicationTools_Jira  5.641862e+11
# 72   te_YearsCoding__ohe_CommunicationTools_Confluence  5.641192e+11
# 73              te_CareerSatisfaction__OperatingSystem  5.523369e+11
# 74                      te_Employment__OperatingSystem  5.479281e+11
# 75   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  5.444788e+11
# 76                       te_CurrencySymbol__MilitaryUS  5.443790e+11
# 77   te_CompanySize__ohe_EducationTypes_Contributed...  5.360027e+11
# 78                          te_CompanySize__SalaryType  5.295300e+11
# 79   agg_mean_Employment_ohe_CommunicationTools_Con...  5.283808e+11
# 80       te_Country__ohe_CommunicationTools_Confluence  5.282121e+11
# 81         te_Country__ohe_DevType_Engineering_manager  5.069281e+11
# 82                      te_Employment__YearsCodingProf  5.041935e+11
# 83           te_Employment__ohe_LanguageWorkedWith_PHP  4.778465e+11
# 84      te_Employment__ohe_DevType_Engineering_manager  4.753690e+11
# 85   agg_std_Country_ohe_ErgonomicDevices_Standing_...  4.727701e+11
# 86            te_CurrencySymbol__ohe_Methodology_Agile  4.721274e+11
# 87   diff_agg_mean_CompanySize_ohe_DevType_Engineer...  4.691671e+11
# 88         rel_agg_mean_NumberMonitors_AssessBenefits2  4.656526e+11
# 89           diff_agg_mean_CompanySize_AssessBenefits2  4.636570e+11
# 90                         te_CompanySize__YearsCoding  4.628400e+11
# 91   diff_agg_mean_Employment_ohe_LanguageWorkedWit...  4.467867e+11
# 92    te_Employment__ohe_CommunicationTools_Confluence  4.341212e+11
# 93                              te_CurrencySymbol__Age  4.326895e+11
# 94   te_FormalEducation__ohe_DevType_Engineering_ma...  4.312187e+11
# 95                  te_FormalEducation__CurrencySymbol  4.308569e+11
# 96                  te_Employment__ohe_DevType_Student  4.266150e+11
# 97        diff_agg_mean_NumberMonitors_AssessBenefits2  4.208193e+11
# 98                   te_Employment__CareerSatisfaction  4.184315e+11
# 99                          te_Employment__YearsCoding  4.147051e+11
# 100                                te_CompanySize__Age  4.140205e+11
# 101                          ohe_LanguageWorkedWith_Go  4.136040e+11
# 102               rel_agg_mean_Country_AssessBenefits2  3.913176e+11
# 103               te_Employment__ohe_Methodology_Agile  3.809631e+11
# 104         te_YearsCoding__ohe_LanguageWorkedWith_PHP  3.785601e+11
# 105                         te_Employment__CompanySize  3.775431e+11
# 106                           svd_LanguageWorkedWith_1  3.756599e+11
# 107              rel_agg_mean_Currency_AssessBenefits2  3.735854e+11
# 108                                te_YearsCoding__Age  3.715430e+11
# 109          agg_mean_Employment_ohe_Methodology_Agile  3.692940e+11
# 110                         te_YearsCoding__SalaryType  3.687271e+11
# 111           diff_agg_mean_MilitaryUS_AssessBenefits2  3.612880e+11
# 112  te_YearsCodingProf__ohe_DevType_Engineering_ma...  3.541813e+11
# 113          te_SalaryType__ohe_LanguageWorkedWith_PHP  3.531691e+11
# 114                               te_Country__Currency  3.448713e+11
# 115                     te_FormalEducation__SalaryType  3.361958e+11
# 116         te_CompanySize__ohe_LanguageWorkedWith_PHP  3.258288e+11
# 117       agg_mean_YearsCodingProf_ohe_DevType_Student  3.168245e+11
# 118     te_FormalEducation__ohe_LanguageWorkedWith_PHP  3.133203e+11
# 119                     te_FormalEducation__MilitaryUS  3.096459e+11
# 120   diff_agg_mean_CurrencySymbol_ohe_DevType_Student  3.077411e+11
# 121       diff_agg_mean_UndergradMajor_AssessBenefits2  2.921260e+11
# 122                       svd_DatabaseDesireNextYear_1  2.919090e+11
# 123        rel_agg_mean_CurrencySymbol_AssessBenefits2  2.903504e+11
# 124  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  2.894933e+11
# 125  agg_mean_YearsCodingProf_ohe_LanguageDesireNex...  2.823921e+11
# 126                                  svd_Methodology_0  2.823210e+11
# 127              diff_agg_mean_Country_AssessBenefits2  2.749231e+11
# 128  te_YearsCoding__ohe_EducationTypes_Contributed...  2.734737e+11
# 129                      te_Age__ohe_Methodology_Agile  2.671096e+11
# 130               te_SalaryType__ohe_Methodology_Agile  2.644834e+11
# 131                         te_CompanySize__Dependents  2.621929e+11
# 132                           svd_DatabaseWorkedWith_1  2.605462e+11
# 133                  te_CareerSatisfaction__SalaryType  2.592272e+11
# 134                     te_YearsCodingProf__Dependents  2.557023e+11
# 135          te_Age__ohe_CommunicationTools_Confluence  2.543291e+11
# 136             te_FormalEducation__CareerSatisfaction  2.541030e+11
# 137                              te_HypotheticalTools2  2.532191e+11
# 138                               svd_VersionControl_1  2.527983e+11
# 139                         te_CareerSatisfaction__Age  2.511399e+11
# 140                    agg_std_Country_AssessBenefits2  2.491780e+11
# 141  te_OperatingSystem__ohe_DevType_Engineering_ma...  2.439357e+11
# 142            agg_mean_Employment_ohe_DevType_Student  2.375912e+11
# 143                                        te_UpdateCV  2.370846e+11
# 144  agg_std_YearsCodingProf_ohe_EducationTypes_Con...  2.342833e+11
# 145                            te_OperatingSystem__Age  2.342649e+11
# 146        rel_agg_mean_UndergradMajor_AssessBenefits2  2.300077e+11
# 147                  diff_agg_mean_Age_AssessBenefits2  2.283134e+11
# 148  agg_mean_Country_ohe_CommunicationTools_Conflu...  2.266650e+11
# 149                                      te_LastNewJob  2.263859e+11
# 150       rel_agg_mean_FormalEducation_AssessBenefits2  2.247617e+11
# 151            rel_agg_mean_SalaryType_AssessBenefits2  2.246209e+11
# 152   te_SalaryType__ohe_CommunicationTools_Confluence  2.209468e+11
# 153             agg_mean_Country_ohe_Methodology_Agile  2.209221e+11
# 154  te_FormalEducation__ohe_EducationTypes_Contrib...  2.201464e+11
# 155                         te_CompanySize__MilitaryUS  2.188902e+11
# 156                  te_CareerSatisfaction__MilitaryUS  2.186108e+11
# 157  te_CareerSatisfaction__ohe_EducationTypes_Cont...  2.172105e+11
# 158  agg_std_Employment_ohe_ErgonomicDevices_Standi...  2.148175e+11
# 159                            te_Currency__SalaryType  2.135970e+11
# 160                te_CompanySize__ohe_DevType_Student  2.132422e+11
# 161                              JobContactPriorities1  2.115594e+11
# 162                       ohe_DatabaseWorkedWith_Redis  2.101666e+11
# 163           rel_agg_mean_CompanySize_AssessBenefits2  2.099238e+11
# 164  te_OperatingSystem__ohe_CommunicationTools_Con...  2.076417e+11
# 165                                      svd_DevType_0  2.068029e+11
# 166                                JobEmailPriorities5  2.067266e+11
# 167                           svd_DatabaseWorkedWith_0  2.058459e+11
# 168                agg_mean_FormalEducation_AssessJob4  2.044730e+11
# 169               ohe_DatabaseWorkedWith_Elasticsearch  2.042310e+11
# 170               agg_mean_CompanySize_AssessBenefits2  2.035353e+11
# 171                       svd_LanguageDesireNextYear_0  2.008672e+11
# 172                       ohe_LanguageWorkedWith_Scala  1.956690e+11
# 173                    te_FormalEducation__CompanySize  1.954138e+11
# 174    te_YearsCoding__ohe_DevType_Engineering_manager  1.944132e+11
# 175           diff_agg_mean_SalaryType_AssessBenefits2  1.917514e+11
# 176  agg_std_Employment_ohe_LanguageDesireNextYear_PHP  1.910757e+11
# 177    diff_agg_mean_CompanySize_ohe_Methodology_Agile  1.893538e+11
# 178                                          svd_IDE_1  1.876165e+11
# 179  te_FormalEducation__ohe_CommunicationTools_Con...  1.866242e+11
# 180                               ohe_DevType_Designer  1.863112e+11
# 181             ohe_DatabaseWorkedWith_Amazon_Redshift  1.862268e+11
# 182       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.842884e+11
# 183  te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  1.841911e+11
# 184                     te_SalaryType__OperatingSystem  1.819671e+11
# 185                       te_FormalEducation__Currency  1.805489e+11
# 186  rel_agg_mean_TimeFullyProductive_ohe_Communica...  1.801750e+11
# 187  agg_std_Country_ohe_CommunicationTools_Confluence  1.798163e+11
# 188            rel_agg_mean_MilitaryUS_AssessBenefits2  1.781280e+11
# 189                             svd_HackathonReasons_1  1.781279e+11
# 190        agg_std_FormalEducation_ohe_DevType_Student  1.768241e+11
# 191  te_Employment__ohe_EducationTypes_Contributed_...  1.761277e+11
# 192                      sum_answer_DatabaseWorkedWith  1.751718e+11
# 193  diff_agg_mean_Employment_ohe_LanguageDesireNex...  1.736989e+11
# 194                 te_Currency__ohe_Methodology_Agile  1.711912e+11
# 195                                        AssessJob10  1.709686e+11
# 196      diff_agg_mean_FormalEducation_AssessBenefits2  1.703192e+11
# 197                 ohe_DevType_Database_administrator  1.700466e+11
# 198  te_Age__ohe_RaceEthnicity_White_or_of_European...  1.694210e+11
# 199                   rel_agg_mean_Age_AssessBenefits2  1.658168e+11
# 200                                 sum_answer_DevType  1.653958e+11
# 201        ohe_DevType_Educator_or_academic_researcher  1.648303e+11
# 202        agg_std_YearsCodingProf_ohe_DevType_Student  1.642540e+11
# 203                                  svd_Methodology_1  1.641026e+11
# 204       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.615252e+11
# 205     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  1.596928e+11
# 206                      te_CurrencySymbol__Dependents  1.596482e+11
# 207                         ohe_LanguageWorkedWith_CSS  1.589133e+11
# 208          diff_agg_mean_YearsCoding_AssessBenefits2  1.558286e+11
# 209                     ohe_FrameworkWorkedWith_Hadoop  1.519150e+11
# 210                                te_EducationParents  1.488374e+11
# 211    agg_mean_Country_ohe_LanguageDesireNextYear_PHP  1.478853e+11
# 212  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  1.467398e+11
# 213                       ohe_PlatformWorkedWith_Azure  1.462881e+11
# 214           diff_agg_mean_Employment_AssessBenefits2  1.445585e+11
# 215  te_Country__ohe_RaceEthnicity_White_or_of_Euro...  1.423017e+11
# 216                      te_StackOverflowJobsRecommend  1.421884e+11
# 217         te_CareerSatisfaction__ohe_DevType_Student  1.412419e+11
# 218                    ohe_DevType_Front_end_developer  1.411634e+11
# 219                     te_OperatingSystem__MilitaryUS  1.410103e+11
# 220             ohe_DatabaseWorkedWith_Google_BigQuery  1.404374e+11
# 221                       svd_DatabaseDesireNextYear_0  1.401496e+11
# 222                             te_Country__MilitaryUS  1.384123e+11
# 223                                      svd_DevType_1  1.379713e+11
# 224                                         AssessJob6  1.372983e+11
# 225         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.370909e+11
# 226                                        te_WakeTime  1.365905e+11
# 227       diff_agg_mean_CurrencySymbol_AssessBenefits2  1.335937e+11
# 228                           svd_PlatformWorkedWith_1  1.330323e+11
# 229                  te_CareerSatisfaction__Dependents  1.322513e+11
# 230                                         te_Country  1.321395e+11
# 231        diff_agg_mean_CareerSatisfaction_AssessJob5  1.314716e+11
# 232  agg_std_Employment_ohe_DevType_Engineering_man...  1.287931e+11
# 233  te_CurrencySymbol__ohe_DevType_Engineering_man...  1.286082e+11
# 234                          svd_FrameworkWorkedWith_1  1.282126e+11
# 235                             sum_answer_Methodology  1.276286e+11
# 236  diff_agg_mean_CurrencySymbol_ohe_EducationType...  1.275780e+11
# 237  agg_mean_HopeFiveYears_ohe_EducationTypes_Cont...  1.273977e+11
# 238            rel_agg_mean_JobSatisfaction_AssessJob5  1.273231e+11
# 239                            te_FormalEducation__Age  1.272181e+11
# 240  te_Employment__ohe_RaceEthnicity_White_or_of_E...  1.271738e+11
# 241   rel_agg_mean_TimeFullyProductive_AssessBenefits2  1.266188e+11
# 242                         te_YearsCoding__Dependents  1.266123e+11
# 243  diff_agg_mean_SalaryType_ohe_DevType_Engineeri...  1.264344e+11
# 244     te_Currency__ohe_CommunicationTools_Confluence  1.254913e+11
# 245     te_MilitaryUS__ohe_DevType_Engineering_manager  1.252623e+11
# 246          te_FormalEducation__ohe_Methodology_Agile  1.236305e+11
# 247           diff_agg_mean_JobSatisfaction_AssessJob5  1.233252e+11
# 248                                 te_Age__MilitaryUS  1.232407e+11
# 249                      ohe_LanguageDesireNextYear_F_  1.228007e+11
# 250       te_Currency__ohe_DevType_Engineering_manager  1.221050e+11
# 251                 te_Age__ohe_LanguageWorkedWith_PHP  1.218878e+11
# 252                              svd_SelfTaughtTypes_1  1.215243e+11
# 253                              JobContactPriorities4  1.204015e+11
# 254                           svd_LanguageWorkedWith_0  1.202176e+11
# 255                   ohe_DevType_System_administrator  1.198408e+11
# 256  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  1.193777e+11
# 257      diff_agg_mean_JobSatisfaction_AssessBenefits2  1.187465e+11
# 258  diff_agg_mean_ohe_RaceEthnicity_White_or_of_Eu...  1.186824e+11
# 259                       svd_LanguageDesireNextYear_1  1.183640e+11
# 260           ohe_Methodology_Extreme_programming__XP_  1.178474e+11
# 261                                JobEmailPriorities6  1.163486e+11
# 262      te_ohe_DevType_Student__ohe_Methodology_Agile  1.144533e+11
# 263                         ohe_PlatformWorkedWith_AWS  1.126480e+11
# 264  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  1.122116e+11
# 265                    te_FormalEducation__YearsCoding  1.120912e+11
# 266  diff_agg_mean_Country_ohe_RaceEthnicity_White_...  1.119756e+11
# 267                              JobContactPriorities3  1.118431e+11
# 268   diff_agg_mean_CareerSatisfaction_AssessBenefits2  1.114517e+11
# 269                   ohe_DatabaseWorkedWith_Cassandra  1.108332e+11
# 270                                        te_Exercise  1.098244e+11
# 271                              te_StackOverflowVisit  1.091947e+11
# 272                                   AssessBenefits11  1.085729e+11
# 273                                    te_HoursOutside  1.077885e+11
# 274  diff_agg_mean_Country_ohe_DevType_Engineering_...  1.071207e+11
# 275  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  1.055769e+11
# 276        rel_agg_mean_TimeFullyProductive_AssessJob5  1.052777e+11
# 277  te_ohe_CommunicationTools_Confluence__ohe_Lang...  1.051598e+11
# 278  diff_agg_mean_YearsCodingProf_ohe_ErgonomicDev...  1.050889e+11
# 279                    te_CareerSatisfaction__Currency  1.050739e+11
# 280       te_CareerSatisfaction__ohe_Methodology_Agile  1.046412e+11
# 281                                          svd_IDE_0  1.042183e+11
# 282            diff_agg_mean_UndergradMajor_AssessJob5  1.039038e+11
# 283                       ohe_CommunicationTools_Slack  1.033167e+11
# 284                                    AssessBenefits8  1.032365e+11
# 285  rel_agg_mean_TimeFullyProductive_ohe_Communica...  1.022389e+11
# 286                               svd_EducationTypes_1  1.017289e+11
# 287               diff_agg_mean_CompanySize_AssessJob5  1.012548e+11
# 288                                   te_Currency__Age  1.012266e+11
# 289                       svd_PlatformDesireNextYear_0  1.010687e+11
# 290                              te_HypotheticalTools1  1.004625e+11
# 291    rel_agg_mean_CurrencySymbol_ohe_DevType_Student  1.004109e+11
# 292  diff_agg_mean_Country_ohe_ErgonomicDevices_Sta...  9.993648e+10
# 293        diff_agg_mean_HopeFiveYears_AssessBenefits2  9.959738e+10
# 294                                    AssessBenefits1  9.879145e+10
# 295  rel_agg_mean_YearsCodingProf_ohe_EducationType...  9.829542e+10
# 296       diff_agg_mean_SalaryType_ohe_DevType_Student  9.757320e+10
# 297              diff_agg_mean_Student_AssessBenefits2  9.526374e+10
# 298                          te_Employment__Dependents  9.508666e+10
# 299                      agg_std_SalaryType_AssessJob8  9.464651e+10

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 65920.71483471,  92204.33567973,  87863.82437765, ...,
#         89813.01057995,  80200.94811851, 117428.91730357])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/015_svd_20263.csv", index=False)
