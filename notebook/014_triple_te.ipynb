# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 465), (11259, 464))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
# te_cols = [c for c in use_cols if "agg_" not in c and train_df[c].nunique() >= 5]
te_cols = [c for c in train_df.columns if c in cat_cols]

# %%
for c in tqdm(te_cols):
    new_col = "te_" + c
    train_df[new_col] = 0
    test_df[new_col] = 0
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=65.0), HTML(value='')))

# %% [markdown]
# ### Multiple Target Encoding

# %%
# multiple target encoding
multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
imp_feats = get_importance_cols(use_num=30)
multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))

# %%
for col_a, col_b in tqdm(combi_multi_te_cols):
    new_col = "te_" + col_a + "__" + col_b
    train_df[new_col] = 0
    test_df[new_col] = 0
    train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
    test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
    del train_df["tmp"], test_df["tmp"]
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=210.0), HTML(value='')))

# %% [markdown]
# ### Triple Target Encoding

# %%
triple_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
imp_feats = get_importance_cols(use_num=20)
triple_te_cols = [c for c in triple_te_cols if c in imp_feats]
combi_triple_te_cols = list(itertools.combinations(triple_te_cols, 3))

# %%
len(combi_triple_te_cols)
# Out:
# 560

# %%
for col_a, col_b, col_c in tqdm(combi_triple_te_cols):
    new_col = "te_triple_" + col_a + "__" + col_b + "__" + col_c
    train_df[new_col] = 0
    test_df[new_col] = 0
    train_df["tmp"] = \
        train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str) + train_df[col_c].fillna("").astype(str)
    test_df["tmp"] = \
        test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str) + test_df[col_c].fillna("").astype(str)
    for trn_idx, val_idx in fold_idx_list:
        mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
        train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
        test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
    train_df[new_col] = train_df[new_col].astype(np.float32)
    test_df[new_col] = test_df[new_col].astype(np.float32)
    del train_df["tmp"], test_df["tmp"]
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=560.0), HTML(value='')))

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 4091

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if feature_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path)
                test_feats = pd.read_pickle(test_feat_path)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = list(np.setdiff1d(before_cols, after_cols))
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'regression',
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20620.8	valid_1's rmse: 21591.6
# [200]	training's rmse: 19520.4	valid_1's rmse: 21106.1
# [300]	training's rmse: 18889.9	valid_1's rmse: 20944.3
# [400]	training's rmse: 18379	valid_1's rmse: 20886.9
# [500]	training's rmse: 17930.2	valid_1's rmse: 20812.6
# [600]	training's rmse: 17535.9	valid_1's rmse: 20748
# [700]	training's rmse: 17185.9	valid_1's rmse: 20715
# [800]	training's rmse: 16887.5	valid_1's rmse: 20690.1
# [900]	training's rmse: 16571.3	valid_1's rmse: 20655.3
# [1000]	training's rmse: 16273.1	valid_1's rmse: 20616
# [1100]	training's rmse: 15994.7	valid_1's rmse: 20607.9
# [1200]	training's rmse: 15740.7	valid_1's rmse: 20605
# Early stopping, best iteration is:
# [1164]	training's rmse: 15825.9	valid_1's rmse: 20593.2
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20560.4	valid_1's rmse: 21654.1
# [200]	training's rmse: 19486.9	valid_1's rmse: 21061.2
# [300]	training's rmse: 18818.5	valid_1's rmse: 20798.1
# [400]	training's rmse: 18317.3	valid_1's rmse: 20643.3
# [500]	training's rmse: 17929	valid_1's rmse: 20552.3
# [600]	training's rmse: 17560.9	valid_1's rmse: 20479.7
# [700]	training's rmse: 17233.2	valid_1's rmse: 20425.5
# [800]	training's rmse: 16915.7	valid_1's rmse: 20355.3
# [900]	training's rmse: 16619.8	valid_1's rmse: 20307.9
# [1000]	training's rmse: 16328.2	valid_1's rmse: 20255.4
# [1100]	training's rmse: 16058	valid_1's rmse: 20242.1
# [1200]	training's rmse: 15796.7	valid_1's rmse: 20229.8
# [1300]	training's rmse: 15546	valid_1's rmse: 20204.1
# [1400]	training's rmse: 15293	valid_1's rmse: 20188.8
# [1500]	training's rmse: 15059.3	valid_1's rmse: 20166.7
# [1600]	training's rmse: 14830.9	valid_1's rmse: 20153.5
# [1700]	training's rmse: 14612.8	valid_1's rmse: 20137.8
# [1800]	training's rmse: 14403.6	valid_1's rmse: 20130.7
# [1900]	training's rmse: 14185.5	valid_1's rmse: 20117
# [2000]	training's rmse: 13986.2	valid_1's rmse: 20111
# [2100]	training's rmse: 13799.9	valid_1's rmse: 20109.2
# Early stopping, best iteration is:
# [2073]	training's rmse: 13848.6	valid_1's rmse: 20105.2
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20586.9	valid_1's rmse: 21510.2
# [200]	training's rmse: 19473.4	valid_1's rmse: 21041
# [300]	training's rmse: 18791.7	valid_1's rmse: 20892.6
# [400]	training's rmse: 18300.5	valid_1's rmse: 20818.6
# [500]	training's rmse: 17859.4	valid_1's rmse: 20776.7
# [600]	training's rmse: 17495	valid_1's rmse: 20713.2
# [700]	training's rmse: 17146.2	valid_1's rmse: 20670.3
# [800]	training's rmse: 16837.5	valid_1's rmse: 20650.8
# [900]	training's rmse: 16531.5	valid_1's rmse: 20623.1
# [1000]	training's rmse: 16255.6	valid_1's rmse: 20613.5
# [1100]	training's rmse: 15967.3	valid_1's rmse: 20605.5
# [1200]	training's rmse: 15697	valid_1's rmse: 20578.9
# [1300]	training's rmse: 15471.6	valid_1's rmse: 20573.4
# [1400]	training's rmse: 15247.5	valid_1's rmse: 20553
# [1500]	training's rmse: 15043.3	valid_1's rmse: 20529.8
# [1600]	training's rmse: 14814.2	valid_1's rmse: 20520.6
# [1700]	training's rmse: 14590.6	valid_1's rmse: 20509.1
# [1800]	training's rmse: 14390.6	valid_1's rmse: 20508.5
# Early stopping, best iteration is:
# [1728]	training's rmse: 14533.3	valid_1's rmse: 20504.5
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20617.8	valid_1's rmse: 21567.7
# [200]	training's rmse: 19488.8	valid_1's rmse: 21031.4
# [300]	training's rmse: 18833.6	valid_1's rmse: 20820.6
# [400]	training's rmse: 18280.9	valid_1's rmse: 20689.5
# [500]	training's rmse: 17861.5	valid_1's rmse: 20608
# [600]	training's rmse: 17504	valid_1's rmse: 20554.6
# [700]	training's rmse: 17163.1	valid_1's rmse: 20491
# [800]	training's rmse: 16828.1	valid_1's rmse: 20458
# [900]	training's rmse: 16533.1	valid_1's rmse: 20424.7
# [1000]	training's rmse: 16242.8	valid_1's rmse: 20403.6
# [1100]	training's rmse: 15974.4	valid_1's rmse: 20376.9
# [1200]	training's rmse: 15689.9	valid_1's rmse: 20361.2
# [1300]	training's rmse: 15432	valid_1's rmse: 20351.9
# [1400]	training's rmse: 15181.4	valid_1's rmse: 20338.7
# [1500]	training's rmse: 14947.5	valid_1's rmse: 20330.9
# [1600]	training's rmse: 14712.4	valid_1's rmse: 20322.3
# [1700]	training's rmse: 14505.9	valid_1's rmse: 20330.2
# Early stopping, best iteration is:
# [1668]	training's rmse: 14568.3	valid_1's rmse: 20316.3
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20644.7	valid_1's rmse: 21386.8
# [200]	training's rmse: 19568.3	valid_1's rmse: 20775.7
# [300]	training's rmse: 18914.6	valid_1's rmse: 20554.7
# [400]	training's rmse: 18381.9	valid_1's rmse: 20403.7
# [500]	training's rmse: 17937.5	valid_1's rmse: 20337.2
# [600]	training's rmse: 17575.1	valid_1's rmse: 20265.1
# [700]	training's rmse: 17217	valid_1's rmse: 20219.3
# [800]	training's rmse: 16908.8	valid_1's rmse: 20182.1
# [900]	training's rmse: 16599.9	valid_1's rmse: 20132.9
# [1000]	training's rmse: 16303.9	valid_1's rmse: 20112.6
# Early stopping, best iteration is:
# [977]	training's rmse: 16377.6	valid_1's rmse: 20106.6

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20326.15565148381

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0    te_triple_Country__YearsCodingProf__ohe_DevTyp...  4.796870e+13
# 1           te_triple_Country__Employment__YearsCoding  2.893201e+13
# 2       te_triple_Country__YearsCodingProf__SalaryType  2.303977e+13
# 3                   te_triple_Country__Employment__Age  1.842757e+13
# 4       te_triple_Country__YearsCodingProf__MilitaryUS  1.601460e+13
# 5       te_triple_Country__Employment__YearsCodingProf  1.596051e+13
# 6                          te_Country__YearsCodingProf  1.388566e+13
# 7      te_triple_Country__CompanySize__YearsCodingProf  1.334823e+13
# 8    te_triple_Country__YearsCoding__ohe_DevType_St...  1.207057e+13
# 9    te_triple_YearsCodingProf__SalaryType__Currenc...  9.941284e+12
# 10         te_triple_Country__Age__ohe_DevType_Student  8.872077e+12
# 11   te_triple_Country__ohe_DevType_Engineering_man...  6.796631e+12
# 12   te_triple_Country__YearsCodingProf__ohe_Commun...  6.476823e+12
# 13           te_triple_Country__Employment__SalaryType  4.121191e+12
# 14   te_triple_Country__SalaryType__ohe_DevType_Stu...  4.115329e+12
# 15   te_triple_CompanySize__YearsCodingProf__Curren...  4.010248e+12
# 16          te_triple_Country__CareerSatisfaction__Age  3.997767e+12
# 17   te_triple_Country__YearsCodingProf__ohe_DevTyp...  3.859907e+12
# 18   te_triple_YearsCodingProf__Currency__Operating...  3.350928e+12
# 19     te_triple_YearsCodingProf__Currency__SalaryType  2.720727e+12
# 20          te_triple_Country__YearsCoding__SalaryType  2.429130e+12
# 21           te_triple_SalaryType__CurrencySymbol__Age  2.315663e+12
# 22   te_triple_Country__Employment__ohe_DevType_Eng...  2.311219e+12
# 23   te_triple_Country__YearsCodingProf__ohe_RaceEt...  2.112566e+12
# 24   te_triple_Country__YearsCodingProf__CareerSati...  2.098925e+12
# 25             te_triple_Country__YearsCodingProf__Age  1.925844e+12
# 26    te_triple_Employment__SalaryType__CurrencySymbol  1.783817e+12
# 27   te_triple_Country__YearsCodingProf__OperatingS...  1.712071e+12
# 28   te_triple_YearsCodingProf__CurrencySymbol__ohe...  1.681562e+12
# 29   te_triple_Country__Employment__ohe_DevType_Stu...  1.606755e+12
# 30   te_triple_Employment__YearsCodingProf__Currenc...  1.572985e+12
# 31   te_triple_Country__CompanySize__ohe_DevType_St...  1.443616e+12
# 32   te_triple_CompanySize__YearsCodingProf__Operat...  1.307941e+12
# 33    te_triple_CompanySize__YearsCodingProf__Currency  1.242139e+12
# 34                  te_triple_Country__SalaryType__Age  1.236358e+12
# 35     te_triple_Country__YearsCoding__OperatingSystem  1.149060e+12
# 36      te_triple_Country__Employment__OperatingSystem  1.109609e+12
# 37             te_triple_Country__OperatingSystem__Age  1.075469e+12
# 38   te_triple_YearsCodingProf__SalaryType__Operati...  8.984784e+11
# 39   te_triple_YearsCodingProf__CareerSatisfaction_...  8.881456e+11
# 40   te_triple_YearsCodingProf__CurrencySymbol__Ope...  8.314201e+11
# 41   te_triple_CompanySize__ohe_DevType_Engineering...  8.233450e+11
# 42           te_triple_Employment__CurrencySymbol__Age  8.024703e+11
# 43                 te_triple_Country__CompanySize__Age  7.632741e+11
# 44         te_triple_YearsCoding__Currency__SalaryType  7.593756e+11
# 45   te_triple_Country__Age__ohe_CommunicationTools...  7.427105e+11
# 46   te_triple_YearsCoding__SalaryType__CurrencySymbol  7.329041e+11
# 47   te_triple_Country__CareerSatisfaction__SalaryType  7.316082e+11
# 48   te_triple_YearsCodingProf__CareerSatisfaction_...  7.268414e+11
# 49         te_triple_Country__CompanySize__YearsCoding  6.878616e+11
# 50   te_triple_Employment__CompanySize__OperatingSy...  6.579832e+11
# 51   te_triple_YearsCoding__CurrencySymbol__Operati...  6.575480e+11
# 52   te_triple_Country__Employment__ohe_Communicati...  6.530994e+11
# 53   te_triple_CompanySize__OperatingSystem__ohe_De...  6.489790e+11
# 54   te_triple_YearsCodingProf__CareerSatisfaction_...  6.426947e+11
# 55   te_triple_CompanySize__CareerSatisfaction__ohe...  6.379299e+11
# 56                                     te_Country__Age  6.277110e+11
# 57   te_triple_CompanySize__OperatingSystem__ohe_Co...  6.074189e+11
# 58       te_triple_CareerSatisfaction__SalaryType__Age  6.055546e+11
# 59   te_triple_CompanySize__YearsCoding__CurrencySy...  5.911564e+11
# 60   te_triple_YearsCodingProf__OperatingSystem__Mi...  5.867758e+11
# 61   te_triple_YearsCoding__CareerSatisfaction__Ope...  5.753592e+11
# 62                 te_triple_Currency__SalaryType__Age  5.665005e+11
# 63         rel_agg_mean_NumberMonitors_AssessBenefits2  5.628766e+11
# 64    te_triple_YearsCoding__Currency__OperatingSystem  5.592754e+11
# 65              diff_agg_mean_Currency_AssessBenefits2  5.578550e+11
# 66   te_triple_CompanySize__YearsCodingProf__Salary...  5.319309e+11
# 67   te_triple_Employment__CareerSatisfaction__ohe_...  5.292650e+11
# 68           te_Employment__ohe_LanguageWorkedWith_PHP  5.138232e+11
# 69     te_triple_Country__CompanySize__OperatingSystem  5.030750e+11
# 70   te_FormalEducation__ohe_EducationTypes_Contrib...  5.000149e+11
# 71      te_FormalEducation__ohe_LanguageWorkedWith_PHP  4.961933e+11
# 72   te_triple_Employment__YearsCoding__CurrencySymbol  4.877379e+11
# 73   te_triple_YearsCodingProf__CareerSatisfaction_...  4.776070e+11
# 74   te_triple_Employment__Age__ohe_CommunicationTo...  4.760473e+11
# 75          te_triple_Employment__Currency__SalaryType  4.727018e+11
# 76   te_triple_YearsCoding__YearsCodingProf__Operat...  4.680529e+11
# 77   te_triple_Country__Age__ohe_DevType_Engineerin...  4.477560e+11
# 78   te_triple_CompanySize__CurrencySymbol__Operati...  4.408389e+11
# 79                   diff_agg_mean_Age_AssessBenefits2  4.374669e+11
# 80   te_triple_YearsCodingProf__CareerSatisfaction_...  4.345272e+11
# 81   te_triple_YearsCoding__CareerSatisfaction__ohe...  4.324050e+11
# 82                           ohe_LanguageWorkedWith_Go  4.304990e+11
# 83   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  4.299537e+11
# 84   te_triple_YearsCodingProf__SalaryType__ohe_Com...  3.921133e+11
# 85               te_CompanySize__ohe_Methodology_Agile  3.912590e+11
# 86   te_triple_Employment__OperatingSystem__ohe_Dev...  3.874699e+11
# 87   te_triple_YearsCoding__CurrencySymbol__ohe_Dev...  3.759751e+11
# 88   te_triple_YearsCodingProf__OperatingSystem__oh...  3.709602e+11
# 89   te_triple_Employment__CareerSatisfaction__Oper...  3.707278e+11
# 90                    rel_agg_mean_Age_AssessBenefits2  3.632667e+11
# 91   te_triple_Employment__ohe_DevType_Engineering_...  3.612194e+11
# 92   te_triple_Country__SalaryType__ohe_Communicati...  3.608986e+11
# 93              te_FormalEducation__CareerSatisfaction  3.478035e+11
# 94   te_triple_Employment__CareerSatisfaction__ohe_...  3.473421e+11
# 95   te_triple_SalaryType__CurrencySymbol__ohe_DevT...  3.408543e+11
# 96        diff_agg_mean_CurrencySymbol_AssessBenefits2  3.385091e+11
# 97   te_triple_CompanySize__CareerSatisfaction__ohe...  3.361315e+11
# 98   te_triple_CareerSatisfaction__ohe_DevType_Engi...  3.342508e+11
# 99      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  3.323062e+11
# 100  te_triple_YearsCodingProf__CareerSatisfaction_...  3.322180e+11
# 101  te_triple_Country__CompanySize__ohe_Communicat...  3.297211e+11
# 102                       ohe_DatabaseWorkedWith_Redis  3.269504e+11
# 103                     te_Employment__FormalEducation  3.239251e+11
# 104  te_triple_YearsCoding__CareerSatisfaction__Sal...  3.235146e+11
# 105  te_triple_Country__Employment__ohe_RaceEthnici...  3.229342e+11
# 106                             te_Country__Employment  3.175111e+11
# 107  te_triple_YearsCodingProf__OperatingSystem__oh...  3.167649e+11
# 108  te_triple_CompanySize__YearsCoding__CareerSati...  3.163177e+11
# 109      diff_agg_mean_FormalEducation_AssessBenefits2  3.150324e+11
# 110  te_triple_Employment__CompanySize__ohe_DevType...  3.141067e+11
# 111  te_triple_CompanySize__CareerSatisfaction__Sal...  3.126336e+11
# 112  te_triple_CompanySize__YearsCodingProf__Career...  3.117493e+11
# 113  te_triple_YearsCoding__CurrencySymbol__ohe_Com...  3.062299e+11
# 114  te_triple_CompanySize__YearsCoding__OperatingS...  3.055130e+11
# 115              diff_agg_mean_Country_AssessBenefits2  3.030372e+11
# 116  te_triple_Country__ohe_DevType_Student__ohe_Co...  3.020267e+11
# 117        rel_agg_mean_CurrencySymbol_AssessBenefits2  2.980039e+11
# 118  te_ohe_LanguageWorkedWith_PHP__ohe_Methodology...  2.971644e+11
# 119    te_triple_YearsCodingProf__Currency__MilitaryUS  2.936023e+11
# 120  te_triple_Employment__OperatingSystem__ohe_Com...  2.900864e+11
# 121              te_triple_Employment__SalaryType__Age  2.897204e+11
# 122               rel_agg_mean_Country_AssessBenefits2  2.881313e+11
# 123  te_FormalEducation__ohe_DevType_Engineering_ma...  2.870288e+11
# 124                               ohe_DevType_Designer  2.859654e+11
# 125       rel_agg_mean_FormalEducation_AssessBenefits2  2.814341e+11
# 126  te_triple_Employment__CareerSatisfaction__ohe_...  2.794461e+11
# 127  te_triple_CompanySize__YearsCodingProf__ohe_De...  2.733718e+11
# 128  te_triple_Employment__CurrencySymbol__Operatin...  2.699464e+11
# 129  te_triple_CompanySize__CurrencySymbol__ohe_Com...  2.635901e+11
# 130  te_triple_CompanySize__CareerSatisfaction__Ope...  2.565106e+11
# 131               ohe_DatabaseWorkedWith_Elasticsearch  2.548865e+11
# 132  te_triple_Employment__CompanySize__CareerSatis...  2.484360e+11
# 133            rel_agg_mean_SalaryType_AssessBenefits2  2.481558e+11
# 134  te_triple_Employment__CompanySize__ohe_DevType...  2.454939e+11
# 135                              JobContactPriorities1  2.453740e+11
# 136  te_triple_SalaryType__ohe_DevType_Student__ohe...  2.413428e+11
# 137              rel_agg_mean_Currency_AssessBenefits2  2.407600e+11
# 138                                        te_UpdateCV  2.394308e+11
# 139      te_triple_Country__Employment__CurrencySymbol  2.391809e+11
# 140        te_triple_CompanySize__OperatingSystem__Age  2.374546e+11
# 141                                      te_LastNewJob  2.354275e+11
# 142  te_triple_Employment__CurrencySymbol__ohe_DevT...  2.348199e+11
# 143  te_triple_Employment__SalaryType__ohe_DevType_...  2.336895e+11
# 144  te_triple_CompanySize__CareerSatisfaction__ohe...  2.325674e+11
# 145  te_triple_CurrencySymbol__OperatingSystem__ohe...  2.320735e+11
# 146  te_triple_YearsCodingProf__CareerSatisfaction_...  2.312347e+11
# 147  te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  2.282327e+11
# 148          diff_agg_mean_YearsCoding_AssessBenefits2  2.274840e+11
# 149  te_triple_Country__CareerSatisfaction__ohe_Com...  2.250561e+11
# 150          te_triple_Country__Employment__MilitaryUS  2.240496e+11
# 151             ohe_DatabaseWorkedWith_Amazon_Redshift  2.195901e+11
# 152     te_triple_YearsCodingProf__CurrencySymbol__Age  2.193662e+11
# 153            rel_agg_mean_MilitaryUS_AssessBenefits2  2.166505e+11
# 154  te_triple_YearsCodingProf__ohe_CommunicationTo...  2.166224e+11
# 155             te_triple_Country__CurrencySymbol__Age  2.155941e+11
# 156  te_triple_Country__Employment__CareerSatisfaction  2.146946e+11
# 157                    te_CompanySize__OperatingSystem  2.127038e+11
# 158  te_triple_Country__CurrencySymbol__ohe_DevType...  2.104984e+11
# 159  te_triple_CareerSatisfaction__OperatingSystem_...  2.094095e+11
# 160  te_triple_CompanySize__YearsCodingProf__ohe_De...  2.032823e+11
# 161                te_FormalEducation__OperatingSystem  2.032030e+11
# 162  te_triple_YearsCodingProf__Currency__ohe_DevTy...  2.010551e+11
# 163           diff_agg_mean_SalaryType_AssessBenefits2  1.989332e+11
# 164  te_triple_YearsCoding__CareerSatisfaction__ohe...  1.988284e+11
# 165                              te_HypotheticalTools2  1.972318e+11
# 166  te_triple_YearsCodingProf__CurrencySymbol__Mil...  1.955455e+11
# 167  te_triple_YearsCodingProf__OperatingSystem__oh...  1.906007e+11
# 168  te_triple_YearsCoding__YearsCodingProf__Career...  1.899750e+11
# 169     te_triple_CompanySize__CareerSatisfaction__Age  1.884441e+11
# 170   te_triple_Country__Currency__ohe_DevType_Student  1.883981e+11
# 171    te_triple_Employment__Currency__OperatingSystem  1.861497e+11
# 172     te_triple_Country__SalaryType__OperatingSystem  1.844086e+11
# 173                        te_Country__FormalEducation  1.833333e+11
# 174  te_triple_CareerSatisfaction__OperatingSystem_...  1.831309e+11
# 175  te_triple_YearsCodingProf__CareerSatisfaction_...  1.828362e+11
# 176                                        AssessJob10  1.810092e+11
# 177                    ohe_DevType_Front_end_developer  1.785091e+11
# 178                         ohe_LanguageWorkedWith_CSS  1.764855e+11
# 179       diff_agg_mean_NumberMonitors_AssessBenefits2  1.753621e+11
# 180  te_triple_Country__YearsCoding__CareerSatisfac...  1.746335e+11
# 181  te_ohe_EducationTypes_Contributed_to_open_sour...  1.742704e+11
# 182  te_triple_Employment__YearsCodingProf__Operati...  1.731963e+11
# 183  te_triple_CareerSatisfaction__ohe_DevType_Stud...  1.724198e+11
# 184           rel_agg_mean_CompanySize_AssessBenefits2  1.718512e+11
# 185         te_triple_YearsCodingProf__SalaryType__Age  1.718498e+11
# 186  te_triple_YearsCoding__OperatingSystem__ohe_Co...  1.716481e+11
# 187  diff_agg_mean_Employment_ohe_EducationTypes_Pa...  1.712403e+11
# 188          te_FormalEducation__ohe_Methodology_Agile  1.712123e+11
# 189  te_triple_YearsCodingProf__CareerSatisfaction_...  1.703677e+11
# 190        rel_agg_mean_UndergradMajor_AssessBenefits2  1.701924e+11
# 191  te_triple_Country__OperatingSystem__ohe_DevTyp...  1.690674e+11
# 192  te_triple_YearsCodingProf__SalaryType__MilitaryUS  1.687117e+11
# 193  diff_agg_mean_TimeFullyProductive_AssessBenefits2  1.643541e+11
# 194                         te_CompanySize__Dependents  1.638983e+11
# 195  te_CareerSatisfaction__ohe_EducationTypes_Cont...  1.635002e+11
# 196  te_triple_CompanySize__YearsCodingProf__ohe_Co...  1.629659e+11
# 197                       ohe_PlatformWorkedWith_Azure  1.622661e+11
# 198  te_triple_Employment__YearsCodingProf__CareerS...  1.618455e+11
# 199  te_triple_Employment__YearsCodingProf__ohe_Com...  1.575105e+11
# 200         te_triple_YearsCodingProf__Age__MilitaryUS  1.559185e+11
# 201  te_triple_YearsCoding__CareerSatisfaction__ohe...  1.553867e+11
# 202                     ohe_FrameworkWorkedWith_Hadoop  1.537263e+11
# 203  te_triple_CompanySize__YearsCodingProf__Milita...  1.534572e+11
# 204     te_triple_Employment__CompanySize__YearsCoding  1.516851e+11
# 205               te_Employment__ohe_Methodology_Agile  1.513340e+11
# 206  diff_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_E...  1.502241e+11
# 207  diff_agg_mean_ohe_RaceEthnicity_White_or_of_Eu...  1.501583e+11
# 208  te_triple_CareerSatisfaction__SalaryType__Curr...  1.497324e+11
# 209             ohe_DatabaseWorkedWith_Google_BigQuery  1.496165e+11
# 210  te_triple_Currency__OperatingSystem__ohe_DevTy...  1.487995e+11
# 211  te_triple_Employment__SalaryType__OperatingSystem  1.485628e+11
# 212      te_triple_Employment__YearsCoding__SalaryType  1.476582e+11
# 213                                JobEmailPriorities5  1.467085e+11
# 214  te_CompanySize__ohe_EducationTypes_Contributed...  1.465741e+11
# 215                 ohe_DevType_Database_administrator  1.465586e+11
# 216       te_triple_CompanySize__YearsCoding__Currency  1.456341e+11
# 217  te_triple_YearsCodingProf__CurrencySymbol__ohe...  1.455000e+11
# 218     te_triple_Employment__Age__ohe_DevType_Student  1.431404e+11
# 219            te_triple_Country__Currency__SalaryType  1.423920e+11
# 220  te_triple_CompanySize__SalaryType__CurrencySymbol  1.422461e+11
# 221                              JobContactPriorities4  1.404799e+11
# 222  te_triple_Employment__YearsCodingProf__MilitaryUS  1.399102e+11
# 223    te_triple_Employment__YearsCodingProf__Currency  1.393733e+11
# 224         te_triple_Country__CompanySize__SalaryType  1.391850e+11
# 225       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.385360e+11
# 226    te_triple_YearsCodingProf__OperatingSystem__Age  1.373393e+11
# 227     te_triple_CompanySize__YearsCoding__SalaryType  1.369274e+11
# 228  te_triple_CompanySize__OperatingSystem__ohe_De...  1.361563e+11
# 229        ohe_DevType_Educator_or_academic_researcher  1.360118e+11
# 230         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.355445e+11
# 231           ohe_Methodology_Extreme_programming__XP_  1.347107e+11
# 232  te_triple_CareerSatisfaction__OperatingSystem_...  1.340843e+11
# 233                         ohe_PlatformWorkedWith_AWS  1.331591e+11
# 234         te_triple_Country__Employment__CompanySize  1.331573e+11
# 235                      te_StackOverflowJobsRecommend  1.326155e+11
# 236     te_Employment__ohe_DevType_Engineering_manager  1.325814e+11
# 237           diff_agg_mean_MilitaryUS_AssessBenefits2  1.323825e+11
# 238  te_triple_CompanySize__YearsCoding__ohe_DevTyp...  1.323797e+11
# 239  te_triple_Employment__ohe_DevType_Engineering_...  1.323259e+11
# 240  te_triple_CareerSatisfaction__Age__ohe_Communi...  1.317584e+11
# 241  te_ohe_CommunicationTools_Confluence__ohe_Lang...  1.307476e+11
# 242   te_triple_CompanySize__Currency__OperatingSystem  1.298827e+11
# 243                te_triple_Employment__Currency__Age  1.293380e+11
# 244  te_triple_CompanySize__Currency__ohe_Communica...  1.279283e+11
# 245        te_triple_CompanySize__YearsCodingProf__Age  1.273800e+11
# 246           rel_agg_mean_YearsCoding_AssessBenefits2  1.270110e+11
# 247  agg_mean_HopeFiveYears_ohe_DevType_Engineering...  1.260860e+11
# 248                                 sum_answer_DevType  1.251585e+11
# 249  te_triple_Employment__YearsCoding__YearsCoding...  1.241841e+11
# 250   diff_agg_mean_CareerSatisfaction_AssessBenefits2  1.238503e+11
# 251  te_triple_YearsCoding__CareerSatisfaction__Cur...  1.224411e+11
# 252  te_triple_Employment__SalaryType__ohe_Communic...  1.224220e+11
# 253  rel_agg_mean_ohe_LanguageWorkedWith_PHP_ohe_Ed...  1.223787e+11
# 254                                te_EducationParents  1.223771e+11
# 255                 te_FormalEducation__CurrencySymbol  1.222855e+11
# 256  te_triple_Employment__YearsCodingProf__SalaryType  1.218701e+11
# 257       te_CareerSatisfaction__ohe_Methodology_Agile  1.218694e+11
# 258        te_triple_YearsCoding__OperatingSystem__Age  1.216040e+11
# 259  te_triple_Employment__CareerSatisfaction__Sala...  1.212426e+11
# 260      te_triple_Country__SalaryType__CurrencySymbol  1.211030e+11
# 261     te_triple_YearsCoding__CareerSatisfaction__Age  1.208165e+11
# 262       diff_agg_mean_UndergradMajor_AssessBenefits2  1.206543e+11
# 263          te_YearsCodingProf__ohe_Methodology_Agile  1.198247e+11
# 264  te_triple_Country__CareerSatisfaction__Operati...  1.196584e+11
# 265        diff_agg_mean_Country_ohe_Methodology_Agile  1.196364e+11
# 266       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.194730e+11
# 267             te_triple_YearsCoding__SalaryType__Age  1.193879e+11
# 268  te_triple_CompanySize__YearsCoding__ohe_Commun...  1.188871e+11
# 269  te_triple_YearsCoding__OperatingSystem__Milita...  1.186650e+11
# 270        te_triple_CompanySize__Currency__SalaryType  1.181872e+11
# 271                             sum_answer_Methodology  1.179385e+11
# 272  te_triple_YearsCoding__SalaryType__OperatingSy...  1.179219e+11
# 273  te_triple_CompanySize__SalaryType__OperatingSy...  1.177621e+11
# 274  te_triple_YearsCoding__YearsCodingProf__ohe_Ra...  1.166493e+11
# 275  te_triple_CareerSatisfaction__Currency__Salary...  1.164945e+11
# 276        te_triple_Employment__YearsCoding__Currency  1.160091e+11
# 277          diff_agg_mean_CompanySize_AssessBenefits2  1.160086e+11
# 278                te_triple_Country__YearsCoding__Age  1.153528e+11
# 279  te_triple_Employment__CareerSatisfaction__ohe_...  1.150567e+11
# 280                   ohe_DevType_System_administrator  1.144372e+11
# 281                      ohe_LanguageDesireNextYear_F_  1.132047e+11
# 282                       ohe_LanguageWorkedWith_Scala  1.131682e+11
# 283  te_triple_CareerSatisfaction__CurrencySymbol__...  1.126361e+11
# 284  te_triple_CompanySize__YearsCoding__YearsCodin...  1.125497e+11
# 285  te_ohe_EducationTypes_Contributed_to_open_sour...  1.118409e+11
# 286              te_triple_SalaryType__Age__MilitaryUS  1.109827e+11
# 287  te_triple_YearsCodingProf__CareerSatisfaction_...  1.108631e+11
# 288  rel_agg_mean_ohe_DevType_Engineering_manager_o...  1.107035e+11
# 289  te_triple_YearsCodingProf__SalaryType__ohe_Rac...  1.106508e+11
# 290                      sum_answer_DatabaseWorkedWith  1.098965e+11
# 291                                        te_WakeTime  1.096474e+11
# 292    te_triple_Country__YearsCoding__YearsCodingProf  1.095791e+11
# 293  ohe_AdsActions_Paid_to_access_a_website_advert...  1.092459e+11
# 294  te_triple_YearsCoding__YearsCodingProf__Salary...  1.089641e+11
# 295     te_triple_Country__YearsCoding__CurrencySymbol  1.088583e+11
# 296  diff_agg_mean_ohe_DevType_Engineering_manager_...  1.083382e+11
# 297  te_triple_SalaryType__CurrencySymbol__ohe_Comm...  1.082177e+11
# 298             agg_mean_HopeFiveYears_AssessBenefits2  1.077120e+11
# 299   rel_agg_mean_TimeFullyProductive_AssessBenefits2  1.077084e+11

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 65236.19139976,  92697.12739522,  87430.675776  , ...,
#         92311.81348641,  80452.43599129, 119939.15244922])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
sub_df.to_csv("../predict/014_triple_te_20314.csv", index=False)
