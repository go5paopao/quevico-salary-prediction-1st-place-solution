# %% [markdown]
# ## Prepare and read data

# %%
import gc
import itertools
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import lightgbm as lgb

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import TruncatedSVD

# %%
pd.set_option("max_columns", 300)
pd.set_option("max_rows", 500)

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")

# %%
def feature_cache(reset=False):
    def _feature_cache(func):
        def wrapper(train_df, test_df, *args):
            func_name = func.__name__
            train_feat_path = Path("../feature") / f"train_{func_name}.pkl"
            test_feat_path = Path("../feature") / f"test_{func_name}.pkl"
            # if feature exists, load feature
            if train_feat_path.exists() and test_feat_path.exists() and not reset:
                train_feats = pd.read_pickle(train_feat_path).reset_index(drop=True)
                test_feats = pd.read_pickle(test_feat_path).reset_index(drop=True)
                train_df = pd.concat([train_df, train_feats], axis=1)
                test_df = pd.concat([test_df, test_feats], axis=1)
            # if not exists, make feature and save as pickle
            else:
                before_cols = train_df.columns.tolist()
                train_df, test_df = func(train_df, test_df, *args)
                after_cols = train_df.columns.tolist()
                new_cols = [c for c in after_cols if c not in before_cols]
                train_feats = train_df[new_cols]
                test_feats = test_df[new_cols]
                train_feats.to_pickle(train_feat_path)
                test_feats.to_pickle(test_feat_path)            
            return train_df, test_df
        return wrapper

    return _feature_cache

# %% [markdown]
# ## Feature Engineering

# %%
def get_multi_cat_cols(train_df):
    tmp = train_df.iloc[:1000]
    multi_cols = []
    for c in train_df.columns:
        sep_num = tmp[c].astype(str).fillna("").str.contains(";").sum()
        if sep_num > 10:
            multi_cols.append(c)
    return multi_cols

# %%
original_cols = train_df.columns.tolist()

# %%
multi_cat_cols = get_multi_cat_cols(train_df)

# %%
nume_cols = [
    c for c in list(np.setdiff1d(original_cols, multi_cat_cols))
    if c not in ["Salary", "No"] and "float" in train_df[c].dtype.name
]

# %%
cat_cols = [c for c in train_df.columns if c not in multi_cat_cols + nume_cols + ["Salary", "No"]]

# %%
len(original_cols), len(cat_cols), len(nume_cols), len(multi_cat_cols)
# Out:
# (128, 65, 40, 21)

# %% [markdown]
# ### Multi-category encoding

# %%
for c in tqdm(multi_cat_cols):
    binarizer = MultiLabelBinarizer()
    train_multi_srs = train_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    test_multi_srs = test_df[c].map(lambda x: x.split(";") if x is not np.nan else [])
    train_arr = binarizer.fit_transform(train_multi_srs)
    test_arr = binarizer.transform(test_multi_srs)
    feat_cols = [f"ohe_{c}_{val}" for val in binarizer.classes_]
    train_feat_df = pd.DataFrame(train_arr, columns=feat_cols, dtype=np.int8)
    test_feat_df = pd.DataFrame(test_arr, columns=feat_cols, dtype=np.int8)
    all_feat_df = pd.concat([train_feat_df, test_feat_df], axis=0, ignore_index=True)
    train_feat_df[f"sum_answer_{c}"] = (train_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    test_feat_df[f"sum_answer_{c}"] = (test_df[c].str.count(";") + 1).fillna(-1).astype(np.int8)
    train_df = pd.concat([train_df, train_feat_df], axis=1)
    test_df = pd.concat([test_df, test_feat_df], axis=1)
    # SVD
    svd = TruncatedSVD(n_components=2)
    all_svd_feats = pd.DataFrame(svd.fit_transform(all_feat_df), columns=[f"svd_{c}_{ix}" for ix in range(2)])
    train_df = pd.concat([train_df, all_svd_feats.iloc[:len(train_df)]], axis=1)
    test_df = pd.concat([test_df, all_svd_feats.iloc[len(train_df):].reset_index(drop=True)], axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %% [markdown]
# ### Simple-category encoding

# %%
for c in cat_cols:
    train_df[c], uniques = pd.factorize(train_df[c], sort=True)
    test_df[c] = uniques.get_indexer(test_df[c])

# %% [markdown]
# ### Reduce data memory

# %%
for c in nume_cols:
    if train_df[c].nunique() > 1000:
        train_df[c] = train_df[c].astype(np.float32)
        test_df[c] = test_df[c].astype(np.float32)
    else:
        train_df[c] = train_df[c].astype(np.float16)
        test_df[c] = test_df[c].astype(np.float16)

# %%
for c in cat_cols:
    if train_df[c].max() > 32767:
        train_df[c] = train_df[c].astype(np.int32)
        test_df[c] = test_df[c].astype(np.int32)
    else:
        train_df[c] = train_df[c].astype(np.int16)
        test_df[c] = test_df[c].astype(np.int16)

# %%
train_df.shape, test_df.shape
# Out:
# ((33857, 507), (11259, 506))

# %% [markdown]
# ### Change Category Name

# %%
train_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in train_df.columns]
test_df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in test_df.columns]

# %% [markdown]
# ### Aggregation

# %%
def get_importance_cols(use_num=50):
    # basicなモデルのimportanceを読み込み
    importance_df = pd.read_csv("../data/importance/003_importance.csv")
    imp_feats = importance_df["feature"].iloc[:use_num].tolist()
    return imp_feats

# %%
imp_feats = get_importance_cols(use_num=50)
imp_cat_cols = [c for c in imp_feats if c in cat_cols or c[:4] == "ohe_"]
imp_nume_cols = [c for c in imp_feats if c in nume_cols or c[:4] == "ohe_"]

# %%
len(imp_cat_cols), len(imp_nume_cols)
# Out:
# (32, 15)

# %%
all_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
for cat_col in tqdm(imp_cat_cols):
    for nume_col in imp_nume_cols:
        # one-hotは同じカテゴリの場合がある
        if cat_col == nume_col:
            continue
        all_df[f"agg_mean_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("mean").astype(np.float32)
        all_df[f"agg_std_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("std").astype(np.float32)
        all_df[f"agg_max_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("max").astype(np.float32)
        all_df[f"agg_min_{cat_col}_{nume_col}"] = \
            all_df.groupby(cat_col)[nume_col].transform("min").astype(np.float32)
        all_df[f"diff_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] - all_df[f"agg_mean_{cat_col}_{nume_col}"]
        all_df[f"rel_agg_mean_{cat_col}_{nume_col}"] = \
            all_df[nume_col] / (1 + all_df[f"agg_mean_{cat_col}_{nume_col}"])
train_df = all_df.iloc[:len(train_df)].reset_index(drop=True)
test_df = all_df.iloc[len(train_df):].reset_index(drop=True)
del all_df
gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# 58

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]

# %%
folds = KFold(n_splits=5, random_state=2020, shuffle=True)
fold_idx_list = [(trn_idx, val_idx) for trn_idx, val_idx in folds.split(train_df, train_df["Salary"])]

# %% [markdown]
# ### Target Encoding

# %%
@feature_cache(reset=False)
def target_encoding(train_df, test_df):
    te_cols = [c for c in train_df.columns if c in cat_cols]
    for c in tqdm(te_cols):
        new_col = "te_" + c
        train_df[new_col] = 0
        test_df[new_col] = 0
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby(c)["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, c].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, c].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
    return train_df, test_df

# %%
train_df, test_df = target_encoding(train_df, test_df)

# %%
@feature_cache(reset=False)
def multiple_target_encoding(train_df, test_df):
     # multiple target encoding
    multi_te_cols = [c for c in train_df.columns if c in cat_cols or c[:4] == "ohe_"]
    imp_feats = get_importance_cols(use_num=30)
    multi_te_cols = [c for c in multi_te_cols if c in imp_feats]
    combi_multi_te_cols = list(itertools.combinations(multi_te_cols, 2))   

    for col_a, col_b in tqdm(combi_multi_te_cols):
        new_col = "te_" + col_a + "__" + col_b
        train_df[new_col] = 0
        test_df[new_col] = 0
        train_df["tmp"] = train_df[col_a].fillna("").astype(str) + train_df[col_b].fillna("").astype(str)
        test_df["tmp"] = test_df[col_a].fillna("").astype(str) + test_df[col_b].fillna("").astype(str)
        for trn_idx, val_idx in fold_idx_list:
            mean_val = train_df.loc[trn_idx].groupby("tmp")["Salary"].mean().astype(np.float32)
            train_df.loc[val_idx, new_col] = train_df.loc[val_idx, "tmp"].map(mean_val)
            test_df.loc[:, new_col] += test_df.loc[:, "tmp"].map(mean_val) / len(fold_idx_list)
        train_df[new_col] = train_df[new_col].astype(np.float32)
        test_df[new_col] = test_df[new_col].astype(np.float32)
        del train_df["tmp"], test_df["tmp"]
        gc.collect()
    return train_df, test_df

# %%
train_df, test_df = multiple_target_encoding(train_df, test_df)

# %%
use_cols = [c for c in train_df.columns if c not in multi_cat_cols + ["Salary", "No"]]
print(len(use_cols))
# Out:
# 3573

# %% [markdown]
# ## Training

# %%
lgb_params = {
            'objective': 'tweedie',
            "tweedie_variance_power": 1.05,
            "metric": "rmse",
            "verbosity": -1,
            "boosting": "gbdt",
            'learning_rate': 0.05,
            'num_leaves': 64,
            'min_data_in_leaf': 80, 
            'max_depth': 4,
            "bagging_freq": 5,
            "bagging_fraction": 0.8,
            "lambda_l1": 0.5,
            "lambda_l2": 0.5,
            "feature_fraction": 0.1,
            "seed": 2020,
            "num_threads": -1,
            "max_bins": 30
}

# %%
importances = pd.DataFrame()
oof_preds = np.zeros(len(train_df))
models = []

for fold_i, (trn_idx, val_idx) in enumerate(fold_idx_list):
    print(f"Fold {fold_i+1}")
    train_dataset = lgb.Dataset(
        train_df.loc[trn_idx, use_cols],
        label = train_df.loc[trn_idx, "Salary"]
    )
    valid_dataset = lgb.Dataset(
        train_df.loc[val_idx, use_cols],
        label = train_df.loc[val_idx, "Salary"]
    )
    model = lgb.train(
                lgb_params,
                train_dataset,
                3000,
                valid_sets = [train_dataset, valid_dataset],
                verbose_eval=100,
                early_stopping_rounds = 100,
                #feval = eval_f1,
                #callbacks = [log_callback],
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = use_cols
    imp_df['gain'] = model.feature_importance(importance_type="gain")
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_idx] = model.predict(train_df.loc[val_idx, use_cols])
    models.append(model)
# Out:
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20960.6	valid_1's rmse: 21690.4
# [200]	training's rmse: 19771	valid_1's rmse: 21074.8
# [300]	training's rmse: 19137.6	valid_1's rmse: 20841.8
# [400]	training's rmse: 18665.4	valid_1's rmse: 20717.9
# [500]	training's rmse: 18240.5	valid_1's rmse: 20630.1
# [600]	training's rmse: 17863.3	valid_1's rmse: 20597.4
# [700]	training's rmse: 17545	valid_1's rmse: 20563.8
# [800]	training's rmse: 17199.6	valid_1's rmse: 20525.9
# [900]	training's rmse: 16886.8	valid_1's rmse: 20508
# [1000]	training's rmse: 16600.4	valid_1's rmse: 20479.4
# [1100]	training's rmse: 16340.1	valid_1's rmse: 20460.6
# [1200]	training's rmse: 16071.5	valid_1's rmse: 20450.3
# [1300]	training's rmse: 15830.6	valid_1's rmse: 20433.2
# [1400]	training's rmse: 15590.4	valid_1's rmse: 20406.2
# [1500]	training's rmse: 15322.9	valid_1's rmse: 20408.6
# Early stopping, best iteration is:
# [1402]	training's rmse: 15584.9	valid_1's rmse: 20403.6
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20920.4	valid_1's rmse: 21751.4
# [200]	training's rmse: 19763.9	valid_1's rmse: 20993.9
# [300]	training's rmse: 19138.6	valid_1's rmse: 20703.8
# [400]	training's rmse: 18677.9	valid_1's rmse: 20548.5
# [500]	training's rmse: 18276.4	valid_1's rmse: 20437.2
# [600]	training's rmse: 17923.7	valid_1's rmse: 20372.3
# [700]	training's rmse: 17597.6	valid_1's rmse: 20307.5
# [800]	training's rmse: 17278.7	valid_1's rmse: 20262.1
# [900]	training's rmse: 17005	valid_1's rmse: 20222.4
# [1000]	training's rmse: 16717.1	valid_1's rmse: 20198.7
# [1100]	training's rmse: 16431.1	valid_1's rmse: 20177.8
# [1200]	training's rmse: 16153.4	valid_1's rmse: 20136.4
# [1300]	training's rmse: 15905.8	valid_1's rmse: 20119.3
# [1400]	training's rmse: 15671.5	valid_1's rmse: 20105
# [1500]	training's rmse: 15441.1	valid_1's rmse: 20104
# Early stopping, best iteration is:
# [1453]	training's rmse: 15542.1	valid_1's rmse: 20097.6
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20951.6	valid_1's rmse: 21604.6
# [200]	training's rmse: 19772.8	valid_1's rmse: 20997.3
# [300]	training's rmse: 19139.1	valid_1's rmse: 20822.2
# [400]	training's rmse: 18685.7	valid_1's rmse: 20712.9
# [500]	training's rmse: 18323.3	valid_1's rmse: 20643.5
# [600]	training's rmse: 17947.5	valid_1's rmse: 20594.5
# [700]	training's rmse: 17623.7	valid_1's rmse: 20564.2
# [800]	training's rmse: 17297.7	valid_1's rmse: 20539.8
# [900]	training's rmse: 16979.4	valid_1's rmse: 20503.6
# [1000]	training's rmse: 16697.9	valid_1's rmse: 20494.8
# [1100]	training's rmse: 16458.1	valid_1's rmse: 20486.6
# [1200]	training's rmse: 16181.6	valid_1's rmse: 20475.8
# [1300]	training's rmse: 15918.8	valid_1's rmse: 20464
# Early stopping, best iteration is:
# [1290]	training's rmse: 15941.5	valid_1's rmse: 20459.3
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20925.7	valid_1's rmse: 21637.1
# [200]	training's rmse: 19755.6	valid_1's rmse: 21022.3
# [300]	training's rmse: 19159.5	valid_1's rmse: 20801.5
# [400]	training's rmse: 18699.7	valid_1's rmse: 20674.4
# [500]	training's rmse: 18310.7	valid_1's rmse: 20584
# [600]	training's rmse: 17966.5	valid_1's rmse: 20516.3
# [700]	training's rmse: 17645.5	valid_1's rmse: 20442.5
# [800]	training's rmse: 17311.6	valid_1's rmse: 20386.8
# [900]	training's rmse: 16979.9	valid_1's rmse: 20325.3
# [1000]	training's rmse: 16706.4	valid_1's rmse: 20311.6
# [1100]	training's rmse: 16396.1	valid_1's rmse: 20278.1
# [1200]	training's rmse: 16135	valid_1's rmse: 20280.1
# Early stopping, best iteration is:
# [1105]	training's rmse: 16378.8	valid_1's rmse: 20276.7
# Fold 5
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 20995.8	valid_1's rmse: 21482.1
# [200]	training's rmse: 19836.3	valid_1's rmse: 20728.8
# [300]	training's rmse: 19207.6	valid_1's rmse: 20472.8
# [400]	training's rmse: 18747.4	valid_1's rmse: 20312.4
# [500]	training's rmse: 18352	valid_1's rmse: 20216.3
# [600]	training's rmse: 17996.9	valid_1's rmse: 20139.5
# [700]	training's rmse: 17675	valid_1's rmse: 20072.7
# [800]	training's rmse: 17386.1	valid_1's rmse: 20050.6
# [900]	training's rmse: 17081.3	valid_1's rmse: 20014.8
# [1000]	training's rmse: 16783.9	valid_1's rmse: 19977.8
# [1100]	training's rmse: 16514.2	valid_1's rmse: 19966.2
# [1200]	training's rmse: 16253.7	valid_1's rmse: 19926.8
# [1300]	training's rmse: 16025.9	valid_1's rmse: 19942.6
# Early stopping, best iteration is:
# [1231]	training's rmse: 16187.4	valid_1's rmse: 19924

# %%
oof_score = np.sqrt(mean_squared_error(train_df["Salary"], oof_preds))
oof_score
# Out:
# 20233.230939728062

# %%
importances.groupby("feature")["gain"].mean().sort_values(ascending=False).reset_index().iloc[:300]
# Out:
#                                                feature          gain
# 0                          te_Country__YearsCodingProf  3.540792e+08
# 1                      te_Country__ohe_DevType_Student  3.509223e+08
# 2               te_Country__ohe_LanguageWorkedWith_PHP  2.218623e+08
# 3                                      te_Country__Age  2.058722e+08
# 4                               te_Country__Dependents  1.858720e+08
# 5                               te_Country__Employment  1.274744e+08
# 6                       te_YearsCodingProf__MilitaryUS  1.150568e+08
# 7                              te_Country__YearsCoding  1.134862e+08
# 8                   te_YearsCodingProf__CurrencySymbol  1.030893e+08
# 9                       te_YearsCodingProf__SalaryType  8.001464e+07
# 10               te_CareerSatisfaction__CurrencySymbol  7.498982e+07
# 11   te_YearsCodingProf__ohe_RaceEthnicity_White_or...  7.384318e+07
# 12                          te_Country__CurrencySymbol  6.793280e+07
# 13   te_Country__ohe_EducationTypes_Contributed_to_...  6.156767e+07
# 14                              te_Country__SalaryType  6.060101e+07
# 15                  te_SalaryType__ohe_DevType_Student  5.525041e+07
# 16                      te_Country__CareerSatisfaction  5.228920e+07
# 17                        te_YearsCodingProf__Currency  5.216876e+07
# 18                         te_Country__OperatingSystem  4.655411e+07
# 19                            te_YearsCoding__Currency  3.751241e+07
# 20                       te_Employment__CurrencySymbol  3.722075e+07
# 21                           te_Employment__SalaryType  3.603742e+07
# 22                     te_CompanySize__YearsCodingProf  3.073059e+07
# 23                 te_YearsCodingProf__OperatingSystem  3.068128e+07
# 24                   te_Country__ohe_Methodology_Agile  2.959692e+07
# 25   agg_mean_YearsCodingProf_ohe_CommunicationTool...  2.826937e+07
# 26                             te_Country__CompanySize  2.738281e+07
# 27   agg_mean_Country_ohe_EducationTypes_Contribute...  2.640592e+07
# 28              te_CurrencySymbol__ohe_DevType_Student  2.441195e+07
# 29                    te_Currency__ohe_DevType_Student  2.028983e+07
# 30   agg_mean_YearsCodingProf_ohe_EducationTypes_Co...  1.915563e+07
# 31                                  te_Employment__Age  1.817505e+07
# 32                         te_Country__FormalEducation  1.801928e+07
# 33   agg_std_Country_ohe_CommunicationTools_Confluence  1.769501e+07
# 34   te_YearsCodingProf__ohe_EducationTypes_Contrib...  1.707504e+07
# 35             te_YearsCodingProf__ohe_DevType_Student  1.554402e+07
# 36                      te_Employment__YearsCodingProf  1.535923e+07
# 37                      te_YearsCoding__CurrencySymbol  1.461978e+07
# 38   te_YearsCodingProf__ohe_CommunicationTools_Con...  1.345679e+07
# 39                     te_YearsCoding__OperatingSystem  1.324209e+07
# 40                 te_FormalEducation__YearsCodingProf  1.313036e+07
# 41                     te_YearsCoding__YearsCodingProf  1.309600e+07
# 42                              te_CurrencySymbol__Age  1.290428e+07
# 43      te_YearsCodingProf__ohe_LanguageWorkedWith_PHP  1.162979e+07
# 44                       te_SalaryType__CurrencySymbol  1.124172e+07
# 45               te_CompanySize__ohe_Methodology_Agile  1.039237e+07
# 46              te_YearsCodingProf__CareerSatisfaction  1.026231e+07
# 47                     te_CompanySize__OperatingSystem  9.722707e+06
# 48                  te_CurrencySymbol__OperatingSystem  9.181713e+06
# 49   te_CurrencySymbol__ohe_EducationTypes_Contribu...  8.760575e+06
# 50   te_CompanySize__ohe_CommunicationTools_Confluence  8.760166e+06
# 51                           te_Employment__MilitaryUS  8.634636e+06
# 52                                       te_LastNewJob  8.481808e+06
# 53                       te_CurrencySymbol__MilitaryUS  8.458702e+06
# 54                      te_CompanySize__CurrencySymbol  8.080550e+06
# 55                         te_CompanySize__YearsCoding  7.855290e+06
# 56                  te_CompanySize__CareerSatisfaction  7.657126e+06
# 57                      te_Employment__FormalEducation  7.654747e+06
# 58                                 te_CompanySize__Age  7.611845e+06
# 59    diff_agg_mean_CurrencySymbol_ohe_DevType_Student  7.542085e+06
# 60                                 te_YearsCoding__Age  7.241828e+06
# 61                            svd_CommunicationTools_0  7.170005e+06
# 62                             te_Employment__Currency  7.149266e+06
# 63                  te_Employment__ohe_DevType_Student  6.752626e+06
# 64            te_CurrencySymbol__ohe_Methodology_Agile  6.721503e+06
# 65   te_CurrencySymbol__ohe_CommunicationTools_Conf...  6.589301e+06
# 66                         agg_mean_Country_AssessJob8  6.532977e+06
# 67         rel_agg_mean_SalaryType_ohe_DevType_Student  6.437758e+06
# 68       te_CurrencySymbol__ohe_LanguageWorkedWith_PHP  6.417873e+06
# 69     agg_mean_Employment_ohe_CommunicationTools_Jira  6.375102e+06
# 70   diff_agg_mean_OperatingSystem_ohe_LanguageWork...  6.354038e+06
# 71                             te_YearsCodingProf__Age  6.162518e+06
# 72                          te_Employment__CompanySize  6.099007e+06
# 73      te_Employment__ohe_DevType_Engineering_manager  6.048272e+06
# 74                 agg_mean_Employment_AssessBenefits2  5.991274e+06
# 75                                  te_SalaryType__Age  5.921543e+06
# 76   te_CareerSatisfaction__ohe_CommunicationTools_...  5.660691e+06
# 77                 te_YearsCoding__ohe_DevType_Student  5.660588e+06
# 78           te_YearsCodingProf__ohe_Methodology_Agile  5.604114e+06
# 79   te_CareerSatisfaction__ohe_LanguageWorkedWith_PHP  5.567162e+06
# 80   te_CareerSatisfaction__ohe_DevType_Engineering...  5.561967e+06
# 81                      te_Employment__OperatingSystem  5.440150e+06
# 82               te_YearsCoding__ohe_Methodology_Agile  5.399629e+06
# 83              diff_agg_mean_Currency_AssessBenefits2  4.645380e+06
# 84   te_ohe_DevType_Engineering_manager__ohe_DevTyp...  4.460783e+06
# 85                          te_YearsCoding__MilitaryUS  4.439344e+06
# 86   te_FormalEducation__ohe_DevType_Engineering_ma...  4.419102e+06
# 87           te_Employment__ohe_LanguageWorkedWith_PHP  4.354176e+06
# 88                          te_Employment__YearsCoding  4.343015e+06
# 89                te_Employment__ohe_Methodology_Agile  4.325679e+06
# 90    te_SalaryType__ohe_CommunicationTools_Confluence  4.242635e+06
# 91              agg_mean_Country_ohe_Methodology_Agile  4.241214e+06
# 92                rel_agg_mean_Country_AssessBenefits2  4.222243e+06
# 93                                te_Country__Currency  4.197580e+06
# 94   diff_agg_mean_CompanySize_ohe_DevType_Engineer...  4.196505e+06
# 95    te_Employment__ohe_CommunicationTools_Confluence  4.193827e+06
# 96   te_CurrencySymbol__ohe_RaceEthnicity_White_or_...  4.033367e+06
# 97                        te_Currency__OperatingSystem  3.949838e+06
# 98                             te_Currency__SalaryType  3.693676e+06
# 99                         te_Age__ohe_DevType_Student  3.654835e+06
# 100             te_CareerSatisfaction__OperatingSystem  3.648362e+06
# 101    te_CompanySize__ohe_DevType_Engineering_manager  3.625293e+06
# 102                     te_FormalEducation__SalaryType  3.564933e+06
# 103                            te_FormalEducation__Age  3.553456e+06
# 104                 te_YearsCoding__CareerSatisfaction  3.477913e+06
# 105                         te_CareerSatisfaction__Age  3.470890e+06
# 106                           svd_LanguageWorkedWith_1  3.400556e+06
# 107  te_OperatingSystem__ohe_DevType_Engineering_ma...  3.400185e+06
# 108                            te_OperatingSystem__Age  3.366290e+06
# 109                      te_Age__ohe_Methodology_Agile  3.348026e+06
# 110                 te_FormalEducation__CurrencySymbol  3.300330e+06
# 111                          te_Employment__Dependents  3.259236e+06
# 112  diff_agg_mean_YearsCodingProf_ohe_EducationTyp...  3.228877e+06
# 113                te_FormalEducation__OperatingSystem  3.192547e+06
# 114  diff_agg_mean_Employment_ohe_LanguageWorkedWit...  3.188092e+06
# 115  agg_std_YearsCodingProf_ohe_EducationTypes_Con...  3.172874e+06
# 116                         te_CompanySize__SalaryType  3.156511e+06
# 117                         te_CompanySize__Dependents  3.141188e+06
# 118  te_CompanySize__ohe_EducationTypes_Contributed...  3.120271e+06
# 119  te_FormalEducation__ohe_EducationTypes_Contrib...  3.106069e+06
# 120     agg_std_Country_ohe_LanguageDesireNextYear_PHP  3.104454e+06
# 121                  te_Employment__CareerSatisfaction  3.019545e+06
# 122               te_SalaryType__ohe_Methodology_Agile  2.991328e+06
# 123                       svd_DatabaseDesireNextYear_1  2.982157e+06
# 124                     te_YearsCodingProf__Dependents  2.980205e+06
# 125  te_Country__ohe_RaceEthnicity_White_or_of_Euro...  2.954864e+06
# 126       agg_mean_YearsCodingProf_ohe_DevType_Student  2.874109e+06
# 127                         te_YearsCoding__SalaryType  2.811357e+06
# 128          te_FormalEducation__ohe_Methodology_Agile  2.804938e+06
# 129          diff_agg_mean_CompanySize_AssessBenefits2  2.802959e+06
# 130                     te_SalaryType__OperatingSystem  2.785671e+06
# 131                           te_CompanySize__Currency  2.777982e+06
# 132          te_Age__ohe_CommunicationTools_Confluence  2.755138e+06
# 133  te_Age__ohe_EducationTypes_Contributed_to_open...  2.739121e+06
# 134                 te_Currency__ohe_Methodology_Agile  2.731280e+06
# 135         te_CompanySize__ohe_LanguageWorkedWith_PHP  2.711009e+06
# 136        rel_agg_mean_NumberMonitors_AssessBenefits2  2.669862e+06
# 137                  te_CareerSatisfaction__SalaryType  2.664939e+06
# 138                                  svd_Methodology_0  2.620476e+06
# 139         te_YearsCoding__ohe_LanguageWorkedWith_PHP  2.607065e+06
# 140  agg_mean_Employment_ohe_CommunicationTools_Con...  2.551001e+06
# 141  agg_mean_YearsCodingProf_ohe_LanguageDesireNex...  2.533538e+06
# 142              rel_agg_mean_Currency_AssessBenefits2  2.516056e+06
# 143                te_CompanySize__ohe_DevType_Student  2.473849e+06
# 144     te_FormalEducation__ohe_LanguageWorkedWith_PHP  2.470205e+06
# 145                      te_CurrencySymbol__Dependents  2.444361e+06
# 146        te_Country__ohe_DevType_Engineering_manager  2.390195e+06
# 147                       te_FormalEducation__Currency  2.339131e+06
# 148        rel_agg_mean_CurrencySymbol_AssessBenefits2  2.327860e+06
# 149                    te_FormalEducation__CompanySize  2.313341e+06
# 150                               ohe_DevType_Designer  2.312786e+06
# 151  agg_std_Employment_ohe_ErgonomicDevices_Standi...  2.294546e+06
# 152                          ohe_LanguageWorkedWith_Go  2.257310e+06
# 153                                   te_Currency__Age  2.255742e+06
# 154                                      te_Employment  2.249115e+06
# 155                                JobEmailPriorities5  2.215343e+06
# 156  te_OperatingSystem__ohe_CommunicationTools_Con...  2.205418e+06
# 157      te_Country__ohe_CommunicationTools_Confluence  2.199399e+06
# 158                                        te_UpdateCV  2.190490e+06
# 159       diff_agg_mean_NumberMonitors_AssessBenefits2  2.188735e+06
# 160                               svd_VersionControl_1  2.185450e+06
# 161                              JobContactPriorities1  2.169844e+06
# 162       te_CareerSatisfaction__ohe_Methodology_Agile  2.164548e+06
# 163          te_SalaryType__ohe_LanguageWorkedWith_PHP  2.105556e+06
# 164  agg_std_SalaryType_ohe_CommunicationTools_Conf...  2.029106e+06
# 165  te_Employment__ohe_EducationTypes_Contributed_...  2.023602e+06
# 166            rel_agg_mean_SalaryType_AssessBenefits2  1.992441e+06
# 167  te_YearsCoding__ohe_CommunicationTools_Confluence  1.989070e+06
# 168                           svd_DatabaseWorkedWith_1  1.951818e+06
# 169          agg_mean_Employment_ohe_Methodology_Agile  1.948636e+06
# 170                              te_HypotheticalTools2  1.930188e+06
# 171              diff_agg_mean_Country_AssessBenefits2  1.886970e+06
# 172  agg_std_Employment_ohe_CommunicationTools_Conf...  1.827802e+06
# 173                    te_FormalEducation__YearsCoding  1.827260e+06
# 174  te_CareerSatisfaction__ohe_EducationTypes_Cont...  1.818149e+06
# 175  te_ohe_CommunicationTools_Confluence__ohe_Lang...  1.790943e+06
# 176                       ohe_DatabaseWorkedWith_Redis  1.772771e+06
# 177                                        te_WakeTime  1.750468e+06
# 178                                   ohe_IDE_NetBeans  1.704375e+06
# 179         rel_agg_mean_HopeFiveYears_AssessBenefits2  1.703824e+06
# 180                                        AssessJob10  1.701672e+06
# 181             te_FormalEducation__CareerSatisfaction  1.694935e+06
# 182           rel_agg_mean_Country_ohe_DevType_Student  1.675686e+06
# 183                                          svd_IDE_1  1.618911e+06
# 184          diff_agg_mean_Country_ohe_DevType_Student  1.616780e+06
# 185                          te_SalaryType__Dependents  1.608396e+06
# 186                           svd_DatabaseWorkedWith_0  1.562490e+06
# 187         te_CareerSatisfaction__ohe_DevType_Student  1.558453e+06
# 188  te_FormalEducation__ohe_CommunicationTools_Con...  1.533480e+06
# 189                                 te_Age__Dependents  1.531553e+06
# 190           diff_agg_mean_Employment_AssessBenefits2  1.526315e+06
# 191                                    AssessBenefits1  1.521455e+06
# 192  diff_agg_mean_Dependents_ohe_EducationTypes_Pa...  1.514962e+06
# 193           rel_agg_mean_CompanySize_AssessBenefits2  1.506704e+06
# 194                    ohe_DevType_Front_end_developer  1.492296e+06
# 195                 te_Age__ohe_LanguageWorkedWith_PHP  1.452416e+06
# 196                agg_std_Country_ohe_DevType_Student  1.449777e+06
# 197        ohe_DevType_Educator_or_academic_researcher  1.447715e+06
# 198                         ohe_LanguageWorkedWith_CSS  1.437376e+06
# 199                             te_Country__MilitaryUS  1.417304e+06
# 200                                      svd_DevType_0  1.393250e+06
# 201                       svd_LanguageDesireNextYear_0  1.371186e+06
# 202  rel_agg_mean_Country_ohe_RaceEthnicity_White_o...  1.360052e+06
# 203        agg_std_FormalEducation_ohe_DevType_Student  1.353061e+06
# 204                              JobContactPriorities3  1.344027e+06
# 205  agg_std_Employment_ohe_DevType_Engineering_man...  1.329976e+06
# 206            te_FormalEducation__ohe_DevType_Student  1.329916e+06
# 207      diff_agg_mean_FormalEducation_AssessBenefits2  1.328192e+06
# 208        rel_agg_mean_UndergradMajor_AssessBenefits2  1.288947e+06
# 209                             svd_HackathonReasons_1  1.270696e+06
# 210                                         te_Country  1.270669e+06
# 211       rel_agg_mean_YearsCodingProf_AssessBenefits2  1.265868e+06
# 212               ohe_DatabaseWorkedWith_Elasticsearch  1.263724e+06
# 213                                        te_Exercise  1.256828e+06
# 214                     ohe_FrameworkWorkedWith_Hadoop  1.254492e+06
# 215    rel_agg_mean_CurrencySymbol_ohe_DevType_Student  1.253510e+06
# 216                                JobEmailPriorities6  1.230984e+06
# 217             agg_std_SalaryType_ohe_DevType_Student  1.221940e+06
# 218  diff_agg_mean_Country_ohe_RaceEthnicity_White_...  1.216228e+06
# 219       rel_agg_mean_JobSatisfaction_AssessBenefits2  1.215738e+06
# 220  diff_agg_mean_TimeFullyProductive_AssessBenefits2  1.212997e+06
# 221  agg_mean_Country_ohe_CommunicationTools_Conflu...  1.203892e+06
# 222                       ohe_PlatformWorkedWith_Azure  1.176168e+06
# 223               te_Dependents__ohe_Methodology_Agile  1.173850e+06
# 224                       ohe_CommunicationTools_Slack  1.171650e+06
# 225  te_ohe_CommunicationTools_Confluence__ohe_Meth...  1.171165e+06
# 226     te_Currency__ohe_CommunicationTools_Confluence  1.166514e+06
# 227  rel_agg_mean_ohe_RaceEthnicity_White_or_of_Eur...  1.163381e+06
# 228                               svd_EducationTypes_0  1.158771e+06
# 229                    te_CareerSatisfaction__Currency  1.156245e+06
# 230                     te_OperatingSystem__Dependents  1.155236e+06
# 231  diff_agg_mean_Country_ohe_EducationTypes_Contr...  1.148791e+06
# 232           diff_agg_mean_MilitaryUS_AssessBenefits2  1.140499e+06
# 233  agg_mean_HopeFiveYears_ohe_EducationTypes_Cont...  1.137695e+06
# 234  agg_std_Country_ohe_EducationTypes_Contributed...  1.133582e+06
# 235                       svd_DatabaseDesireNextYear_0  1.123271e+06
# 236                                te_EducationParents  1.116462e+06
# 237                      te_StackOverflowJobsRecommend  1.113662e+06
# 238  te_ohe_DevType_Student__ohe_LanguageWorkedWith...  1.111347e+06
# 239  te_Employment__ohe_RaceEthnicity_White_or_of_E...  1.110657e+06
# 240                              JobContactPriorities4  1.105696e+06
# 241                      sum_answer_DatabaseWorkedWith  1.104781e+06
# 242  diff_agg_mean_ohe_DevType_Engineering_manager_...  1.104148e+06
# 243          diff_agg_mean_YearsCoding_AssessBenefits2  1.103919e+06
# 244                 ohe_DevType_Database_administrator  1.099832e+06
# 245  diff_agg_mean_ohe_RaceEthnicity_White_or_of_Eu...  1.099564e+06
# 246                  te_CareerSatisfaction__Dependents  1.097145e+06
# 247      te_ohe_DevType_Student__ohe_Methodology_Agile  1.091433e+06
# 248                                         AssessJob6  1.085253e+06
# 249  diff_agg_mean_CurrencySymbol_ohe_LanguageDesir...  1.083615e+06
# 250                   diff_agg_mean_Country_AssessJob5  1.072544e+06
# 251                                     te_CheckInCode  1.070835e+06
# 252                    rel_agg_mean_Country_AssessJob5  1.058078e+06
# 253       rel_agg_mean_FormalEducation_AssessBenefits2  1.056315e+06
# 254  te_YearsCoding__ohe_EducationTypes_Contributed...  1.050967e+06
# 255                        ohe_LanguageWorkedWith_HTML  1.034537e+06
# 256  diff_agg_mean_Employment_ohe_EducationTypes_Pa...  1.025223e+06
# 257                         agg_std_Country_AssessJob8  1.025188e+06
# 258  rel_agg_mean_Employment_ohe_CommunicationTools...  1.020775e+06
# 259          rel_agg_mean_Currency_ohe_DevType_Student  1.017087e+06
# 260    agg_mean_Country_ohe_LanguageDesireNextYear_PHP  1.012928e+06
# 261               agg_mean_CompanySize_AssessBenefits2  1.010765e+06
# 262                       svd_LanguageDesireNextYear_1  1.008664e+06
# 263          diff_agg_mean_Student_ohe_DevType_Student  1.001079e+06
# 264  agg_mean_CurrencySymbol_ohe_LanguageDesireNext...  9.991646e+05
# 265                                  ohe_IDE_Notepad__  9.960700e+05
# 266            rel_agg_mean_JobSatisfaction_AssessJob5  9.928932e+05
# 267     te_OperatingSystem__ohe_LanguageWorkedWith_PHP  9.886851e+05
# 268                          svd_FrameworkWorkedWith_1  9.875513e+05
# 269                       svd_PlatformDesireNextYear_0  9.843359e+05
# 270           diff_agg_mean_SalaryType_AssessBenefits2  9.824197e+05
# 271                                   AssessBenefits11  9.779398e+05
# 272  diff_agg_mean_TimeFullyProductive_ohe_DevType_...  9.713383e+05
# 273                      ohe_LanguageDesireNextYear_F_  9.679790e+05
# 274                diff_agg_mean_Employment_AssessJob5  9.674421e+05
# 275  diff_agg_mean_Country_ohe_DevType_Engineering_...  9.664037e+05
# 276                 ohe_PlatformDesireNextYear_Android  9.563608e+05
# 277       diff_agg_mean_UndergradMajor_AssessBenefits2  9.541811e+05
# 278  diff_agg_mean_Employment_ohe_LanguageDesireNex...  9.444506e+05
# 279  diff_agg_mean_NumberMonitors_ohe_Methodology_A...  9.417596e+05
# 280  agg_mean_Employment_ohe_RaceEthnicity_White_or...  9.406458e+05
# 281                                   AssessBenefits10  9.363566e+05
# 282                                    YearsCodingProf  9.282809e+05
# 283                             sum_answer_Methodology  9.229672e+05
# 284        diff_agg_mean_CareerSatisfaction_AssessJob5  9.223311e+05
# 285     ohe_VersionControl_I_don_t_use_version_control  9.154356e+05
# 286  te_SalaryType__ohe_RaceEthnicity_White_or_of_E...  9.091989e+05
# 287  te_Age__ohe_RaceEthnicity_White_or_of_European...  9.089238e+05
# 288                                         AssessJob1  9.010415e+05
# 289                                  svd_Methodology_1  8.944353e+05
# 290                  diff_agg_mean_Age_AssessBenefits2  8.875884e+05
# 291           diff_agg_mean_JobSatisfaction_AssessJob5  8.862475e+05
# 292  diff_agg_mean_ohe_DevType_Engineering_manager_...  8.856617e+05
# 293                           svd_PlatformWorkedWith_1  8.850188e+05
# 294             ohe_DatabaseWorkedWith_Amazon_Redshift  8.827846e+05
# 295                  sum_answer_LanguageDesireNextYear  8.811310e+05
# 296              diff_agg_mean_Student_AssessBenefits2  8.809665e+05
# 297  rel_agg_mean_ohe_DevType_Engineering_manager_o...  8.782376e+05
# 298  agg_mean_YearsCodingProf_ohe_RaceEthnicity_Whi...  8.724342e+05
# 299  agg_mean_Employment_ohe_DevType_Engineering_ma...  8.709066e+05

# %% [markdown]
# ## Prediction

# %%
test_pred = np.zeros(len(test_df))

for model in models:
    test_pred += model.predict(test_df[use_cols]) / len(models)

# %%
test_pred
# Out:
# array([ 69493.26514271,  93058.78859525,  84463.13183881, ...,
#         87815.84352235,  83725.53336848, 120273.10786866])

# %%
sub_df = pd.read_csv("../input/submit.csv")

# %%
sub_df["Salary"] = test_pred

# %%
# sub_df.to_csv("../predict/018_poisson_20206.csv", index=False)
